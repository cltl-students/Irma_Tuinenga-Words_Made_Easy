# %% [markdown]
# ### Post-evaluation analysis on test set: Substitute Ranking (SR) step with CEFR levels:
#
# This notebook corresponds to the post-evaluation analysis for the CEFR-all dataset, presented in section 6.4 of the thesis.
#
# The average of six out of ten predicted substitutes not found in the CEFR database is also discussed in section 5.1 of the thesis.

# %%
from utils_test import *

# %%
weighted_dataset = './cefr_all/cefr_all_combined.tsv'

# %%
prediction = './predictions/test/SS_phase2_option3f_BSrobertalarge_robertabase.tsv'

# %% [markdown]
# #### Complex word and substitutes:
# Code includes averages not found in the combined CEFR database, and statistical measures of variation.

# %%
posteval_analysis_cefr_weighted_stats_complexword_substitutes(weighted_dataset, prediction)
# Out:
# On average, there were 6.088709677419355 substitutes of the provided 10 substitutes that had not been found in the combined CEFR dataset.
#
# Count and Percentage of rows with unavailable CEFR level for the complex word: 253 and 68.01075268817205%
#
# Average CEFR level for substitutes (except level 7): 3.6608618961086274
# Median CEFR level for substitutes (except level 7): 3.728168684924261
# Standard Deviation of CEFR level for substitutes (except level 7): 0.8639482364847901
# Kurtosis of CEFR level for substitutes (except level 7): 0.20093206190829704
# Average CEFR level for complex words: 4.3234102185155665
# Median CEFR level for complex words: 4.0
# Standard Deviation of CEFR level for complex words: 0.7150626125397226
# Kurtosis of CEFR level for complex words: 0.4238483388516179

# %% [markdown]
# #### Gold labels:
#
# Code includes averages of gold labels not found in the combined CEFR database, and statistical measures of variation for gold labels.

# %%
gold = './data/test/tsar2022_en_test_gold_no_noise.tsv'

# %%
posteval_analysis_cefr_weighted_stats_goldlabels(weighted_dataset,gold)
# Out:
# Average CEFR level for gold substitutes (except level 7): 3.5747650935785895
# Median CEFR level for gold substitutes (except level 7): 3.633617439763973
# Standard Deviation of CEFR level for gold substitutes (except level 7): 0.9118945563913673
# Kurtosis of CEFR level for gold substitutes (except level 7): -0.12481104762541229
# Rows with 0 CEFR level: 120
# Rows with 1 CEFR level: 30
# Rows with more than 1 CEFR level: 223
# Rows where the first CEFR level is lower than the last: 110 (49.327354260089685%)
# Rows where the first CEFR level is higher than the last: 107 (47.98206278026906%)
# Rows where the first CEFR level is equal to the last: 6 (2.690582959641256%)
# Rows where the first CEFR level is the lowest of all: 43 (19.282511210762333%)
# Rows where CEFR levels are in ascending order: 11 (2.949061662198391%)
