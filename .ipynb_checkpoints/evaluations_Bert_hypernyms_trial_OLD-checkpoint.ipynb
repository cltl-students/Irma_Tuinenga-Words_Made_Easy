# %% [markdown]
# #### Evaluations BERT for the trial set (10 sentences)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
# the code below is used for morphological adjustments in step MA
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %%
# the code below is used when word embeddings are used in step SS
from transformers import TFAutoModel
import tensorflow as tf
import numpy as np

# %%
# the code below is used when Bertscore is used in step SS
import bert_score
from bert_score import score

# %%
# set the display.max_rows option to None to display all rows instead of limiting it to 50
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Bert-base-uncased

# %%
# Instantiate the tokenizer and the model

# for bert-base:
lm_tokenizer_bertbase = AutoTokenizer.from_pretrained("bert-base-uncased")
lm_model_bertbase = AutoModelForMaskedLM.from_pretrained("bert-base-uncased")


# Instantiate the fill-mask pipeline with the model
fill_mask_bertbase = pipeline("fill-mask", lm_model_bertbase, tokenizer = lm_tokenizer_bertbase)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #### Substitute Generation and Morphological Adaptation:

# %%
# # in each row, for each complex word: 
# for index, row in data.iterrows():
    
#     # print the sentence and the complex word
#     sentence, complex_word = row["sentence"], row["complex_word"]
#     #print(f"Sentence: {sentence}")
#     #print(f"Complex word: {complex_word}")
    
    
#     # for bertbase model:
       
#     # 1. Substitute Generation (SG): perform masking and generate substitutes:

#     ## in the sentence, replace the complex word with a masked word
#     sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

#     ## concatenate the original sentence and the masked sentence
#     sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

#     ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
#     top_k = 30
#     result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
#     substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
#     #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


#     #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
#     ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
#     ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

#     punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
#     punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

#     try:
#         substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
#                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
#         # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
#     except TypeError as error:
#         continue



#     ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
#     ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
#     substitutes_no_dupl_bertbase = []
#     for sub in substitutes_bertbase:
#         if sub not in substitutes_no_dupl_bertbase:
#             substitutes_no_dupl_bertbase.append(sub)
#     #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



#     ## c) remove duplicates and inflected forms of the complex word from the substitute list

#     ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
#     doc_complex_word = nlp(complex_word)
#     complex_word_lemma = doc_complex_word[0].lemma_
#     #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


#     ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
#     substitutes_no_dupl_complex_word_bertbase = []
#     for substitute in substitutes_no_dupl_bertbase:
#         doc_substitute = nlp(substitute)
#         substitute_lemma = doc_substitute[0].lemma_
#         if substitute_lemma != complex_word_lemma:
#             substitutes_no_dupl_complex_word_bertbase.append(substitute)
#     #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


#      ## d) remove antonyms of the complex word from the substitute list
#     ## step 1: get the antonyms of the complex word
#     antonyms_complex_word = []
#     for syn in wn.synsets(complex_word_lemma):
#         for lemma in syn.lemmas():
#             for antonym in lemma.antonyms():
#                     antonyms_complex_word.append(antonym.name())

#     print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

#     ## step 2: remove antonyms of the complex word from the list with substitutes
#     substitutes_no_antonyms_bertbase = []
#     for substitute in substitutes_no_dupl_complex_word_bertbase:
#         doc_substitute = nlp(substitute)
#         substitute_lemma = doc_substitute[0].lemma_
#         if substitute_lemma not in antonyms_complex_word:
#             substitutes_no_antonyms_bertbase.append(substitute)
#         else:
#             print(f"Removed antonym: {substitute}")
#     print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n") 
  
    
        
#     # limit the substitutes to the 10 highest ranked ones for evaluation
#     top_10_substitutes = substitutes_no_antonyms_bertbase[:10]
#     #print(f"top-10 substitutes SG and MA: {top_10_substitutes}\n")
    
#     # fill the dataframe with 10 elements even if there are less than 10 in the previous list
#     required_for_dataframe = 10
#     # pad the list with None until it has 10 elements
#     top_10_substitutes += [None] * (required_for_dataframe - len(top_10_substitutes))

#     # # add the sentence, complex_word, and the substitutes to the dataframe 
#     substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
#     #print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# # export the dataframe to a tsv file for evaluation
# substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA.tsv", sep="\t", index=False, header=False)
# print("BertBase_SG_MA exported to csv in path './predictions/trial/BertBase_SG_MA.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA.tsv --output_file ./output/trial/BertBase_SG_MA.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2888
# MAP@5 = 0.2253
# MAP@10 = 0.1298
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.8
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### Substitute Generation and Morphological Adaptation, with additions:
# - moving already generated hypernyms (1 or 2 layers above) from the generated top-30 to the top-10 (if not already there), as they may be perceived as simpler.
# - adding hypernyms to the generated list, to the top-10 so that the top-10 can be ranked on SR in the SR step.
#
# Question to consider: should adding or moving hypernyms be executed before the SS step (Bertscores) or after? Even if Bertscores reveal that they are not very similar, did annotators still use hypernyms  for simplification? If so, then the hypernyms should be added after the SS step (Bertscores).
# Answer: perform both before and after Bertscores, and see from the trial set results what will be the best approach.

# %% [markdown]
# ### Before the SS step:

# %% [markdown]
# #### 1-level (= direct) hypernyms first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n")
    
    
    ## Substitute selection step: check for hypernyms in the substitute list
    # step 1: get immediate hypernyms of complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms = [syn.hypernyms() for syn in complex_word_synsets]
    complex_word_hypernyms_lemmas = [lemma for sublist in complex_word_hypernyms for h in sublist for lemma in h.lemma_names()] # list of hypernyms' lemmas
    print(f"complex_word_hypernyms_lemmas: {complex_word_hypernyms_lemmas}")

    # step 2: get one-level hypernyms of the substitutes
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)

        # Checking one level hypernyms
        substitute_hypernyms_1 = [syn.hypernyms() for syn in substitute_synsets]
        substitute_hypernyms_1_lemmas = [lemma for sublist in substitute_hypernyms_1 for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas

        # Check if the substitute has the same one-level hypernyms as the complex word
        intersection_1 = set(complex_word_hypernyms_lemmas).intersection(set(substitute_hypernyms_1_lemmas))
        if intersection_1:
            print(f"Substitute {substitute} has the same one-level hypernyms as the complex word: {intersection_1}")
            intersection_1_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)

    # step 3: append the substitute lists
    selected_substitutes = intersection_1_substitutes + other_substitutes
    print(f"Selected substitutes: {selected_substitutes}")

    #limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = selected_substitutes[:10]
    print(f"top-10 substitutes SG and MA with direct hypernyms of complex word ranked first: {top_10_substitutes}\n")

    # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
#     #print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# # export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_level1hypernymsfirst.tsv", sep="\t", index=False, header=False)
print("BertBase_SG_MA_level1hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level1hypernymsfirst.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# complex_word_lemma for complex word 'compulsory': compulsory
#
# Antonyms for complex word 'compulsory': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# complex_word_hypernyms_lemmas: []
# Selected substitutes: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
# top-10 substitutes SG and MA: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier']
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# complex_word_lemma for complex word 'instilled': instill
#
# Antonyms for complex word 'instilled': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# complex_word_hypernyms_lemmas: ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full']
# Substitute created has the same one-level hypernyms as the complex word: {'move'}
# Substitute attacked has the same one-level hypernyms as the complex word: {'move', 'affect'}
# Substitute rewarded has the same one-level hypernyms as the complex word: {'move'}
# Substitute introduced has the same one-level hypernyms as the complex word: {'introduce'}
# Substitute set has the same one-level hypernyms as the complex word: {'move', 'impress'}
# Substitute treated has the same one-level hypernyms as the complex word: {'affect'}
# Substitute hit has the same one-level hypernyms as the complex word: {'move', 'affect'}
# Substitute surprised has the same one-level hypernyms as the complex word: {'move', 'impress', 'affect', 'strike'}
# Substitute infused has the same one-level hypernyms as the complex word: {'fill', 'drill', 'fill_up', 'make_full'}
# Substitute secured has the same one-level hypernyms as the complex word: {'fill_up'}
# Substitute delivered has the same one-level hypernyms as the complex word: {'bring'}
# Selected substitutes: ['created', 'attacked', 'rewarded', 'introduced', 'set', 'treated', 'hit', 'surprised', 'infused', 'secured', 'delivered', 'strengthened', 'targeted', 'tested', 'provided', 'affected', 'addressed', 'punished', 'bred', 'empowered', 'shocked', 'silenced', 'improved', 'defeated', 'reinforced', 'prepared', 'hardened', 'challenged', 'released', 'established']
# top-10 substitutes SG and MA: ['created', 'attacked', 'rewarded', 'introduced', 'set', 'treated', 'hit', 'surprised', 'infused', 'secured']
#
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# complex_word_lemma for complex word 'maniacs': maniac
#
# Antonyms for complex word 'maniacs': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# complex_word_hypernyms_lemmas: ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
# Selected substitutes: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
# top-10 substitutes SG and MA: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors']
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# complex_word_lemma for complex word 'observers': observer
#
# Antonyms for complex word 'observers': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# complex_word_hypernyms_lemmas: ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
# Substitute witnesses has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute victims has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute travelers has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute experts has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute workers has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute survivors has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute combatants has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Selected substitutes: ['witnesses', 'victims', 'travelers', 'experts', 'workers', 'survivors', 'combatants', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'delegates', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'volunteers', 'citizens', 'civilians']
# top-10 substitutes SG and MA: ['witnesses', 'victims', 'travelers', 'experts', 'workers', 'survivors', 'combatants', 'participants', 'casualties', 'refugees']
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# complex_word_lemma for complex word 'shrapnel': shrapnel
#
# Antonyms for complex word 'shrapnel': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# complex_word_hypernyms_lemmas: ['shell']
# Selected substitutes: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
# top-10 substitutes SG and MA: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing']
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# complex_word_lemma for complex word 'disguised': disguised
#
# Antonyms for complex word 'disguised': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# complex_word_hypernyms_lemmas: ['hide', 'conceal']
# Substitute masked has the same one-level hypernyms as the complex word: {'hide', 'conceal'}
# Substitute disguise has the same one-level hypernyms as the complex word: {'hide', 'conceal'}
# Substitute covered has the same one-level hypernyms as the complex word: {'hide', 'conceal'}
# Selected substitutes: ['masked', 'disguise', 'covered', 'dressed', 'clad', 'clothed', 'dressing', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
# top-10 substitutes SG and MA: ['masked', 'disguise', 'covered', 'dressed', 'clad', 'clothed', 'dressing', 'concealed', 'cloak', 'posing']
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# complex_word_lemma for complex word 'offshoot': offshoot
#
# Antonyms for complex word 'offshoot': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# complex_word_hypernyms_lemmas: ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
# Substitute branch has the same one-level hypernyms as the complex word: {'result', 'upshot', 'effect', 'outcome', 'consequence', 'issue', 'event'}
# Substitute offspring has the same one-level hypernyms as the complex word: {'result', 'upshot', 'effect', 'outcome', 'consequence', 'issue', 'event'}
# Selected substitutes: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
# top-10 substitutes SG and MA: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack']
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# complex_word_lemma for complex word 'symphonic': symphonic
#
# Antonyms for complex word 'symphonic': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# complex_word_hypernyms_lemmas: []
# Selected substitutes: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
# top-10 substitutes SG and MA: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra']
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# complex_word_lemma for complex word 'deploy': deploy
#
# Antonyms for complex word 'deploy': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# complex_word_hypernyms_lemmas: ['position', 'spread', 'distribute']
# Selected substitutes: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
# top-10 substitutes SG and MA: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain']
#
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# complex_word_lemma for complex word 'authorities': authority
#
# Antonyms for complex word 'authorities': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# complex_word_hypernyms_lemmas: ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
# Substitute nationals has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute protesters has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute subjects has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute agencies has the same one-level hypernyms as the complex word: {'administrative_body', 'administrative_unit'}
# Substitute suspects has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Substitute leaders has the same one-level hypernyms as the complex word: {'individual', 'mortal', 'somebody', 'someone', 'soul', 'person'}
# Selected substitutes: ['nationals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'personnel', 'organisations', 'interests', 'politicians', 'activists', 'institutions']
# top-10 substitutes SG and MA: ['nationals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'officials', 'police', 'citizens', 'forces']
#
# BertBase_SG_MA_level1hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level1hypernymsfirst.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_level1hypernymsfirst.tsv --output_file ./output/trial/BertBase_SG_MA_level1hypernymsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_level1hypernymsfirst.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_level1hypernymsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.2888
# MAP@5 = 0.2463
# MAP@10 = 0.1436
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.2
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# ### 1 and 2-level hypernyms first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n")
    
    
    ## Substitute selection step: checking for hypernyms in the substitute list
    # step 1: get immediate hypernyms of the complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms = [syn.hypernyms() for syn in complex_word_synsets]
    complex_word_hypernyms_lemmas = [lemma for sublist in complex_word_hypernyms for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas

    # step 2: get two-level up hypernyms of the complex word
    complex_word_hypernyms_up2 = [syn.hypernyms() for h in complex_word_hypernyms for syn in h]
    complex_word_hypernyms_up2_lemmas = [lemma for sublist in complex_word_hypernyms_up2 for h in sublist for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

    # step 3: get one and two-level up hypernyms of the substitutes
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)

        # Checking one level hypernyms
        substitute_hypernyms_1 = [syn.hypernyms() for syn in substitute_synsets]
        substitute_hypernyms_1_lemmas = [lemma for sublist in substitute_hypernyms_1 for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas

        # Checking two-level up hypernyms
        substitute_hypernyms_up2 = [syn.hypernyms() for h in substitute_hypernyms_1 for syn in h for syn in syn.hypernyms()]
        substitute_hypernyms_up2_lemmas = [lemma for sublist in substitute_hypernyms_up2 for h in sublist for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

        # Check if the substitute has the same one or two-level hypernyms as the complex word
        intersection_1 = set(complex_word_hypernyms_lemmas).intersection(set(substitute_hypernyms_1_lemmas))
        intersection_up2 = set(complex_word_hypernyms_up2_lemmas).intersection(set(substitute_hypernyms_up2_lemmas))

        if intersection_1 or intersection_up2:
            print(f"Substitute {substitute} has the same one or two-level hypernyms as the complex word")
            intersection_1_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)

    # # step 3: append the substitute lists
    selected_substitutes = intersection_1_substitutes + other_substitutes
    print(f"Selected substitutes: {selected_substitutes}")


    #limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = selected_substitutes[:10]
    print(f"top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: {top_10_substitutes}\n")

    # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
#     #print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# # export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv", sep="\t", index=False, header=False)
print("BertBase_SG_MA_level1and2hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# complex_word_lemma for complex word 'compulsory': compulsory
#
# Antonyms for complex word 'compulsory': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Selected substitutes: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier']
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# complex_word_lemma for complex word 'instilled': instill
#
# Antonyms for complex word 'instilled': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute tested has the same one or two-level hypernyms as the complex word
# Substitute created has the same one or two-level hypernyms as the complex word
# Substitute addressed has the same one or two-level hypernyms as the complex word
# Substitute attacked has the same one or two-level hypernyms as the complex word
# Substitute rewarded has the same one or two-level hypernyms as the complex word
# Substitute introduced has the same one or two-level hypernyms as the complex word
# Substitute set has the same one or two-level hypernyms as the complex word
# Substitute treated has the same one or two-level hypernyms as the complex word
# Substitute prepared has the same one or two-level hypernyms as the complex word
# Substitute hit has the same one or two-level hypernyms as the complex word
# Substitute surprised has the same one or two-level hypernyms as the complex word
# Substitute hardened has the same one or two-level hypernyms as the complex word
# Substitute infused has the same one or two-level hypernyms as the complex word
# Substitute released has the same one or two-level hypernyms as the complex word
# Substitute secured has the same one or two-level hypernyms as the complex word
# Substitute delivered has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['tested', 'created', 'addressed', 'attacked', 'rewarded', 'introduced', 'set', 'treated', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'released', 'secured', 'delivered', 'strengthened', 'targeted', 'provided', 'affected', 'punished', 'bred', 'empowered', 'shocked', 'silenced', 'improved', 'defeated', 'reinforced', 'challenged', 'established']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['tested', 'created', 'addressed', 'attacked', 'rewarded', 'introduced', 'set', 'treated', 'prepared', 'hit']
#
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# complex_word_lemma for complex word 'maniacs': maniac
#
# Antonyms for complex word 'maniacs': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Selected substitutes: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors']
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# complex_word_lemma for complex word 'observers': observer
#
# Antonyms for complex word 'observers': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute witnesses has the same one or two-level hypernyms as the complex word
# Substitute participants has the same one or two-level hypernyms as the complex word
# Substitute casualties has the same one or two-level hypernyms as the complex word
# Substitute visitors has the same one or two-level hypernyms as the complex word
# Substitute monitors has the same one or two-level hypernyms as the complex word
# Substitute victims has the same one or two-level hypernyms as the complex word
# Substitute travelers has the same one or two-level hypernyms as the complex word
# Substitute experts has the same one or two-level hypernyms as the complex word
# Substitute inspectors has the same one or two-level hypernyms as the complex word
# Substitute allies has the same one or two-level hypernyms as the complex word
# Substitute workers has the same one or two-level hypernyms as the complex word
# Substitute pilgrims has the same one or two-level hypernyms as the complex word
# Substitute officials has the same one or two-level hypernyms as the complex word
# Substitute tourists has the same one or two-level hypernyms as the complex word
# Substitute survivors has the same one or two-level hypernyms as the complex word
# Substitute volunteers has the same one or two-level hypernyms as the complex word
# Substitute citizens has the same one or two-level hypernyms as the complex word
# Substitute civilians has the same one or two-level hypernyms as the complex word
# Substitute combatants has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['witnesses', 'participants', 'casualties', 'visitors', 'monitors', 'victims', 'travelers', 'experts', 'inspectors', 'allies', 'workers', 'pilgrims', 'officials', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants', 'refugees', 'delegates', 'troops', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'people', 'deaths']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['witnesses', 'participants', 'casualties', 'visitors', 'monitors', 'victims', 'travelers', 'experts', 'inspectors', 'allies']
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# complex_word_lemma for complex word 'shrapnel': shrapnel
#
# Antonyms for complex word 'shrapnel': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Selected substitutes: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing']
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# complex_word_lemma for complex word 'disguised': disguised
#
# Antonyms for complex word 'disguised': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute masked has the same one or two-level hypernyms as the complex word
# Substitute disguise has the same one or two-level hypernyms as the complex word
# Substitute covered has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['masked', 'disguise', 'covered', 'dressed', 'clad', 'clothed', 'dressing', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['masked', 'disguise', 'covered', 'dressed', 'clad', 'clothed', 'dressing', 'concealed', 'cloak', 'posing']
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# complex_word_lemma for complex word 'offshoot': offshoot
#
# Antonyms for complex word 'offshoot': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute branch has the same one or two-level hypernyms as the complex word
# Substitute offspring has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack']
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# complex_word_lemma for complex word 'symphonic': symphonic
#
# Antonyms for complex word 'symphonic': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Selected substitutes: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra']
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# complex_word_lemma for complex word 'deploy': deploy
#
# Antonyms for complex word 'deploy': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Selected substitutes: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain']
#
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# complex_word_lemma for complex word 'authorities': authority
#
# Antonyms for complex word 'authorities': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute officials has the same one or two-level hypernyms as the complex word
# Substitute citizens has the same one or two-level hypernyms as the complex word
# Substitute officers has the same one or two-level hypernyms as the complex word
# Substitute residents has the same one or two-level hypernyms as the complex word
# Substitute troops has the same one or two-level hypernyms as the complex word
# Substitute nationals has the same one or two-level hypernyms as the complex word
# Substitute persons has the same one or two-level hypernyms as the complex word
# Substitute civilians has the same one or two-level hypernyms as the complex word
# Substitute individuals has the same one or two-level hypernyms as the complex word
# Substitute protesters has the same one or two-level hypernyms as the complex word
# Substitute subjects has the same one or two-level hypernyms as the complex word
# Substitute agencies has the same one or two-level hypernyms as the complex word
# Substitute suspects has the same one or two-level hypernyms as the complex word
# Substitute leaders has the same one or two-level hypernyms as the complex word
# Substitute politicians has the same one or two-level hypernyms as the complex word
# Substitute activists has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['officials', 'citizens', 'officers', 'residents', 'troops', 'nationals', 'persons', 'civilians', 'individuals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'politicians', 'activists', 'police', 'forces', 'people', 'government', 'governments', 'courts', 'policemen', 'personnel', 'organisations', 'interests', 'institutions']
# top-10 substitutes SG and MA with hypernyms of complex word (up to 2 levels) ranked first: ['officials', 'citizens', 'officers', 'residents', 'troops', 'nationals', 'persons', 'civilians', 'individuals', 'protesters']
#
# BertBase_SG_MA_level1and2hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv --output_file ./output/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv

# %% [raw]
# al/BertBase_SG_MA_level1and2hypernymsfirst.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_level1and2hypernymsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3277
# MAP@5 = 0.2476
# MAP@10 = 0.1435
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# Result: better than only 1 level up.

# %% [markdown]
# #### only 2-level up hypernyms:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n")
    
    
    
    
    ## Substitute selection step: check for hypernyms in the substitute list
    # step 1: get immediate hypernyms of the complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms_up2 = [h for syn in complex_word_synsets for h in syn.hypernyms() for h2 in h.hypernyms()]
    complex_word_hypernyms_up2_lemmas = [lemma for h in complex_word_hypernyms_up2 for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

    # step 2: get two-level up hypernyms of the substitutes
    intersection_up2_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)

        # Checking two-level up hypernyms
        substitute_hypernyms_up2 = [h for syn in substitute_synsets for h in syn.hypernyms() for h2 in h.hypernyms()]
        substitute_hypernyms_up2_lemmas = [lemma for h in substitute_hypernyms_up2 for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

        # Check if the substitute has the same two-level hypernyms as the complex word
        intersection_up2 = set(complex_word_hypernyms_up2_lemmas).intersection(set(substitute_hypernyms_up2_lemmas))

        if intersection_up2:
            print(f"Substitute {substitute} has the same two-level hypernyms as the complex word")
            intersection_up2_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)

    # step 3: append the substitutes
    selected_substitutes = intersection_up2_substitutes + other_substitutes
    print(f"Selected substitutes: {selected_substitutes}")


    #limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = selected_substitutes[:10]
    print(f"top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: {top_10_substitutes}\n")

    # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
#     #print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# # export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_level2hypernymsfirst.tsv", sep="\t", index=False, header=False)
print("BertBase_SG_MA_level2hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level2hypernymsfirst.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# complex_word_lemma for complex word 'compulsory': compulsory
#
# Antonyms for complex word 'compulsory': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Selected substitutes: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier']
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# complex_word_lemma for complex word 'instilled': instill
#
# Antonyms for complex word 'instilled': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute introduced has the same two-level hypernyms as the complex word
# Substitute infused has the same two-level hypernyms as the complex word
# Substitute secured has the same two-level hypernyms as the complex word
# Substitute delivered has the same two-level hypernyms as the complex word
# Selected substitutes: ['introduced', 'infused', 'secured', 'delivered', 'strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'challenged', 'released', 'established']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['introduced', 'infused', 'secured', 'delivered', 'strengthened', 'targeted', 'tested', 'provided', 'created', 'affected']
#
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# complex_word_lemma for complex word 'maniacs': maniac
#
# Antonyms for complex word 'maniacs': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Selected substitutes: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors']
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# complex_word_lemma for complex word 'observers': observer
#
# Antonyms for complex word 'observers': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute witnesses has the same two-level hypernyms as the complex word
# Substitute victims has the same two-level hypernyms as the complex word
# Substitute travelers has the same two-level hypernyms as the complex word
# Substitute experts has the same two-level hypernyms as the complex word
# Substitute workers has the same two-level hypernyms as the complex word
# Substitute survivors has the same two-level hypernyms as the complex word
# Substitute combatants has the same two-level hypernyms as the complex word
# Selected substitutes: ['witnesses', 'victims', 'travelers', 'experts', 'workers', 'survivors', 'combatants', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'delegates', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'volunteers', 'citizens', 'civilians']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['witnesses', 'victims', 'travelers', 'experts', 'workers', 'survivors', 'combatants', 'participants', 'casualties', 'refugees']
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# complex_word_lemma for complex word 'shrapnel': shrapnel
#
# Antonyms for complex word 'shrapnel': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Selected substitutes: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing']
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# complex_word_lemma for complex word 'disguised': disguised
#
# Antonyms for complex word 'disguised': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Selected substitutes: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared']
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# complex_word_lemma for complex word 'offshoot': offshoot
#
# Antonyms for complex word 'offshoot': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute branch has the same two-level hypernyms as the complex word
# Substitute offspring has the same two-level hypernyms as the complex word
# Selected substitutes: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack']
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# complex_word_lemma for complex word 'symphonic': symphonic
#
# Antonyms for complex word 'symphonic': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Selected substitutes: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra']
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# complex_word_lemma for complex word 'deploy': deploy
#
# Antonyms for complex word 'deploy': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Selected substitutes: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain']
#
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# complex_word_lemma for complex word 'authorities': authority
#
# Antonyms for complex word 'authorities': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute nationals has the same two-level hypernyms as the complex word
# Substitute protesters has the same two-level hypernyms as the complex word
# Substitute subjects has the same two-level hypernyms as the complex word
# Substitute agencies has the same two-level hypernyms as the complex word
# Substitute suspects has the same two-level hypernyms as the complex word
# Substitute leaders has the same two-level hypernyms as the complex word
# Selected substitutes: ['nationals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'personnel', 'organisations', 'interests', 'politicians', 'activists', 'institutions']
# top-10 substitutes SG and MA with hypernyms of complex word (only 2 levels up) ranked first: ['nationals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'officials', 'police', 'citizens', 'forces']
#
# BertBase_SG_MA_level2hypernymsfirst exported to csv in path './predictions/trial/BertBase_SG_MA_level2hypernymsfirst.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_level2hypernymsfirst.tsv --output_file ./output/trial/BertBase_SG_MA_level2hypernymsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_level2hypernymsfirst.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_level2hypernymsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3222
# MAP@5 = 0.2293
# MAP@10 = 0.1333
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### Conclusion:
# level 1 and level 2 together, and level 2 only, score best, although the differences are small

# %% [markdown]
# #### Substitute Generation, Morphological Adaptation, and BertScore:

# %% [raw]
# ##### BErtscore based on BERT:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms_bertbase]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='bert-base-uncased', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms_bertbase, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))

    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_SS_bsBert.tsv", sep="\t", index=False, header=False)
print("BertBase_SG_MA_SS_bsBert exported to csv in path './predictions/trial/BertBase_SG_MA_SS_bsBert.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_SS_bsBert.tsv --output_file ./output/trial/BertBase_SG_MA_SS_bsBert.tsv

# %% [markdown]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_SS_bsBert.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_SS_bsBert.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.3222
# MAP@5 = 0.2203
# MAP@10 = 0.1386
#
# Potential@3 = 0.8
# Potential@5 = 1.0
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.5
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# #### Bertscores after the hypernyms have been put first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n") 
  
    
    
    ## Substitute selection step: checking for hypernyms in the substitute list
    # Step 1: Getting immediate hypernyms of the complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms = [syn.hypernyms() for syn in complex_word_synsets]
    complex_word_hypernyms_lemmas = [lemma for sublist in complex_word_hypernyms for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas

    # Step 2: Getting two-level up hypernyms of the complex word
    complex_word_hypernyms_up2 = [syn.hypernyms() for h in complex_word_hypernyms for syn in h]
    complex_word_hypernyms_up2_lemmas = [lemma for sublist in complex_word_hypernyms_up2 for h in sublist for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

    # Step 3: Getting one and two-level up hypernyms of the substitutes
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)

        # Checking one level hypernyms
        substitute_hypernyms_1 = [syn.hypernyms() for syn in substitute_synsets]
        substitute_hypernyms_1_lemmas = [lemma for sublist in substitute_hypernyms_1 for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas

        # Checking two-level up hypernyms
        substitute_hypernyms_up2 = [syn.hypernyms() for h in substitute_hypernyms_1 for syn in h for syn in syn.hypernyms()]
        substitute_hypernyms_up2_lemmas = [lemma for sublist in substitute_hypernyms_up2 for h in sublist for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas

        # Check if the substitute has the same one or two-level hypernyms as the complex word
        intersection_1 = set(complex_word_hypernyms_lemmas).intersection(set(substitute_hypernyms_1_lemmas))
        intersection_up2 = set(complex_word_hypernyms_up2_lemmas).intersection(set(substitute_hypernyms_up2_lemmas))

        if intersection_1 or intersection_up2:
            print(f"Substitute {substitute} has the same one or two-level hypernyms as the complex word")
            intersection_1_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)

    # Append the substitutes
    selected_substitutes = intersection_1_substitutes + other_substitutes

    # Print the final list of selected substitutes
    print(f"Selected substitutes: {selected_substitutes}")
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in selected_substitutes]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='bert-base-uncased', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(selected_substitutes, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv", sep="\t", index=False, header=False)
print("BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert exported to csv in path './predictions/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv'}\n")
# Out:
# Antonyms for complex word 'compulsory': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Selected substitutes: ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
# Antonyms for complex word 'instilled': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute tested has the same one or two-level hypernyms as the complex word
# Substitute created has the same one or two-level hypernyms as the complex word
# Substitute addressed has the same one or two-level hypernyms as the complex word
# Substitute attacked has the same one or two-level hypernyms as the complex word
# Substitute rewarded has the same one or two-level hypernyms as the complex word
# Substitute introduced has the same one or two-level hypernyms as the complex word
# Substitute set has the same one or two-level hypernyms as the complex word
# Substitute treated has the same one or two-level hypernyms as the complex word
# Substitute prepared has the same one or two-level hypernyms as the complex word
# Substitute hit has the same one or two-level hypernyms as the complex word
# Substitute surprised has the same one or two-level hypernyms as the complex word
# Substitute hardened has the same one or two-level hypernyms as the complex word
# Substitute infused has the same one or two-level hypernyms as the complex word
# Substitute released has the same one or two-level hypernyms as the complex word
# Substitute secured has the same one or two-level hypernyms as the complex word
# Substitute delivered has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['tested', 'created', 'addressed', 'attacked', 'rewarded', 'introduced', 'set', 'treated', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'released', 'secured', 'delivered', 'strengthened', 'targeted', 'provided', 'affected', 'punished', 'bred', 'empowered', 'shocked', 'silenced', 'improved', 'defeated', 'reinforced', 'challenged', 'established']
# Antonyms for complex word 'maniacs': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Selected substitutes: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
# Antonyms for complex word 'observers': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute witnesses has the same one or two-level hypernyms as the complex word
# Substitute participants has the same one or two-level hypernyms as the complex word
# Substitute casualties has the same one or two-level hypernyms as the complex word
# Substitute visitors has the same one or two-level hypernyms as the complex word
# Substitute monitors has the same one or two-level hypernyms as the complex word
# Substitute victims has the same one or two-level hypernyms as the complex word
# Substitute travelers has the same one or two-level hypernyms as the complex word
# Substitute experts has the same one or two-level hypernyms as the complex word
# Substitute inspectors has the same one or two-level hypernyms as the complex word
# Substitute allies has the same one or two-level hypernyms as the complex word
# Substitute workers has the same one or two-level hypernyms as the complex word
# Substitute pilgrims has the same one or two-level hypernyms as the complex word
# Substitute officials has the same one or two-level hypernyms as the complex word
# Substitute tourists has the same one or two-level hypernyms as the complex word
# Substitute survivors has the same one or two-level hypernyms as the complex word
# Substitute volunteers has the same one or two-level hypernyms as the complex word
# Substitute citizens has the same one or two-level hypernyms as the complex word
# Substitute civilians has the same one or two-level hypernyms as the complex word
# Substitute combatants has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['witnesses', 'participants', 'casualties', 'visitors', 'monitors', 'victims', 'travelers', 'experts', 'inspectors', 'allies', 'workers', 'pilgrims', 'officials', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants', 'refugees', 'delegates', 'troops', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'people', 'deaths']
# Antonyms for complex word 'shrapnel': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Selected substitutes: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
# Antonyms for complex word 'disguised': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute masked has the same one or two-level hypernyms as the complex word
# Substitute disguise has the same one or two-level hypernyms as the complex word
# Substitute covered has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['masked', 'disguise', 'covered', 'dressed', 'clad', 'clothed', 'dressing', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
# Antonyms for complex word 'offshoot': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute branch has the same one or two-level hypernyms as the complex word
# Substitute offspring has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['branch', 'offspring', 'affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
# Antonyms for complex word 'symphonic': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Selected substitutes: ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
# Antonyms for complex word 'deploy': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Selected substitutes: ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
# Antonyms for complex word 'authorities': []
#
# Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute officials has the same one or two-level hypernyms as the complex word
# Substitute citizens has the same one or two-level hypernyms as the complex word
# Substitute officers has the same one or two-level hypernyms as the complex word
# Substitute residents has the same one or two-level hypernyms as the complex word
# Substitute troops has the same one or two-level hypernyms as the complex word
# Substitute nationals has the same one or two-level hypernyms as the complex word
# Substitute persons has the same one or two-level hypernyms as the complex word
# Substitute civilians has the same one or two-level hypernyms as the complex word
# Substitute individuals has the same one or two-level hypernyms as the complex word
# Substitute protesters has the same one or two-level hypernyms as the complex word
# Substitute subjects has the same one or two-level hypernyms as the complex word
# Substitute agencies has the same one or two-level hypernyms as the complex word
# Substitute suspects has the same one or two-level hypernyms as the complex word
# Substitute leaders has the same one or two-level hypernyms as the complex word
# Substitute politicians has the same one or two-level hypernyms as the complex word
# Substitute activists has the same one or two-level hypernyms as the complex word
# Selected substitutes: ['officials', 'citizens', 'officers', 'residents', 'troops', 'nationals', 'persons', 'civilians', 'individuals', 'protesters', 'subjects', 'agencies', 'suspects', 'leaders', 'politicians', 'activists', 'police', 'forces', 'people', 'government', 'governments', 'courts', 'policemen', 'personnel', 'organisations', 'interests', 'institutions']
# BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert exported to csv in path './predictions/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv --output_file ./output/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv

# %% [raw]
# output/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_SS_level1and2hypernymsfirst_bsBert.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.3222
# MAP@5 = 0.2203
# MAP@10 = 0.1386
#
# Potential@3 = 0.8
# Potential@5 = 1.0
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.5
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [raw]
# REsult: stays the same. Bertscore works best of all!

# %% [markdown]
# Result: best performance so far, on all metrics.

# %% [markdown]
# #### bertscore based on electra since it performed so well on Electramodel:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bertscores: 
    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms_bertbase]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='google/electra-base-generator', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
    
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms_bertbase, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    ## fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    ## pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
   


    ## add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   

# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_SS_bsElectra.tsv", sep="\t", index=False, header=False)   
print("BertBase_SG_MA_SS_bsElectra exported to csv in path './predictions/trial/BertBase_SG_MA_SS_bsElectra.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_SS_bsElectra.tsv --output_file ./output/trial/BertBase_SG_MA_SS_bsElectra.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_SS_bsElectra.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_SS_bsElectra.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3555
# MAP@5 = 0.2663
# MAP@10 = 0.1612
#
# Potential@3 = 0.8
# Potential@5 = 1.0
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# #### bertscore based on Roberta:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
    # for bertbase model:
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word_bertbase = sentence.replace(complex_word, lm_tokenizer_bertbase.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat_bertbase = f"{sentence} {lm_tokenizer_bertbase.sep_token} {sentence_masked_word_bertbase}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result_bertbase = fill_mask_bertbase(sentences_concat_bertbase, top_k=top_k)
    substitutes_bertbase = [substitute["token_str"] for substitute in result_bertbase if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes_bertbase}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes_bertbase = [substitute["token_str"].lower().strip() for substitute in result_bertbase if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters for bertbase model: {substitutes_bertbase}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl_bertbase = []
    for sub in substitutes_bertbase:
        if sub not in substitutes_no_dupl_bertbase:
            substitutes_no_dupl_bertbase.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes for bertbase model: {substitutes_no_dupl_bertbase}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word_bertbase = []
    for substitute in substitutes_no_dupl_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word_bertbase.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word for bertbase model: {substitutes_no_dupl_complex_word_bertbase}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms_bertbase = []
    for substitute in substitutes_no_dupl_complex_word_bertbase:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms_bertbase.append(substitute)
        else:
            print(f"Removed antonym: {substitute}")
    print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word for bertbase model: {substitutes_no_antonyms_bertbase}\n") 
  
    
    
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms_bertbase]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='roberta-base', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms_bertbase, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
   
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/BertBase_SG_MA_SS_bsRoberta.tsv", sep="\t", index=False, header=False) 
print("BertBase_SG_MA_SS_bsRoberta exported to csv in path './predictions/trial/BertBase_SG_MA_SS_bsRoberta.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/BertBase_SG_MA_SS_bsRoberta.tsv --output_file ./output/trial/BertBase_SG_MA_SS_bsRoberta.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/BertBase_SG_MA_SS_bsRoberta.tsv
# OUTPUT file = ./output/trial/BertBase_SG_MA_SS_bsRoberta.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.2722
# MAP@5 = 0.2083
# MAP@10 = 0.1508
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# #### Conclusion (based on on MAP@1):
# 1. BertBase_SG_MA_SS_bs (0.7)
# 2. BertBase_SG_MA_SS_bsElectra (0.6) (based on other scores)
# 3. BertBase_SG_MA_SS_ce (0.6) (based on other scores)
# 4. BertBase_SG_MA_SS_bsRoberta (0.6)
# 5. BertBase_SG_MA_SS   (0.5)
