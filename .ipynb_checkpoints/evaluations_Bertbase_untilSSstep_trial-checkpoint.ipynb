# %% [markdown]
# #### Evaluations BERTbase for the trial set (10 sentences)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %%
# the code below is used when Bertscore is used in step SS
import bert_score
from bert_score import score

# %% [markdown]
# ## Bert-base-uncased

# %%
# Instantiate the tokenizer and the model

# for bert-base:
lm_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
lm_model= AutoModelForMaskedLM.from_pretrained("bert-base-uncased")


# Instantiate the fill-mask pipeline with the model
fill_mask= pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #### Substitute Generation including noise removal:
# ##### including the original, unmasked, sentence:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f" Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    print(f"Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
        
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes[:10]
    print(f"Substitute Generation (SG) final step c): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_bertbase.tsv", sep="\t", index=False, header=False)
print("SG_bertbase exported to csv in path './predictions/trial/SG_bertbase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Generation (SG) step a): initial substitute list: ['compulsory', 'mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['compulsory', 'mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'compulsory': ['compulsory', 'mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Generation (SG) step a): initial substitute list: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'instilled': ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Generation (SG) step a): initial substitute list: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', '##heads', 'ants', 'pigs', 'elephants', 'doctors', '##games', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', '##ists', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', '##ts', 'workers']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'maniacs': ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Generation (SG) step a): initial substitute list: ['observers', 'witnesses', 'participants', 'casualties', 'refugees', 'observer', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['observers', 'witnesses', 'participants', 'casualties', 'refugees', 'observer', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'observers': ['observers', 'witnesses', 'participants', 'casualties', 'refugees', 'observer', 'visitors', 'monitors', 'victims', 'delegates']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Generation (SG) step a): initial substitute list: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'shrapnel': ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Generation (SG) step a): initial substitute list: ['disguised', 'dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', ',', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['disguised', 'dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'disguised': ['disguised', 'dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Generation (SG) step a): initial substitute list: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'offshoot': ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Generation (SG) step a): initial substitute list: ['symphonic', 'orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['symphonic', 'orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'symphonic': ['symphonic', 'orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Generation (SG) step a): initial substitute list: ['deploy', 'deployed', 'withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['deploy', 'deployed', 'withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'deploy': ['deploy', 'deployed', 'withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Generation (SG) step a): initial substitute list: ['authorities', 'officials', 'police', '##s', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'authority', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['authorities', 'officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'authority', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'authorities': ['authorities', 'officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SG_bertbase exported to csv in path './predictions/trial/SG_bertbase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_bertbase.tsv --output_file ./output/trial/SG_bertbase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_bertbase.tsv
# OUTPUT file = ./output/trial/SG_bertbase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2888
# MAP@5 = 0.2243
# MAP@10 = 0.1289
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.8
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### Substitute Selection phase 1 (removal of: dupl.of complex word + infl.forms of complex word + antonyms of complex word):

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
  
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes_no_antonyms[:10]
    print(f"Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase1_bertbase.tsv", sep="\t", index=False, header=False)
print("SS_phase1_bertbase exported to csv in path './predictions/trial/SS_phase1_bertbase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['compulsory', 'mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'compulsory': ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Antonyms for complex word 'compulsory': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'compulsory': ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier', 'only', 'illegal', 'sufficient', 'unnecessary', 'easy', 'normal', 'permitted', 'mandated', 'difficult', 'simple', 'appropriate', 'expensive', 'possible', 'commonplace', 'essential', 'proper', 'available', 'enough', 'affordable']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'compulsory': ['mandatory', 'obligatory', 'optional', 'required', 'necessary', 'standard', 'voluntary', 'customary', 'impossible', 'easier']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'instilled': ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Antonyms for complex word 'instilled': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'instilled': ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred', 'rewarded', 'empowered', 'shocked', 'introduced', 'silenced', 'improved', 'set', 'defeated', 'treated', 'reinforced', 'prepared', 'hit', 'surprised', 'hardened', 'infused', 'challenged', 'released', 'secured', 'delivered', 'established']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'instilled': ['strengthened', 'targeted', 'tested', 'provided', 'created', 'affected', 'addressed', 'attacked', 'punished', 'bred']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'maniacs': ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Antonyms for complex word 'maniacs': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'maniacs': ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors', 'bandits', 'priests', 'demons', 'hawks', 'lords', 'machine', 'soldiers', 'leaders', 'monsters', 'heroes', 'drones', 'fighters', 'veterans', 'puppets', 'ministers', 'workers']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'maniacs': ['criminals', 'machines', 'rats', 'crimes', 'dogs', 'robots', 'ants', 'pigs', 'elephants', 'doctors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['observers', 'witnesses', 'participants', 'casualties', 'refugees', 'observer', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'observers': ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Antonyms for complex word 'observers': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'observers': ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts', 'troops', 'inspectors', 'allies', 'diplomats', 'inspections', 'soldiers', 'fatalities', 'workers', 'pilgrims', 'people', 'officials', 'deaths', 'tourists', 'survivors', 'volunteers', 'citizens', 'civilians', 'combatants']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'observers': ['witnesses', 'participants', 'casualties', 'refugees', 'visitors', 'monitors', 'victims', 'delegates', 'travelers', 'experts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'shrapnel': ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Antonyms for complex word 'shrapnel': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'shrapnel': ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing', 'laser', 'open', 'two', 'rifle', 'serious', 'blunt', 'similar', 'blast', 'numerous', 'penetrating', 'three', 'sword', 'some', 'slash', 'shooting', 'the', 'painful', 'fatal', 'deep', 'horrible']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'shrapnel': ['stab', 'gunshot', 'bullet', 'knife', 'multiple', 'severe', 'arrow', 'several', 'minor', 'stabbing']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['disguised', 'dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'disguised': ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Antonyms for complex word 'disguised': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'disguised': ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared', 'dress', 'posed', 'guise', 'costume', 'attire', 'appearing', 'dresses', 'hiding', 'hooded', 'covered', 'draped', 'costumes', 'hidden', 'wrapped', 'undercover', 'lured', 'present', 'adorned']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'disguised': ['dressed', 'clad', 'masked', 'clothed', 'dressing', 'disguise', 'concealed', 'cloak', 'posing', 'appeared']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'offshoot': ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Antonyms for complex word 'offshoot': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'offshoot': ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost', 'associate', 'advocate', 'enemy', 'aspect', 'origin', 'branch', 'adversary', 'independent', 'alliance', 'ancestor', 'iteration', 'evolution', 'independently', 'antagonist', 'offspring', 'overthrow', 'imitation', 'implementation', 'organization', 'example']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'offshoot': ['affiliate', 'extension', 'arm', 'adaptation', 'incarnation', 'ally', 'opponent', 'attack', 'expansion', 'outpost']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['symphonic', 'orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'symphonic': ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Antonyms for complex word 'symphonic': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'symphonic': ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra', 'instrumental', 'concert', 'historical', 'popular', 'concerto', 'harmonic', 'symphonies', 'technical', 'trombone', 'romantic', 'lyric', 'liturgical', 'dramatic', 'thematic', 'traditional', 'composers', 'vocal', 'dynamic', 'general']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'symphonic': ['orchestral', 'symphony', 'musical', 'classical', 'operatic', 'philharmonic', 'melodic', 'choral', 'music', 'orchestra']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['deploy', 'deployed', 'withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'deploy': ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Antonyms for complex word 'deploy': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'deploy': ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain', 'move', 'utilize', 'request', 'return', 'include', 'add', 'launch', 'designate', 'fire', 'operate', 'provide', 'establish', 'employ', 'outfit', 'purchase', 'expand', 'retire', 'build']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'deploy': ['withdraw', 'activate', 'deployment', 'send', 'maintain', 'dispatch', 'use', 'acquire', 'reserve', 'retain']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['authorities', 'officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'authority', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'authorities': ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Antonyms for complex word 'authorities': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'authorities': ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops', 'nationals', 'persons', 'civilians', 'courts', 'policemen', 'individuals', 'protesters', 'subjects', 'personnel', 'organisations', 'agencies', 'suspects', 'interests', 'leaders', 'politicians', 'activists', 'institutions']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'authorities': ['officials', 'police', 'citizens', 'forces', 'officers', 'people', 'government', 'residents', 'governments', 'troops']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase1_bertbase exported to csv in path './predictions/trial/SS_phase1_bertbase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase1_bertbase.tsv --output_file ./output/trial/SS_phase1_bertbase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_SS_phase1_bertbase.tsv
# OUTPUT file = ./output/trial/SG_SS_phase1_bertbase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2888
# MAP@5 = 0.2253
# MAP@10 = 0.1298
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.8
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### The results obtained after this step served as baselines to compare the six models. I continued with Roberta-base and Electralarge, as they had the best results on the trial set. Therefore, I have not performed further experiments with Bert-base.
