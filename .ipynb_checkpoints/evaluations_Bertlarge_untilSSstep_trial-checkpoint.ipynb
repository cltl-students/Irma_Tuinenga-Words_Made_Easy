# %% [markdown]
# #### Evaluations BERTlarge for the trial set (10 sentences)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %%
# the code below is used when Bertscore is used in step SS
import bert_score
from bert_score import score

# %% [markdown]
# ## Bert-large-uncased

# %%
# Instantiate the tokenizer and the model

lm_tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")
lm_model = AutoModelForMaskedLM.from_pretrained("bert-large-uncased")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #### Substitute Generation including noise removal:
# ##### including the original, unmasked, sentence:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f" Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    print(f"Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
        
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes[:10]
    print(f"Substitute Generation (SG) final step c): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/SG_bertlarge.tsv", sep="\t", index=False, header=False)
print("SG_bertlarge exported to csv in path './predictions/trial/SG_bertlarge.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Generation (SG) step a): initial substitute list: ['compulsory', 'mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', '##rricular', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['compulsory', 'mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'compulsory': ['compulsory', 'mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Generation (SG) step a): initial substitute list: ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed', 'gifted', 'struck', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed', 'gifted', 'struck', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'instilled': ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Generation (SG) step a): initial substitute list: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', '##atics', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', '##kers', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'maniacs': ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Generation (SG) step a): initial substitute list: ['observers', 'observer', 'monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', '##keepers', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['observers', 'observer', 'monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'observers': ['observers', 'observer', 'monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Generation (SG) step a): initial substitute list: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'shrapnel': ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Generation (SG) step a): initial substitute list: ['disguised', 'dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding', 'draped', 'posing', 'appearing', ',', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'cloak', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['disguised', 'dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding', 'draped', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'cloak', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'disguised': ['disguised', 'dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Generation (SG) step a): initial substitute list: ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'offshoot': ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Generation (SG) step a): initial substitute list: ['symphonic', 'orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['symphonic', 'orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'symphonic': ['symphonic', 'orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Generation (SG) step a): initial substitute list: ['deploy', 'deployed', 'activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['deploy', 'deployed', 'activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'deploy': ['deploy', 'deployed', 'activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Generation (SG) step a): initial substitute list: ['authorities', 'police', '##s', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'authority', 'applicants', '##ns', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['authorities', 'police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'authority', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'authorities': ['authorities', 'police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SG_bertlarge exported to csv in path './predictions/trial/SG_bertlarge.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_bertlarge.tsv --output_file ./output/trial/SG_bertlarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_bertlarge.tsv
# OUTPUT file = ./output/trial/SG_bertlarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.3055
# MAP@5 = 0.1873
# MAP@10 = 0.1278
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### Substitute Selection phase 1 (removal of: dupl.of complex word + infl.forms of complex word + antonyms of complex word):

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
  
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes_no_antonyms[:10]
    print(f"Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase1_bertlarge.tsv", sep="\t", index=False, header=False)
print("SS_phase1_bertlarge exported to csv in path './predictions/trial/SS_phase1_bertlarge.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['compulsory', 'mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'compulsory': ['mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Antonyms for complex word 'compulsory': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'compulsory': ['mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'compulsory': ['mandatory', 'obligatory', 'required', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed', 'gifted', 'struck', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'instilled': ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed', 'gifted', 'struck', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Antonyms for complex word 'instilled': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'instilled': ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed', 'gifted', 'struck', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'instilled': ['provided', 'injected', 'infused', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'impressed', 'fed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'maniacs': ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Antonyms for complex word 'maniacs': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'maniacs': ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'maniacs': ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['observers', 'observer', 'monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'observers': ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Antonyms for complex word 'observers': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'observers': ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'observers': ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'shrapnel': ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Antonyms for complex word 'shrapnel': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'shrapnel': ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'shrapnel': ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['disguised', 'dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding', 'draped', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'cloak', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'disguised': ['dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding', 'draped', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'cloak', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Antonyms for complex word 'disguised': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'disguised': ['dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding', 'draped', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'cloak', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'disguised': ['dressed', 'masked', 'disguise', 'dressing', 'armoured', 'clothed', 'concealed', 'clad', 'guise', 'hiding']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'offshoot': ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Antonyms for complex word 'offshoot': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'offshoot': ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'offshoot': ['extension', 'affiliate', 'ally', 'arm', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['symphonic', 'orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Antonyms for complex word 'symphonic': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['deploy', 'deployed', 'activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'deploy': ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Antonyms for complex word 'deploy': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'deploy': ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'deploy': ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['authorities', 'police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'authority', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'authorities': ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Antonyms for complex word 'authorities': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'authorities': ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'authorities': ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase1_bertlarge exported to csv in path './predictions/trial/SS_phase1_bertlarge.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase1_bertlarge.tsv --output_file ./output/trial/SS_phase1_bertlarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase1_bertlarge.tsv
# OUTPUT file = ./output/trial/SS_phase1_bertlarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.3111
# MAP@5 = 0.2026
# MAP@10 = 0.1355
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### Substitute Selection phase 2, option 1: duplicates that are synonyms of the complex word first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
    
    
    
     # 3. Substitute Selection (SS) phase 2, option 1: sort the duplicates that are synonyms with the complex word first:
    ## create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    ## iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word '{complex_word}'. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
    ## print the lists of synonyms and non-synonyms
    print(f"List of substitutes that are synonyms with the complex word '{complex_word}' in Wordnet: {synonyms}\n")
    print(f"List of substitutes that are NO synonyms with the complex word '{complex_word}' in Wordnet: {non_synonyms}\n")

    ## combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    print(f"Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word '{complex_word}' first: {final_list}\n")

        
    ## limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    print(f"Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word '{complex_word}' first: {top_10_substitutes}\n")
    
    print('--------------------------------------------------------------------------------------------------------------------------------------------')

    
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase2_option1Synsfirst_bertlarge.tsv", sep="\t", index=False, header=False)
print("SS_phase2_option1Synsfirst_bertlarge exported to csv in path './predictions/trial/SS_phase2_option1Synsfirst_bertlarge.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# List of substitutes that are synonyms with the complex word 'compulsory' in Wordnet: ['mandatory', 'required']
#
# List of substitutes that are NO synonyms with the complex word 'compulsory' in Wordnet: ['obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'compulsory' first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'compulsory' first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# List of substitutes that are synonyms with the complex word 'instilled' in Wordnet: ['infused', 'impressed', 'struck']
#
# List of substitutes that are NO synonyms with the complex word 'instilled' in Wordnet: ['provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'fed', 'gifted', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'instilled' first: ['infused', 'impressed', 'struck', 'provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'fed', 'gifted', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'instilled' first: ['infused', 'impressed', 'struck', 'provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# List of substitutes that are synonyms with the complex word 'maniacs' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'maniacs' in Wordnet: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'maniacs' first: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'maniacs' first: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# List of substitutes that are synonyms with the complex word 'observers' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'observers' in Wordnet: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'observers' first: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'observers' first: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# List of substitutes that are synonyms with the complex word 'shrapnel' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'shrapnel' in Wordnet: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'shrapnel' first: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'shrapnel' first: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# List of substitutes that are synonyms with the complex word 'disguised' in Wordnet: ['masked', 'disguise', 'clothed', 'draped', 'cloak']
#
# List of substitutes that are NO synonyms with the complex word 'disguised' in Wordnet: ['dressed', 'dressing', 'armoured', 'concealed', 'clad', 'guise', 'hiding', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'disguised' first: ['masked', 'disguise', 'clothed', 'draped', 'cloak', 'dressed', 'dressing', 'armoured', 'concealed', 'clad', 'guise', 'hiding', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'disguised' first: ['masked', 'disguise', 'clothed', 'draped', 'cloak', 'dressed', 'dressing', 'armoured', 'concealed', 'clad']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# List of substitutes that are synonyms with the complex word 'offshoot' in Wordnet: ['arm']
#
# List of substitutes that are NO synonyms with the complex word 'offshoot' in Wordnet: ['extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'offshoot' first: ['arm', 'extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'offshoot' first: ['arm', 'extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# List of substitutes that are synonyms with the complex word 'symphonic' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'symphonic' in Wordnet: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'symphonic' first: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'symphonic' first: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# List of substitutes that are synonyms with the complex word 'deploy' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'deploy' in Wordnet: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'deploy' first: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'deploy' first: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# List of substitutes that are synonyms with the complex word 'authorities' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'authorities' in Wordnet: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'authorities' first: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'authorities' first: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase2_option1Synsfirst_bertlarge exported to csv in path './predictions/trial/SS_phase2_option1Synsfirst_bertlarge.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase2_option1Synsfirst_bertlarge.tsv --output_file ./output/trial/SS_phase2_option1Synsfirst_bertlarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase2_option1Synsfirst_bertlarge.tsv
# OUTPUT file = ./output/trial/SS_phase2_option1Synsfirst_bertlarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3333
# MAP@5 = 0.216
# MAP@10 = 0.1423
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# ### The results obtained after this step served as baselines to compare the six models. I continued with Roberta-base and Electralarge, as they had the best results on the trial set. Therefore, I have not performed further experiments with Bert-large.
