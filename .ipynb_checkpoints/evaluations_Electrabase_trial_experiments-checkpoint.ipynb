# %% [markdown]
# #### Evaluations electrabase for the trial set (10 sentences)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %%
# the code below is used when Bertscore is used in step SS
import bert_score
from bert_score import score

# %% [markdown]
# ## Electra-base-generator

# %%
# Instantiate the tokenizer and the model
lm_tokenizer = AutoTokenizer.from_pretrained("google/electra-base-generator")
lm_model = AutoModelForMaskedLM.from_pretrained("google/electra-base-generator")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)

# %% [markdown]
# #### Substitute Generation including noise removal:
# ##### including the original, unmasked, sentence:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f" Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    print(f"Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
        
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes[:10]
    print(f"Substitute Generation (SG) final step c): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_electrabase.tsv", sep="\t", index=False, header=False)
print("SG_electrabase exported to csv in path './predictions/trial/SG_electrabase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Generation (SG) step a): initial substitute list: ['compulsory', 'mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['compulsory', 'mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'compulsory': ['compulsory', 'mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Generation (SG) step a): initial substitute list: ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'instilled': ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Generation (SG) step a): initial substitute list: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', '##makers', 'leaders', '##heads', '##men', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', '##cs', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'maniacs': ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Generation (SG) step a): initial substitute list: ['observers', 'people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'observer', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['observers', 'people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'observer', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'observers': ['observers', 'people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Generation (SG) step a): initial substitute list: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'shrapnel': ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Generation (SG) step a): initial substitute list: ['dressed', 'disguised', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', ',', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['dressed', 'disguised', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'disguised': ['dressed', 'disguised', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Generation (SG) step a): initial substitute list: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'offshoot': ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Generation (SG) step a): initial substitute list: ['symphonic', 'orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['symphonic', 'orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'symphonic': ['symphonic', 'orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Generation (SG) step a): initial substitute list: ['deploy', 'use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['deploy', 'use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'deploy': ['deploy', 'use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Generation (SG) step a): initial substitute list: ['authorities', 'police', 'officials', 'officers', '##s', 'people', 'citizens', 'policemen', 'government', 'authority', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'agencies', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Generation (SG) step b): substitute list without empty elements and unwanted characters: ['authorities', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'authority', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'agencies', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Generation (SG) final step c): top-10 substitutes for the complex word 'authorities': ['authorities', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'authority', 'forces']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SG_electrabase exported to csv in path './predictions/trial/SG_electrabase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_electrabase.tsv --output_file ./output/trial/SG_electrabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_electrabase.tsv
# OUTPUT file = ./output/trial/SG_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3
# MAP@5 = 0.233
# MAP@10 = 0.148
#
# Potential@3 = 0.5
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# #### Substitute Selection phase 1 (removal of: dupl.of complex word + infl.forms of complex word + antonyms of complex word):

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
  
        
    # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = substitutes_no_antonyms[:10]
    print(f"Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word '{complex_word}': {top_10_substitutes}\n")
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase1_electrabase.tsv", sep="\t", index=False, header=False)
print("SS_phase1_electrabase exported to csv in path './predictions/trial/SS_phase1_electrabase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['compulsory', 'mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'compulsory': ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Antonyms for complex word 'compulsory': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'compulsory': ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'compulsory': ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'instilled': ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Antonyms for complex word 'instilled': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'instilled': ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'instilled': ['provided', 'rewarded', 'lured', 'infused', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'maniacs': ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Antonyms for complex word 'maniacs': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'maniacs': ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'maniacs': ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['observers', 'people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'observer', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'observers': ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Antonyms for complex word 'observers': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'observers': ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'observers': ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'shrapnel': ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Antonyms for complex word 'shrapnel': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'shrapnel': ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'shrapnel': ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['dressed', 'disguised', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'disguised': ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Antonyms for complex word 'disguised': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'disguised': ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'disguised': ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'offshoot': ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Antonyms for complex word 'offshoot': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'offshoot': ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'offshoot': ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['symphonic', 'orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Antonyms for complex word 'symphonic': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'symphonic': ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['deploy', 'use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'deploy': ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Antonyms for complex word 'deploy': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'deploy': ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'deploy': ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: ['authorities', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'authority', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'agencies', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word 'authorities': ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'agencies', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Antonyms for complex word 'authorities': []
#
# Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word 'authorities': ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'agencies', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Selection (SS) phase 1, final step d): top-10 substitutes for the complex word 'authorities': ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'suspects']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase1_electrabase exported to csv in path './predictions/trial/SS_phase1_electrabase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase1_electrabase.tsv --output_file ./output/trial/SS_phase1_electrabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase1_electrabase.tsv
# OUTPUT file = ./output/trial/SS_phase1_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3
# MAP@5 = 0.233
# MAP@10 = 0.148
#
# Potential@3 = 0.5
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# #### Substitute Selection phase 2, option 1: duplicates that are synonyms of the complex word first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
     
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
    
    
    
     # 3. Substitute Selection (SS) phase 2, option 1: sort the duplicates that are synonyms with the complex word first:
    ## create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    ## iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word '{complex_word}'. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
    ## print the lists of synonyms and non-synonyms
    print(f"List of substitutes that are synonyms with the complex word '{complex_word}' in Wordnet: {synonyms}\n")
    print(f"List of substitutes that are NO synonyms with the complex word '{complex_word}' in Wordnet: {non_synonyms}\n")

    ## combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    print(f"Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word '{complex_word}' first: {final_list}\n")

        
    ## limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    print(f"Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word '{complex_word}' first: {top_10_substitutes}\n")
    
    print('--------------------------------------------------------------------------------------------------------------------------------------------')

    
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase2_option1Synsfirst_electrabase.tsv", sep="\t", index=False, header=False)
print("SS_phase2_option1Synsfirst_electrabase exported to csv in path './predictions/trial/SS_phase2_option1Synsfirst_electrabase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# List of substitutes that are synonyms with the complex word 'compulsory' in Wordnet: ['mandatory', 'required']
#
# List of substitutes that are NO synonyms with the complex word 'compulsory' in Wordnet: ['obligatory', 'necessary', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'compulsory' first: ['mandatory', 'required', 'obligatory', 'necessary', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'compulsory' first: ['mandatory', 'required', 'obligatory', 'necessary', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# List of substitutes that are synonyms with the complex word 'instilled' in Wordnet: ['infused', 'impressed']
#
# List of substitutes that are NO synonyms with the complex word 'instilled' in Wordnet: ['provided', 'rewarded', 'lured', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'instilled' first: ['infused', 'impressed', 'provided', 'rewarded', 'lured', 'blessed', 'fed', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'flooded', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'presented', 'confronted', 'united', 'led', 'entered', 'encouraged', 'fortified', 'created', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'instilled' first: ['infused', 'impressed', 'provided', 'rewarded', 'lured', 'blessed', 'fed', 'supplied', 'left', 'brought']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# List of substitutes that are synonyms with the complex word 'maniacs' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'maniacs' in Wordnet: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'maniacs' first: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'maniacs' first: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'freaks']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# List of substitutes that are synonyms with the complex word 'observers' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'observers' in Wordnet: ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'observers' first: ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'specialists', 'dead', 'citizens', 'residents', 'combatants', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'observers' first: ['people', 'monitors', 'journalists', 'witnesses', 'participants', 'experts', 'reporters', 'civilians', 'persons', 'refugees']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# List of substitutes that are synonyms with the complex word 'shrapnel' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'shrapnel' in Wordnet: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'shrapnel' first: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'shrapnel' first: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# List of substitutes that are synonyms with the complex word 'disguised' in Wordnet: ['clothed', 'masked', 'wrapped', 'cloak', 'disguise', 'draped', 'camouflage']
#
# List of substitutes that are NO synonyms with the complex word 'disguised' in Wordnet: ['dressed', 'clad', 'dressing', 'posing', 'hiding', 'covered', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'sleeping', 'dress', 'standing', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'disguised' first: ['clothed', 'masked', 'wrapped', 'cloak', 'disguise', 'draped', 'camouflage', 'dressed', 'clad', 'dressing', 'posing', 'hiding', 'covered', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'sleeping', 'dress', 'standing', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'disguised' first: ['clothed', 'masked', 'wrapped', 'cloak', 'disguise', 'draped', 'camouflage', 'dressed', 'clad', 'dressing']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# List of substitutes that are synonyms with the complex word 'offshoot' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'offshoot' in Wordnet: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'offshoot' first: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'offspring', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'offshoot' first: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# List of substitutes that are synonyms with the complex word 'symphonic' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'symphonic' in Wordnet: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'symphonic' first: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'symphonic' first: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# List of substitutes that are synonyms with the complex word 'deploy' in Wordnet: []
#
# List of substitutes that are NO synonyms with the complex word 'deploy' in Wordnet: ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'deploy' first: ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain', 'introduce']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'deploy' first: ['use', 'build', 'acquire', 'launch', 'develop', 'install', 'purchase', 'send', 'construct', 'ship']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# List of substitutes that are synonyms with the complex word 'authorities' in Wordnet: ['agencies']
#
# List of substitutes that are NO synonyms with the complex word 'authorities' in Wordnet: ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Selection (SS) phase 2, option 1, step a): substitutes sorted on synonyms for the complex word 'authorities' first: ['agencies', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'suspects', 'personnel', 'investigators', 'nationals', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services', 'victims']
#
# Substitute Selection (SS) phase 2, option 1, final step b): top 10 substitutes, sorted on synonyms for the complex word 'authorities' first: ['agencies', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase2_option1Synsfirst_electrabase exported to csv in path './predictions/trial/SS_phase2_option1Synsfirst_electrabase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase2_option1Synsfirst_electrabase.tsv --output_file ./output/trial/SS_phase2_option1Synsfirst_electrabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase2_option1Synsfirst_electrabase.tsv
# OUTPUT file = ./output/trial/SS_phase2_option1Synsfirst_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2888
# MAP@5 = 0.2363
# MAP@10 = 0.1404
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.2
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# #### Substitute Selection phase 2, option 2a: sort the duplicates that share their direct hypernyms with the complex word first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
    
    
    
    # 3. Substitute Selection (SS) phase 2, option 2-a: sort the duplicates that share their direct hypernyms (1 level up) with the complex word first:
    
    ## step a: get 1-level hypernym of complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms = [syn.hypernyms() for syn in complex_word_synsets]
    complex_word_hypernyms_lemmas = [lemma for sublist in complex_word_hypernyms for h in sublist for lemma in h.lemma_names()] # list of hypernyms' lemmas
    print(f"Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_lemmas}\n")

    ## step b: get 1-level hypernyms of the substitutes and get the intersection of shared hypernyms for complex word and the substitutes
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)
        #print (f"substitute synsets for substitute {substitute}: {substitute_synsets}\n")

        # check 1-level hypernyms
        substitute_hypernyms_1 = [syn.hypernyms() for syn in substitute_synsets]
        substitute_hypernyms_1_lemmas = [lemma for sublist in substitute_hypernyms_1 for h in sublist for lemma in h.lemma_names()] # List of hypernyms' lemmas
        #print(f"Substitute_hypernyms_lemmas 1st level (direct hypernyms) for substitute {substitute}: {substitute_hypernyms_1_lemmas}\n")
        

        # check if the substitute has the same 1-level hypernyms as the complex word
        intersection_1 = set(complex_word_hypernyms_lemmas).intersection(set(substitute_hypernyms_1_lemmas))
        if intersection_1:
            #print(f"Substitute {substitute} has the same one-level hypernym as the complex word {complex_word} in Wordnet. Matching hypernym: {intersection_1}\n")
            intersection_1_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)
            
    print(f"Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word '{complex_word}' in Wordnet: {intersection_1_substitutes}\n")
    print(f"Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word '{complex_word}' in Wordnet: {other_substitutes}\n")
    

    ## step c: create the final list, by putting the intersection first
    final_list = intersection_1_substitutes + other_substitutes
    print(f"Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    # step d): limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    print(f"Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word '{complex_word}' in Wordnet first: {top_10_substitutes}\n")

    # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
 
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase2_option2aHyps1first_electrabase.tsv", sep="\t", index=False, header=False)
print("SS_phase2_option2aHyps1first_electrabase exported to csv in path './predictions/trial/SS_phase2_option2aHyps1first_electrabase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'compulsory': []
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'compulsory' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'compulsory' in Wordnet: ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'compulsory' in Wordnet first:  ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'compulsory' in Wordnet first: ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'instilled' in Wordnet: ['rewarded', 'infused', 'blessed', 'fed', 'left', 'beaten', 'flooded', 'jolted', 'presented', 'led', 'fortified', 'created', 'impressed', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'instilled' in Wordnet: ['provided', 'lured', 'supplied', 'brought', 'restored', 'threatened', 'angered', 'filled', 'showered', 'shocked', 'confronted', 'united', 'entered', 'encouraged', 'branded']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'instilled' in Wordnet first:  ['rewarded', 'infused', 'blessed', 'fed', 'left', 'beaten', 'flooded', 'jolted', 'presented', 'led', 'fortified', 'created', 'impressed', 'hit', 'shaken', 'provided', 'lured', 'supplied', 'brought', 'restored', 'threatened', 'angered', 'filled', 'showered', 'shocked', 'confronted', 'united', 'entered', 'encouraged', 'branded']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'instilled' in Wordnet first: ['rewarded', 'infused', 'blessed', 'fed', 'left', 'beaten', 'flooded', 'jolted', 'presented', 'led']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'maniacs' in Wordnet: ['freaks']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'maniacs' in Wordnet: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'maniacs' in Wordnet first:  ['freaks', 'criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'maniacs' in Wordnet first: ['freaks', 'criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'observers' in Wordnet: ['witnesses', 'experts', 'specialists', 'combatants']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'observers' in Wordnet: ['people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'dead', 'citizens', 'residents', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'observers' in Wordnet first:  ['witnesses', 'experts', 'specialists', 'combatants', 'people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'dead', 'citizens', 'residents', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'observers' in Wordnet first: ['witnesses', 'experts', 'specialists', 'combatants', 'people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'shrapnel': ['shell']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'shrapnel' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'shrapnel' in Wordnet: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'shrapnel' in Wordnet first:  ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'shrapnel' in Wordnet first: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'disguised': ['hide', 'conceal']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'disguised' in Wordnet: ['covered', 'masked', 'disguise']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'disguised' in Wordnet: ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'disguised' in Wordnet first:  ['covered', 'masked', 'disguise', 'dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'disguised' in Wordnet first: ['covered', 'masked', 'disguise', 'dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'concealed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'offshoot' in Wordnet: ['offspring']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'offshoot' in Wordnet: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'offshoot' in Wordnet first:  ['offspring', 'ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'offshoot' in Wordnet first: ['offspring', 'ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'symphonic': []
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'symphonic' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'symphonic' in Wordnet: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'symphonic' in Wordnet first:  ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'symphonic' in Wordnet first: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'deploy': ['position', 'spread', 'distribute']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'deploy' in Wordnet: ['install', 'ship', 'introduce']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'deploy' in Wordnet: ['use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send', 'construct', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'deploy' in Wordnet first:  ['install', 'ship', 'introduce', 'use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send', 'construct', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'deploy' in Wordnet first: ['install', 'ship', 'introduce', 'use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Selection (SS) phase 2, option 2, step a): complex_word_hypernyms_lemmas 1st level (direct hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that share the same one-level hypernym with the complex word 'authorities' in Wordnet: ['suspects', 'investigators', 'nationals', 'agencies', 'victims']
#
# Substitute Selection (SS) phase 2, option 2-a, step b): list of substitutes that DO NOT share the same one-level hypernym with the complex word 'authorities' in Wordnet: ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'personnel', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services']
#
# Substitute Selection (SS) phase 2, option 2-a, step c): substitutes sorted on shared one-level hypernyms with the complex word 'authorities' in Wordnet first:  ['suspects', 'investigators', 'nationals', 'agencies', 'victims', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'personnel', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services']
#
# Substitute Selection (SS) phase 2, option 2-a, final step d): top 10 of substitutes, sorted on shared one-level hypernyms with the complex word 'authorities' in Wordnet first: ['suspects', 'investigators', 'nationals', 'agencies', 'victims', 'police', 'officials', 'officers', 'people', 'citizens']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase2_option2aHyps1first_electrabase exported to csv in path './predictions/trial/SS_phase2_option2aHyps1first_electrabase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase2_option2aHyps1first_electrabase.tsv --output_file ./output/trial/SS_phase2_option2aHyps1first_electrabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase2_option2aHyps1first_electrabase.tsv
# OUTPUT file = ./output/trial/SS_phase2_option2aHyps1first_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2833
# MAP@5 = 0.223
# MAP@10 = 0.1389
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.2
# Accuracy@3@top_gold_1 = 0.2

# %% [markdown]
# #### Substitute Selection phase 2, option 2b: sort the duplicates that share their indirect hypernyms (2 levels up) with the complex word first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")
    
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (SG) step a): initial substitute list: {substitutes}\n")


    
    ## remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    #print(f"Substitute Generation (SG) final step b): substitute list without empty elements and unwanted characters: {substitutes}\n")
    
    
        
    # 2. Substitute Selection (SS) phase 1: remove duplicates, inflected forms, and antonyms of complex word:
    
    ## a) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Substitute Selection (SS) phase 1, step a): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")


    ## b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")

    ## then, remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Substitute Selection (SS) phase 1, step b): substitute list without duplicates nor inflected forms of the complex word '{complex_word}': {substitutes_no_dupl_complex_word}\n")

    ## c) remove antonyms of the complex word from the substitute list
    ## get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Substitute Selection (SS) phase 1, step c): substitute list without antonyms of the complex word '{complex_word}': {substitutes_no_antonyms}\n") 
    
    
    
    # 3. Substitute Selection (SS) phase 2, option 2-b: sort the duplicates that share their indirect (2 levels up) hypernyms with the complex word first:
    
    ## step a: get 2-level hypernym of complex word
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms_2 = [h for syn in complex_word_synsets for h in syn.hypernyms() for h2 in h.hypernyms()]
    complex_word_hypernyms_2_lemmas = [lemma for h in complex_word_hypernyms_2 for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas
    print(f"Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_2_lemmas}\n")

    ## step b: get 2-level hypernyms of the substitutes and get the intersection of shared 2-lvel hypernyms for complex word and the substitutes
    intersection_2_substitutes = []
    other_substitutes = []

    for substitute in substitutes_no_antonyms:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)
        #print (f"substitute synsets for substitute {substitute}: {substitute_synsets}\n")

        # check 2-level hypernyms
        substitute_hypernyms_2 = [h for syn in substitute_synsets for h in syn.hypernyms() for h2 in h.hypernyms()]
        substitute_hypernyms_2_lemmas = [lemma for h in substitute_hypernyms_2 for lemma in h.lemma_names()] # List of two-level up hypernyms' lemmas
        #print(f"Substitute_hypernyms_lemmas 2nd level for substitute {substitute}: {substitute_hypernyms_2_lemmas}\n")
        

        # check if the substitute has the same 2-level hypernyms as the complex word
        intersection_2 = set(complex_word_hypernyms_2_lemmas).intersection(set(substitute_hypernyms_2_lemmas))
        if intersection_2:
            #print(f"Substitute {substitute} has the same two-level hypernym as the complex word {complex_word} in Wordnet. Matching hypernym: {intersection_2}\n")
            intersection_2_substitutes.append(substitute)
        else:
            other_substitutes.append(substitute)
            
    print(f"Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word '{complex_word}' in Wordnet: {intersection_2_substitutes}\n")
    print(f"Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word '{complex_word}' in Wordnet: {other_substitutes}\n")
    

    ## step c: create the final list, by putting the intersection first
    final_list = intersection_2_substitutes + other_substitutes
    print(f"Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    # step d): limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    print(f"Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word '{complex_word}' in Wordnet first: {top_10_substitutes}\n")

    # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
 
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SS_phase2_option2bHyps2first_electrabase.tsv", sep="\t", index=False, header=False)
print("SS_phase2_option2bHyps2first_electrabase exported to csv in path './predictions/trial/SS_phase2_option2bHyps2first_electrabase.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'compulsory': []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'compulsory' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'compulsory' in Wordnet: ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'compulsory' in Wordnet first:  ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal', 'free', 'forbidden', 'safe', 'unnecessary', 'impossible', 'legal', 'illegal', 'prohibited', 'acceptable', 'difficult', 'easier', 'fine', 'automatic', 'appropriate', 'proper', 'recommended', 'dangerous', 'unlawful', 'eligible']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'compulsory' in Wordnet first: ['mandatory', 'obligatory', 'necessary', 'required', 'optional', 'voluntary', 'essential', 'available', 'possible', 'normal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'drill', 'fill', 'fill_up', 'make_full']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'instilled' in Wordnet: ['infused', 'blessed', 'fed', 'flooded', 'presented', 'fortified']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'instilled' in Wordnet: ['provided', 'rewarded', 'lured', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'confronted', 'united', 'led', 'entered', 'encouraged', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'instilled' in Wordnet first:  ['infused', 'blessed', 'fed', 'flooded', 'presented', 'fortified', 'provided', 'rewarded', 'lured', 'supplied', 'left', 'brought', 'restored', 'threatened', 'beaten', 'jolted', 'angered', 'filled', 'showered', 'shocked', 'confronted', 'united', 'led', 'entered', 'encouraged', 'created', 'impressed', 'branded', 'hit', 'shaken']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'instilled' in Wordnet first: ['infused', 'blessed', 'fed', 'flooded', 'presented', 'fortified', 'provided', 'rewarded', 'lured', 'supplied']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'maniacs' in Wordnet: ['freaks']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'maniacs' in Wordnet: ['criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'maniacs' in Wordnet first:  ['freaks', 'criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors', 'soldiers', 'walkers', 'forces', 'partisans', 'mania', 'titans', 'nationalists', 'players', 'fighters', 'monsters', 'men', 'crusaders', 'parties', 'supporters', 'nazis', 'minions']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'maniacs' in Wordnet first: ['freaks', 'criminals', 'heroes', 'veterans', 'rebels', 'thugs', 'opponents', 'leaders', 'zombies', 'warriors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'observers' in Wordnet: ['witnesses', 'experts', 'specialists', 'combatants']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'observers' in Wordnet: ['people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'dead', 'citizens', 'residents', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'observers' in Wordnet first:  ['witnesses', 'experts', 'specialists', 'combatants', 'people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians', 'persons', 'refugees', 'individuals', 'others', 'diplomats', 'spectators', 'deaths', 'americans', 'activists', 'volunteers', 'dead', 'citizens', 'residents', 'sites', 'casualties', 'cameras', 'birds', 'visitors']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'observers' in Wordnet first: ['witnesses', 'experts', 'specialists', 'combatants', 'people', 'monitors', 'journalists', 'participants', 'reporters', 'civilians']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'shrapnel': ['shell']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'shrapnel' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'shrapnel' in Wordnet: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'shrapnel' in Wordnet first:  ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious', 'minor', 'torn', 'several', 'leg', 'nerve', 'bone', 'ear', 'surgical', 'blood', 'knee', 'skin', 'two', 'spinal', 'painful', 'severe', 'bleeding', 'superficial', 'foot', 'kidney', 'dead']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'shrapnel' in Wordnet first: ['gunshot', 'stab', 'the', 'bullet', 'broken', 'some', 'bloody', 'multiple', 'from', 'serious']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'disguised': []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'disguised' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'disguised' in Wordnet: ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'disguised' in Wordnet first:  ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed', 'hidden', 'appearing', 'wearing', 'wrapped', 'sleeping', 'cloak', 'disguise', 'dress', 'standing', 'draped', 'identified', 'shown', 'hooded', 'posed', 'bundled', 'bound', 'trained', 'camouflage']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'disguised' in Wordnet first: ['dressed', 'clad', 'dressing', 'clothed', 'posing', 'hiding', 'covered', 'masked', 'concealed', 'armed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'offshoot' in Wordnet: ['offspring']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'offshoot' in Wordnet: ['ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'offshoot' in Wordnet first:  ['offspring', 'ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite', 'adversary', 'alliance', 'echo', 'imitation', 'inversion', 'associate', 'agent', 'advocate', 'amalgamation', 'axis', 'outside', 'icon', 'example', 'aspect', 'outpost', 'incarnation', 'out', 'ancestor', 'attack', 'interpretation']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'offshoot' in Wordnet first: ['offspring', 'ally', 'opponent', 'affiliate', 'enemy', 'extension', 'element', 'antagonist', 'independent', 'opposite']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'symphonic': []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'symphonic' in Wordnet: []
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'symphonic' in Wordnet: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'symphonic' in Wordnet first:  ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque', 'concert', 'epic', 'melodic', 'gothic', 'literary', 'romantic', 'technical', 'harmonic', 'string', 'lyric', 'physical', 'war', 'historical', 'instrumental', 'scientific', 'industrial', 'academic', 'contemporary', 'military']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'symphonic' in Wordnet first: ['orchestral', 'classical', 'symphony', 'choral', 'musical', 'music', 'operatic', 'dramatic', 'opera', 'baroque']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'deploy': ['position']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'deploy' in Wordnet: ['install', 'ship', 'introduce']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'deploy' in Wordnet: ['use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send', 'construct', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'deploy' in Wordnet first:  ['install', 'ship', 'introduce', 'use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send', 'construct', 'reinforce', 'utilize', 'adopt', 'defend', 'add', 'upgrade', 'dispatch', 'buy', 'operate', 'assemble', 'fly', 'fire', 'withdraw', 'abandon', 'employ', 'release', 'support', 'retain']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'deploy' in Wordnet first: ['install', 'ship', 'introduce', 'use', 'build', 'acquire', 'launch', 'develop', 'purchase', 'send']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# Substitute Selection (SS) phase 2, option 2-b, step a): complex_word_hypernyms_lemmas 2nd level hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that share the same two-level hypernym with the complex word 'authorities' in Wordnet: ['suspects', 'investigators', 'nationals', 'agencies', 'victims']
#
# Substitute Selection (SS) phase 2, option 2-b, step b): list of substitutes that DO NOT share the same two-level hypernym with the complex word 'authorities' in Wordnet: ['police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'personnel', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services']
#
# Substitute Selection (SS) phase 2, option 2-b, step c): substitutes sorted on shared two-level hypernyms with the complex word 'authorities' in Wordnet first:  ['suspects', 'investigators', 'nationals', 'agencies', 'victims', 'police', 'officials', 'officers', 'people', 'citizens', 'policemen', 'government', 'forces', 'magistrates', 'personnel', 'residents', 'courts', 'persons', 'security', 'governments', 'troops', 'judges', 'staff', 'constabulary', 'prosecutors', 'communities', 'services']
#
# Substitute Selection (SS) phase 2, option 2-b, final step d): top 10 of substitutes, sorted on shared two-level hypernyms with the complex word 'authorities' in Wordnet first: ['suspects', 'investigators', 'nationals', 'agencies', 'victims', 'police', 'officials', 'officers', 'people', 'citizens']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SS_phase2_option2bHyps2first_electrabase exported to csv in path './predictions/trial/SS_phase2_option2bHyps2first_electrabase.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_phase2_option2bHyps2first_electrabase.tsv --output_file ./output/trial/SS_phase2_option2bHyps2first_electrabase.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_phase2_option2bHyps2first_electrabase.tsv
# OUTPUT file = ./output/trial/SS_phase2_option2bHyps2first_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.2666
# MAP@5 = 0.198
# MAP@10 = 0.1335
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# #### Substitute Selection phase 2, option 3: duplicates ranked on their BertScores:

# %% [markdown]
# ##### Bs with bertbase:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation (step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms= []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='bert-base-uncased', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsBertbase_electrabase.tsv", sep="\t", index=False, header=False)
print("SG_MA_SS_bsBertbase_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsBertbase_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsBertbase_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsBertbase_electrabase.tsv

# %% [raw]
# _bsBertbase_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsBertbase_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsBertbase_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.35
# MAP@5 = 0.22
# MAP@10 = 0.1437
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ##### Bs with bertlarge:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms= []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='bert-large-uncased', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
    
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsBertlarge_electrabase.tsv", sep="\t", index=False, header=False)
print("SG_MA_SS_bsBertlarge_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsBertlarge_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsBertlarge_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsBertlarge_electrabase.tsv

# %% [raw]
# S_bsBertlarge_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsBertlarge_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsBertlarge_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3277
# MAP@5 = 0.2146
# MAP@10 = 0.1315
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.8
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ##### bs with electrabase:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
        
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word : {substitutes_no_dupl_complex_word\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bertscores: 
    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='google/electra-base-generator', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
    
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    ## fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    ## pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
   


    ## add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   

# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsElectrabase_electrabase.tsv", sep="\t", index=False, header=False)   
print("SG_MA_SS_bsElectrabase_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsElectrabase_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsElectrabase_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsElectrabase_electrabase.tsv

# %% [raw]
# _SS_bsElectrabase_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsElectrabase_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsElectrabase_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.4111
# MAP@5 = 0.2836
# MAP@10 = 0.1676
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ##### bs with electralarge:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
        
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat= f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word : {substitutes_no_dupl_complex_word\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    #3: Substitute Selection (SS) by calculating Bertscores: 
    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='google/electra-large-generator', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
    
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    ## fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    ## pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
   


    ## add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   

# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsElectralarge_electrabase.tsv", sep="\t", index=False, header=False)   
print("SG_MA_SS_bsElectralarge_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsElectralarge_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsElectralarge_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsElectralarge_electrabase.tsv

# %% [raw]
# A_SS_bsElectralarge_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsElectralarge_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsElectralarge_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2944
# MAP@5 = 0.2366
# MAP@10 = 0.1619
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ##### bs with robertabase:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='roberta-base', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
   
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsRobertabase_electrabase.tsv", sep="\t", index=False, header=False) 
print("SG_MA_SS_bsRobertabase_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsRobertabase_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsRobertabase_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsRobertabase_electrabase.tsv

# %% [raw]
# _SS_bsRobertabase_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsRobertabase_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsRobertabase_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3222
# MAP@5 = 0.2253
# MAP@10 = 0.1462
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# ##### bs with robertalarge:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
  
    
    
    
    
    
    #3: Substitute Selection (SS) by calculating Bert scores: 

    ## create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_antonyms]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


    ## calculate BERTScores, and rank the substitutes based on these scores
    if len(sentence_with_substitutes) > 0: # to make sure the list with substitutes is always filled
        logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
        scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='roberta-large', verbose=False)
        logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
        
        # create a list of tuples, each tuple containing a substitute and its score
        substitute_score_pairs = list(zip(substitutes_no_antonyms, scores[0].tolist()))

        # sort the list of tuples by the scores (the second element of each tuple), in descending order
        sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

        # # print each substitute with its score
        # for substitute, score in sorted_substitute_score_pairs:
        #     print(f"Substitute: {substitute}, BertScore: {score}")

        # extract the list of substitutes from the sorted pairs
        bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
        #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}\n")

        # limit the substitutes to the 10 first ones for evaluation
        bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
        #print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")

    else:
        bertscore_top_10_substitutes = []


    ## add the results to the dataframe
    # fill the dataframe with 10 elements even if there are less than 10 in the previous list
    required_for_dataframe = 10

    # pad the list with None until it has 10 elements
    bertscore_top_10_substitutes += [None] * (required_for_dataframe - len(bertscore_top_10_substitutes))
  


    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes

    #print('---------------------------------------------------------------------------------------------------------------------------------------------')
   
   
    
# export the dataframe to tsv for evaluation
substitutes_df.to_csv("./predictions/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv", sep="\t", index=False, header=False) 
print("SG_MA_SS_bsRobertalarge_electrabase exported to csv in path './predictions/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv'}\n")

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv --output_file ./output/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv

# %% [raw]
# A_SS_bsRobertalarge_electrabase.tsv
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv
# OUTPUT file = ./output/trial/SG_MA_SS_bsRobertalarge_electrabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3833
# MAP@5 = 0.295
# MAP@10 = 0.1868
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5
