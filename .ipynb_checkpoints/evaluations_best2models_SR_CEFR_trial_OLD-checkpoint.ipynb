# %% [markdown]
# ## trial set: SR step for CEFR datasets

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# map spaCy PoS tags to WordNet PoS tags
def map_pos_spacy_wordnet(pos_spacy):
    pos_map = {
        'NOUN': wn.NOUN,
        'VERB': wn.VERB,
        'ADJ': wn.ADJ,
        'ADV': wn.ADV
    }
    return pos_map.get(pos_spacy, wn.NOUN) # default to NOUN if pos_spacy does not exist in the dict

# %% [markdown]
# ## for CEFR-J dataset:

# %% [markdown]
# ### for model  SS_bsRobertalarge_robertabase:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the 'cefrj_all_treebank.tsv' file, and
# If the POS tag of that word (as listed in 'cefrj_all_treebank.tsv') matches the POS tag of the substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    print(f"complex_word: {complex_word}\n")
    #print(f"substitutes: {substitutes}\n")
    
    
    # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
    #print(f"substitutes_cefr: {substitutes_cefr}\n")
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv'\n")
# Out:
# complex_word: compulsory
#
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# complex_word: instilled
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# complex_word: maniacs
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# complex_word: observers
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# complex_word: shrapnel
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# complex_word: disguised
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# complex_word: offshoot
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('arm', 1), ('branch', 2), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# complex_word: symphonic
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('opera', 1), ('musical', 2), ('classical', 3), ('dramatic', 3), ('formal', 3), ('composition', 3), ('contemporary', 4), ('harmonic', 7), ('concert', 7), ('instrumental', 7)]
#
# complex_word: deploy
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('use', 7), ('install', 7), ('unleash', 7)]
#
# complex_word: authorities
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3166
# MAP@5 = 0.22
# MAP@10 = 0.1466
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.7
# Accuracy@3@top_gold_1 = 0.7

# %%
# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    print(f"complex_word: {complex_word}\n")
    #print(f"substitutes: {substitutes}\n")
    

    # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")


    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
    #print(f"substitutes_cefr: {substitutes_cefr}\n")
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv'\n")
# Out:
# complex_word: compulsory
#
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# complex_word: instilled
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# complex_word: maniacs
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# complex_word: observers
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# complex_word: shrapnel
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# complex_word: disguised
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# complex_word: offshoot
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('arm', 1), ('branch', 2), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# complex_word: symphonic
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('opera', 1), ('musical', 2), ('classical', 3), ('dramatic', 3), ('formal', 3), ('composition', 3), ('contemporary', 4), ('harmonic', 7), ('concert', 7), ('instrumental', 7)]
#
# complex_word: deploy
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('use', 7), ('install', 7), ('unleash', 7)]
#
# complex_word: authorities
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_j.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3166
# MAP@5 = 0.22
# MAP@10 = 0.1466
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.7
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the 'cefrj_all_treebank.tsv' file, and
# If the POS tag of that word (as listed in 'cefrj_all_treebank.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    print(f"complex_word: {complex_word}\n")
    #print(f"substitutes: {substitutes}\n")
    

    # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
    #print(f"substitutes_cefr: {substitutes_cefr}\n")
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])


# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv'\n")
# Out:
# complex_word: compulsory
#
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('free', 1), ('necessary', 2), ('illegal', 2), ('essential', 3), ('optional', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# complex_word: instilled
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# complex_word: maniacs
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# complex_word: observers
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('police', 2), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# complex_word: shrapnel
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('small', 1), ('severe', 3), ('minor', 3), ('multiple', 4), ('superficial', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# complex_word: disguised
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# complex_word: offshoot
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('aspect', 3), ('extension', 4), ('ally', 4), ('echo', 6), ('assimilation', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# complex_word: symphonic
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('musical', 2), ('classical', 3), ('orchestral', 4), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# complex_word: deploy
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('send', 2), ('launch', 3), ('commit', 3), ('employ', 4), ('utilize', 6), ('dispatch', 7), ('activate', 7), ('station', 7), ('use', 7), ('install', 7)]
#
# complex_word: authorities
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# Substitute Ranking (SR), option 2: substitutes with cefr level ranked first: [('government', 2), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_j exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_j.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3388
# MAP@5 = 0.2743
# MAP@10 = 0.1739
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ## for Uchida et al. (CEFR-LS_ dataset:

# %% [markdown]
# ### for model SS_bsRobertalarge_robertabase:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr/uchida_pos.tsv' file, and
# If the POS tag of that word (as listed in './cefr/uchida_pos.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_ls/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match


    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])



# create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_ls exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# ranked_cefr_subs: [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# ranked_cefr_subs: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# ranked_cefr_subs: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# ranked_cefr_subs: [('instrumental', 2), ('composition', 3), ('contemporary', 4), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# ranked_cefr_subs: [('send', 2), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('use', 7), ('install', 7), ('unleash', 7), ('operate', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_ls exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_ls.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3444
# MAP@5 = 0.2326
# MAP@10 = 0.1529
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr/uchida_pos.tsv' file, and
# If the POS tag of that word (as listed in './cefr/uchida_pos.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_ls/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
   
     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
 
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])




# create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_ls exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# ranked_cefr_subs: [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# ranked_cefr_subs: [('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7), ('police', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# ranked_cefr_subs: [('minor', 3), ('multiple', 4), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# ranked_cefr_subs: [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# ranked_cefr_subs: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# ranked_cefr_subs: [('send', 2), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('use', 7), ('install', 7), ('launch', 7), ('commit', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_ls exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_ls.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.35
# MAP@5 = 0.2739
# MAP@10 = 0.1758
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### EFFLEX dataset: based on most frequent CEFR level:

# %% [markdown]
# ### for model SS_bsRobertalarge_robertabase::

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the ./cefr_efllex/EFLLex_mostfreq.tsv' file, and
# If the POS tag of that word (as listed in './cefr_efllex/EFLLex_mostfreq.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    
    

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# ranked_cefr_subs: [('hawks', 3), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# ranked_cefr_subs: [('arm', 2), ('evolution', 4), ('extension', 5), ('branch', 5), ('affiliate', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('imprint', 7), ('adjunct', 7)]
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('opera', 3), ('formal', 4), ('composition', 4), ('dramatic', 5), ('contemporary', 5), ('instrumental', 5), ('harmonic', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# ranked_cefr_subs: [('dispatch', 4), ('mobilize', 5), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('operate', 5), ('send', 5), ('use', 7), ('unleash', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_mostfreq.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2611
# MAP@5 = 0.2096
# MAP@10 = 0.1382
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %% [markdown]
# #### with pos tag of substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_efllex/EFLLex_mostfreq.tsv' file, and
# If the POS tag of that word (as listed in ./cefr_efllex/EFLLex_mostfreq.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    
     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    
    
    

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('essential', 5), ('illegal', 5), ('required', 7), ('mandated', 7), ('prohibited', 7), ('free', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# ranked_cefr_subs: [('police', 2), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# ranked_cefr_subs: [('small', 1), ('multiple', 3), ('severe', 5), ('superficial', 5), ('minor', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# ranked_cefr_subs: [('ally', 4), ('extension', 5), ('aspect', 5), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# ranked_cefr_subs: [('dispatch', 4), ('commit', 4), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('launch', 5), ('send', 5), ('station', 7), ('use', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# ranked_cefr_subs: [('government', 5), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv

# %% [raw]
# ==========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_mostfreq.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2277
# MAP@5 = 0.2186
# MAP@10 = 0.148
#
# Potential@3 = 0.6
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### EFFLEX dataset: based on weighted average across CEFR levels:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_efllex/EFLLex_weighted.tsv' file, and
# If the POS tag of that word (as listed in './cefr_efllex/EFLLex.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %% [markdown]
# ### for model SS_bsRobertalarge_robertabase:

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_weighted.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in EFLLex_weighted.tsv AND the POS tag of that word (in EFLLex_weighted.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# substitutes_cefr ranked on weighted average: [('optional', 4.0), ('voluntary', 4.030806623720507), ('necessary', 4.195970238761346), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# substitutes_cefr ranked on weighted average: [('hawks', 3.0), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# substitutes_cefr ranked on weighted average: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# substitutes_cefr ranked on weighted average: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# substitutes_cefr ranked on weighted average: [('arm', 2.9370921788689635), ('evolution', 4.495682840812356), ('branch', 4.736650890216304), ('extension', 5.0), ('affiliate', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('imprint', 7), ('adjunct', 7)]
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# substitutes_cefr ranked on weighted average: [('classical', 2.479910974472549), ('musical', 2.8468569168465128), ('opera', 3.119009552739917), ('formal', 3.817295439689949), ('composition', 4.0), ('dramatic', 4.401183311947395), ('contemporary', 4.949262941378128), ('instrumental', 5.0), ('harmonic', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# substitutes_cefr ranked on weighted average: [('send', 3.1563799910692736), ('dispatch', 4.0), ('employ', 4.321393460601456), ('operate', 4.499347626487976), ('mobilize', 5.0), ('activate', 5.0), ('utilize', 5.0), ('install', 5.0), ('use', 7), ('unleash', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# substitutes_cefr ranked on weighted average: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_efl_weighted.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3277
# MAP@5 = 0.2406
# MAP@10 = 0.1512
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_weighted.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in EFLLex_weighted.tsv AND the POS tag of that word (in EFLLex_weighted.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# substitutes_cefr ranked on weighted average: [('optional', 4.0), ('voluntary', 4.030806623720507), ('necessary', 4.195970238761346), ('illegal', 4.309478791176403), ('essential', 4.922895620647522), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('prohibited', 7), ('free', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# substitutes_cefr ranked on weighted average: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# substitutes_cefr ranked on weighted average: [('police', 2.822945866591008), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# substitutes_cefr ranked on weighted average: [('small', 2.7645901142535982), ('multiple', 3.0160404252976223), ('minor', 4.411037062545155), ('severe', 4.925980063195703), ('superficial', 5.0), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# substitutes_cefr ranked on weighted average: [('ally', 3.5032308952461846), ('aspect', 4.63326666738738), ('extension', 5.0), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# substitutes_cefr ranked on weighted average: [('classical', 2.479910974472549), ('musical', 2.8468569168465128), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# substitutes_cefr ranked on weighted average: [('send', 3.1563799910692736), ('dispatch', 4.0), ('launch', 4.156138407011127), ('commit', 4.2196428245966215), ('employ', 4.321393460601456), ('activate', 5.0), ('utilize', 5.0), ('install', 5.0), ('station', 7), ('use', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# substitutes_cefr ranked on weighted average: [('government', 4.232236061235025), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_efl_weighted.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2833
# MAP@5 = 0.246
# MAP@10 = 0.16
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### all CEFR datasets combined: (unique word-postag groups with duplicate CEFR scores have been averaged):

# %% [markdown]
# ### for model SS_bsRobertalarge_robertabase:

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_all/cefr_all_combined.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr = []
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in './cefr_all/cefr_all_combined.tsv' AND the POS tag of that word (in './cefr_all/cefr_all_combined.tsv') is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# substitutes_cefr ranked on weighted average: [('necessary', 3.097985119380673), ('optional', 4.0), ('voluntary', 4.515403311860254), ('mandatory', 5.0), ('conditional', 5.0), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# substitutes_cefr ranked on weighted average: [('hawks', 3.0), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# substitutes_cefr ranked on weighted average: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# substitutes_cefr ranked on weighted average: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# substitutes_cefr ranked on weighted average: [('arm', 1.9685460894344815), ('branch', 3.368325445108152), ('evolution', 4.2478414204061785), ('extension', 4.5), ('offspring', 5.0), ('echo', 6.0), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# substitutes_cefr ranked on weighted average: [('opera', 2.0595047763699585), ('musical', 2.423428458423256), ('classical', 2.7399554872362746), ('formal', 3.4086477198449745), ('composition', 3.5), ('instrumental', 3.5), ('dramatic', 3.700591655973697), ('contemporary', 4.474631470689064), ('harmonic', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# substitutes_cefr ranked on weighted average: [('send', 2.578189995534637), ('operate', 3.249673813243988), ('dispatch', 4.0), ('employ', 4.160696730300728), ('mobilize', 5.0), ('activate', 5.0), ('install', 5.0), ('utilize', 5.5), ('use', 7), ('unleash', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# substitutes_cefr ranked on weighted average: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.3333
# MAP@5 = 0.242
# MAP@10 = 0.1569
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.7
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### code updated to present averages of substitutes not found in the combined CEFR database

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_all/cefr_all_combined.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr = []
count_7 = 0  # counter of substitutes with level 7
total_rows = 0  # counter of total number of rows
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    
     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in './cefr_all/cefr_all_combined.tsv' AND the POS tag of that word (in './cefr_all/cefr_all_combined.tsv') is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
            count_7 += 1  # add 1 to the counter per substitute with level 7

    total_rows += 1  # add 1 to the total number of rows

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all'\n")

# calculate the average number of substitutes with level 7
average_7 = count_7 / total_rows
print(f"On average, there were {average_7} substitutes of the provided 10 substitutes that had not been found in the combined CEFR dataset.")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('enforced', 'enforce'), ('conditional', 'conditional'), ('obligatory', 'obligatory'), ('forced', 'force')]
#
# substitutes_cefr ranked on weighted average: [('necessary', 3.097985119380673), ('optional', 4.0), ('voluntary', 4.515403311860254), ('mandatory', 5.0), ('conditional', 5.0), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('filled', 'fill'), ('injected', 'inject'), ('bolstered', 'bolster'), ('stirred', 'stir'), ('inspired', 'inspire'), ('provided', 'provide'), ('pumped', 'pump'), ('seeded', 'seed'), ('reassured', 'reassure')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# Substitutes with their lemmas: [('thugs', 'thug'), ('nazis', 'nazi'), ('hawks', 'hawk'), ('monsters', 'monster'), ('idiots', 'idiot'), ('terrorists', 'terrorist'), ('criminals', 'criminal'), ('perpetrators', 'perpetrator'), ('creatures', 'creature'), ('murderers', 'murderer')]
#
# substitutes_cefr ranked on weighted average: [('hawks', 3.0), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('inspectors', 'inspector'), ('investigators', 'investigator'), ('responders', 'responder'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('supporters', 'supporter'), ('analysts', 'analyst')]
#
# substitutes_cefr ranked on weighted average: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('projectile', 'projectile'), ('blast', 'blast'), ('mortar', 'mortar'), ('shell', 'shell'), ('grenade', 'grenade'), ('shotgun', 'shotgun'), ('ammunition', 'ammunition')]
#
# substitutes_cefr ranked on weighted average: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('cloaked', 'cloak'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('veiled', 'veil'), ('shrouded', 'shroud'), ('wrapped', 'wrap')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('arm', 'arm'), ('offspring', 'offspring'), ('outpost', 'outpost'), ('echo', 'echo'), ('evolution', 'evolution'), ('imprint', 'imprint'), ('branch', 'branch'), ('adjunct', 'adjunct')]
#
# substitutes_cefr ranked on weighted average: [('arm', 1.9685460894344815), ('branch', 3.368325445108152), ('evolution', 4.2478414204061785), ('extension', 4.5), ('offspring', 5.0), ('echo', 6.0), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# Substitutes with their lemmas: [('classical', 'classical'), ('musical', 'musical'), ('dramatic', 'dramatic'), ('opera', 'opera'), ('harmonic', 'harmonic'), ('formal', 'formal'), ('concert', 'concert'), ('composition', 'composition'), ('contemporary', 'contemporary'), ('instrumental', 'instrumental')]
#
# substitutes_cefr ranked on weighted average: [('opera', 2.0595047763699585), ('musical', 2.423428458423256), ('classical', 2.7399554872362746), ('formal', 3.4086477198449745), ('composition', 3.5), ('instrumental', 3.5), ('dramatic', 3.700591655973697), ('contemporary', 4.474631470689064), ('harmonic', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('mobilize', 'mobilize'), ('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('unleash', 'unleash'), ('operate', 'operate'), ('send', 'send')]
#
# substitutes_cefr ranked on weighted average: [('send', 2.578189995534637), ('operate', 3.249673813243988), ('dispatch', 4.0), ('employ', 4.160696730300728), ('mobilize', 5.0), ('activate', 5.0), ('install', 5.0), ('utilize', 5.5), ('use', 7), ('unleash', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('officers', 'officer'), ('agencies', 'agency'), ('forces', 'force'), ('courts', 'court'), ('regulators', 'regulator'), ('counterparts', 'counterpart')]
#
# substitutes_cefr ranked on weighted average: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefr_all'
#
# On average, there were 7.2 substitutes of the provided 10 substitutes that had not been found in the combined CEFR dataset.

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_all/cefr_all_combined.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in './cefr_all/cefr_all_combined.tsv' AND the POS tag of that word (in './cefr_all/cefr_all_combined.tsv') is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all'\n")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# substitutes_cefr ranked on weighted average: [('free', 1.9211746218154655), ('necessary', 3.097985119380673), ('illegal', 3.154739395588201), ('essential', 3.961447810323761), ('optional', 4.0), ('voluntary', 4.515403311860254), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# substitutes_cefr ranked on weighted average: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# substitutes_cefr ranked on weighted average: [('police', 2.411472933295504), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# substitutes_cefr ranked on weighted average: [('small', 1.8822950571267991), ('multiple', 3.508020212648811), ('minor', 3.7055185312725776), ('severe', 3.962990031597852), ('superficial', 5.0), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# substitutes_cefr ranked on weighted average: [('ally', 3.751615447623093), ('aspect', 3.81663333369369), ('extension', 4.5), ('echo', 6.0), ('assimilation', 6.0), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# substitutes_cefr ranked on weighted average: [('musical', 2.423428458423256), ('classical', 2.7399554872362746), ('orchestral', 4.0), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# substitutes_cefr ranked on weighted average: [('send', 2.578189995534637), ('commit', 3.609821412298311), ('dispatch', 4.0), ('employ', 4.160696730300728), ('activate', 5.0), ('install', 5.0), ('utilize', 5.5), ('station', 7), ('use', 7), ('launch', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# substitutes_cefr ranked on weighted average: [('government', 3.1161180306175127), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3055
# MAP@5 = 0.2493
# MAP@10 = 0.164
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### code updated with averages of substitues not found in the combined CEFR database

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_all/cefr_all_combined.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
predictions_cefr = []
count_7 = 0  # counter of substitutes with level 7
total_rows = 0  # counter of total number of rows
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

     # replace the complex word in the sentence with the substitute, and parse it to get the pos tag of the substitute
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
    
    # get the lemma of the substitute based on its pos tag
    substitutes_lemmas = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitutes_lemmas.append((substitute, substitute_lemma))
    print(f"Substitutes with their lemmas: {substitutes_lemmas}\n")
    
    

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmas:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in './cefr_all/cefr_all_combined.tsv' AND the POS tag of that word (in './cefr_all/cefr_all_combined.tsv') is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
            count_7 += 1  # add 1 to the counter per substitute with level 7

    total_rows += 1  # add 1 to the total number of rows

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    predictions_cefr.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(predictions_cefr)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all'\n")

# calculate the average number of substitutes with level 7
average_7 = count_7 / total_rows
print(f"On average, there were {average_7} substitutes of the provided 10 substitutes that had not been found in the combined CEFR dataset.")
# Out:
# Substitutes with their lemmas: [('mandatory', 'mandatory'), ('required', 'require'), ('mandated', 'mandate'), ('necessary', 'necessary'), ('essential', 'essential'), ('voluntary', 'voluntary'), ('optional', 'optional'), ('prohibited', 'prohibit'), ('free', 'free'), ('illegal', 'illegal')]
#
# substitutes_cefr ranked on weighted average: [('free', 1.9211746218154655), ('necessary', 3.097985119380673), ('illegal', 3.154739395588201), ('essential', 3.961447810323761), ('optional', 4.0), ('voluntary', 4.515403311860254), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# Substitutes with their lemmas: [('infused', 'infuse'), ('fed', 'fed'), ('blessed', 'bless'), ('impressed', 'impress'), ('captured', 'capture'), ('reinforced', 'reinforce'), ('packed', 'packed'), ('stunned', 'stun'), ('surprised', 'surprised'), ('cultivated', 'cultivate')]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# Substitutes with their lemmas: [('freaks', 'freak'), ('thugs', 'thug'), ('nazis', 'nazi'), ('monsters', 'monster'), ('devotees', 'devotee'), ('minions', 'minion'), ('criminals', 'criminal'), ('operators', 'operator'), ('mania', 'mania'), ('machines', 'machine')]
#
# substitutes_cefr ranked on weighted average: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# Substitutes with their lemmas: [('monitors', 'monitor'), ('diplomats', 'diplomat'), ('experts', 'expert'), ('observations', 'observation'), ('reporters', 'reporter'), ('witnesses', 'witness'), ('officials', 'official'), ('specialists', 'specialist'), ('analysts', 'analyst'), ('police', 'police')]
#
# substitutes_cefr ranked on weighted average: [('police', 2.411472933295504), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# Substitutes with their lemmas: [('bullet', 'bullet'), ('stab', 'stab'), ('gunshot', 'gunshot'), ('knife', 'knife'), ('multiple', 'multiple'), ('stabbing', 'stab'), ('severe', 'severe'), ('superficial', 'superficial'), ('small', 'small'), ('minor', 'minor')]
#
# substitutes_cefr ranked on weighted average: [('small', 1.8822950571267991), ('multiple', 3.508020212648811), ('minor', 3.7055185312725776), ('severe', 3.962990031597852), ('superficial', 5.0), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# Substitutes with their lemmas: [('masked', 'mask'), ('concealed', 'conceal'), ('clothed', 'clothe'), ('posing', 'pose'), ('dressed', 'dressed'), ('clad', 'clad'), ('wrapped', 'wrap'), ('hidden', 'hide'), ('dressing', 'dress'), ('hiding', 'hiding')]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# Substitutes with their lemmas: [('extension', 'extension'), ('affiliate', 'affiliate'), ('outpost', 'outpost'), ('echo', 'echo'), ('amalgamation', 'amalgamation'), ('ally', 'ally'), ('aspect', 'aspect'), ('assimilation', 'assimilation'), ('adjunct', 'adjunct'), ('analogue', 'analogue')]
#
# substitutes_cefr ranked on weighted average: [('ally', 3.751615447623093), ('aspect', 3.81663333369369), ('extension', 4.5), ('echo', 6.0), ('assimilation', 6.0), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# Substitutes with their lemmas: [('symphony', 'symphony'), ('orchestral', 'orchestral'), ('melodic', 'melodic'), ('operatic', 'operatic'), ('concerto', 'concerto'), ('classical', 'classical'), ('musical', 'musical'), ('gothic', 'gothic'), ('choral', 'choral'), ('concert', 'concert')]
#
# substitutes_cefr ranked on weighted average: [('musical', 2.423428458423256), ('classical', 2.7399554872362746), ('orchestral', 4.0), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# Substitutes with their lemmas: [('dispatch', 'dispatch'), ('activate', 'activate'), ('utilize', 'utilize'), ('station', 'station'), ('employ', 'employ'), ('use', 'use'), ('install', 'install'), ('launch', 'launch'), ('send', 'send'), ('commit', 'commit')]
#
# substitutes_cefr ranked on weighted average: [('send', 2.578189995534637), ('commit', 3.609821412298311), ('dispatch', 4.0), ('employ', 4.160696730300728), ('activate', 5.0), ('install', 5.0), ('utilize', 5.5), ('station', 7), ('use', 7), ('launch', 7)]
#
# Substitutes with their lemmas: [('officials', 'official'), ('investigators', 'investigator'), ('prosecutors', 'prosecutor'), ('police', 'police'), ('magistrates', 'magistrate'), ('officers', 'officer'), ('agencies', 'agency'), ('government', 'government'), ('courts', 'court'), ('prisons', 'prison')]
#
# substitutes_cefr ranked on weighted average: [('government', 3.1161180306175127), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefr_all exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefr_all'
#
# On average, there were 7.1 substitutes of the provided 10 substitutes that had not been found in the combined CEFR dataset.
