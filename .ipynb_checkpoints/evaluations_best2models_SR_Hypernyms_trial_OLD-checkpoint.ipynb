# %% [markdown]
# ## trial set: Substitute Ranking (SR) step with hypernym relations:

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### for model  SS_bsRobertalarge_robertabase:

# %% [markdown]
# ### Substitute Ranking option 1a:  rank the substitutes that are a 1-level up hypernym of the complex word first:

# %%
# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # step a: get the complex word lemma, the complex word synsets, and its first level hypernym
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms_1 = [h for syn in complex_word_synsets for h in syn.hypernyms()]
    complex_word_hypernyms_1_lemmas = [lemma for h in complex_word_hypernyms_1 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_1_lemmas}\n")
   
    

    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for substitute in substitutes:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")
       

    ## step c: get the intersection of the substitute synsets with the 1st level hypernyms of the complex word
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the 1st level hypernym of the complex word
        intersection_1 = set(complex_word_hypernyms_1_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection_1:
            intersection_1_substitutes.append(substitute)  # append original substitute
        else:
            other_substitutes.append(substitute)  # append original substitute
            
            
    print(f"Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word '{complex_word}' in Wordnet: {intersection_1_substitutes}\n")
    print(f"Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word '{complex_word}' in Wordnet: {other_substitutes}\n")     

      
    ## step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_1_substitutes + other_substitutes
    print(f"Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1aShared1first_robertabase.tsv", sep="\t", index=False, header=False)
print("SR_option1aShared1first_robertabase exported to csv in path './predictions/trial/SR_option1aShared1first_robertabase.tsv'}\n")
# Out:
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('mandatary.n.01'), Synset('mandate.n.02'), Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.n.01'), Synset('mandate.n.02'), Synset('mandate.n.03'), Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessity.n.02'), Synset('necessary.a.01'), Synset('necessary.s.02')]), ('voluntary', 'voluntary', [Synset('volunteer.n.01'), Synset('voluntary.n.02'), Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('enforced', 'enforce', [Synset('enforce.v.01'), Synset('enforce.v.02')]), ('conditional', 'conditional', [Synset('conditional.s.01'), Synset('conditional.a.02')]), ('obligatory', 'obligatory', [Synset('obligatory.a.01'), Synset('obligatory.s.02')]), ('forced', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'compulsory' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'compulsory' in Wordnet: ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('filled', 'fill', [Synset('fill.n.01'), Synset('filling.n.01'), Synset('fill.v.01'), Synset('fill.v.02'), Synset('occupy.v.03'), Synset('fill.v.04'), Synset('meet.v.04'), Synset('fill.v.06'), Synset('fill_up.v.04'), Synset('satiate.v.01'), Synset('fill.v.09')]), ('injected', 'inject', [Synset('inject.v.01'), Synset('inject.v.02'), Synset('inject.v.03'), Synset('inject.v.04'), Synset('inject.v.05'), Synset('interject.v.01')]), ('bolstered', 'bolster', [Synset('bolster.n.01'), Synset('bolster.v.01'), Synset('bolster.v.02'), Synset('pad.v.04')]), ('stirred', 'stir', [Synset('stir.n.01'), Synset('stir.n.02'), Synset('bustle.n.01'), Synset('stir.v.01'), Synset('stir.v.02'), Synset('stimulate.v.06'), Synset('stimulate.v.03'), Synset('touch.v.03'), Synset('raise.v.07'), Synset('arouse.v.06'), Synset('stir.v.08')]), ('inspired', 'inspire', [Synset('inspire.v.01'), Synset('inspire.v.02'), Synset('prompt.v.02'), Synset('cheer.v.05'), Synset('revolutionize.v.03'), Synset('inhale.v.02')]), ('provided', 'provide', [Synset('supply.v.01'), Synset('provide.v.02'), Synset('provide.v.03'), Synset('put_up.v.02'), Synset('leave.v.06'), Synset('provide.v.06'), Synset('provide.v.07')]), ('pumped', 'pump', [Synset('pump.n.01'), Synset('heart.n.02'), Synset('pump.n.03'), Synset('pump.v.01'), Synset('pump.v.02'), Synset('pump.v.03'), Synset('pump.v.04'), Synset('pump.v.05'), Synset('pump.v.06'), Synset('pump.v.07'), Synset('pump.v.08')]), ('seeded', 'seed', [Synset('seed.n.01'), Synset('seed.n.02'), Synset('seeded_player.n.01'), Synset('source.n.03'), Synset('semen.n.01'), Synset('seed.v.01'), Synset('seed.v.02'), Synset('seed.v.03'), Synset('sow.v.01'), Synset('seed.v.05'), Synset('seed.v.06'), Synset('seed.v.07'), Synset('seed.v.08')]), ('reassured', 'reassure', [Synset('reassure.v.01'), Synset('reassure.v.02')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'instilled' in Wordnet: ['filled']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'instilled' in Wordnet: ['infused', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'instilled' in Wordnet first:  ['filled', 'infused', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02'), Synset('nazi.a.01'), Synset('national_socialist.a.01')]), ('hawks', 'hawk', [Synset('hawk.n.01'), Synset('hawk.n.02'), Synset('mortarboard.n.01'), Synset('peddle.v.01'), Synset('hawk.v.02'), Synset('clear_the_throat.v.01')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('idiots', 'idiot', [Synset('idiot.n.01')]), ('terrorists', 'terrorist', [Synset('terrorist.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01'), Synset('condemnable.s.01'), Synset('criminal.s.02'), Synset('criminal.s.03')]), ('perpetrators', 'perpetrator', [Synset('perpetrator.n.01')]), ('creatures', 'creature', [Synset('animal.n.01'), Synset('creature.n.02'), Synset('creature.n.03')]), ('murderers', 'murderer', [Synset('murderer.n.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'maniacs' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'maniacs' in Wordnet: ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'maniacs' in Wordnet first:  ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07'), Synset('monitor.v.01'), Synset('monitor.v.02')]), ('inspectors', 'inspector', [Synset('inspector.n.01'), Synset('examiner.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('responders', 'responder', [Synset('respondent.n.02')]), ('experts', 'expert', [Synset('expert.n.01'), Synset('adept.s.01'), Synset('technical.s.04')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05'), Synset('witness.v.01'), Synset('witness.v.02')]), ('supporters', 'supporter', [Synset('supporter.n.01'), Synset('patron.n.03'), Synset('assistant.n.01'), Synset('garter.n.01'), Synset('athletic_supporter.n.01')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'observers' in Wordnet: ['experts']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'observers' in Wordnet: ['monitors', 'inspectors', 'investigators', 'responders', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'observers' in Wordnet first:  ['experts', 'monitors', 'inspectors', 'investigators', 'responders', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'shrapnel': ['shell']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', [Synset('pang.n.01'), Synset('stab.n.02'), Synset('shot.n.16'), Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('projectile', 'projectile', [Synset('projectile.n.01'), Synset('rocket.n.01'), Synset('projectile.s.01')]), ('blast', 'blast', [Synset('blast.n.01'), Synset('bang.n.02'), Synset('gust.n.01'), Synset('blast.n.04'), Synset('good_time.n.01'), Synset('fire.n.09'), Synset('blast.v.01'), Synset('smash.v.01'), Synset('blast.v.03'), Synset('blast.v.04'), Synset('blast.v.05'), Synset('blast.v.06'), Synset('blast.v.07'), Synset('savage.v.02'), Synset('blast.v.09'), Synset('blast.v.10')]), ('mortar', 'mortar', [Synset('mortar.n.01'), Synset('mortar.n.02'), Synset('mortar.n.03'), Synset('mortar.v.01')]), ('shell', 'shell', [Synset('shell.n.01'), Synset('shell.n.02'), Synset('carapace.n.01'), Synset('shell.n.04'), Synset('shell.n.05'), Synset('shell.n.06'), Synset('shell.n.07'), Synset('shell.n.08'), Synset('plate.n.14'), Synset('shell.n.10'), Synset('blast.v.03'), Synset('blast.v.05'), Synset('shell.v.03'), Synset('shell.v.04'), Synset('shell.v.05'), Synset('beat.v.01'), Synset('shell.v.07'), Synset('husk.v.01')]), ('grenade', 'grenade', [Synset('grenade.n.01')]), ('shotgun', 'shotgun', [Synset('shotgun.n.01')]), ('ammunition', 'ammunition', [Synset('ammunition.n.01'), Synset('ammunition.n.02'), Synset('ammunition.n.03')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'shrapnel' in Wordnet: ['blast', 'shell']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'shrapnel' in Wordnet: ['bullet', 'stab', 'gunshot', 'projectile', 'mortar', 'grenade', 'shotgun', 'ammunition']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'shrapnel' in Wordnet first:  ['blast', 'shell', 'bullet', 'stab', 'gunshot', 'projectile', 'mortar', 'grenade', 'shotgun', 'ammunition']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'disguised': ['hide', 'conceal']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('mask.n.01'), Synset('mask.n.02'), Synset('masquerade.n.01'), Synset('mask.n.04'), Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('cloaked', 'cloak', [Synset('cloak.n.01'), Synset('cloak.n.02'), Synset('dissemble.v.02'), Synset('clothe.v.03'), Synset('cloak.v.03')]), ('posing', 'pose', [Synset('airs.n.01'), Synset('pose.n.02'), Synset('affectation.n.01'), Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16'), Synset('appareled.s.01'), Synset('dressed.s.02'), Synset('dressed.s.03'), Synset('dressed.s.04')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03'), Synset('clothed.a.01'), Synset('clad.s.02')]), ('veiled', 'veil', [Synset('head_covering.n.01'), Synset('veil.n.02'), Synset('caul.n.02'), Synset('humeral_veil.n.01'), Synset('veil.v.01'), Synset('obscure.v.05')]), ('shrouded', 'shroud', [Synset('shroud.n.01'), Synset('sheet.n.07'), Synset('pall.n.02'), Synset('shroud.v.01'), Synset('shroud.v.02'), Synset('shroud.v.03')]), ('wrapped', 'wrap', [Synset('wrap.n.01'), Synset('wrap.n.02'), Synset('wrapping.n.01'), Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'disguised' in Wordnet: ['concealed', 'veiled', 'shrouded']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'disguised' in Wordnet: ['masked', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'wrapped']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'disguised' in Wordnet first:  ['concealed', 'veiled', 'shrouded', 'masked', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'wrapped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02'), Synset('consort.v.01'), Synset('affiliate.v.02')]), ('arm', 'arm', [Synset('arm.n.01'), Synset('arm.n.02'), Synset('weapon.n.01'), Synset('arm.n.04'), Synset('branch.n.01'), Synset('sleeve.n.01'), Synset('arm.v.01'), Synset('arm.v.02')]), ('offspring', 'offspring', [Synset('offspring.n.01'), Synset('offspring.n.02'), Synset('young.n.01')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06'), Synset('repeat.v.04'), Synset('resound.v.01'), Synset('echo.v.03')]), ('evolution', 'evolution', [Synset('development.n.02'), Synset('evolution.n.02')]), ('imprint', 'imprint', [Synset('imprint.n.01'), Synset('depression.n.08'), Synset('imprint.n.03'), Synset('imprint.n.04'), Synset('imprint.n.05'), Synset('imprint.v.01'), Synset('impress.v.04')]), ('branch', 'branch', [Synset('branch.n.01'), Synset('branch.n.02'), Synset('branch.n.03'), Synset('outgrowth.n.01'), Synset('branch.n.05'), Synset('arm.n.02'), Synset('ramify.v.02'), Synset('branch.v.02')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03'), Synset('accessory.s.02'), Synset('adjunct.s.02')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'offshoot' in Wordnet: ['offspring']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'offshoot' in Wordnet: ['extension', 'affiliate', 'arm', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'offshoot' in Wordnet first:  ['offspring', 'extension', 'affiliate', 'arm', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('classical', 'classical', [Synset('classical_music.n.01'), Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.n.01'), Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('dramatic', 'dramatic', [Synset('dramatic.a.01'), Synset('dramatic.s.02'), Synset('dramatic.a.03'), Synset('dramatic.a.04')]), ('opera', 'opera', [Synset('opera.n.01'), Synset('opera.n.02'), Synset('opera.n.03')]), ('harmonic', 'harmonic', [Synset('harmonic.n.01'), Synset('harmonic.n.02'), Synset('harmonic.a.01'), Synset('harmonic.a.02'), Synset('harmonic.a.03'), Synset('harmonic.s.04'), Synset('consonant.s.01')]), ('formal', 'formal', [Synset('ball.n.09'), Synset('dinner_dress.n.01'), Synset('formal.a.01'), Synset('formal.s.02'), Synset('formal.a.03'), Synset('conventional.s.05'), Synset('formal.s.05'), Synset('courtly.s.01')]), ('concert', 'concert', [Synset('concert.n.01'), Synset('concert.v.01'), Synset('concert.v.02')]), ('composition', 'composition', [Synset('composition.n.01'), Synset('constitution.n.04'), Synset('composition.n.03'), Synset('musical_composition.n.01'), Synset('composing.n.02'), Synset('writing.n.01'), Synset('typography.n.02'), Synset('composition.n.08'), Synset('composition.n.09')]), ('contemporary', 'contemporary', [Synset('contemporary.n.01'), Synset('contemporary.s.01'), Synset('contemporary.s.02'), Synset('contemporaneous.s.01')]), ('instrumental', 'instrumental', [Synset('instrumental.a.01'), Synset('implemental.s.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'symphonic' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'symphonic' in Wordnet: ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'symphonic' in Wordnet first:  ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'deploy': ['position', 'spread', 'distribute']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('mobilize', 'mobilize', [Synset('mobilize.v.01'), Synset('call_up.v.04'), Synset('mobilize.v.03'), Synset('mobilize.v.04')]), ('dispatch', 'dispatch', [Synset('dispatch.n.01'), Synset('dispatch.n.02'), Synset('dispatch.n.03'), Synset('dispatch.n.04'), Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('employ', 'employ', [Synset('employment.n.01'), Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.n.01'), Synset('function.n.02'), Synset('use.n.03'), Synset('consumption.n.03'), Synset('habit.n.02'), Synset('manipulation.n.01'), Synset('use.n.07'), Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('unleash', 'unleash', [Synset('unleash.v.01'), Synset('unleash.v.02'), Synset('unleash.v.03')]), ('operate', 'operate', [Synset('operate.v.01'), Synset('function.v.01'), Synset('operate.v.03'), Synset('manoeuver.v.03'), Synset('operate.v.05'), Synset('engage.v.10'), Synset('operate_on.v.01')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'deploy' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'deploy' in Wordnet: ['mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate', 'send']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'deploy' in Wordnet first:  ['mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate', 'send']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02'), Synset('official.a.01'), Synset('official.a.02'), Synset('official.s.03'), Synset('official.s.04'), Synset('official.s.05')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01'), Synset('patrol.v.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04'), Synset('officer.v.01')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('forces', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11'), Synset('woo.v.02'), Synset('woo.v.01'), Synset('court.v.03')]), ('regulators', 'regulator', [Synset('regulator.n.01'), Synset('regulator.n.02'), Synset('governor.n.02')]), ('counterparts', 'counterpart', [Synset('counterpart.n.01'), Synset('counterpart.n.02')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'authorities' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'authorities' in Wordnet: ['officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'forces', 'courts', 'regulators', 'counterparts']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'authorities' in Wordnet first:  ['officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'forces', 'courts', 'regulators', 'counterparts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1aShared1first_robertabase exported to csv in path './predictions/trial/SR_option1aShared1first_robertabase.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1aShared1first_robertabase.tsv --output_file ./output/trial/SR_option1aShared1first_robertabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1aShared1first_robertabase.tsv
# OUTPUT file = ./output/trial/SR_option1aShared1first_robertabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2388
# MAP@5 = 0.2023
# MAP@10 = 0.1327
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### Substitute Ranking option 1b:  rank the substitutes that are a 2-level up hypernym of the complex word first:

# %%
# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # step a: get the complex word lemma, the complex word synsets, and its first level hypernym
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms_1 = [h for syn in complex_word_synsets for h in syn.hypernyms()]
    complex_word_hypernyms_1_lemmas = [lemma for h in complex_word_hypernyms_1 for lemma in h.lemma_names()]
    complex_word_hypernyms_2 = [h2 for h1 in complex_word_hypernyms_1 for h2 in h1.hypernyms()]
    complex_word_hypernyms_2_lemmas = [lemma for h in complex_word_hypernyms_2 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_2_lemmas}\n")
   
    

    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for substitute in substitutes:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")
       

    ## step c: get the intersection of the substitute synsets with the 2nd level hypernyms of the complex word
    intersection_2_substitutes = []
    other_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the 1st level hypernym of the complex word
        intersection_2 = set(complex_word_hypernyms_2_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection_2:
            intersection_2_substitutes.append(substitute)  # append original substitute
        else:
            other_substitutes.append(substitute)  # append original substitute
            
            
    print(f"Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word '{complex_word}' in Wordnet: {intersection_2_substitutes}\n")
    print(f"Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word '{complex_word}' in Wordnet: {other_substitutes}\n")     

      
    ## step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_2_substitutes + other_substitutes
    print(f"Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1bShared2first_robertabase.tsv", sep="\t", index=False, header=False)
print("SR_option1bShared2first_robertabase exported to csv in path './predictions/trial/SR_option1bShared2first_robertabase.tsv'}\n")
# Out:
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('mandatary.n.01'), Synset('mandate.n.02'), Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.n.01'), Synset('mandate.n.02'), Synset('mandate.n.03'), Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessity.n.02'), Synset('necessary.a.01'), Synset('necessary.s.02')]), ('voluntary', 'voluntary', [Synset('volunteer.n.01'), Synset('voluntary.n.02'), Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('enforced', 'enforce', [Synset('enforce.v.01'), Synset('enforce.v.02')]), ('conditional', 'conditional', [Synset('conditional.s.01'), Synset('conditional.a.02')]), ('obligatory', 'obligatory', [Synset('obligatory.a.01'), Synset('obligatory.s.02')]), ('forced', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'compulsory' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'compulsory' in Wordnet: ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'instilled': ['change', 'alter', 'modify', 'attach', 'teach', 'learn', 'instruct', 'change', 'alter', 'modify']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('filled', 'fill', [Synset('fill.n.01'), Synset('filling.n.01'), Synset('fill.v.01'), Synset('fill.v.02'), Synset('occupy.v.03'), Synset('fill.v.04'), Synset('meet.v.04'), Synset('fill.v.06'), Synset('fill_up.v.04'), Synset('satiate.v.01'), Synset('fill.v.09')]), ('injected', 'inject', [Synset('inject.v.01'), Synset('inject.v.02'), Synset('inject.v.03'), Synset('inject.v.04'), Synset('inject.v.05'), Synset('interject.v.01')]), ('bolstered', 'bolster', [Synset('bolster.n.01'), Synset('bolster.v.01'), Synset('bolster.v.02'), Synset('pad.v.04')]), ('stirred', 'stir', [Synset('stir.n.01'), Synset('stir.n.02'), Synset('bustle.n.01'), Synset('stir.v.01'), Synset('stir.v.02'), Synset('stimulate.v.06'), Synset('stimulate.v.03'), Synset('touch.v.03'), Synset('raise.v.07'), Synset('arouse.v.06'), Synset('stir.v.08')]), ('inspired', 'inspire', [Synset('inspire.v.01'), Synset('inspire.v.02'), Synset('prompt.v.02'), Synset('cheer.v.05'), Synset('revolutionize.v.03'), Synset('inhale.v.02')]), ('provided', 'provide', [Synset('supply.v.01'), Synset('provide.v.02'), Synset('provide.v.03'), Synset('put_up.v.02'), Synset('leave.v.06'), Synset('provide.v.06'), Synset('provide.v.07')]), ('pumped', 'pump', [Synset('pump.n.01'), Synset('heart.n.02'), Synset('pump.n.03'), Synset('pump.v.01'), Synset('pump.v.02'), Synset('pump.v.03'), Synset('pump.v.04'), Synset('pump.v.05'), Synset('pump.v.06'), Synset('pump.v.07'), Synset('pump.v.08')]), ('seeded', 'seed', [Synset('seed.n.01'), Synset('seed.n.02'), Synset('seeded_player.n.01'), Synset('source.n.03'), Synset('semen.n.01'), Synset('seed.v.01'), Synset('seed.v.02'), Synset('seed.v.03'), Synset('sow.v.01'), Synset('seed.v.05'), Synset('seed.v.06'), Synset('seed.v.07'), Synset('seed.v.08')]), ('reassured', 'reassure', [Synset('reassure.v.01'), Synset('reassure.v.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'instilled' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'instilled' in Wordnet: ['infused', 'filled', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'instilled' in Wordnet first:  ['infused', 'filled', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'maniacs': ['unfortunate', 'unfortunate_person', 'admirer', 'adorer']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02'), Synset('nazi.a.01'), Synset('national_socialist.a.01')]), ('hawks', 'hawk', [Synset('hawk.n.01'), Synset('hawk.n.02'), Synset('mortarboard.n.01'), Synset('peddle.v.01'), Synset('hawk.v.02'), Synset('clear_the_throat.v.01')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('idiots', 'idiot', [Synset('idiot.n.01')]), ('terrorists', 'terrorist', [Synset('terrorist.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01'), Synset('condemnable.s.01'), Synset('criminal.s.02'), Synset('criminal.s.03')]), ('perpetrators', 'perpetrator', [Synset('perpetrator.n.01')]), ('creatures', 'creature', [Synset('animal.n.01'), Synset('creature.n.02'), Synset('creature.n.03')]), ('murderers', 'murderer', [Synset('murderer.n.01')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'maniacs' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'maniacs' in Wordnet: ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'maniacs' in Wordnet first:  ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'observers': ['causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07'), Synset('monitor.v.01'), Synset('monitor.v.02')]), ('inspectors', 'inspector', [Synset('inspector.n.01'), Synset('examiner.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('responders', 'responder', [Synset('respondent.n.02')]), ('experts', 'expert', [Synset('expert.n.01'), Synset('adept.s.01'), Synset('technical.s.04')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05'), Synset('witness.v.01'), Synset('witness.v.02')]), ('supporters', 'supporter', [Synset('supporter.n.01'), Synset('patron.n.03'), Synset('assistant.n.01'), Synset('garter.n.01'), Synset('athletic_supporter.n.01')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'observers' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'observers' in Wordnet: ['monitors', 'inspectors', 'investigators', 'responders', 'experts', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'observers' in Wordnet first:  ['monitors', 'inspectors', 'investigators', 'responders', 'experts', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'shrapnel': ['ammunition', 'ammo']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', [Synset('pang.n.01'), Synset('stab.n.02'), Synset('shot.n.16'), Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('projectile', 'projectile', [Synset('projectile.n.01'), Synset('rocket.n.01'), Synset('projectile.s.01')]), ('blast', 'blast', [Synset('blast.n.01'), Synset('bang.n.02'), Synset('gust.n.01'), Synset('blast.n.04'), Synset('good_time.n.01'), Synset('fire.n.09'), Synset('blast.v.01'), Synset('smash.v.01'), Synset('blast.v.03'), Synset('blast.v.04'), Synset('blast.v.05'), Synset('blast.v.06'), Synset('blast.v.07'), Synset('savage.v.02'), Synset('blast.v.09'), Synset('blast.v.10')]), ('mortar', 'mortar', [Synset('mortar.n.01'), Synset('mortar.n.02'), Synset('mortar.n.03'), Synset('mortar.v.01')]), ('shell', 'shell', [Synset('shell.n.01'), Synset('shell.n.02'), Synset('carapace.n.01'), Synset('shell.n.04'), Synset('shell.n.05'), Synset('shell.n.06'), Synset('shell.n.07'), Synset('shell.n.08'), Synset('plate.n.14'), Synset('shell.n.10'), Synset('blast.v.03'), Synset('blast.v.05'), Synset('shell.v.03'), Synset('shell.v.04'), Synset('shell.v.05'), Synset('beat.v.01'), Synset('shell.v.07'), Synset('husk.v.01')]), ('grenade', 'grenade', [Synset('grenade.n.01')]), ('shotgun', 'shotgun', [Synset('shotgun.n.01')]), ('ammunition', 'ammunition', [Synset('ammunition.n.01'), Synset('ammunition.n.02'), Synset('ammunition.n.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'shrapnel' in Wordnet: ['ammunition']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'shrapnel' in Wordnet: ['bullet', 'stab', 'gunshot', 'projectile', 'blast', 'mortar', 'shell', 'grenade', 'shotgun']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'shrapnel' in Wordnet first:  ['ammunition', 'bullet', 'stab', 'gunshot', 'projectile', 'blast', 'mortar', 'shell', 'grenade', 'shotgun']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'disguised': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('mask.n.01'), Synset('mask.n.02'), Synset('masquerade.n.01'), Synset('mask.n.04'), Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('cloaked', 'cloak', [Synset('cloak.n.01'), Synset('cloak.n.02'), Synset('dissemble.v.02'), Synset('clothe.v.03'), Synset('cloak.v.03')]), ('posing', 'pose', [Synset('airs.n.01'), Synset('pose.n.02'), Synset('affectation.n.01'), Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16'), Synset('appareled.s.01'), Synset('dressed.s.02'), Synset('dressed.s.03'), Synset('dressed.s.04')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03'), Synset('clothed.a.01'), Synset('clad.s.02')]), ('veiled', 'veil', [Synset('head_covering.n.01'), Synset('veil.n.02'), Synset('caul.n.02'), Synset('humeral_veil.n.01'), Synset('veil.v.01'), Synset('obscure.v.05')]), ('shrouded', 'shroud', [Synset('shroud.n.01'), Synset('sheet.n.07'), Synset('pall.n.02'), Synset('shroud.v.01'), Synset('shroud.v.02'), Synset('shroud.v.03')]), ('wrapped', 'wrap', [Synset('wrap.n.01'), Synset('wrap.n.02'), Synset('wrapping.n.01'), Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'disguised' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'disguised' in Wordnet: ['masked', 'concealed', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'veiled', 'shrouded', 'wrapped']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'disguised' in Wordnet first:  ['masked', 'concealed', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'veiled', 'shrouded', 'wrapped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'offshoot': ['phenomenon']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02'), Synset('consort.v.01'), Synset('affiliate.v.02')]), ('arm', 'arm', [Synset('arm.n.01'), Synset('arm.n.02'), Synset('weapon.n.01'), Synset('arm.n.04'), Synset('branch.n.01'), Synset('sleeve.n.01'), Synset('arm.v.01'), Synset('arm.v.02')]), ('offspring', 'offspring', [Synset('offspring.n.01'), Synset('offspring.n.02'), Synset('young.n.01')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06'), Synset('repeat.v.04'), Synset('resound.v.01'), Synset('echo.v.03')]), ('evolution', 'evolution', [Synset('development.n.02'), Synset('evolution.n.02')]), ('imprint', 'imprint', [Synset('imprint.n.01'), Synset('depression.n.08'), Synset('imprint.n.03'), Synset('imprint.n.04'), Synset('imprint.n.05'), Synset('imprint.v.01'), Synset('impress.v.04')]), ('branch', 'branch', [Synset('branch.n.01'), Synset('branch.n.02'), Synset('branch.n.03'), Synset('outgrowth.n.01'), Synset('branch.n.05'), Synset('arm.n.02'), Synset('ramify.v.02'), Synset('branch.v.02')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03'), Synset('accessory.s.02'), Synset('adjunct.s.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'offshoot' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'offshoot' in Wordnet: ['extension', 'affiliate', 'arm', 'offspring', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'offshoot' in Wordnet first:  ['extension', 'affiliate', 'arm', 'offspring', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('classical', 'classical', [Synset('classical_music.n.01'), Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.n.01'), Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('dramatic', 'dramatic', [Synset('dramatic.a.01'), Synset('dramatic.s.02'), Synset('dramatic.a.03'), Synset('dramatic.a.04')]), ('opera', 'opera', [Synset('opera.n.01'), Synset('opera.n.02'), Synset('opera.n.03')]), ('harmonic', 'harmonic', [Synset('harmonic.n.01'), Synset('harmonic.n.02'), Synset('harmonic.a.01'), Synset('harmonic.a.02'), Synset('harmonic.a.03'), Synset('harmonic.s.04'), Synset('consonant.s.01')]), ('formal', 'formal', [Synset('ball.n.09'), Synset('dinner_dress.n.01'), Synset('formal.a.01'), Synset('formal.s.02'), Synset('formal.a.03'), Synset('conventional.s.05'), Synset('formal.s.05'), Synset('courtly.s.01')]), ('concert', 'concert', [Synset('concert.n.01'), Synset('concert.v.01'), Synset('concert.v.02')]), ('composition', 'composition', [Synset('composition.n.01'), Synset('constitution.n.04'), Synset('composition.n.03'), Synset('musical_composition.n.01'), Synset('composing.n.02'), Synset('writing.n.01'), Synset('typography.n.02'), Synset('composition.n.08'), Synset('composition.n.09')]), ('contemporary', 'contemporary', [Synset('contemporary.n.01'), Synset('contemporary.s.01'), Synset('contemporary.s.02'), Synset('contemporaneous.s.01')]), ('instrumental', 'instrumental', [Synset('instrumental.a.01'), Synset('implemental.s.01')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'symphonic' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'symphonic' in Wordnet: ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'symphonic' in Wordnet first:  ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'deploy': ['put', 'set', 'place', 'pose', 'position', 'lay']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('mobilize', 'mobilize', [Synset('mobilize.v.01'), Synset('call_up.v.04'), Synset('mobilize.v.03'), Synset('mobilize.v.04')]), ('dispatch', 'dispatch', [Synset('dispatch.n.01'), Synset('dispatch.n.02'), Synset('dispatch.n.03'), Synset('dispatch.n.04'), Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('employ', 'employ', [Synset('employment.n.01'), Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.n.01'), Synset('function.n.02'), Synset('use.n.03'), Synset('consumption.n.03'), Synset('habit.n.02'), Synset('manipulation.n.01'), Synset('use.n.07'), Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('unleash', 'unleash', [Synset('unleash.v.01'), Synset('unleash.v.02'), Synset('unleash.v.03')]), ('operate', 'operate', [Synset('operate.v.01'), Synset('function.v.01'), Synset('operate.v.03'), Synset('manoeuver.v.03'), Synset('operate.v.05'), Synset('engage.v.10'), Synset('operate_on.v.01')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'deploy' in Wordnet: ['send']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'deploy' in Wordnet: ['mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'deploy' in Wordnet first:  ['send', 'mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'authorities': ['power', 'powerfulness', 'causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'cognitive_state', 'state_of_mind', 'unit', 'social_unit', 'approval', 'commendation', 'publication']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02'), Synset('official.a.01'), Synset('official.a.02'), Synset('official.s.03'), Synset('official.s.04'), Synset('official.s.05')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01'), Synset('patrol.v.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04'), Synset('officer.v.01')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('forces', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11'), Synset('woo.v.02'), Synset('woo.v.01'), Synset('court.v.03')]), ('regulators', 'regulator', [Synset('regulator.n.01'), Synset('regulator.n.02'), Synset('governor.n.02')]), ('counterparts', 'counterpart', [Synset('counterpart.n.01'), Synset('counterpart.n.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the second level hypernyms of the complex word 'authorities' in Wordnet: ['forces']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the second-level hypernym of the complex word 'authorities' in Wordnet: ['officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'courts', 'regulators', 'counterparts']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'authorities' in Wordnet first:  ['forces', 'officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'courts', 'regulators', 'counterparts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1bShared2first_robertabase exported to csv in path './predictions/trial/SR_option1bShared2first_robertabase.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1bShared2first_robertabase.tsv --output_file ./output/trial/SR_option1bShared2first_robertabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1bShared2first_robertabase.tsv
# OUTPUT file = ./output/trial/SR_option1bShared2first_robertabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3444
# MAP@5 = 0.2376
# MAP@10 = 0.1559
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.7
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### Substitute Ranking option 1c:  rank the substitutes that are either a first level or a second level hypernym of the complex word first:

# %%
# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # step a: get the complex word lemma, the complex word synsets, and its first level hypernym
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    complex_word_synsets = wn.synsets(complex_word_lemma)
    complex_word_hypernyms_1 = [h for syn in complex_word_synsets for h in syn.hypernyms()]
    complex_word_hypernyms_1_lemmas = [lemma for h in complex_word_hypernyms_1 for lemma in h.lemma_names()]
    complex_word_hypernyms_2 = [h2 for h1 in complex_word_hypernyms_1 for h2 in h1.hypernyms()]
    complex_word_hypernyms_2_lemmas = [lemma for h in complex_word_hypernyms_2 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_1_lemmas}\n")
    print(f"Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_2_lemmas}\n")
   
    

    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for substitute in substitutes:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        substitute_synsets = wn.synsets(substitute_lemma)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")
       

    ## step c: get the intersection of the substitute synsets with: the 1st and the 2nd level hypernyms of the complex word
    intersection_1_2_substitutes = []
    other_1_2_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the 1st or 2nd level hypernym of the complex word
        intersection_1_2 = set(complex_word_hypernyms_1_lemmas + complex_word_hypernyms_2_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection_1_2:
            intersection_1_2_substitutes.append(substitute)  # append original substitute
        else:
            other_1_2_substitutes.append(substitute)  # append original substitute
            
            
    print(f"Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word '{complex_word}' in Wordnet: {intersection_1_2_substitutes}\n")
    print(f"Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word '{complex_word}' in Wordnet: {other_1_2_substitutes}\n")     

      
    ## step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_1_2_substitutes + other_1_2_substitutes
    print(f"Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1cShared1+2first_robertabase.tsv", sep="\t", index=False, header=False)
print("SR_option1cShared1+2first_robertabase exported to csv in path './predictions/trial/SR_option1cShared1+2first_robertabase.tsv'}\n")
# Out:
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('mandatary.n.01'), Synset('mandate.n.02'), Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.n.01'), Synset('mandate.n.02'), Synset('mandate.n.03'), Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessity.n.02'), Synset('necessary.a.01'), Synset('necessary.s.02')]), ('voluntary', 'voluntary', [Synset('volunteer.n.01'), Synset('voluntary.n.02'), Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('enforced', 'enforce', [Synset('enforce.v.01'), Synset('enforce.v.02')]), ('conditional', 'conditional', [Synset('conditional.s.01'), Synset('conditional.a.02')]), ('obligatory', 'obligatory', [Synset('obligatory.a.01'), Synset('obligatory.s.02')]), ('forced', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'compulsory' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'compulsory' in Wordnet: ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'voluntary', 'optional', 'enforced', 'conditional', 'obligatory', 'forced']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'instilled': ['change', 'alter', 'modify', 'attach', 'teach', 'learn', 'instruct', 'change', 'alter', 'modify']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('filled', 'fill', [Synset('fill.n.01'), Synset('filling.n.01'), Synset('fill.v.01'), Synset('fill.v.02'), Synset('occupy.v.03'), Synset('fill.v.04'), Synset('meet.v.04'), Synset('fill.v.06'), Synset('fill_up.v.04'), Synset('satiate.v.01'), Synset('fill.v.09')]), ('injected', 'inject', [Synset('inject.v.01'), Synset('inject.v.02'), Synset('inject.v.03'), Synset('inject.v.04'), Synset('inject.v.05'), Synset('interject.v.01')]), ('bolstered', 'bolster', [Synset('bolster.n.01'), Synset('bolster.v.01'), Synset('bolster.v.02'), Synset('pad.v.04')]), ('stirred', 'stir', [Synset('stir.n.01'), Synset('stir.n.02'), Synset('bustle.n.01'), Synset('stir.v.01'), Synset('stir.v.02'), Synset('stimulate.v.06'), Synset('stimulate.v.03'), Synset('touch.v.03'), Synset('raise.v.07'), Synset('arouse.v.06'), Synset('stir.v.08')]), ('inspired', 'inspire', [Synset('inspire.v.01'), Synset('inspire.v.02'), Synset('prompt.v.02'), Synset('cheer.v.05'), Synset('revolutionize.v.03'), Synset('inhale.v.02')]), ('provided', 'provide', [Synset('supply.v.01'), Synset('provide.v.02'), Synset('provide.v.03'), Synset('put_up.v.02'), Synset('leave.v.06'), Synset('provide.v.06'), Synset('provide.v.07')]), ('pumped', 'pump', [Synset('pump.n.01'), Synset('heart.n.02'), Synset('pump.n.03'), Synset('pump.v.01'), Synset('pump.v.02'), Synset('pump.v.03'), Synset('pump.v.04'), Synset('pump.v.05'), Synset('pump.v.06'), Synset('pump.v.07'), Synset('pump.v.08')]), ('seeded', 'seed', [Synset('seed.n.01'), Synset('seed.n.02'), Synset('seeded_player.n.01'), Synset('source.n.03'), Synset('semen.n.01'), Synset('seed.v.01'), Synset('seed.v.02'), Synset('seed.v.03'), Synset('sow.v.01'), Synset('seed.v.05'), Synset('seed.v.06'), Synset('seed.v.07'), Synset('seed.v.08')]), ('reassured', 'reassure', [Synset('reassure.v.01'), Synset('reassure.v.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'instilled' in Wordnet: ['filled']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'instilled' in Wordnet: ['infused', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'instilled' in Wordnet first:  ['filled', 'infused', 'injected', 'bolstered', 'stirred', 'inspired', 'provided', 'pumped', 'seeded', 'reassured']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'maniacs': ['unfortunate', 'unfortunate_person', 'admirer', 'adorer']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02'), Synset('nazi.a.01'), Synset('national_socialist.a.01')]), ('hawks', 'hawk', [Synset('hawk.n.01'), Synset('hawk.n.02'), Synset('mortarboard.n.01'), Synset('peddle.v.01'), Synset('hawk.v.02'), Synset('clear_the_throat.v.01')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('idiots', 'idiot', [Synset('idiot.n.01')]), ('terrorists', 'terrorist', [Synset('terrorist.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01'), Synset('condemnable.s.01'), Synset('criminal.s.02'), Synset('criminal.s.03')]), ('perpetrators', 'perpetrator', [Synset('perpetrator.n.01')]), ('creatures', 'creature', [Synset('animal.n.01'), Synset('creature.n.02'), Synset('creature.n.03')]), ('murderers', 'murderer', [Synset('murderer.n.01')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'maniacs' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'maniacs' in Wordnet: ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'maniacs' in Wordnet first:  ['thugs', 'nazis', 'hawks', 'monsters', 'idiots', 'terrorists', 'criminals', 'perpetrators', 'creatures', 'murderers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'observers': ['causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07'), Synset('monitor.v.01'), Synset('monitor.v.02')]), ('inspectors', 'inspector', [Synset('inspector.n.01'), Synset('examiner.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('responders', 'responder', [Synset('respondent.n.02')]), ('experts', 'expert', [Synset('expert.n.01'), Synset('adept.s.01'), Synset('technical.s.04')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05'), Synset('witness.v.01'), Synset('witness.v.02')]), ('supporters', 'supporter', [Synset('supporter.n.01'), Synset('patron.n.03'), Synset('assistant.n.01'), Synset('garter.n.01'), Synset('athletic_supporter.n.01')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'observers' in Wordnet: ['experts']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'observers' in Wordnet: ['monitors', 'inspectors', 'investigators', 'responders', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'observers' in Wordnet first:  ['experts', 'monitors', 'inspectors', 'investigators', 'responders', 'observations', 'reporters', 'witnesses', 'supporters', 'analysts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'shrapnel': ['shell']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'shrapnel': ['ammunition', 'ammo']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', [Synset('pang.n.01'), Synset('stab.n.02'), Synset('shot.n.16'), Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('projectile', 'projectile', [Synset('projectile.n.01'), Synset('rocket.n.01'), Synset('projectile.s.01')]), ('blast', 'blast', [Synset('blast.n.01'), Synset('bang.n.02'), Synset('gust.n.01'), Synset('blast.n.04'), Synset('good_time.n.01'), Synset('fire.n.09'), Synset('blast.v.01'), Synset('smash.v.01'), Synset('blast.v.03'), Synset('blast.v.04'), Synset('blast.v.05'), Synset('blast.v.06'), Synset('blast.v.07'), Synset('savage.v.02'), Synset('blast.v.09'), Synset('blast.v.10')]), ('mortar', 'mortar', [Synset('mortar.n.01'), Synset('mortar.n.02'), Synset('mortar.n.03'), Synset('mortar.v.01')]), ('shell', 'shell', [Synset('shell.n.01'), Synset('shell.n.02'), Synset('carapace.n.01'), Synset('shell.n.04'), Synset('shell.n.05'), Synset('shell.n.06'), Synset('shell.n.07'), Synset('shell.n.08'), Synset('plate.n.14'), Synset('shell.n.10'), Synset('blast.v.03'), Synset('blast.v.05'), Synset('shell.v.03'), Synset('shell.v.04'), Synset('shell.v.05'), Synset('beat.v.01'), Synset('shell.v.07'), Synset('husk.v.01')]), ('grenade', 'grenade', [Synset('grenade.n.01')]), ('shotgun', 'shotgun', [Synset('shotgun.n.01')]), ('ammunition', 'ammunition', [Synset('ammunition.n.01'), Synset('ammunition.n.02'), Synset('ammunition.n.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'shrapnel' in Wordnet: ['blast', 'shell', 'ammunition']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'shrapnel' in Wordnet: ['bullet', 'stab', 'gunshot', 'projectile', 'mortar', 'grenade', 'shotgun']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'shrapnel' in Wordnet first:  ['blast', 'shell', 'ammunition', 'bullet', 'stab', 'gunshot', 'projectile', 'mortar', 'grenade', 'shotgun']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'disguised': ['hide', 'conceal']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'disguised': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('mask.n.01'), Synset('mask.n.02'), Synset('masquerade.n.01'), Synset('mask.n.04'), Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('cloaked', 'cloak', [Synset('cloak.n.01'), Synset('cloak.n.02'), Synset('dissemble.v.02'), Synset('clothe.v.03'), Synset('cloak.v.03')]), ('posing', 'pose', [Synset('airs.n.01'), Synset('pose.n.02'), Synset('affectation.n.01'), Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16'), Synset('appareled.s.01'), Synset('dressed.s.02'), Synset('dressed.s.03'), Synset('dressed.s.04')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03'), Synset('clothed.a.01'), Synset('clad.s.02')]), ('veiled', 'veil', [Synset('head_covering.n.01'), Synset('veil.n.02'), Synset('caul.n.02'), Synset('humeral_veil.n.01'), Synset('veil.v.01'), Synset('obscure.v.05')]), ('shrouded', 'shroud', [Synset('shroud.n.01'), Synset('sheet.n.07'), Synset('pall.n.02'), Synset('shroud.v.01'), Synset('shroud.v.02'), Synset('shroud.v.03')]), ('wrapped', 'wrap', [Synset('wrap.n.01'), Synset('wrap.n.02'), Synset('wrapping.n.01'), Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'disguised' in Wordnet: ['concealed', 'veiled', 'shrouded']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'disguised' in Wordnet: ['masked', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'wrapped']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'disguised' in Wordnet first:  ['concealed', 'veiled', 'shrouded', 'masked', 'clothed', 'cloaked', 'posing', 'dressed', 'clad', 'wrapped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'offshoot': ['phenomenon']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02'), Synset('consort.v.01'), Synset('affiliate.v.02')]), ('arm', 'arm', [Synset('arm.n.01'), Synset('arm.n.02'), Synset('weapon.n.01'), Synset('arm.n.04'), Synset('branch.n.01'), Synset('sleeve.n.01'), Synset('arm.v.01'), Synset('arm.v.02')]), ('offspring', 'offspring', [Synset('offspring.n.01'), Synset('offspring.n.02'), Synset('young.n.01')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06'), Synset('repeat.v.04'), Synset('resound.v.01'), Synset('echo.v.03')]), ('evolution', 'evolution', [Synset('development.n.02'), Synset('evolution.n.02')]), ('imprint', 'imprint', [Synset('imprint.n.01'), Synset('depression.n.08'), Synset('imprint.n.03'), Synset('imprint.n.04'), Synset('imprint.n.05'), Synset('imprint.v.01'), Synset('impress.v.04')]), ('branch', 'branch', [Synset('branch.n.01'), Synset('branch.n.02'), Synset('branch.n.03'), Synset('outgrowth.n.01'), Synset('branch.n.05'), Synset('arm.n.02'), Synset('ramify.v.02'), Synset('branch.v.02')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03'), Synset('accessory.s.02'), Synset('adjunct.s.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'offshoot' in Wordnet: ['offspring']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'offshoot' in Wordnet: ['extension', 'affiliate', 'arm', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'offshoot' in Wordnet first:  ['offspring', 'extension', 'affiliate', 'arm', 'outpost', 'echo', 'evolution', 'imprint', 'branch', 'adjunct']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('classical', 'classical', [Synset('classical_music.n.01'), Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.n.01'), Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('dramatic', 'dramatic', [Synset('dramatic.a.01'), Synset('dramatic.s.02'), Synset('dramatic.a.03'), Synset('dramatic.a.04')]), ('opera', 'opera', [Synset('opera.n.01'), Synset('opera.n.02'), Synset('opera.n.03')]), ('harmonic', 'harmonic', [Synset('harmonic.n.01'), Synset('harmonic.n.02'), Synset('harmonic.a.01'), Synset('harmonic.a.02'), Synset('harmonic.a.03'), Synset('harmonic.s.04'), Synset('consonant.s.01')]), ('formal', 'formal', [Synset('ball.n.09'), Synset('dinner_dress.n.01'), Synset('formal.a.01'), Synset('formal.s.02'), Synset('formal.a.03'), Synset('conventional.s.05'), Synset('formal.s.05'), Synset('courtly.s.01')]), ('concert', 'concert', [Synset('concert.n.01'), Synset('concert.v.01'), Synset('concert.v.02')]), ('composition', 'composition', [Synset('composition.n.01'), Synset('constitution.n.04'), Synset('composition.n.03'), Synset('musical_composition.n.01'), Synset('composing.n.02'), Synset('writing.n.01'), Synset('typography.n.02'), Synset('composition.n.08'), Synset('composition.n.09')]), ('contemporary', 'contemporary', [Synset('contemporary.n.01'), Synset('contemporary.s.01'), Synset('contemporary.s.02'), Synset('contemporaneous.s.01')]), ('instrumental', 'instrumental', [Synset('instrumental.a.01'), Synset('implemental.s.01')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'symphonic' in Wordnet: []
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'symphonic' in Wordnet: ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'symphonic' in Wordnet first:  ['classical', 'musical', 'dramatic', 'opera', 'harmonic', 'formal', 'concert', 'composition', 'contemporary', 'instrumental']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'deploy': ['position', 'spread', 'distribute']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'deploy': ['put', 'set', 'place', 'pose', 'position', 'lay']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('mobilize', 'mobilize', [Synset('mobilize.v.01'), Synset('call_up.v.04'), Synset('mobilize.v.03'), Synset('mobilize.v.04')]), ('dispatch', 'dispatch', [Synset('dispatch.n.01'), Synset('dispatch.n.02'), Synset('dispatch.n.03'), Synset('dispatch.n.04'), Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('employ', 'employ', [Synset('employment.n.01'), Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.n.01'), Synset('function.n.02'), Synset('use.n.03'), Synset('consumption.n.03'), Synset('habit.n.02'), Synset('manipulation.n.01'), Synset('use.n.07'), Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('unleash', 'unleash', [Synset('unleash.v.01'), Synset('unleash.v.02'), Synset('unleash.v.03')]), ('operate', 'operate', [Synset('operate.v.01'), Synset('function.v.01'), Synset('operate.v.03'), Synset('manoeuver.v.03'), Synset('operate.v.05'), Synset('engage.v.10'), Synset('operate_on.v.01')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'deploy' in Wordnet: ['send']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'deploy' in Wordnet: ['mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'deploy' in Wordnet first:  ['send', 'mobilize', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'unleash', 'operate']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'authorities': ['power', 'powerfulness', 'causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'cognitive_state', 'state_of_mind', 'unit', 'social_unit', 'approval', 'commendation', 'publication']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02'), Synset('official.a.01'), Synset('official.a.02'), Synset('official.s.03'), Synset('official.s.04'), Synset('official.s.05')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01'), Synset('patrol.v.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04'), Synset('officer.v.01')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('forces', 'force', [Synset('force.n.01'), Synset('force.n.02'), Synset('force.n.03'), Synset('force.n.04'), Synset('military_unit.n.01'), Synset('violence.n.01'), Synset('power.n.05'), Synset('force.n.08'), Synset('effect.n.05'), Synset('force_out.n.01'), Synset('coerce.v.01'), Synset('impel.v.01'), Synset('push.v.01'), Synset('force.v.04'), Synset('wedge.v.02'), Synset('force.v.06'), Synset('pull.v.01'), Synset('force.v.08'), Synset('storm.v.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11'), Synset('woo.v.02'), Synset('woo.v.01'), Synset('court.v.03')]), ('regulators', 'regulator', [Synset('regulator.n.01'), Synset('regulator.n.02'), Synset('governor.n.02')]), ('counterparts', 'counterpart', [Synset('counterpart.n.01'), Synset('counterpart.n.02')])]
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are the same as the 1st or the 2nd level hypernyms of the complex word 'authorities' in Wordnet: ['forces']
#
# Substitute Ranking (SR) option 1b, step c): list of substitutes of which their synsets are NOT the same as the 1st or the 2nd level hypernym of the complex word 'authorities' in Wordnet: ['officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'courts', 'regulators', 'counterparts']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'authorities' in Wordnet first:  ['forces', 'officials', 'investigators', 'prosecutors', 'police', 'officers', 'agencies', 'courts', 'regulators', 'counterparts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1cShared1+2first_robertabase exported to csv in path './predictions/trial/SR_option1cShared1+2first_robertabase.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1cShared1+2first_robertabase.tsv --output_file ./output/trial/SR_option1cShared1+2first_robertabase.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1cShared1+2first_robertabase.tsv
# OUTPUT file = ./output/trial/SR_option1cShared1+2first_robertabase.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2555
# MAP@5 = 0.2043
# MAP@10 = 0.138
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SS_bsRobertalarge_electralarge:

# %% [markdown]
# ### Substitute Ranking option 1a:  rank the substitutes that are a 1-level up hypernym of the complex word first:

# %%
from nltk.corpus import wordnet

# map spaCy PoS tags to WordNet PoS tags
def map_pos_spacy_wordnet(pos_spacy):
    pos_map = {
        'NOUN': wordnet.NOUN,
        'VERB': wordnet.VERB,
        'ADJ': wordnet.ADJ,
        'ADV': wordnet.ADV
    }
    return pos_map.get(pos_spacy, wordnet.NOUN) # default to NOUN if pos_spacy does not exist in the dict

# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # parse the sentence and get the POS tag of the complex word
    doc = nlp(sentence)
    complex_word_pos_spacy = [token.pos_ for token in doc if token.text == complex_word][0]
    complex_word_pos_wordnet = map_pos_spacy_wordnet(complex_word_pos_spacy)

    # replace the complex word in the sentence and parse it again to get the POS tags of the substitutes
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc_replaced = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc_replaced if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
        
    
    # step a: get the lemma, synsets and the hypernyms of the complex word
    complex_word_lemma = [token.lemma_ for token in doc if token.text == complex_word][0] if complex_word in [token.text for token in doc] else complex_word
    print(f"complex_word_lemma: {complex_word_lemma}\n")
    
    complex_word_synsets = wn.synsets(complex_word_lemma, pos=complex_word_pos_wordnet)
    complex_word_hypernyms_1 = [h for syn in complex_word_synsets for h in syn.hypernyms()]
    complex_word_hypernyms_1_lemmas = [lemma for h in complex_word_hypernyms_1 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_1_lemmas}\n")
   

    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitute_synsets = wn.synsets(substitute_lemma, pos=pos_substitute_wordnet)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")
   


    ## step c: get the intersection of the substitute synsets with the 1st level hypernyms of the complex word
    intersection_1_substitutes = []
    other_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the 1st level hypernym of the complex word
        intersection_1 = set(complex_word_hypernyms_1_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection_1:
            intersection_1_substitutes.append(substitute)  # append original substitute
        else:
            other_substitutes.append(substitute)  # append original substitute
            
            
    print(f"Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word '{complex_word}' in Wordnet: {intersection_1_substitutes}\n")
    print(f"Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word '{complex_word}' in Wordnet: {other_substitutes}\n")     

      
    ## step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_1_substitutes + other_substitutes
    print(f"Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1aShared1first_electralarge.tsv", sep="\t", index=False, header=False)
print("SR_option1aShared1first_electralarge exported to csv in path './predictions/trial/SR_option1aShared1first_electralarge.tsv'}\n")
# Out:
# complex_word_lemma: compulsory
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessary.a.01'), Synset('necessary.s.02')]), ('essential', 'essential', [Synset('essential.s.01'), Synset('essential.a.02'), Synset('all-important.s.01'), Synset('essential.a.04'), Synset('substantive.a.02')]), ('voluntary', 'voluntary', [Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('prohibited', 'prohibit', [Synset('forbid.v.01')]), ('free', 'free', [Synset('free.a.01'), Synset('free.a.02'), Synset('complimentary.s.02'), Synset('free.s.04'), Synset('detached.s.06'), Synset('free.a.06'), Synset('spare.s.03'), Synset('barren.s.03'), Synset('free.s.09')]), ('illegal', 'illegal', [Synset('illegal.a.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'compulsory' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'compulsory' in Wordnet: ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: instill
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('fed', 'fed', [Synset('feed.v.01'), Synset('feed.v.02'), Synset('feed.v.03'), Synset('feed.v.04'), Synset('feed.v.05'), Synset('feed.v.06'), Synset('feed.v.07'), Synset('run.v.06'), Synset('prey.v.01'), Synset('feed.v.10'), Synset('fertilize.v.01')]), ('blessed', 'bless', [Synset('bless.v.01'), Synset('bless.v.02'), Synset('bless.v.03'), Synset('consecrate.v.04')]), ('impressed', 'impress', [Synset('affect.v.05'), Synset('impress.v.02'), Synset('impress.v.03'), Synset('impress.v.04'), Synset('print.v.04'), Synset('shanghai.v.01'), Synset('impress.v.07')]), ('captured', 'capture', [Synset('capture.v.01'), Synset('capture.v.02'), Synset('get.v.11'), Synset('capture.v.04'), Synset('appropriate.v.02'), Synset('capture.v.06')]), ('reinforced', 'reinforce', [Synset('reinforce.v.01'), Synset('reinforce.v.02')]), ('packed', 'packed', [Synset('pack.v.01'), Synset('pack.v.02'), Synset('pack.v.03'), Synset('pack.v.04'), Synset('pack.v.05'), Synset('carry.v.02'), Synset('throng.v.01'), Synset('backpack.v.01'), Synset('tamp_down.v.01'), Synset('pack.v.10'), Synset('compact.v.01'), Synset('pack.v.12'), Synset('pack.v.13')]), ('stunned', 'stun', [Synset('stun.v.01'), Synset('sandbag.v.03'), Synset('stun.v.03')]), ('surprised', 'surprised', [Synset('surprise.v.01'), Synset('surprise.v.02'), Synset('storm.v.05')]), ('cultivated', 'cultivate', [Synset('cultivate.v.01'), Synset('cultivate.v.02'), Synset('educate.v.03'), Synset('domesticate.v.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'instilled' in Wordnet: ['impressed']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'instilled' in Wordnet: ['infused', 'fed', 'blessed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'instilled' in Wordnet first:  ['impressed', 'infused', 'fed', 'blessed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: maniac
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('freaks', 'freak', [Synset('freak.n.01'), Synset('addict.n.01')]), ('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('devotees', 'devotee', [Synset('fan.n.03')]), ('minions', 'minion', [Synset('minion.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01')]), ('operators', 'operator', [Synset('operator.n.01'), Synset('operator.n.02'), Synset('operator.n.03'), Synset('hustler.n.02'), Synset('operator.n.05')]), ('mania', 'mania', [Synset('mania.n.01'), Synset('mania.n.02')]), ('machines', 'machine', [Synset('machine.n.01'), Synset('machine.n.02'), Synset('machine.n.03'), Synset('machine.n.04'), Synset('machine.n.05'), Synset('car.n.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'maniacs' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'maniacs' in Wordnet: ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'maniacs' in Wordnet first:  ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: observer
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07')]), ('diplomats', 'diplomat', [Synset('diplomat.n.01'), Synset('diplomat.n.02')]), ('experts', 'expert', [Synset('expert.n.01')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05')]), ('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('specialists', 'specialist', [Synset('specialist.n.01'), Synset('specialist.n.02')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')]), ('police', 'police', [Synset('police.n.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'observers' in Wordnet: ['experts']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'observers' in Wordnet: ['monitors', 'diplomats', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'observers' in Wordnet first:  ['experts', 'monitors', 'diplomats', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: shrapnel
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'shrapnel': ['shell']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', []), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('knife', 'knife', [Synset('knife.n.01'), Synset('knife.n.02'), Synset('tongue.n.03')]), ('multiple', 'multiple', [Synset('multiple.a.01')]), ('stabbing', 'stab', [Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('severe', 'severe', [Synset('severe.s.01'), Synset('hard.s.04'), Synset('austere.s.01'), Synset('severe.s.04'), Synset('dangerous.s.02'), Synset('severe.s.06')]), ('superficial', 'superficial', [Synset('superficial.a.01'), Synset('superficial.a.02'), Synset('superficial.s.03')]), ('small', 'small', [Synset('small.a.01'), Synset('minor.s.10'), Synset('little.s.03'), Synset('small.s.04'), Synset('humble.s.01'), Synset('little.s.07'), Synset('little.s.05'), Synset('small.s.08'), Synset('modest.s.02'), Synset('belittled.s.01')]), ('minor', 'minor', [Synset('minor.a.01'), Synset('minor.a.02'), Synset('minor.a.03'), Synset('minor.a.04'), Synset('minor.a.05'), Synset('minor.a.06'), Synset('minor.a.07'), Synset('minor.s.08'), Synset('minor.s.09'), Synset('minor.s.10')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'shrapnel' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'shrapnel' in Wordnet: ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'shrapnel' in Wordnet first:  ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: disguise
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'disguised': ['hide', 'conceal']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('posing', 'pose', [Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('wrapped', 'wrap', [Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')]), ('hidden', 'hide', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')]), ('dressing', 'dress', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('hiding', 'hiding', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'disguised' in Wordnet: ['concealed', 'hidden', 'hiding']
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'disguised' in Wordnet: ['masked', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'dressing']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'disguised' in Wordnet first:  ['concealed', 'hidden', 'hiding', 'masked', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'dressing']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: offshoot
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06')]), ('amalgamation', 'amalgamation', [Synset('amalgamation.n.01')]), ('ally', 'ally', [Synset('ally.n.01'), Synset('ally.n.02')]), ('aspect', 'aspect', [Synset('aspect.n.01'), Synset('aspect.n.02'), Synset('view.n.02'), Synset('aspect.n.04'), Synset('expression.n.01')]), ('assimilation', 'assimilation', [Synset('assimilation.n.01'), Synset('assimilation.n.02'), Synset('assimilation.n.03'), Synset('assimilation.n.04'), Synset('acculturation.n.03'), Synset('assimilation.n.06')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03')]), ('analogue', 'analogue', [Synset('analogue.n.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'offshoot' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'offshoot' in Wordnet: ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'offshoot' in Wordnet first:  ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: symphonic
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('symphony', 'symphony', [Synset('symphony.n.01'), Synset('symphony_orchestra.n.01')]), ('orchestral', 'orchestral', [Synset('orchestral.a.01')]), ('melodic', 'melodic', [Synset('melodious.a.02'), Synset('melodic.a.02')]), ('operatic', 'operatic', [Synset('operatic.a.01')]), ('concerto', 'concerto', [Synset('concerto.n.01')]), ('classical', 'classical', [Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('gothic', 'gothic', [Synset('gothic.n.01'), Synset('gothic.n.02'), Synset('gothic.n.03')]), ('choral', 'choral', [Synset('choral.a.01')]), ('concert', 'concert', [Synset('concert.n.01')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'symphonic' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'symphonic' in Wordnet: ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'symphonic' in Wordnet first:  ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: deploy
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'deploy': ['position', 'spread', 'distribute']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('dispatch', 'dispatch', [Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('station', 'station', [Synset('station.v.01')]), ('employ', 'employ', [Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('launch', 'launch', [Synset('establish.v.01'), Synset('launch.v.02'), Synset('launch.v.03'), Synset('plunge.v.04'), Synset('launch.v.05'), Synset('launch.v.06')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')]), ('commit', 'commit', [Synset('perpetrate.v.01'), Synset('give.v.18'), Synset('commit.v.03'), Synset('entrust.v.01'), Synset('invest.v.01'), Synset('commit.v.06')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'deploy' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'deploy' in Wordnet: ['dispatch', 'activate', 'utilize', 'station', 'employ', 'use', 'install', 'launch', 'send', 'commit']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'deploy' in Wordnet first:  ['dispatch', 'activate', 'utilize', 'station', 'employ', 'use', 'install', 'launch', 'send', 'commit']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: authority
#
# Substitute Ranking (SR), option 1-a, step a): complex_word_hypernyms_lemmas (1st level hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book']
#
# Substitute Ranking (SR), option 1-a, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01')]), ('magistrates', 'magistrate', [Synset('magistrate.n.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('government', 'government', [Synset('government.n.01'), Synset('government.n.02'), Synset('government.n.03'), Synset('politics.n.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11')]), ('prisons', 'prison', [Synset('prison.n.01'), Synset('prison.n.02')])]
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are the same as the first level hypernyms of the complex word 'authorities' in Wordnet: []
#
# Substitute Ranking (SR) option 1a, step c): list of substitutes of which their synsets are NOT the same as the one-level hypernym of the complex word 'authorities' in Wordnet: ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# Substitute Ranking (SR) option 1a, step d): substitutes sorted on whether they belong to a synset that is the same as the first level hypernym of the complex word 'authorities' in Wordnet first:  ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1aShared1first_electralarge exported to csv in path './predictions/trial/SR_option1aShared1first_electralarge.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1aShared1first_electralarge.tsv --output_file ./output/trial/SR_option1aShared1first_electralarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1aShared1first_electralarge.tsv
# OUTPUT file = ./output/trial/SR_option1aShared1first_electralarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3388
# MAP@5 = 0.2763
# MAP@10 = 0.177
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### Substitute Ranking option 1b:  rank the substitutes that are a 2-level up hypernym of the complex word first:

# %%
from nltk.corpus import wordnet

# map spaCy PoS tags to WordNet PoS tags
def map_pos_spacy_wordnet(pos_spacy):
    pos_map = {
        'NOUN': wordnet.NOUN,
        'VERB': wordnet.VERB,
        'ADJ': wordnet.ADJ,
        'ADV': wordnet.ADV
    }
    return pos_map.get(pos_spacy, wordnet.NOUN) # default to NOUN if pos_spacy does not exist in the dict

# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # parse the sentence and get the POS tag of the complex word
    doc = nlp(sentence)
    complex_word_pos_spacy = [token.pos_ for token in doc if token.text == complex_word][0]
    complex_word_pos_wordnet = map_pos_spacy_wordnet(complex_word_pos_spacy)

    # replace the complex word in the sentence and parse it again to get the POS tags of the substitutes
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc_replaced = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc_replaced if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
        
    
    # step a: get the lemma, synsets and the hypernyms of the complex word
    complex_word_lemma = [token.lemma_ for token in doc if token.text == complex_word][0] if complex_word in [token.text for token in doc] else complex_word
    print(f"complex_word_lemma: {complex_word_lemma}\n")
    
    complex_word_synsets = wn.synsets(complex_word_lemma, pos=complex_word_pos_wordnet)
    complex_word_hypernyms_2 = [h for syn in complex_word_synsets for h1 in syn.hypernyms() for h in h1.hypernyms()]
    complex_word_hypernyms_2_lemmas = [lemma for h in complex_word_hypernyms_2 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_2_lemmas}\n")
   

    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitute_synsets = wn.synsets(substitute_lemma, pos=pos_substitute_wordnet)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")

    # step c: get the intersection of the substitute synsets with the 2nd level hypernyms of the complex word
    intersection_2_substitutes = []
    other_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the two-level hypernym of the complex word
        intersection_2 = set(complex_word_hypernyms_2_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection_2:
            intersection_2_substitutes.append(substitute)  # append original substitute
        else:
            other_substitutes.append(substitute)  # append original substitute

    print(f"Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word '{complex_word}' in Wordnet first: {intersection_2_substitutes + other_substitutes}\n")


    
    # step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_2_substitutes + other_substitutes
    print(f"Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1bShared2first_electralarge.tsv", sep="\t", index=False, header=False)
print("SR_option1bShared2first_electralarge exported to csv in path './predictions/trial/SR_option1bShared2first_electralarge.tsv'}\n")
# Out:
# complex_word_lemma: compulsory
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessary.a.01'), Synset('necessary.s.02')]), ('essential', 'essential', [Synset('essential.s.01'), Synset('essential.a.02'), Synset('all-important.s.01'), Synset('essential.a.04'), Synset('substantive.a.02')]), ('voluntary', 'voluntary', [Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('prohibited', 'prohibit', [Synset('forbid.v.01')]), ('free', 'free', [Synset('free.a.01'), Synset('free.a.02'), Synset('complimentary.s.02'), Synset('free.s.04'), Synset('detached.s.06'), Synset('free.a.06'), Synset('spare.s.03'), Synset('barren.s.03'), Synset('free.s.09')]), ('illegal', 'illegal', [Synset('illegal.a.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'compulsory' in Wordnet first: ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: instill
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'instilled': ['change', 'alter', 'modify', 'attach', 'teach', 'learn', 'instruct', 'change', 'alter', 'modify']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('fed', 'fed', [Synset('feed.v.01'), Synset('feed.v.02'), Synset('feed.v.03'), Synset('feed.v.04'), Synset('feed.v.05'), Synset('feed.v.06'), Synset('feed.v.07'), Synset('run.v.06'), Synset('prey.v.01'), Synset('feed.v.10'), Synset('fertilize.v.01')]), ('blessed', 'bless', [Synset('bless.v.01'), Synset('bless.v.02'), Synset('bless.v.03'), Synset('consecrate.v.04')]), ('impressed', 'impress', [Synset('affect.v.05'), Synset('impress.v.02'), Synset('impress.v.03'), Synset('impress.v.04'), Synset('print.v.04'), Synset('shanghai.v.01'), Synset('impress.v.07')]), ('captured', 'capture', [Synset('capture.v.01'), Synset('capture.v.02'), Synset('get.v.11'), Synset('capture.v.04'), Synset('appropriate.v.02'), Synset('capture.v.06')]), ('reinforced', 'reinforce', [Synset('reinforce.v.01'), Synset('reinforce.v.02')]), ('packed', 'packed', [Synset('pack.v.01'), Synset('pack.v.02'), Synset('pack.v.03'), Synset('pack.v.04'), Synset('pack.v.05'), Synset('carry.v.02'), Synset('throng.v.01'), Synset('backpack.v.01'), Synset('tamp_down.v.01'), Synset('pack.v.10'), Synset('compact.v.01'), Synset('pack.v.12'), Synset('pack.v.13')]), ('stunned', 'stun', [Synset('stun.v.01'), Synset('sandbag.v.03'), Synset('stun.v.03')]), ('surprised', 'surprised', [Synset('surprise.v.01'), Synset('surprise.v.02'), Synset('storm.v.05')]), ('cultivated', 'cultivate', [Synset('cultivate.v.01'), Synset('cultivate.v.02'), Synset('educate.v.03'), Synset('domesticate.v.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'instilled' in Wordnet first: ['infused', 'fed', 'blessed', 'impressed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'instilled' in Wordnet first:  ['infused', 'fed', 'blessed', 'impressed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: maniac
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'maniacs': ['unfortunate', 'unfortunate_person', 'admirer', 'adorer']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('freaks', 'freak', [Synset('freak.n.01'), Synset('addict.n.01')]), ('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('devotees', 'devotee', [Synset('fan.n.03')]), ('minions', 'minion', [Synset('minion.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01')]), ('operators', 'operator', [Synset('operator.n.01'), Synset('operator.n.02'), Synset('operator.n.03'), Synset('hustler.n.02'), Synset('operator.n.05')]), ('mania', 'mania', [Synset('mania.n.01'), Synset('mania.n.02')]), ('machines', 'machine', [Synset('machine.n.01'), Synset('machine.n.02'), Synset('machine.n.03'), Synset('machine.n.04'), Synset('machine.n.05'), Synset('car.n.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'maniacs' in Wordnet first: ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'maniacs' in Wordnet first:  ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: observer
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'observers': ['causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07')]), ('diplomats', 'diplomat', [Synset('diplomat.n.01'), Synset('diplomat.n.02')]), ('experts', 'expert', [Synset('expert.n.01')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05')]), ('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('specialists', 'specialist', [Synset('specialist.n.01'), Synset('specialist.n.02')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')]), ('police', 'police', [Synset('police.n.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'observers' in Wordnet first: ['monitors', 'diplomats', 'experts', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'observers' in Wordnet first:  ['monitors', 'diplomats', 'experts', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: shrapnel
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'shrapnel': ['ammunition', 'ammo']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', []), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('knife', 'knife', [Synset('knife.n.01'), Synset('knife.n.02'), Synset('tongue.n.03')]), ('multiple', 'multiple', [Synset('multiple.a.01')]), ('stabbing', 'stab', [Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('severe', 'severe', [Synset('severe.s.01'), Synset('hard.s.04'), Synset('austere.s.01'), Synset('severe.s.04'), Synset('dangerous.s.02'), Synset('severe.s.06')]), ('superficial', 'superficial', [Synset('superficial.a.01'), Synset('superficial.a.02'), Synset('superficial.s.03')]), ('small', 'small', [Synset('small.a.01'), Synset('minor.s.10'), Synset('little.s.03'), Synset('small.s.04'), Synset('humble.s.01'), Synset('little.s.07'), Synset('little.s.05'), Synset('small.s.08'), Synset('modest.s.02'), Synset('belittled.s.01')]), ('minor', 'minor', [Synset('minor.a.01'), Synset('minor.a.02'), Synset('minor.a.03'), Synset('minor.a.04'), Synset('minor.a.05'), Synset('minor.a.06'), Synset('minor.a.07'), Synset('minor.s.08'), Synset('minor.s.09'), Synset('minor.s.10')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'shrapnel' in Wordnet first: ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'shrapnel' in Wordnet first:  ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: disguise
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'disguised': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('posing', 'pose', [Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('wrapped', 'wrap', [Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')]), ('hidden', 'hide', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')]), ('dressing', 'dress', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('hiding', 'hiding', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'disguised' in Wordnet first: ['masked', 'concealed', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'hidden', 'dressing', 'hiding']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'disguised' in Wordnet first:  ['masked', 'concealed', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'hidden', 'dressing', 'hiding']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: offshoot
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'offshoot': ['phenomenon']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06')]), ('amalgamation', 'amalgamation', [Synset('amalgamation.n.01')]), ('ally', 'ally', [Synset('ally.n.01'), Synset('ally.n.02')]), ('aspect', 'aspect', [Synset('aspect.n.01'), Synset('aspect.n.02'), Synset('view.n.02'), Synset('aspect.n.04'), Synset('expression.n.01')]), ('assimilation', 'assimilation', [Synset('assimilation.n.01'), Synset('assimilation.n.02'), Synset('assimilation.n.03'), Synset('assimilation.n.04'), Synset('acculturation.n.03'), Synset('assimilation.n.06')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03')]), ('analogue', 'analogue', [Synset('analogue.n.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'offshoot' in Wordnet first: ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'offshoot' in Wordnet first:  ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: symphonic
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('symphony', 'symphony', [Synset('symphony.n.01'), Synset('symphony_orchestra.n.01')]), ('orchestral', 'orchestral', [Synset('orchestral.a.01')]), ('melodic', 'melodic', [Synset('melodious.a.02'), Synset('melodic.a.02')]), ('operatic', 'operatic', [Synset('operatic.a.01')]), ('concerto', 'concerto', [Synset('concerto.n.01')]), ('classical', 'classical', [Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('gothic', 'gothic', [Synset('gothic.n.01'), Synset('gothic.n.02'), Synset('gothic.n.03')]), ('choral', 'choral', [Synset('choral.a.01')]), ('concert', 'concert', [Synset('concert.n.01')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'symphonic' in Wordnet first: ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'symphonic' in Wordnet first:  ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: deploy
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'deploy': ['put', 'set', 'place', 'pose', 'position', 'lay']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('dispatch', 'dispatch', [Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('station', 'station', [Synset('station.v.01')]), ('employ', 'employ', [Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('launch', 'launch', [Synset('establish.v.01'), Synset('launch.v.02'), Synset('launch.v.03'), Synset('plunge.v.04'), Synset('launch.v.05'), Synset('launch.v.06')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')]), ('commit', 'commit', [Synset('perpetrate.v.01'), Synset('give.v.18'), Synset('commit.v.03'), Synset('entrust.v.01'), Synset('invest.v.01'), Synset('commit.v.06')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'deploy' in Wordnet first: ['station', 'send', 'commit', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'launch']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'deploy' in Wordnet first:  ['station', 'send', 'commit', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'launch']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: authority
#
# Substitute Ranking (SR), option 1-b, step a): complex_word_hypernyms_lemmas (2nd level hypernyms) for complex word 'authorities': ['power', 'powerfulness', 'causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'cognitive_state', 'state_of_mind', 'unit', 'social_unit', 'approval', 'commendation', 'publication']
#
# Substitute Ranking (SR), option 1-b, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01')]), ('magistrates', 'magistrate', [Synset('magistrate.n.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('government', 'government', [Synset('government.n.01'), Synset('government.n.02'), Synset('government.n.03'), Synset('politics.n.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11')]), ('prisons', 'prison', [Synset('prison.n.01'), Synset('prison.n.02')])]
#
# Substitute Ranking (SR), option 1-b, step c): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'authorities' in Wordnet first: ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# Substitute Ranking (SR) option 1b, step d): substitutes sorted on whether they belong to a synset that is the same as the second level hypernym of the complex word 'authorities' in Wordnet first:  ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1bShared2first_electralarge exported to csv in path './predictions/trial/SR_option1bShared2first_electralarge.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1bShared2first_electralarge.tsv --output_file ./output/trial/SR_option1bShared2first_electralarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1bShared2first_electralarge.tsv
# OUTPUT file = ./output/trial/SR_option1bShared2first_electralarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.3722
# MAP@5 = 0.2903
# MAP@10 = 0.182
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### Substitute Ranking option 1c:  rank the substitutes that are either a first level or a second level hypernym of the complex word first:

# %%
from nltk.corpus import wordnet

# map spaCy PoS tags to WordNet PoS tags
def map_pos_spacy_wordnet(pos_spacy):
    pos_map = {
        'NOUN': wordnet.NOUN,
        'VERB': wordnet.VERB,
        'ADJ': wordnet.ADJ,
        'ADV': wordnet.ADV
    }
    return pos_map.get(pos_spacy, wordnet.NOUN) # default to NOUN if pos_spacy does not exist in the dict

# read the predictions file into a df
pred_df = pd.read_csv('./predictions/trial/SS_phase2_option3f_BSrobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions df:
for index, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # parse the sentence and get the POS tag of the complex word
    doc = nlp(sentence)
    complex_word_pos_spacy = [token.pos_ for token in doc if token.text == complex_word][0]
    complex_word_pos_wordnet = map_pos_spacy_wordnet(complex_word_pos_spacy)

    # replace the complex word in the sentence and parse it again to get the POS tags of the substitutes
    substitute_pos = []
    for substitute in substitutes:
        replaced_sentence = sentence.replace(complex_word, substitute)
        doc_replaced = nlp(replaced_sentence)
        pos = [token.pos_ for token in doc_replaced if token.text == substitute][0]
        substitute_pos.append((substitute, pos))
        
    # step a: get the lemma, synsets and the hypernyms of the complex word
    complex_word_lemma = [token.lemma_ for token in doc if token.text == complex_word][0] if complex_word in [token.text for token in doc] else complex_word
    print(f"complex_word_lemma: {complex_word_lemma}\n")
    
    complex_word_synsets = wn.synsets(complex_word_lemma, pos=complex_word_pos_wordnet)
    complex_word_hypernyms_1 = [h for syn in complex_word_synsets for h in syn.hypernyms()]
    complex_word_hypernyms_1_lemmas = [lemma for h in complex_word_hypernyms_1 for lemma in h.lemma_names()]
    complex_word_hypernyms_2 = [h for h1 in complex_word_hypernyms_1 for h in h1.hypernyms()]
    complex_word_hypernyms_2_lemmas = [lemma for h in complex_word_hypernyms_2 for lemma in h.lemma_names()]
    print(f"Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word '{complex_word}': {complex_word_hypernyms_1_lemmas + complex_word_hypernyms_2_lemmas}\n")


    # step b: get the lemma and synsets of the substitutes, and store the original substitutes with the lemmas and synsets
    substitute_lemmas_synsets = []
    for sub_pos in substitute_pos:
        substitute, pos_spacy = sub_pos
        pos_substitute_wordnet = map_pos_spacy_wordnet(pos_spacy)
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_ if substitute in [token.text for token in doc_substitute] else substitute
        substitute_synsets = wn.synsets(substitute_lemma, pos=pos_substitute_wordnet)
        substitute_lemmas_synsets.append((substitute, substitute_lemma, substitute_synsets)) 
    print(f"Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: {substitute_lemmas_synsets}\n")

   # step c: get the intersection of the substitute synsets with the 1st and 2nd level hypernyms of the complex word
    intersection_1_2_substitutes = []
    other_substitutes = []

    for substitute, substitute_lemma, substitute_synsets in substitute_lemmas_synsets:
        # get the lemmas of the substitute synsets
        substitute_synsets_lemmas = [lemma for syn in substitute_synsets for lemma in syn.lemma_names()] 

        # check if the substitute belongs to a synset that is the same as the first or second-level hypernym of the complex word
        intersection = set(complex_word_hypernyms_1_lemmas + complex_word_hypernyms_2_lemmas).intersection(set(substitute_synsets_lemmas))
        if intersection:
            intersection_1_2_substitutes.append(substitute)  # append original substitute
        else:
            other_substitutes.append(substitute)  # append original substitute

    print(f"Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: {intersection_1_2_substitutes}\n")
    print(f"Substitute Ranking (SR), option 1-c, step c): other substitutes: {other_substitutes}\n")
        
     
    
    # step d: create the final list, by putting the intersection first in the list, appending the list with the other substitutes
    final_list = intersection_1_2_substitutes + other_substitutes
    print(f"Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word '{complex_word}' in Wordnet first:  {final_list}\n")

    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
    # add the sentence, complex_word, and the substitutes to the dataframe 
    pred_df.loc[index] = [sentence, complex_word] +  final_list

    
# export the dataframe to tsv for evaluation
pred_df.to_csv("./predictions/trial/SR_option1cShared1+2first_electralarge.tsv", sep="\t", index=False, header=False)
print("SR_option1cShared1+2first_electralarge exported to csv in path './predictions/trial/SR_option1cShared1+2first_electralarge.tsv'}\n")
# Out:
# complex_word_lemma: compulsory
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'compulsory': []
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('mandatory', 'mandatory', [Synset('compulsory.s.01')]), ('required', 'require', [Synset('necessitate.v.01'), Synset('ask.v.04'), Synset('command.v.02'), Synset('want.v.02')]), ('mandated', 'mandate', [Synset('mandate.v.01'), Synset('mandate.v.02'), Synset('mandate.v.03')]), ('necessary', 'necessary', [Synset('necessary.a.01'), Synset('necessary.s.02')]), ('essential', 'essential', [Synset('essential.s.01'), Synset('essential.a.02'), Synset('all-important.s.01'), Synset('essential.a.04'), Synset('substantive.a.02')]), ('voluntary', 'voluntary', [Synset('voluntary.a.01'), Synset('voluntary.a.02')]), ('optional', 'optional', [Synset('optional.a.01')]), ('prohibited', 'prohibit', [Synset('forbid.v.01')]), ('free', 'free', [Synset('free.a.01'), Synset('free.a.02'), Synset('complimentary.s.02'), Synset('free.s.04'), Synset('detached.s.06'), Synset('free.a.06'), Synset('spare.s.03'), Synset('barren.s.03'), Synset('free.s.09')]), ('illegal', 'illegal', [Synset('illegal.a.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'compulsory' in Wordnet first:  ['mandatory', 'required', 'mandated', 'necessary', 'essential', 'voluntary', 'optional', 'prohibited', 'free', 'illegal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: instill
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'instilled': ['lend', 'impart', 'bestow', 'contribute', 'add', 'bring', 'insert', 'infix', 'enter', 'introduce', 'affect', 'impress', 'move', 'strike', 'drill', 'fill', 'fill_up', 'make_full', 'change', 'alter', 'modify', 'attach', 'teach', 'learn', 'instruct', 'change', 'alter', 'modify']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('infused', 'infuse', [Synset('inculcate.v.01'), Synset('impregnate.v.01'), Synset('infuse.v.03'), Synset('steep.v.02'), Synset('infuse.v.05')]), ('fed', 'fed', [Synset('feed.v.01'), Synset('feed.v.02'), Synset('feed.v.03'), Synset('feed.v.04'), Synset('feed.v.05'), Synset('feed.v.06'), Synset('feed.v.07'), Synset('run.v.06'), Synset('prey.v.01'), Synset('feed.v.10'), Synset('fertilize.v.01')]), ('blessed', 'bless', [Synset('bless.v.01'), Synset('bless.v.02'), Synset('bless.v.03'), Synset('consecrate.v.04')]), ('impressed', 'impress', [Synset('affect.v.05'), Synset('impress.v.02'), Synset('impress.v.03'), Synset('impress.v.04'), Synset('print.v.04'), Synset('shanghai.v.01'), Synset('impress.v.07')]), ('captured', 'capture', [Synset('capture.v.01'), Synset('capture.v.02'), Synset('get.v.11'), Synset('capture.v.04'), Synset('appropriate.v.02'), Synset('capture.v.06')]), ('reinforced', 'reinforce', [Synset('reinforce.v.01'), Synset('reinforce.v.02')]), ('packed', 'packed', [Synset('pack.v.01'), Synset('pack.v.02'), Synset('pack.v.03'), Synset('pack.v.04'), Synset('pack.v.05'), Synset('carry.v.02'), Synset('throng.v.01'), Synset('backpack.v.01'), Synset('tamp_down.v.01'), Synset('pack.v.10'), Synset('compact.v.01'), Synset('pack.v.12'), Synset('pack.v.13')]), ('stunned', 'stun', [Synset('stun.v.01'), Synset('sandbag.v.03'), Synset('stun.v.03')]), ('surprised', 'surprised', [Synset('surprise.v.01'), Synset('surprise.v.02'), Synset('storm.v.05')]), ('cultivated', 'cultivate', [Synset('cultivate.v.01'), Synset('cultivate.v.02'), Synset('educate.v.03'), Synset('domesticate.v.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: ['impressed']
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['infused', 'fed', 'blessed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'instilled' in Wordnet first:  ['impressed', 'infused', 'fed', 'blessed', 'captured', 'reinforced', 'packed', 'stunned', 'surprised', 'cultivated']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: maniac
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'maniacs': ['sick_person', 'diseased_person', 'sufferer', 'fancier', 'enthusiast', 'unfortunate', 'unfortunate_person', 'admirer', 'adorer']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('freaks', 'freak', [Synset('freak.n.01'), Synset('addict.n.01')]), ('thugs', 'thug', [Synset('hood.n.01')]), ('nazis', 'nazi', [Synset('nazi.n.01'), Synset('nazi.n.02')]), ('monsters', 'monster', [Synset('monster.n.01'), Synset('giant.n.05'), Synset('freak.n.01'), Synset('monster.n.04'), Synset('monster.n.05')]), ('devotees', 'devotee', [Synset('fan.n.03')]), ('minions', 'minion', [Synset('minion.n.01')]), ('criminals', 'criminal', [Synset('criminal.n.01')]), ('operators', 'operator', [Synset('operator.n.01'), Synset('operator.n.02'), Synset('operator.n.03'), Synset('hustler.n.02'), Synset('operator.n.05')]), ('mania', 'mania', [Synset('mania.n.01'), Synset('mania.n.02')]), ('machines', 'machine', [Synset('machine.n.01'), Synset('machine.n.02'), Synset('machine.n.03'), Synset('machine.n.04'), Synset('machine.n.05'), Synset('car.n.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'maniacs' in Wordnet first:  ['freaks', 'thugs', 'nazis', 'monsters', 'devotees', 'minions', 'criminals', 'operators', 'mania', 'machines']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: observer
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'observers': ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('monitors', 'monitor', [Synset('proctor.n.01'), Synset('admonisher.n.01'), Synset('monitor.n.03'), Synset('monitor.n.04'), Synset('monitor.n.05'), Synset('monitor.n.06'), Synset('monitor.n.07')]), ('diplomats', 'diplomat', [Synset('diplomat.n.01'), Synset('diplomat.n.02')]), ('experts', 'expert', [Synset('expert.n.01')]), ('observations', 'observation', [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]), ('reporters', 'reporter', [Synset('reporter.n.01')]), ('witnesses', 'witness', [Synset('witness.n.01'), Synset('spectator.n.01'), Synset('witness.n.03'), Synset('witness.n.04'), Synset('witness.n.05')]), ('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('specialists', 'specialist', [Synset('specialist.n.01'), Synset('specialist.n.02')]), ('analysts', 'analyst', [Synset('analyst.n.01'), Synset('analyst.n.02'), Synset('analyst.n.03')]), ('police', 'police', [Synset('police.n.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: ['experts']
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['monitors', 'diplomats', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'observers' in Wordnet first:  ['experts', 'monitors', 'diplomats', 'observations', 'reporters', 'witnesses', 'officials', 'specialists', 'analysts', 'police']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: shrapnel
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'shrapnel': ['shell', 'ammunition', 'ammo']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('bullet', 'bullet', [Synset('bullet.n.01'), Synset('bullet_train.n.01'), Synset('fastball.n.01')]), ('stab', 'stab', []), ('gunshot', 'gunshot', [Synset('gunfire.n.01')]), ('knife', 'knife', [Synset('knife.n.01'), Synset('knife.n.02'), Synset('tongue.n.03')]), ('multiple', 'multiple', [Synset('multiple.a.01')]), ('stabbing', 'stab', [Synset('knife.v.01'), Synset('stab.v.02'), Synset('jab.v.01')]), ('severe', 'severe', [Synset('severe.s.01'), Synset('hard.s.04'), Synset('austere.s.01'), Synset('severe.s.04'), Synset('dangerous.s.02'), Synset('severe.s.06')]), ('superficial', 'superficial', [Synset('superficial.a.01'), Synset('superficial.a.02'), Synset('superficial.s.03')]), ('small', 'small', [Synset('small.a.01'), Synset('minor.s.10'), Synset('little.s.03'), Synset('small.s.04'), Synset('humble.s.01'), Synset('little.s.07'), Synset('little.s.05'), Synset('small.s.08'), Synset('modest.s.02'), Synset('belittled.s.01')]), ('minor', 'minor', [Synset('minor.a.01'), Synset('minor.a.02'), Synset('minor.a.03'), Synset('minor.a.04'), Synset('minor.a.05'), Synset('minor.a.06'), Synset('minor.a.07'), Synset('minor.s.08'), Synset('minor.s.09'), Synset('minor.s.10')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'shrapnel' in Wordnet first:  ['bullet', 'stab', 'gunshot', 'knife', 'multiple', 'stabbing', 'severe', 'superficial', 'small', 'minor']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: disguise
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'disguised': ['hide', 'conceal']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('masked', 'mask', [Synset('dissemble.v.02'), Synset('mask.v.02'), Synset('disguise.v.01'), Synset('mask.v.04'), Synset('mask.v.05')]), ('concealed', 'conceal', [Synset('hide.v.01'), Synset('conceal.v.02')]), ('clothed', 'clothe', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('posing', 'pose', [Synset('present.v.05'), Synset('model.v.03'), Synset('pose.v.03'), Synset('pose.v.04'), Synset('put.v.01'), Synset('perplex.v.01')]), ('dressed', 'dressed', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('clad', 'clad', [Synset('dress.v.02'), Synset('invest.v.03'), Synset('clothe.v.03')]), ('wrapped', 'wrap', [Synset('wrap.v.01'), Synset('wind.v.03'), Synset('envelop.v.01'), Synset('wrap.v.04')]), ('hidden', 'hide', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')]), ('dressing', 'dress', [Synset('dress.v.01'), Synset('dress.v.02'), Synset('dress.v.03'), Synset('dress.v.04'), Synset('preen.v.03'), Synset('dress.v.06'), Synset('dress.v.07'), Synset('trim.v.06'), Synset('dress.v.09'), Synset('dress.v.10'), Synset('snip.v.02'), Synset('dress.v.12'), Synset('dress.v.13'), Synset('dress.v.14'), Synset('dress.v.15'), Synset('dress.v.16')]), ('hiding', 'hiding', [Synset('hide.v.01'), Synset('hide.v.02'), Synset('shroud.v.01'), Synset('obscure.v.05')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: ['concealed', 'hidden', 'hiding']
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['masked', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'dressing']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'disguised' in Wordnet first:  ['concealed', 'hidden', 'hiding', 'masked', 'clothed', 'posing', 'dressed', 'clad', 'wrapped', 'dressing']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: offshoot
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'offshoot': ['consequence', 'effect', 'outcome', 'result', 'event', 'issue', 'upshot', 'phenomenon']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('extension', 'extension', [Synset('extension.n.01'), Synset('extension.n.02'), Synset('propagation.n.01'), Synset('extension.n.04'), Synset('extension.n.05'), Synset('extension.n.06'), Synset('reference.n.06'), Synset('extension.n.08'), Synset('extension.n.09'), Synset('extension.n.10'), Synset('elongation.n.02'), Synset('annex.n.01')]), ('affiliate', 'affiliate', [Synset('affiliate.n.01'), Synset('affiliate.n.02')]), ('outpost', 'outpost', [Synset('outstation.n.01'), Synset('frontier_settlement.n.01'), Synset('outpost.n.03')]), ('echo', 'echo', [Synset('echo.n.01'), Synset('echo.n.02'), Synset('echo.n.03'), Synset('echo.n.04'), Synset('echo.n.05'), Synset('echo.n.06')]), ('amalgamation', 'amalgamation', [Synset('amalgamation.n.01')]), ('ally', 'ally', [Synset('ally.n.01'), Synset('ally.n.02')]), ('aspect', 'aspect', [Synset('aspect.n.01'), Synset('aspect.n.02'), Synset('view.n.02'), Synset('aspect.n.04'), Synset('expression.n.01')]), ('assimilation', 'assimilation', [Synset('assimilation.n.01'), Synset('assimilation.n.02'), Synset('assimilation.n.03'), Synset('assimilation.n.04'), Synset('acculturation.n.03'), Synset('assimilation.n.06')]), ('adjunct', 'adjunct', [Synset('adjunct.n.01'), Synset('adjunct.n.02'), Synset('adjunct.n.03')]), ('analogue', 'analogue', [Synset('analogue.n.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'offshoot' in Wordnet first:  ['extension', 'affiliate', 'outpost', 'echo', 'amalgamation', 'ally', 'aspect', 'assimilation', 'adjunct', 'analogue']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: symphonic
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'symphonic': []
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('symphony', 'symphony', [Synset('symphony.n.01'), Synset('symphony_orchestra.n.01')]), ('orchestral', 'orchestral', [Synset('orchestral.a.01')]), ('melodic', 'melodic', [Synset('melodious.a.02'), Synset('melodic.a.02')]), ('operatic', 'operatic', [Synset('operatic.a.01')]), ('concerto', 'concerto', [Synset('concerto.n.01')]), ('classical', 'classical', [Synset('classical.a.01'), Synset('authoritative.s.02'), Synset('classical.a.03'), Synset('classical.s.04'), Synset('classical.s.05')]), ('musical', 'musical', [Synset('musical.a.01'), Synset('musical.a.02'), Synset('musical.a.03'), Synset('melodious.a.02')]), ('gothic', 'gothic', [Synset('gothic.n.01'), Synset('gothic.n.02'), Synset('gothic.n.03')]), ('choral', 'choral', [Synset('choral.a.01')]), ('concert', 'concert', [Synset('concert.n.01')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'symphonic' in Wordnet first:  ['symphony', 'orchestral', 'melodic', 'operatic', 'concerto', 'classical', 'musical', 'gothic', 'choral', 'concert']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: deploy
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'deploy': ['position', 'spread', 'distribute', 'put', 'set', 'place', 'pose', 'position', 'lay']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('dispatch', 'dispatch', [Synset('dispatch.v.01'), Synset('dispatch.v.02'), Synset('murder.v.01'), Synset('dispatch.v.04'), Synset('dispatch.v.05')]), ('activate', 'activate', [Synset('trip.v.04'), Synset('activate.v.02'), Synset('activate.v.03'), Synset('activate.v.04'), Synset('activate.v.05')]), ('utilize', 'utilize', [Synset('use.v.01'), Synset('utilize.v.02')]), ('station', 'station', [Synset('station.v.01')]), ('employ', 'employ', [Synset('use.v.01'), Synset('hire.v.01')]), ('use', 'use', [Synset('use.v.01'), Synset('use.v.02'), Synset('use.v.03'), Synset('use.v.04'), Synset('practice.v.04'), Synset('use.v.06')]), ('install', 'install', [Synset('install.v.01'), Synset('install.v.02'), Synset('install.v.03')]), ('launch', 'launch', [Synset('establish.v.01'), Synset('launch.v.02'), Synset('launch.v.03'), Synset('plunge.v.04'), Synset('launch.v.05'), Synset('launch.v.06')]), ('send', 'send', [Synset('send.v.01'), Synset('send.v.02'), Synset('mail.v.02'), Synset('transport.v.04'), Synset('station.v.01'), Synset('send.v.06'), Synset('commit.v.03'), Synset('air.v.03')]), ('commit', 'commit', [Synset('perpetrate.v.01'), Synset('give.v.18'), Synset('commit.v.03'), Synset('entrust.v.01'), Synset('invest.v.01'), Synset('commit.v.06')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: ['station', 'send', 'commit']
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'launch']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'deploy' in Wordnet first:  ['station', 'send', 'commit', 'dispatch', 'activate', 'utilize', 'employ', 'use', 'install', 'launch']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# complex_word_lemma: authority
#
# Substitute Ranking (SR), option 1-c, step a): complex_word_hypernyms_lemmas (1st and 2nd level hypernyms) for complex word 'authorities': ['control', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'expert', 'certainty', 'administrative_unit', 'administrative_body', 'permission', 'book', 'power', 'powerfulness', 'causal_agent', 'cause', 'causal_agency', 'organism', 'being', 'person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'cognitive_state', 'state_of_mind', 'unit', 'social_unit', 'approval', 'commendation', 'publication']
#
# Substitute Ranking (SR), option 1-c, step b): substitute lemmas synsets: [('officials', 'official', [Synset('official.n.01'), Synset('official.n.02')]), ('investigators', 'investigator', [Synset('research_worker.n.01'), Synset('investigator.n.02'), Synset('detective.n.01')]), ('prosecutors', 'prosecutor', [Synset('prosecutor.n.01')]), ('police', 'police', [Synset('police.n.01')]), ('magistrates', 'magistrate', [Synset('magistrate.n.01')]), ('officers', 'officer', [Synset('military_officer.n.01'), Synset('officeholder.n.01'), Synset('policeman.n.01'), Synset('officer.n.04')]), ('agencies', 'agency', [Synset('agency.n.01'), Synset('agency.n.02'), Synset('agency.n.03'), Synset('representation.n.04'), Synset('means.n.01')]), ('government', 'government', [Synset('government.n.01'), Synset('government.n.02'), Synset('government.n.03'), Synset('politics.n.02')]), ('courts', 'court', [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11')]), ('prisons', 'prison', [Synset('prison.n.01'), Synset('prison.n.02')])]
#
# Substitute Ranking (SR), option 1-c, step c): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word: []
#
# Substitute Ranking (SR), option 1-c, step c): other substitutes: ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# Substitute Ranking (SR) option 1c, step d): substitutes sorted on whether they belong to a synset that is the same as the first or second level hypernym of the complex word 'authorities' in Wordnet first:  ['officials', 'investigators', 'prosecutors', 'police', 'magistrates', 'officers', 'agencies', 'government', 'courts', 'prisons']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# SR_option1cShared1+2first_electralarge exported to csv in path './predictions/trial/SR_option1cShared1+2first_electralarge.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SR_option1cShared1+2first_electralarge.tsv --output_file ./output/trial/SR_option1cShared1+2first_electralarge.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SR_option1cShared1+2first_electralarge.tsv
# OUTPUT file = ./output/trial/SR_option1cShared1+2first_electralarge.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.4055
# MAP@5 = 0.3033
# MAP@10 = 0.1892
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6
