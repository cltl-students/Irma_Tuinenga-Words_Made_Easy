# %% [markdown]
# ## trial set:

# %% [markdown]
# ### parse sentences and obtain PoS for complex word in new file

# %%
import csv
from nltk import pos_tag, word_tokenize

def get_treebank_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return 'JJ'
    elif treebank_tag.startswith('V'):
        return 'VB'
    elif treebank_tag.startswith('N'):
        return 'NN'
    elif treebank_tag.startswith('R'):
        return 'RB'
    else:
        return ''

# open input file
with open('./data/trial/tsar2022_en_trial_none_no_noise.tsv', 'r') as infile:
    reader = csv.reader(infile, delimiter='\t')

    # open output file
    with open('./data/trial/trial_pos.tsv', 'w') as outfile:
        writer = csv.writer(outfile, delimiter='\t')
        
        # loop over rows in the input file
        for row in reader:
            sentence = row[0]
            complex_word = row[1]

            # tokenize sentence and get POS tags
            tagged_sentence = pos_tag(word_tokenize(sentence))

            # find the POS of the complex word and write the sentence, complex word, and the pos tag of the complex word to the output file
            for word, pos in tagged_sentence:
                if word.lower() == complex_word.lower():
                    # Get the Treebank POS and write to the output file
                    treebank_pos = get_treebank_pos(pos)
                    writer.writerow([sentence, complex_word, treebank_pos])
                    break

# %% [markdown]
# ## for CEFR-J dataset:

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrj_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv'\n")
# Out:
# substitutes with CEFR levels mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 2), ('voluntary', 5), ('optional', 4), ('enforced', 7), ('conditional', 5), ('obligatory', 7), ('forced', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 3), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('provided', 3), ('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 3), ('idiots', 4), ('terrorists', 3), ('criminals', 3), ('perpetrators', 7), ('creatures', 2), ('murderers', 3)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('creatures', 2), ('monsters', 3), ('terrorists', 3), ('criminals', 3), ('murderers', 3), ('idiots', 4), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('perpetrators', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('monitors', 3), ('inspectors', 4), ('investigators', 4), ('responders', 7), ('experts', 2), ('observations', 3), ('reporters', 1), ('witnesses', 3), ('supporters', 3), ('analysts', 4)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('reporters', 1), ('experts', 2), ('monitors', 3), ('observations', 3), ('witnesses', 3), ('supporters', 3), ('inspectors', 4), ('investigators', 4), ('analysts', 4), ('responders', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('projectile', 7), ('blast', 4), ('mortar', 4), ('shell', 4), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('blast', 4), ('mortar', 4), ('shell', 4), ('projectile', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 2), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('dressed', 2), ('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('extension', 4), ('affiliate', 7), ('arm', 3), ('offspring', 5), ('outpost', 7), ('echo', 6), ('evolution', 4), ('imprint', 7), ('branch', 3), ('adjunct', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('arm', 3), ('branch', 3), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('classical', 3), ('musical', 4), ('dramatic', 3), ('opera', 1), ('harmonic', 7), ('formal', 3), ('concert', 1), ('composition', 3), ('contemporary', 4), ('instrumental', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('opera', 1), ('concert', 1), ('classical', 3), ('dramatic', 3), ('formal', 3), ('composition', 3), ('musical', 4), ('contemporary', 4), ('harmonic', 7), ('instrumental', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 6), ('employ', 4), ('use', 1), ('install', 7), ('unleash', 7), ('operate', 2), ('send', 2)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('use', 1), ('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('install', 7), ('unleash', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('officials', 4), ('investigators', 4), ('prosecutors', 7), ('police', 2), ('officers', 1), ('agencies', 6), ('forces', 4), ('courts', 2), ('regulators', 7), ('counterparts', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officers', 1), ('police', 2), ('courts', 2), ('officials', 4), ('investigators', 4), ('forces', 4), ('agencies', 6), ('prosecutors', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrj_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.6

MAP@3 = 0.3777
MAP@5 = 0.2726
MAP@10 = 0.1618

Potential@3 = 0.8
Potential@5 = 0.8
Potential@10 = 1.0

Accuracy@1@top_gold_1 = 0.2
Accuracy@2@top_gold_1 = 0.4
Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('creatures', 2), ('monsters', 3), ('murderers', 3), ('idiots', 4), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7)]
#
# ranked_cefr_subs: [('reporters', 1), ('monitors', 3), ('observations', 3), ('supporters', 3), ('inspectors', 4), ('investigators', 4), ('witnesses', 4), ('analysts', 4), ('responders', 7), ('experts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('arm', 1), ('branch', 2), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('classical', 3), ('dramatic', 3), ('formal', 3), ('contemporary', 4), ('opera', 7), ('harmonic', 7), ('concert', 7), ('composition', 7), ('instrumental', 7)]
#
# ranked_cefr_subs: [('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('use', 7), ('install', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('officers', 1), ('police', 2), ('agencies', 2), ('forces', 2), ('courts', 2), ('investigators', 4), ('officials', 7), ('prosecutors', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_pos.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.7

MAP@3 = 0.3888
MAP@5 = 0.2413
MAP@10 = 0.1622

Potential@3 = 0.9
Potential@5 = 0.9
Potential@10 = 1.0

Accuracy@1@top_gold_1 = 0.3
Accuracy@2@top_gold_1 = 0.6
Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the 'cefrj_all_treebank.tsv' file, and
# If the POS tag of that word (as listed in 'cefrj_all_treebank.tsv') matches the POS tag of the substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('arm', 1), ('branch', 2), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('opera', 1), ('musical', 2), ('classical', 3), ('dramatic', 3), ('formal', 3), ('composition', 3), ('contemporary', 4), ('harmonic', 7), ('concert', 7), ('instrumental', 7)]
#
# ranked_cefr_subs: [('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('use', 7), ('install', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lem_possub_orig.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.5

MAP@3 = 0.3166
MAP@5 = 0.22
MAP@10 = 0.1466

Potential@3 = 0.9
Potential@5 = 0.9
Potential@10 = 1.0

Accuracy@1@top_gold_1 = 0.3
Accuracy@2@top_gold_1 = 0.7
Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)




# read the predictions file into a dataframe
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrj_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv'}\n")
# Out:
# substitutes with CEFR levels mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 2), ('essential', 3), ('voluntary', 5), ('optional', 4), ('prohibited', 7), ('free', 4), ('illegal', 2)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('necessary', 2), ('illegal', 2), ('essential', 3), ('optional', 4), ('free', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 4), ('captured', 7), ('reinforced', 7), ('packed', 4), ('stunned', 7), ('surprised', 2), ('cultivated', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('surprised', 2), ('impressed', 4), ('packed', 4), ('infused', 7), ('fed', 7), ('blessed', 7), ('captured', 7), ('reinforced', 7), ('stunned', 7), ('cultivated', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('freaks', 4), ('thugs', 7), ('nazis', 7), ('monsters', 3), ('devotees', 5), ('minions', 7), ('criminals', 3), ('operators', 4), ('mania', 7), ('machines', 1)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('machines', 1), ('monsters', 3), ('criminals', 3), ('freaks', 4), ('operators', 4), ('devotees', 5), ('thugs', 7), ('nazis', 7), ('minions', 7), ('mania', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('monitors', 3), ('diplomats', 4), ('experts', 2), ('observations', 3), ('reporters', 1), ('witnesses', 3), ('officials', 4), ('specialists', 3), ('analysts', 4), ('police', 2)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('reporters', 1), ('experts', 2), ('police', 2), ('monitors', 3), ('observations', 3), ('witnesses', 3), ('specialists', 3), ('diplomats', 4), ('officials', 4), ('analysts', 4)]
#
# substitutes with CEFR levels mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('knife', 1), ('multiple', 4), ('stabbing', 7), ('severe', 3), ('superficial', 5), ('small', 1), ('minor', 3)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('knife', 1), ('small', 1), ('bullet', 3), ('severe', 3), ('minor', 3), ('stab', 4), ('gunshot', 4), ('multiple', 4), ('superficial', 5), ('stabbing', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 2), ('clad', 7), ('wrapped', 7), ('hidden', 3), ('dressing', 7), ('hiding', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('dressed', 2), ('hidden', 3), ('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('clad', 7), ('wrapped', 7), ('dressing', 7), ('hiding', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('extension', 4), ('affiliate', 7), ('outpost', 7), ('echo', 6), ('amalgamation', 7), ('ally', 6), ('aspect', 3), ('assimilation', 6), ('adjunct', 7), ('analogue', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('aspect', 3), ('extension', 4), ('echo', 6), ('ally', 6), ('assimilation', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('symphony', 2), ('orchestral', 4), ('melodic', 7), ('operatic', 7), ('concerto', 5), ('classical', 3), ('musical', 4), ('gothic', 7), ('choral', 7), ('concert', 1)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('concert', 1), ('symphony', 2), ('classical', 3), ('orchestral', 4), ('musical', 4), ('concerto', 5), ('melodic', 7), ('operatic', 7), ('gothic', 7), ('choral', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('dispatch', 7), ('activate', 7), ('utilize', 6), ('station', 1), ('employ', 4), ('use', 1), ('install', 7), ('launch', 5), ('send', 2), ('commit', 3)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('station', 1), ('use', 1), ('send', 2), ('commit', 3), ('employ', 4), ('launch', 5), ('utilize', 6), ('dispatch', 7), ('activate', 7), ('install', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('officials', 4), ('investigators', 4), ('prosecutors', 7), ('police', 2), ('magistrates', 7), ('officers', 1), ('agencies', 6), ('government', 2), ('courts', 2), ('prisons', 3)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officers', 1), ('police', 2), ('government', 2), ('courts', 2), ('prisons', 3), ('officials', 4), ('investigators', 4), ('agencies', 6), ('prosecutors', 7), ('magistrates', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrj_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.4166
# MAP@5 = 0.314
# MAP@10 = 0.1889
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.1
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# ((each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('free', 1), ('necessary', 2), ('illegal', 2), ('essential', 3), ('optional', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('machines', 1), ('monsters', 3), ('operators', 4), ('devotees', 5), ('freaks', 7), ('thugs', 7), ('nazis', 7), ('minions', 7), ('criminals', 7), ('mania', 7)]
#
# ranked_cefr_subs: [('reporters', 1), ('police', 2), ('monitors', 3), ('observations', 3), ('specialists', 3), ('diplomats', 4), ('witnesses', 4), ('analysts', 4), ('experts', 7), ('officials', 7)]
#
# ranked_cefr_subs: [('small', 1), ('severe', 3), ('minor', 3), ('multiple', 4), ('superficial', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('aspect', 3), ('extension', 4), ('ally', 4), ('echo', 6), ('assimilation', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('classical', 3), ('orchestral', 4), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('send', 2), ('launch', 3), ('commit', 3), ('employ', 4), ('utilize', 6), ('dispatch', 7), ('activate', 7), ('station', 7), ('use', 7), ('install', 7)]
#
# ranked_cefr_subs: [('officers', 1), ('police', 2), ('agencies', 2), ('government', 2), ('courts', 2), ('prisons', 3), ('investigators', 4), ('officials', 7), ('prosecutors', 7), ('magistrates', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_pos.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.6

MAP@3 = 0.3388
MAP@5 = 0.2813
MAP@10 = 0.175

Potential@3 = 0.7
Potential@5 = 0.8
Potential@10 = 0.9

Accuracy@1@top_gold_1 = 0.3
Accuracy@2@top_gold_1 = 0.4
Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the 'cefrj_all_treebank.tsv' file, and
# If the POS tag of that word (as listed in 'cefrj_all_treebank.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('free', 1), ('necessary', 2), ('illegal', 2), ('essential', 3), ('optional', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# ranked_cefr_subs: [('police', 2), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('small', 1), ('severe', 3), ('minor', 3), ('multiple', 4), ('superficial', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('aspect', 3), ('extension', 4), ('ally', 4), ('echo', 6), ('assimilation', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('classical', 3), ('orchestral', 4), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('send', 2), ('launch', 3), ('commit', 3), ('employ', 4), ('utilize', 6), ('dispatch', 7), ('activate', 7), ('station', 7), ('use', 7), ('install', 7)]
#
# ranked_cefr_subs: [('government', 2), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3388
# MAP@5 = 0.2743
# MAP@10 = 0.1739
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ## for Uchida et al dataset:

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos','cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    #print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    
    
# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)

new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefruchida_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv'\n")
# Out:
# ranked substitutes based on their CEFR level mapped to numerical values: [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('creatures', 2), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('murderers', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('experts', 2), ('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('instrumental', 2), ('composition', 3), ('contemporary', 4), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('use', 2), ('send', 2), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('install', 7), ('unleash', 7), ('operate', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officials', 2), ('forces', 2), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefruchida_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.6

MAP@3 = 0.3666
MAP@5 = 0.2369
MAP@10 = 0.1567

Potential@3 = 0.6
Potential@5 = 0.8
Potential@10 = 1.0

Accuracy@1@top_gold_1 = 0.3
Accuracy@2@top_gold_1 = 0.6
Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('creatures', 2), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('murderers', 7)]
#
# ranked_cefr_subs: [('experts', 2), ('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('instrumental', 2), ('contemporary', 4), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7), ('composition', 7)]
#
# ranked_cefr_subs: [('send', 2), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('use', 7), ('install', 7), ('unleash', 7), ('operate', 7)]
#
# ranked_cefr_subs: [('forces', 2), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_pos.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3166
# MAP@5 = 0.208
# MAP@10 = 0.1459
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr/uchida_pos.tsv' file, and
# If the POS tag of that word (as listed in './cefr/uchida_pos.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match


    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])



# create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('instrumental', 2), ('composition', 3), ('contemporary', 4), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('send', 2), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('use', 7), ('install', 7), ('unleash', 7), ('operate', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3444
# MAP@5 = 0.2326
# MAP@10 = 0.1529
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)



# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv'\n")
# Out:
# substitutes with CEFR levels mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 2), ('essential', 3), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 1)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('machines', 1), ('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('monitors', 7), ('diplomats', 7), ('experts', 2), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 2), ('specialists', 3), ('analysts', 7), ('police', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('experts', 2), ('officials', 2), ('specialists', 3), ('monitors', 7), ('diplomats', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('analysts', 7), ('police', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('multiple', 4), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7), ('minor', 3)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('minor', 3), ('multiple', 4), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('aspect', 3), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('use', 2), ('install', 7), ('launch', 7), ('send', 2), ('commit', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('use', 2), ('send', 2), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('install', 7), ('launch', 7), ('commit', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('officials', 2), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officials', 2), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv

# %% [raw]
# ==========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3666
# MAP@5 = 0.2719
# MAP@10 = 0.1754
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])


# Create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('machines', 1), ('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7)]
#
# ranked_cefr_subs: [('experts', 2), ('specialists', 3), ('monitors', 7), ('diplomats', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('analysts', 7), ('police', 7)]
#
# ranked_cefr_subs: [('minor', 3), ('multiple', 4), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('send', 2), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('use', 7), ('install', 7), ('launch', 7), ('commit', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_pos.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3333
# MAP@5 = 0.2599
# MAP@10 = 0.17
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr/uchida_pos.tsv' file, and
# If the POS tag of that word (as listed in './cefr/uchida_pos.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr/uchida_pos.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
 
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])




# create a new dataframe from the new lists and write it to a new TSV file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# ranked_cefr_subs: [('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7), ('police', 7)]
#
# ranked_cefr_subs: [('minor', 3), ('multiple', 4), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('send', 2), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('use', 7), ('install', 7), ('launch', 7), ('commit', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.35
# MAP@5 = 0.2739
# MAP@10 = 0.1758
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### EFFLEX dataset: based on most frequent CEFR level:

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %% [markdown]
# #### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    #print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem.tsv'\n")
# Out:
# ranked substitutes based on their CEFR level mapped to numerical values: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('provided', 5), ('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('monsters', 2), ('hawks', 3), ('idiots', 4), ('criminals', 4), ('murderers', 4), ('nazis', 5), ('terrorists', 5), ('creatures', 5), ('thugs', 7), ('perpetrators', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('reporters', 1), ('inspectors', 2), ('observations', 3), ('witnesses', 4), ('monitors', 5), ('investigators', 5), ('responders', 5), ('experts', 5), ('supporters', 5), ('analysts', 5)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('stab', 2), ('shell', 4), ('bullet', 5), ('gunshot', 5), ('blast', 5), ('shotgun', 5), ('projectile', 7), ('mortar', 7), ('grenade', 7), ('ammunition', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('masked', 4), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('affiliate', 3), ('evolution', 4), ('extension', 5), ('arm', 5), ('echo', 5), ('branch', 5), ('offspring', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('concert', 2), ('classical', 3), ('musical', 3), ('opera', 3), ('formal', 4), ('composition', 4), ('dramatic', 5), ('contemporary', 5), ('instrumental', 5), ('harmonic', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('use', 3), ('dispatch', 4), ('mobilize', 5), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('operate', 5), ('send', 5), ('unleash', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('police', 2), ('agencies', 3), ('courts', 3), ('counterparts', 4), ('officials', 5), ('investigators', 5), ('officers', 5), ('forces', 5), ('prosecutors', 7), ('regulators', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrefflex_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2555
# MAP@5 = 0.1933
# MAP@10 = 0.132
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.0
# Accuracy@2@top_gold_1 = 0.2
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefr_efllex/EFLLex_mostfreq.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5}

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefr_efllex/EFLLex.tsv AND the POS tag of that word (in cefr_efllex/EFLLex.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('provided', 5), ('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('monsters', 2), ('hawks', 3), ('idiots', 4), ('terrorists', 4), ('murderers', 4), ('creatures', 5), ('thugs', 7), ('nazis', 7), ('criminals', 7), ('perpetrators', 7)]
#
# ranked_cefr_subs: [('reporters', 1), ('inspectors', 2), ('observations', 3), ('witnesses', 4), ('investigators', 5), ('responders', 5), ('experts', 5), ('supporters', 5), ('analysts', 5), ('monitors', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('arm', 2), ('evolution', 4), ('extension', 5), ('branch', 5), ('affiliate', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('formal', 4), ('dramatic', 5), ('contemporary', 5), ('instrumental', 5), ('opera', 7), ('harmonic', 7), ('concert', 7), ('composition', 7)]
#
# ranked_cefr_subs: [('dispatch', 4), ('mobilize', 5), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('operate', 5), ('send', 5), ('use', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('police', 2), ('agencies', 3), ('counterparts', 4), ('investigators', 5), ('officers', 5), ('forces', 5), ('officials', 7), ('prosecutors', 7), ('courts', 7), ('regulators', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex__mostfreq_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_pos.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_pos.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_pos.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.25
# MAP@5 = 0.199
# MAP@10 = 0.1328
#
# Potential@3 = 0.8
# Potential@5 = 1.0
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the ./cefr_efllex/EFLLex_mostfreq.tsv' file, and
# If the POS tag of that word (as listed in './cefr_efllex/EFLLex_mostfreq.tsv) matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('hawks', 3), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('arm', 2), ('evolution', 4), ('extension', 5), ('branch', 5), ('affiliate', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('opera', 3), ('formal', 4), ('composition', 4), ('dramatic', 5), ('contemporary', 5), ('instrumental', 5), ('harmonic', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('dispatch', 4), ('mobilize', 5), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('operate', 5), ('send', 5), ('use', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_possub_orig.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_mostfreq_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2611
# MAP@5 = 0.2096
# MAP@10 = 0.1382
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %% [markdown]
# #### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    #print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem.tsv'\n")
# Out:
# ranked substitutes based on their CEFR level mapped to numerical values: [('free', 1), ('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('essential', 5), ('illegal', 5), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('surprised', 3), ('impressed', 5), ('infused', 7), ('fed', 7), ('blessed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('cultivated', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('freaks', 2), ('monsters', 2), ('operators', 2), ('criminals', 4), ('nazis', 5), ('machines', 5), ('thugs', 7), ('devotees', 7), ('minions', 7), ('mania', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('reporters', 1), ('police', 2), ('observations', 3), ('witnesses', 4), ('specialists', 4), ('monitors', 5), ('experts', 5), ('officials', 5), ('analysts', 5), ('diplomats', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('small', 1), ('stab', 2), ('knife', 2), ('multiple', 3), ('bullet', 5), ('gunshot', 5), ('severe', 5), ('superficial', 5), ('minor', 5), ('stabbing', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('dressing', 2), ('masked', 4), ('hidden', 5), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hiding', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('affiliate', 3), ('ally', 4), ('extension', 5), ('echo', 5), ('aspect', 5), ('outpost', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('concert', 2), ('classical', 3), ('musical', 3), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('station', 1), ('use', 3), ('dispatch', 4), ('commit', 4), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('launch', 5), ('send', 5)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('police', 2), ('magistrates', 3), ('agencies', 3), ('courts', 3), ('officials', 5), ('investigators', 5), ('officers', 5), ('government', 5), ('prisons', 5), ('prosecutors', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrefflex_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex__mostfreq_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2555
# MAP@5 = 0.2113
# MAP@10 = 0.1493
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.0
# Accuracy@2@top_gold_1 = 0.0
# Accuracy@3@top_gold_1 = 0.2

# %% [markdown]
# ### with pos tag of the complex word taken into account:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in './cefr_efllex/EFLLex_mostfreq) matches the POS of the complex word

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5}

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in cefr_efllex/EFLLex.tsv AND the POS tag of that word (in cefr_efllex/EFLLex.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('essential', 5), ('illegal', 5), ('required', 7), ('mandated', 7), ('prohibited', 7), ('free', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('monsters', 2), ('operators', 2), ('freaks', 3), ('machines', 5), ('thugs', 7), ('nazis', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('mania', 7)]
#
# ranked_cefr_subs: [('reporters', 1), ('police', 2), ('observations', 3), ('witnesses', 4), ('specialists', 4), ('experts', 5), ('analysts', 5), ('monitors', 7), ('diplomats', 7), ('officials', 7)]
#
# ranked_cefr_subs: [('small', 1), ('multiple', 3), ('severe', 5), ('superficial', 5), ('minor', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('ally', 4), ('extension', 5), ('aspect', 5), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('dispatch', 4), ('commit', 4), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('launch', 5), ('send', 5), ('station', 7), ('use', 7)]
#
# ranked_cefr_subs: [('police', 2), ('magistrates', 3), ('agencies', 3), ('investigators', 5), ('officers', 5), ('government', 5), ('prisons', 5), ('officials', 7), ('prosecutors', 7), ('courts', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_pos.tsv

# %%
=========   EVALUATION config.=========
GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem.tsv
OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_pos.tsv
===============   RESULTS  =============

MAP@1/Potential@1/Precision@1 = 0.4

MAP@3 = 0.2055
MAP@5 = 0.2113
MAP@10 = 0.144

Potential@3 = 0.7
Potential@5 = 0.8
Potential@10 = 0.9

Accuracy@1@top_gold_1 = 0.1
Accuracy@2@top_gold_1 = 0.3
Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# #### with pos tag of substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_efllex/EFLLex_mostfreq.tsv' file, and
# If the POS tag of that word (as listed in ./cefr_efllex/EFLLex_mostfreq.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_mostfreq.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('voluntary', 4), ('optional', 4), ('mandatory', 5), ('necessary', 5), ('essential', 5), ('illegal', 5), ('required', 7), ('mandated', 7), ('prohibited', 7), ('free', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# ranked_cefr_subs: [('police', 2), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('small', 1), ('multiple', 3), ('severe', 5), ('superficial', 5), ('minor', 5), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('ally', 4), ('extension', 5), ('aspect', 5), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('classical', 3), ('musical', 3), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('dispatch', 4), ('commit', 4), ('activate', 5), ('utilize', 5), ('employ', 5), ('install', 5), ('launch', 5), ('send', 5), ('station', 7), ('use', 7)]
#
# ranked_cefr_subs: [('government', 5), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_possub_orig.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_mostfreq_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2277
# MAP@5 = 0.2186
# MAP@10 = 0.148
#
# Potential@3 = 0.6
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### EFFLEX dataset: based on weighted average across CEFR levels:

# %% [markdown]
# ### with pos tag of the substitutes taken into account:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_efllex/EFLLex_weighted.tsv' file, and
# If the POS tag of that word (as listed in './cefr_efllex/EFLLex.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_weighted.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in EFLLex_weighted.tsv AND the POS tag of that word (in EFLLex_weighted.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv'\n")
# Out:
# substitutes_cefr ranked on weighted average: [('optional', 4.0), ('voluntary', 4.030806623720507), ('necessary', 4.195970238761346), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# substitutes_cefr ranked on weighted average: [('hawks', 3.0), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# substitutes_cefr ranked on weighted average: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# substitutes_cefr ranked on weighted average: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# substitutes_cefr ranked on weighted average: [('arm', 2.9370921788689635), ('evolution', 4.495682840812356), ('branch', 4.736650890216304), ('extension', 5.0), ('affiliate', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('imprint', 7), ('adjunct', 7)]
#
# substitutes_cefr ranked on weighted average: [('classical', 2.479910974472549), ('musical', 2.8468569168465128), ('opera', 3.119009552739917), ('formal', 3.817295439689949), ('composition', 4.0), ('dramatic', 4.401183311947395), ('contemporary', 4.949262941378128), ('instrumental', 5.0), ('harmonic', 7), ('concert', 7)]
#
# substitutes_cefr ranked on weighted average: [('send', 3.1563799910692736), ('dispatch', 4.0), ('employ', 4.321393460601456), ('operate', 4.499347626487976), ('mobilize', 5.0), ('activate', 5.0), ('utilize', 5.0), ('install', 5.0), ('use', 7), ('unleash', 7)]
#
# substitutes_cefr ranked on weighted average: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrefflex_weighted_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3277
# MAP@5 = 0.2406
# MAP@10 = 0.1512
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_efllex/EFLLex_weighted.tsv', sep='\t', header=None, names=['word', 'pos', 'Weighted CEFR'])

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its weighted CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its weighted CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in EFLLex_weighted.tsv AND the POS tag of that word (in EFLLex_weighted.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['Weighted CEFR'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

    # sort the substitutes based on their weighted CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print (f"substitutes_cefr ranked on weighted average: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv'\n")
# Out:
# substitutes_cefr ranked on weighted average: [('optional', 4.0), ('voluntary', 4.030806623720507), ('necessary', 4.195970238761346), ('illegal', 4.309478791176403), ('essential', 4.922895620647522), ('mandatory', 5.0), ('required', 7), ('mandated', 7), ('prohibited', 7), ('free', 7)]
#
# substitutes_cefr ranked on weighted average: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# substitutes_cefr ranked on weighted average: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# substitutes_cefr ranked on weighted average: [('police', 2.822945866591008), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# substitutes_cefr ranked on weighted average: [('small', 2.7645901142535982), ('multiple', 3.0160404252976223), ('minor', 4.411037062545155), ('severe', 4.925980063195703), ('superficial', 5.0), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# substitutes_cefr ranked on weighted average: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# substitutes_cefr ranked on weighted average: [('ally', 3.5032308952461846), ('aspect', 4.63326666738738), ('extension', 5.0), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# substitutes_cefr ranked on weighted average: [('classical', 2.479910974472549), ('musical', 2.8468569168465128), ('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# substitutes_cefr ranked on weighted average: [('send', 3.1563799910692736), ('dispatch', 4.0), ('launch', 4.156138407011127), ('commit', 4.2196428245966215), ('employ', 4.321393460601456), ('activate', 5.0), ('utilize', 5.0), ('install', 5.0), ('station', 7), ('use', 7)]
#
# substitutes_cefr ranked on weighted average: [('government', 4.232236061235025), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrefflex_weighted_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2833
# MAP@5 = 0.246
# MAP@10 = 0.16
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### EVP dataset:

# %% [markdown]
# #### lemmatized:

# %% [markdown]
# #### for model SG_MA_SS_bsRobertalarge_robertabase: no changes (Dataset contains a lot of phrases iso words)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index(['word', 'pos'])['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)



# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    
    

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrevp_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv'\n")
# Out:
# substitutes with CEFR levels mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7), ('composition', 7), ('contemporary', 7), ('instrumental', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7), ('composition', 7), ('contemporary', 7), ('instrumental', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('use', 7), ('install', 7), ('unleash', 7), ('operate', 7), ('send', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('use', 7), ('install', 7), ('unleash', 7), ('operate', 7), ('send', 7)]
#
# substitutes with CEFR levels mapped to numerical values: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrevp_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2944
# MAP@5 = 0.2256
# MAP@10 = 0.1456
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.6
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# #### with complex word pos:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in './cefr_evp/evp_american_treebank.tsv AND the POS tag of that word ('./cefr_evp/evp_american_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 3), ('optional', 4), ('voluntary', 5), ('obligatory', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('filled', 3), ('provided', 3), ('inspired', 4), ('reassured', 5), ('stirred', 6), ('infused', 7), ('injected', 7), ('bolstered', 7), ('pumped', 7), ('seeded', 7)]
#
# ranked_cefr_subs: [('monsters', 3), ('criminals', 3), ('murderers', 3), ('idiots', 4), ('terrorists', 4), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('perpetrators', 7), ('creatures', 7)]
#
# ranked_cefr_subs: [('experts', 3), ('reporters', 3), ('monitors', 4), ('inspectors', 4), ('investigators', 4), ('observations', 4), ('witnesses', 4), ('analysts', 4), ('responders', 7), ('supporters', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('wrapped', 4), ('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7)]
#
# ranked_cefr_subs: [('arm', 1), ('branch', 3), ('extension', 4), ('evolution', 4), ('offspring', 6), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('dramatic', 4), ('formal', 4), ('contemporary', 4), ('classical', 6), ('opera', 7), ('harmonic', 7), ('concert', 7), ('composition', 7), ('instrumental', 7)]
#
# ranked_cefr_subs: [('use', 1), ('send', 1), ('employ', 3), ('install', 3), ('operate', 3), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('police', 2), ('officers', 3), ('agencies', 3), ('courts', 3), ('investigators', 4), ('forces', 4), ('counterparts', 5), ('prosecutors', 6), ('officials', 7), ('regulators', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_pos.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3944
# MAP@5 = 0.2586
# MAP@10 = 0.1625
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### with pos of substitutes:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_evp/evp_american_treebank.tsv' file, and
# If the POS tag of that word (as listed in './cefr_evp/evp_american_treebank.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('necessary', 3), ('optional', 4), ('voluntary', 5), ('obligatory', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('conditional', 7), ('forced', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked_cefr_subs: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked_cefr_subs: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked_cefr_subs: [('arm', 1), ('branch', 3), ('extension', 4), ('evolution', 4), ('offspring', 6), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('opera', 2), ('composition', 3), ('dramatic', 4), ('formal', 4), ('contemporary', 4), ('classical', 6), ('harmonic', 7), ('concert', 7), ('instrumental', 7)]
#
# ranked_cefr_subs: [('use', 1), ('send', 1), ('employ', 3), ('install', 3), ('operate', 3), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('unleash', 7)]
#
# ranked_cefr_subs: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrevp_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.3944
# MAP@5 = 0.2806
# MAP@10 = 0.1704
#
# Potential@3 = 0.9
# Potential@5 = 0.9
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.7
# Accuracy@3@top_gold_1 = 0.7

# %% [markdown]
# #### for model SG_MA_SS_bsRobertalarge_electralarge: no changes (dataset contains a lot of phrases iso words).

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the CEFR dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index(['word', 'pos'])['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)



# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    #print(f"substitutes with CEFR levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their CEFR level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    
    

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrevp_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv'\n")
# Out:
# ranked substitutes based on their CEFR level mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 7), ('essential', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7), ('police', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('multiple', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7), ('minor', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('aspect', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('use', 7), ('install', 7), ('launch', 7), ('send', 7), ('commit', 7)]
#
# ranked substitutes based on their CEFR level mapped to numerical values: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrevp_lem exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial//SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv --output_file ./output/trial//SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial//SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv
# OUTPUT file = ./output/trial//SS_bsRobertalarge_electralarge_SR_cefrevp_lem.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3055
# MAP@5 = 0.2633
# MAP@10 = 0.1698
#
# Potential@3 = 0.7
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# #### with complex word pos:
# (each lemmatized substitute is mapped to its CEFR level, and the specific CEFR level is included only if the part of speech (POS) of the word (in ./cefrj/cefrj_all_treebank.tsv) matches the POS of the complex word)

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# read the pos tags of complex words
complex_word_pos_df = pd.read_csv('./data/trial/trial_pos.tsv', sep='\t', header=None, names=['sentence', 'complex_word', 'pos'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]
    
    # Get the pos of the complex_word
    complex_word_pos = complex_word_pos_df[complex_word_pos_df['complex_word'] == complex_word]['pos'].values[0]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # if the lemmatized substitute word is found in './cefr_evp/evp_american_treebank.tsv AND the POS tag of that word ('./cefr_evp/evp_american_treebank.tsv) is the same as the POS tag of the complex word:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == complex_word_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match
         

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv'\n")
# Out:
# ranked_cefr_subs: [('free', 2), ('necessary', 3), ('essential', 3), ('optional', 4), ('illegal', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# ranked_cefr_subs: [('captured', 4), ('reinforced', 5), ('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('machines', 2), ('monsters', 3), ('criminals', 3), ('operators', 4), ('freaks', 7), ('thugs', 7), ('nazis', 7), ('devotees', 7), ('minions', 7), ('mania', 7)]
#
# ranked_cefr_subs: [('police', 2), ('experts', 3), ('reporters', 3), ('monitors', 4), ('diplomats', 4), ('observations', 4), ('witnesses', 4), ('specialists', 4), ('analysts', 4), ('officials', 7)]
#
# ranked_cefr_subs: [('small', 1), ('severe', 4), ('minor', 4), ('multiple', 5), ('superficial', 6), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('wrapped', 4), ('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('extension', 4), ('aspect', 4), ('ally', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('orchestral', 4), ('classical', 6), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('use', 1), ('send', 1), ('employ', 3), ('install', 3), ('launch', 4), ('commit', 4), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7)]
#
# ranked_cefr_subs: [('police', 2), ('officers', 3), ('agencies', 3), ('government', 3), ('courts', 3), ('prisons', 3), ('investigators', 4), ('prosecutors', 6), ('officials', 7), ('magistrates', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv'

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_pos.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.3
#
# MAP@3 = 0.3333
# MAP@5 = 0.2469
# MAP@10 = 0.16
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.2
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# #### with pos of substitutes:

# %% [markdown]
# If the lemmatized version of the substitute is found in the './cefr_evp/evp_american_treebank.tsv' file, and
# If the POS tag of that word (as listed in './cefr_evp/evp_american_treebank.tsv') matches the POS tag of the original substitute word (as determined by parsing the sentence where the complex word is replaced by the original substitute).

# %%
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

# initialize the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# read the CEFR levels file into a dataframe
cefr_df = pd.read_csv('./cefr_evp/evp_american_treebank.tsv', sep='\t', header=None, names=['word', 'pos', 'cefr'])

# define a mapping from CEFR levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the CEFR levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its CEFR level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, lemmatizer.lemmatize(sub)) for sub in substitutes]

    # map each lemmatized substitute to its CEFR level, or to a high number if it doesn't have a CEFR level
    substitutes_cefr = []
    for original, lemmatized in substitutes_lemmatized:
        # get the pos of the original substitute by parsing the sentence where the complex word is replaced by the substitute
        sub_sentence = sentence.replace(complex_word, original)
        sub_pos = dict(pos_tag(word_tokenize(sub_sentence))).get(original)
        # if the lemmatized substitute equals a word that is found in cefrj_all_treebank.tsv AND the POS tag of that word (in cefrj_all_treebank.tsv) is the same as the POS tag of the substitute:
        if lemmatized in cefr_df['word'].values and cefr_df[cefr_df['word'] == lemmatized]['pos'].values[0] == sub_pos:
            substitutes_cefr.append((original, cefr_df[cefr_df['word'] == lemmatized]['cefr'].values[0]))
        else:
            substitutes_cefr.append((original, 7))  # assign a high value if it doesn't have a CEFR level or if pos don't match

         
   

    # sort the substitutes based on their CEFR levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked_cefr_subs: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv'\n")
# Out:
# ranked_cefr_subs: [('free', 2), ('necessary', 3), ('essential', 3), ('optional', 4), ('illegal', 4), ('voluntary', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('prohibited', 7)]
#
# ranked_cefr_subs: [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
#
# ranked_cefr_subs: [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
#
# ranked_cefr_subs: [('police', 2), ('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7)]
#
# ranked_cefr_subs: [('small', 1), ('severe', 4), ('minor', 4), ('multiple', 5), ('superficial', 6), ('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('stabbing', 7)]
#
# ranked_cefr_subs: [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
#
# ranked_cefr_subs: [('extension', 4), ('aspect', 4), ('ally', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
#
# ranked_cefr_subs: [('musical', 2), ('orchestral', 4), ('classical', 6), ('symphony', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
#
# ranked_cefr_subs: [('use', 1), ('send', 1), ('employ', 3), ('install', 3), ('launch', 4), ('commit', 4), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7)]
#
# ranked_cefr_subs: [('government', 3), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('courts', 7), ('prisons', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrevp_lem_possub_orig.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.4055
# MAP@5 = 0.3053
# MAP@10 = 0.1838
#
# Potential@3 = 0.7
# Potential@5 = 0.7
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5
