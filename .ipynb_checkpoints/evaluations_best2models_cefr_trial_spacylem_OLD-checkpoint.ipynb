# %% [markdown]
# ## trial set:

# %% [markdown]
# ## for CEFR-J dataset:

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %%
import pandas as pd
import numpy as np


# read the cefr levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all.tsv', sep='\t', header=None, names=['word', 'cefr'])

# define a mapping from cefr levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the cefr levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# convert the cefr dataframe into a dictionary for efficient lookups
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)


# for each row in the predictions dataframe, map each substitute to its cefr level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # map each substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(sub, cefr_dict.get(sub, 7)) for sub in substitutes]
    print(f"substitutes with cefr levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their cefr level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrj exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj.tsv'}\n")
# Out:
# substitutes with cefr levels mapped to numerical values: [('mandatory', 7), ('required', 7), ('mandated', 7), ('necessary', 2), ('voluntary', 5), ('optional', 4), ('enforced', 7), ('conditional', 5), ('obligatory', 7), ('forced', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('necessary', 2), ('optional', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('required', 7), ('mandated', 7), ('enforced', 7), ('obligatory', 7), ('forced', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 3), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('provided', 3), ('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('projectile', 7), ('blast', 4), ('mortar', 4), ('shell', 4), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('blast', 4), ('mortar', 4), ('shell', 4), ('projectile', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 2), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('dressed', 2), ('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('extension', 4), ('affiliate', 7), ('arm', 3), ('offspring', 5), ('outpost', 7), ('echo', 6), ('evolution', 4), ('imprint', 7), ('branch', 3), ('adjunct', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('arm', 3), ('branch', 3), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('classical', 3), ('musical', 4), ('dramatic', 3), ('opera', 1), ('harmonic', 7), ('formal', 3), ('concert', 1), ('composition', 3), ('contemporary', 4), ('instrumental', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('opera', 1), ('concert', 1), ('classical', 3), ('dramatic', 3), ('formal', 3), ('composition', 3), ('musical', 4), ('contemporary', 4), ('harmonic', 7), ('instrumental', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 6), ('employ', 4), ('use', 1), ('install', 7), ('unleash', 7), ('operate', 2), ('send', 2)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('use', 1), ('operate', 2), ('send', 2), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('install', 7), ('unleash', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 2), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('police', 2), ('officials', 7), ('investigators', 7), ('prosecutors', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrj exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_dataset_cefrj.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_dataset_cefrj.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_dataset_cefrj.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_dataset_cefrj.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.3555
# MAP@5 = 0.2483
# MAP@10 = 0.1524
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### lemmatized:WITH SPACY

# %%
import pandas as pd
import spacy

# Load the English SpaCy model
nlp = spacy.load('en_core_web_sm')

# read the cefr levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all.tsv', sep='\t', header=None, names=['word', 'cefr'])

# define a mapping from cefr levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the cefr levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# lemmatize the words and then convert the cefr dataframe into a dictionary for efficient lookups
cefr_df['word'] = cefr_df['word'].apply(lambda x: nlp(x)[0].lemma_)
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its cefr level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, nlp(sub)[0].lemma_) for sub in substitutes]
    
    # map each lemmatized substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with cefr levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their cefr level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv'\n")
# Out:
# substitutes with cefr levels mapped to numerical values: [('mandatory', 7), ('required', 3), ('mandated', 7), ('necessary', 2), ('voluntary', 5), ('optional', 4), ('enforced', 4), ('conditional', 5), ('obligatory', 7), ('forced', 4)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('necessary', 2), ('required', 3), ('optional', 4), ('enforced', 4), ('forced', 4), ('voluntary', 5), ('conditional', 5), ('mandatory', 7), ('mandated', 7), ('obligatory', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('infused', 7), ('filled', 3), ('injected', 3), ('bolstered', 7), ('stirred', 3), ('inspired', 3), ('provided', 3), ('pumped', 3), ('seeded', 2), ('reassured', 5)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('seeded', 2), ('filled', 3), ('injected', 3), ('stirred', 3), ('inspired', 3), ('provided', 3), ('pumped', 3), ('reassured', 5), ('infused', 7), ('bolstered', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 3), ('idiots', 4), ('terrorists', 3), ('criminals', 3), ('perpetrators', 7), ('creatures', 2), ('murderers', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('creatures', 2), ('monsters', 3), ('terrorists', 3), ('criminals', 3), ('murderers', 3), ('idiots', 4), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('perpetrators', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('monitors', 3), ('inspectors', 4), ('investigators', 4), ('responders', 7), ('experts', 2), ('observations', 3), ('reporters', 1), ('witnesses', 3), ('supporters', 3), ('analysts', 4)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('reporters', 1), ('experts', 2), ('monitors', 3), ('observations', 3), ('witnesses', 3), ('supporters', 3), ('inspectors', 4), ('investigators', 4), ('analysts', 4), ('responders', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('projectile', 7), ('blast', 4), ('mortar', 4), ('shell', 4), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('blast', 4), ('mortar', 4), ('shell', 4), ('projectile', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('masked', 4), ('concealed', 4), ('clothed', 1), ('cloaked', 5), ('posing', 5), ('dressed', 2), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('clothed', 1), ('dressed', 2), ('wrapped', 3), ('masked', 4), ('concealed', 4), ('cloaked', 5), ('posing', 5), ('clad', 7), ('veiled', 7), ('shrouded', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('extension', 4), ('affiliate', 7), ('arm', 2), ('offspring', 5), ('outpost', 7), ('echo', 6), ('evolution', 4), ('imprint', 7), ('branch', 3), ('adjunct', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('arm', 2), ('branch', 3), ('extension', 4), ('evolution', 4), ('offspring', 5), ('echo', 6), ('affiliate', 7), ('outpost', 7), ('imprint', 7), ('adjunct', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('classical', 2), ('musical', 4), ('dramatic', 3), ('opera', 1), ('harmonic', 7), ('formal', 3), ('concert', 1), ('composition', 3), ('contemporary', 4), ('instrumental', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('opera', 1), ('concert', 1), ('classical', 2), ('dramatic', 3), ('formal', 3), ('composition', 3), ('musical', 4), ('contemporary', 4), ('harmonic', 7), ('instrumental', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 6), ('employ', 4), ('use', 3), ('install', 3), ('unleash', 7), ('operate', 2), ('send', 2)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('operate', 2), ('send', 2), ('use', 3), ('install', 3), ('employ', 4), ('utilize', 6), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('unleash', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('officials', 4), ('investigators', 4), ('prosecutors', 7), ('police', 2), ('officers', 1), ('agencies', 6), ('forces', 4), ('courts', 2), ('regulators', 7), ('counterparts', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('officers', 1), ('police', 2), ('courts', 2), ('officials', 4), ('investigators', 4), ('forces', 4), ('agencies', 6), ('prosecutors', 7), ('regulators', 7), ('counterparts', 7)]
#
# SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefrj_lemSpacy.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2888
# MAP@5 = 0.2503
# MAP@10 = 0.1452
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.1
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %% [markdown]
# lemmatized with spacy

# %%
import pandas as pd
import spacy

# Load the English SpaCy model
nlp = spacy.load('en_core_web_sm')

# read the cefr levels file into a dataframe
cefr_df = pd.read_csv('./cefrj/cefrj_all.tsv', sep='\t', header=None, names=['word', 'cefr'])

# define a mapping from cefr levels to numerical values
cefr_level_mapping = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}

# map the cefr levels in the dataframe to numerical values using the mapping
cefr_df['cefr'] = cefr_df['cefr'].map(cefr_level_mapping)

# lemmatize the words and then convert the cefr dataframe into a dictionary for efficient lookups
cefr_df['word'] = cefr_df['word'].apply(lambda x: nlp(x)[0].lemma_)
cefr_dict = cefr_df.set_index('word')['cefr'].to_dict()

# read the predictions file into a dataframe
pred_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# for each row in the predictions dataframe, map each substitute to its cefr level, sort them, and save them into a new list
new_lists = []
for i, row in pred_df.iterrows():
    sentence = row[0]
    complex_word = row[1]
    substitutes = row[2:12]

    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, nlp(sub)[0].lemma_) for sub in substitutes]
    
    # map each lemmatized substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    print(f"substitutes with cefr levels mapped to numerical values: {substitutes_cefr}\n")

    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(f"ranked substitutes based on their cefr level mapped to numerical values: {ranked_cefr_subs}\n")

    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv'\n")
# Out:
# substitutes with cefr levels mapped to numerical values: [('mandatory', 7), ('required', 3), ('mandated', 7), ('necessary', 2), ('essential', 3), ('voluntary', 5), ('optional', 4), ('prohibited', 4), ('free', 4), ('illegal', 2)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('necessary', 2), ('illegal', 2), ('required', 3), ('essential', 3), ('optional', 4), ('prohibited', 4), ('free', 4), ('voluntary', 5), ('mandatory', 7), ('mandated', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('infused', 7), ('fed', 7), ('blessed', 3), ('impressed', 4), ('captured', 3), ('reinforced', 4), ('packed', 4), ('stunned', 3), ('surprised', 2), ('cultivated', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('surprised', 2), ('blessed', 3), ('captured', 3), ('stunned', 3), ('cultivated', 3), ('impressed', 4), ('reinforced', 4), ('packed', 4), ('infused', 7), ('fed', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('freaks', 4), ('thugs', 7), ('nazis', 7), ('monsters', 3), ('devotees', 5), ('minions', 7), ('criminals', 3), ('operators', 4), ('mania', 7), ('machines', 1)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('machines', 1), ('monsters', 3), ('criminals', 3), ('freaks', 4), ('operators', 4), ('devotees', 5), ('thugs', 7), ('nazis', 7), ('minions', 7), ('mania', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('monitors', 3), ('diplomats', 4), ('experts', 2), ('observations', 3), ('reporters', 1), ('witnesses', 3), ('officials', 4), ('specialists', 3), ('analysts', 4), ('police', 2)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('reporters', 1), ('experts', 2), ('police', 2), ('monitors', 3), ('observations', 3), ('witnesses', 3), ('specialists', 3), ('diplomats', 4), ('officials', 4), ('analysts', 4)]
#
# substitutes with cefr levels mapped to numerical values: [('bullet', 3), ('stab', 4), ('gunshot', 4), ('knife', 1), ('multiple', 4), ('stabbing', 4), ('severe', 3), ('superficial', 5), ('small', 1), ('minor', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('knife', 1), ('small', 1), ('bullet', 3), ('severe', 3), ('minor', 3), ('stab', 4), ('gunshot', 4), ('multiple', 4), ('stabbing', 4), ('superficial', 5)]
#
# substitutes with cefr levels mapped to numerical values: [('masked', 4), ('concealed', 4), ('clothed', 1), ('posing', 5), ('dressed', 2), ('clad', 7), ('wrapped', 3), ('hidden', 1), ('dressing', 2), ('hiding', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('clothed', 1), ('hidden', 1), ('dressed', 2), ('dressing', 2), ('wrapped', 3), ('masked', 4), ('concealed', 4), ('posing', 5), ('clad', 7), ('hiding', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('extension', 4), ('affiliate', 7), ('outpost', 7), ('echo', 6), ('amalgamation', 7), ('ally', 6), ('aspect', 3), ('assimilation', 6), ('adjunct', 7), ('analogue', 7)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('aspect', 3), ('extension', 4), ('echo', 6), ('ally', 6), ('assimilation', 6), ('affiliate', 7), ('outpost', 7), ('amalgamation', 7), ('adjunct', 7), ('analogue', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('symphony', 2), ('orchestral', 4), ('melodic', 7), ('operatic', 7), ('concerto', 5), ('classical', 2), ('musical', 4), ('gothic', 7), ('choral', 7), ('concert', 1)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('concert', 1), ('symphony', 2), ('classical', 2), ('orchestral', 4), ('musical', 4), ('concerto', 5), ('melodic', 7), ('operatic', 7), ('gothic', 7), ('choral', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('dispatch', 7), ('activate', 7), ('utilize', 6), ('station', 1), ('employ', 4), ('use', 3), ('install', 3), ('launch', 5), ('send', 2), ('commit', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('station', 1), ('send', 2), ('use', 3), ('install', 3), ('commit', 3), ('employ', 4), ('launch', 5), ('utilize', 6), ('dispatch', 7), ('activate', 7)]
#
# substitutes with cefr levels mapped to numerical values: [('officials', 4), ('investigators', 4), ('prosecutors', 7), ('police', 2), ('magistrates', 7), ('officers', 1), ('agencies', 6), ('government', 2), ('courts', 2), ('prisons', 3)]
#
# ranked substitutes based on their cefr level mapped to numerical values: [('officers', 1), ('police', 2), ('government', 2), ('courts', 2), ('prisons', 3), ('officials', 4), ('investigators', 4), ('agencies', 6), ('prosecutors', 7), ('magistrates', 7)]
#
# SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefrj_lemSpacy.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.3388
# MAP@5 = 0.2363
# MAP@10 = 0.1653
#
# Potential@3 = 0.6
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.0
# Accuracy@2@top_gold_1 = 0.1
# Accuracy@3@top_gold_1 = 0.3

# %% [markdown]
# ## for Uchida et al dataset:

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_robertabase:

# %%
import pandas as pd

# read cefr file
cefr_df = pd.read_csv('./cefr/uchida.tsv', sep='\t', header=None, usecols=range(21))

# read prediction file
predictions_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# convert CEFR levels to numerical values for ranking
cefr_level_mapping = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}

# create a dictionary with substitute as key and its corresponding CEFR level as value
cefr_dict = {}
for i in range(3, 21, 3):
    for word, cefr_level, label in zip(cefr_df[i], cefr_df[i + 1], cefr_df[i + 2]):
        if label == 1:  # only consider the substitute if the label is 1
            cefr_dict[word] = cefr_level_mapping.get(cefr_level, 7)  # default to 7 if CEFR level is not found

# create a new list to store the sorted substitutes with their sentence and complex word
new_lists = []

# map each substitute to its CEFR level and sort them
for sentence, complex_word, *substitutes in predictions_df.values:
    # map each substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(sub, cefr_dict.get(sub, 7)) for sub in substitutes]
    
    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(ranked_cefr_subs)
    
    # append the sorted list of substitutes to the new lists
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])


# # create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefruchida exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv'}\n")
# Out:
# [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
# [('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('seeded', 7), ('reassured', 7)]
# [('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('creatures', 7), ('murderers', 7)]
# [('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
# [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
# [('masked', 7), ('concealed', 7), ('clothed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
# [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
# [('instrumental', 2), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7), ('composition', 7), ('contemporary', 7)]
# [('use', 1), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('install', 7), ('unleash', 7), ('operate', 7), ('send', 7)]
# [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
# SS_bsRobertalarge_robertabase_SR_cefruchida exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv'}

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.3555
# MAP@5 = 0.2353
# MAP@10 = 0.1538
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import spacy

# Load the English SpaCy model
nlp = spacy.load('en_core_web_sm')

# read cefr file
cefr_df = pd.read_csv('./cefr/uchida.tsv', sep='\t', header=None, usecols=range(21))

# read prediction file
predictions_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_robertabase.tsv', sep='\t', header=None)

# convert CEFR levels to numerical values for ranking
cefr_level_mapping = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}

# create a dictionary with substitute (lemmatized) as key and its corresponding CEFR level as value
cefr_dict = {}
for i in range(3, 21, 3):
    for word, cefr_level, label in zip(cefr_df[i], cefr_df[i + 1], cefr_df[i + 2]):
        if label == 1:  # only consider the substitute if the label is 1
            lemmatized_word = nlp(word)[0].lemma_
            cefr_dict[lemmatized_word] = cefr_level_mapping.get(cefr_level, 7)  # default to 7 if CEFR level is not found

# create a new list to store the sorted substitutes with their sentence and complex word
new_lists = []

# map each substitute to its CEFR level and sort them
for sentence, complex_word, *substitutes in predictions_df.values:
    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, nlp(sub)[0].lemma_) for sub in substitutes]
    
    # map each lemmatized substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    
    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(ranked_cefr_subs)
    
    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])

# create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv'\n")
# Out:
# [('necessary', 2), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('enforced', 7), ('conditional', 7), ('obligatory', 7), ('forced', 7)]
# [('seeded', 2), ('infused', 7), ('filled', 7), ('injected', 7), ('bolstered', 7), ('stirred', 7), ('inspired', 7), ('provided', 7), ('pumped', 7), ('reassured', 7)]
# [('creatures', 2), ('thugs', 7), ('nazis', 7), ('hawks', 7), ('monsters', 7), ('idiots', 7), ('terrorists', 7), ('criminals', 7), ('perpetrators', 7), ('murderers', 7)]
# [('experts', 2), ('monitors', 7), ('inspectors', 7), ('investigators', 7), ('responders', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('supporters', 7), ('analysts', 7)]
# [('bullet', 7), ('stab', 7), ('gunshot', 7), ('projectile', 7), ('blast', 7), ('mortar', 7), ('shell', 7), ('grenade', 7), ('shotgun', 7), ('ammunition', 7)]
# [('clothed', 1), ('masked', 7), ('concealed', 7), ('cloaked', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('veiled', 7), ('shrouded', 7), ('wrapped', 7)]
# [('extension', 7), ('affiliate', 7), ('arm', 7), ('offspring', 7), ('outpost', 7), ('echo', 7), ('evolution', 7), ('imprint', 7), ('branch', 7), ('adjunct', 7)]
# [('instrumental', 2), ('classical', 7), ('musical', 7), ('dramatic', 7), ('opera', 7), ('harmonic', 7), ('formal', 7), ('concert', 7), ('composition', 7), ('contemporary', 7)]
# [('use', 1), ('mobilize', 7), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('employ', 7), ('install', 7), ('unleash', 7), ('operate', 7), ('send', 7)]
# [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('officers', 7), ('agencies', 7), ('forces', 7), ('courts', 7), ('regulators', 7), ('counterparts', 7)]
# SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv'

# %%
python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv --output_file ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv

# %% [markdown]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.2888
# MAP@5 = 0.2003
# MAP@10 = 0.1356
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# ### for model SG_MA_SS_bsRobertalarge_electralarge:

# %%
import pandas as pd

# read cefr file
cefr_df = pd.read_csv('./cefr/uchida.tsv', sep='\t', header=None, usecols=range(21))

# read prediction file
predictions_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# convert CEFR levels to numerical values for ranking
cefr_level_mapping = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}

# create a dictionary with substitute as key and its corresponding CEFR level as value
cefr_dict = {}
for i in range(3, 21, 3):
    for word, cefr_level, label in zip(cefr_df[i], cefr_df[i + 1], cefr_df[i + 2]):
        if label == 1:  # only consider the substitute if the label is 1
            cefr_dict[word] = cefr_level_mapping.get(cefr_level, 7)  # default to 7 if CEFR level is not found

# create a new list to store the sorted substitutes with their sentence and complex word
new_lists = []

# map each substitute to its CEFR level and sort them
for sentence, complex_word, *substitutes in predictions_df.values:
    # map each substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(sub, cefr_dict.get(sub, 7)) for sub in substitutes]
    
    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(ranked_cefr_subs)
    
    # append the sorted list of substitutes to the new lists
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])


# # create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefruchida exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv'}\n")
# Out:
# [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
# [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
# [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
# [('monitors', 7), ('diplomats', 7), ('experts', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('specialists', 7), ('analysts', 7), ('police', 7)]
# [('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('multiple', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7), ('minor', 7)]
# [('masked', 7), ('concealed', 7), ('clothed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('dressing', 7), ('hiding', 7)]
# [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
# [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
# [('use', 1), ('launch', 3), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('install', 7), ('send', 7), ('commit', 7)]
# [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
# SS_bsRobertalarge_electralarge_SR_cefruchida exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida.tsv --output_file ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida.tsv
# OUTPUT file = ./output/trial/SS_bsRobertalarge_electralarge_SR_cefruchida.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.7
#
# MAP@3 = 0.4055
# MAP@5 = 0.2993
# MAP@10 = 0.1885
#
# Potential@3 = 0.8
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# ### lemmatized:

# %%
import pandas as pd
import spacy

# Load the English SpaCy model
nlp = spacy.load('en_core_web_sm')

# read cefr file
cefr_df = pd.read_csv('./cefr/uchida.tsv', sep='\t', header=None, usecols=range(21))

# read prediction file
predictions_df = pd.read_csv('./predictions/trial/SG_MA_SS_bsRobertalarge_electralarge.tsv', sep='\t', header=None)

# convert CEFR levels to numerical values for ranking
cefr_level_mapping = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6}

# create a dictionary with substitute (lemmatized) as key and its corresponding CEFR level as value
cefr_dict = {}
for i in range(3, 21, 3):
    for word, cefr_level, label in zip(cefr_df[i], cefr_df[i + 1], cefr_df[i + 2]):
        if label == 1:  # only consider the substitute if the label is 1
            lemmatized_word = nlp(word)[0].lemma_
            cefr_dict[lemmatized_word] = cefr_level_mapping.get(cefr_level, 7)  # default to 7 if CEFR level is not found

# create a new list to store the sorted substitutes with their sentence and complex word
new_lists = []

# map each substitute to its CEFR level and sort them
for sentence, complex_word, *substitutes in predictions_df.values:
    # lemmatize the substitutes but keep original form too
    substitutes_lemmatized = [(sub, nlp(sub)[0].lemma_) for sub in substitutes]
    
    # map each lemmatized substitute to its cefr level, or to a high number if it doesn't have a cefr level
    substitutes_cefr = [(original, cefr_dict.get(lemmatized, 7)) for original, lemmatized in substitutes_lemmatized]
    
    # sort the substitutes based on their cefr levels
    ranked_cefr_subs = sorted(substitutes_cefr, key=lambda x: x[1])
    print(ranked_cefr_subs)
    
    # append the sorted list of substitutes to the new lists, keeping original form
    new_lists.append([sentence, complex_word] + [sub for sub, _ in ranked_cefr_subs])
    
    
# # create a new dataframe from the new lists and write it to a new tsv file
new_df = pd.DataFrame(new_lists)
new_df.to_csv('./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy.tsv', sep='\t', index=False, header=False)
print("SS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv'}\n")
# Out:
# [('necessary', 2), ('essential', 3), ('mandatory', 7), ('required', 7), ('mandated', 7), ('voluntary', 7), ('optional', 7), ('prohibited', 7), ('free', 7), ('illegal', 7)]
# [('infused', 7), ('fed', 7), ('blessed', 7), ('impressed', 7), ('captured', 7), ('reinforced', 7), ('packed', 7), ('stunned', 7), ('surprised', 7), ('cultivated', 7)]
# [('freaks', 7), ('thugs', 7), ('nazis', 7), ('monsters', 7), ('devotees', 7), ('minions', 7), ('criminals', 7), ('operators', 7), ('mania', 7), ('machines', 7)]
# [('experts', 2), ('specialists', 3), ('monitors', 7), ('diplomats', 7), ('observations', 7), ('reporters', 7), ('witnesses', 7), ('officials', 7), ('analysts', 7), ('police', 7)]
# [('bullet', 7), ('stab', 7), ('gunshot', 7), ('knife', 7), ('multiple', 7), ('stabbing', 7), ('severe', 7), ('superficial', 7), ('small', 7), ('minor', 7)]
# [('clothed', 1), ('dressing', 1), ('masked', 7), ('concealed', 7), ('posing', 7), ('dressed', 7), ('clad', 7), ('wrapped', 7), ('hidden', 7), ('hiding', 7)]
# [('aspect', 3), ('extension', 7), ('affiliate', 7), ('outpost', 7), ('echo', 7), ('amalgamation', 7), ('ally', 7), ('assimilation', 7), ('adjunct', 7), ('analogue', 7)]
# [('symphony', 7), ('orchestral', 7), ('melodic', 7), ('operatic', 7), ('concerto', 7), ('classical', 7), ('musical', 7), ('gothic', 7), ('choral', 7), ('concert', 7)]
# [('use', 1), ('launch', 3), ('dispatch', 7), ('activate', 7), ('utilize', 7), ('station', 7), ('employ', 7), ('install', 7), ('send', 7), ('commit', 7)]
# [('officials', 7), ('investigators', 7), ('prosecutors', 7), ('police', 7), ('magistrates', 7), ('officers', 7), ('agencies', 7), ('government', 7), ('courts', 7), ('prisons', 7)]
# SS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy exported to csv in path './predictions/trial/SS_bsRobertalarge_robertabase_SR_cefruchida_lemSpacy.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy.tsv --output_file ./output/trial/SSS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy.tsv

# %% [raw]
# ========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/SS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy.tsv
# OUTPUT file = ./output/trial/SSS_bsRobertalarge_electralarge_SR_cefruchida_lemSpacy.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.35
# MAP@5 = 0.26
# MAP@10 = 0.1745
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.4
