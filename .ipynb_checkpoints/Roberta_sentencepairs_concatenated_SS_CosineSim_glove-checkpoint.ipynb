# %% [markdown]
# ### Cosine similarity -semantics

# %% [markdown]
# #### importing, loading and reading files

# %%
import torch
from transformers import RobertaTokenizer, RobertaForMaskedLM
import pandas as pd
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer # however, does not work for verbs
import spacy

import numpy as np
import gensim.downloader as api

# %%
# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])


# For SG step: load RoBERTa model and tokenizer
model = RobertaForMaskedLM.from_pretrained('roberta-base') # not enough memory for roberta-large
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# for SS step: use spacy for lemmatizing in steps a-d  (as wordnet lemmatizer does not work for verbs)
nlp = spacy.load("en_core_web_sm")

# For SS step: load the GloVe embeddings (this can take some minutes)
glove = api.load("glove-wiki-gigaword-100")

# %% [markdown]
# #### word embeddings with glove:

# %%
# based on glove, with Wordnet lemmatizer (does not seem to work for verbs):


# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>")

    ## concatenate the sentence with the complex word and the sentence with the masked word, by using RoBERTa's separator token to create one string of both sentencesion 
    sentences_concat = f"{sentence} {tokenizer.sep_token} {sentence_masked_word}"

    ## tokenize the concatenated sentence
    sentences_concat_tokenized = tokenizer.encode(sentences_concat, return_tensors='pt')

    ## find the masked word in the tokenized sentence
    mask_location = torch.where(sentences_concat_tokenized == tokenizer.mask_token_id)[1].item()

    ## generate predictions for the masked word (forward pass not needed for predictions, only for training)
    with torch.no_grad():
        outputs = model(sentences_concat_tokenized)
        predictions = outputs.logits

    ## get the top-k substitutes based on the predicted logits
    top_k = 30
    top_tokens = torch.topk(predictions[0, mask_location], top_k).indices

    ## decode the top-k substitutes, lowercase and print them
    substitutes = [tokenizer.decode(token.item()).strip().lower() for token in top_tokens]
    print(f"SG step: generated substitutes: {substitutes}\n")
    
    

    # 2. Substitute Selection (SS): 
    
    # a) remove duplicates from the substitute list 
    
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"SS step: a) substitute list without duplicates: {substitutes_no_dupl}\n")

    # b) remove duplicates and inflected forms of the complex word from the substitute list
   
    ## Lemmmatize the complex word with the WordNet lemmatizer, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same (will be deleted)
    lemmatizer = WordNetLemmatizer()
    complex_word_lemma = lemmatizer.lemmatize(complex_word)
    print(f"Complex_word_lemma: {complex_word_lemma}\n")
    
    ## remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        if lemmatizer.lemmatize(substitute) != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"SS step: b) substitute list without duplicates and inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")

    # c) remove antonyms of the complex word from the substitute list
    
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute:
                    print(f"Antonym removed: {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    print(f"SS step: c): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
       
       
    # d) perform ranking of substitutes_no_dupl_complex_word_no_antonym on semantic similarity
    # compute the semantic similarity between the complex word and each substitute
    
    similarities = []
    for substitute in substitutes_no_dupl_complex_word_no_antonym:
        if substitute.lower() in glove.key_to_index:
            similarity = glove.similarity(complex_word.lower(), substitute.lower())
        else:
            print(f"Word not found in embeddings (will be put at the end of the list): {substitute}")
            similarity = -1.0  # set similarity to a negative value to indicate it should be put at the very end of the list
        similarities.append(similarity)

    # rank the substitutes based on their semantic similarity with the complex word
    substitutes_ranked = [x for _, x in sorted(zip(similarities, substitutes_no_dupl_complex_word_no_antonym), reverse=True)]
    print(f"SS step: d) substitute list ranked based on semantic similarity: {substitutes_ranked}\n")
    print('----------------------------------------------------------------------------------------------------------------------')
    print()
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# SG step: generated substitutes: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion', 'mandatory']
#
# SS step: a) substitute list without duplicates: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# Complex_word_lemma: compulsory
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: c): substitute list without antonyms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: d) substitute list ranked based on semantic similarity: ['obligatory', 'mandatory', 'voluntary', 'requirement', 'required', 'mandated', 'routine', 'enforced', 'uniform', 'customary', 'prerequisite', 'optional', 'universal', 'necessary', 'conditional', 'forced', 'involuntary', 'available', 'obliged', 'sufficient', 'feasible', 'contingent', 'possible', 'forthcoming', 'compelled', 'obligated', 'compulsion', 'indispensable']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# SG step: generated substitutes: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'filled', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: a) substitute list without duplicates: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Complex_word_lemma: instilled
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: c): substitute list without antonyms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Word not found in embeddings (will be put at the end of the list): illed
# SS step: d) substitute list ranked based on semantic similarity: ['stirred', 'undermined', 'infused', 'impressed', 'endowed', 'reassured', 'vested', 'bolstered', 'inspired', 'reinforced', 'intoxicated', 'injected', 'enriched', 'implanted', 'misled', 'stunned', 'augmented', 'inflated', 'pumped', 'invested', 'furnished', 'struck', 'filled', 'imb', 'supplied', 'seeded', 'provided', 'inst', 'illed']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #34-3 "War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# SG step: generated substitutes: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: a) substitute list without duplicates: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Complex_word_lemma: maniac
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: c): substitute list without antonyms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Word not found in embeddings (will be put at the end of the list): riors
# Word not found in embeddings (will be put at the end of the list): igans
# SS step: d) substitute list ranked based on semantic similarity: ['idiots', 'nerds', 'thugs', 'fascists', 'monsters', 'fools', 'murderers', 'criminals', 'beasts', 'killers', 'gangs', 'drums', 'villains', 'nazis', 'demons', 'machines', 'fighters', 'extremists', 'parasites', 'bosses', 'children', 'hawks', 'planes', 'lords', 'devils', 'heads', 'doctors', 'riors', 'igans']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# SG step: generated substitutes: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: a) substitute list without duplicates: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# Complex_word_lemma: observer
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: c): substitute list without antonyms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: d) substitute list ranked based on semantic similarity: ['journalists', 'monitors', 'experts', 'analysts', 'participants', 'commentators', 'parties', 'reporters', 'supporters', 'activists', 'outsiders', 'authorities', 'witnesses', 'inspectors', 'protesters', 'investigators', 'spectators', 'demonstrators', 'residents', 'observing', 'cameras', 'visitors', 'viewers', 'observations', 'followers', 'eyes', 'responders', 'observes']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# SG step: generated substitutes: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: a) substitute list without duplicates: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Complex_word_lemma: shrapnel
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: c): substitute list without antonyms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Word not found in embeddings (will be put at the end of the list): rapnel
# SS step: d) substitute list ranked based on semantic similarity: ['gunshot', 'bullet', 'bullets', 'grenade', 'stab', 'mortar', 'piercing', 'blast', 'bomb', 'rocket', 'stray', 'shell', 'projectile', 'unidentified', 'explosive', 'ammunition', 'shotgun', 'fragmentation', 'radiation', 'torpedo', 'stun', 'cartridge', 'pillow', 'insurgent', 'microscopic', 'crippling', 'similar', 'terrorist', 'slug', 'rapnel']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# SG step: generated substitutes: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: a) substitute list without duplicates: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# Complex_word_lemma: disguised
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: c): substitute list without antonyms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# Word not found in embeddings (will be put at the end of the list): camoufl
# SS step: d) substitute list ranked based on semantic similarity: ['disguise', 'veiled', 'masked', 'concealed', 'posing', 'dressed', 'hidden', 'camouflage', 'hid', 'clothed', 'cloaked', 'hiding', 'armed', 'clad', 'smuggled', 'posed', 'draped', 'wrapped', 'described', 'known', 'staged', 'trained', 'decorated', 'shrouded', 'covered', 'presented', 'buried', 'marked', 'camoufl']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# SG step: generated substitutes: ['off', 'extension', 'opposite', 'outpost', 'off', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: a) substitute list without duplicates: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# Complex_word_lemma: offshoot
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: c): substitute list without antonyms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: d) substitute list ranked based on semantic similarity: ['ideology', 'affiliate', 'overthrow', 'archetype', 'imprint', 'independent', 'branch', 'alternative', 'element', 'outpost', 'opposition', 'evolution', 'arm', 'embrace', 'offspring', 'expansion', 'indication', 'example', 'out', 'outside', 'echo', 'adjunct', 'extension', 'off', 'instance', 'overhaul', 'opposite', 'extend', 'upset']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# SG step: generated substitutes: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: a) substitute list without duplicates: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Complex_word_lemma: symphonic
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: c): substitute list without antonyms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Word not found in embeddings (will be put at the end of the list): onic
# SS step: d) substitute list ranked based on semantic similarity: ['orchestra', 'piano', 'classical', 'opera', 'composition', 'musical', 'concert', 'jazz', 'music', 'instrumental', 'lyric', 'composing', 'vocal', 'harmonic', 'singing', 'contemporary', 'trumpet', 'keyboard', 'dramatic', 'modern', 'sonic', 'popular', 'english', 'formal', 'early', 'technical', 'standard', 'major', 'sym', 'onic']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# SG step: generated substitutes: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'deploy', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: a) substitute list without duplicates: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# Complex_word_lemma: deploy
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: c): substitute list without antonyms of the complex word: ['deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: d) substitute list ranked based on semantic similarity: ['deploying', 'deployed', 'deployment', 'equip', 'send', 'withdraw', 'install', 'mobilize', 'dispatch', 'recruit', 'operate', 'employ', 'activate', 'utilize', 'unleash', 'engage', 'locate', 'adopt', 'use', 'summon', 'construct', 'commit', 'reserve', 'possess', 'transport', 'cultivate', 'expend', 'ploy']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #35-14 UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# SG step: generated substitutes: ['authorities', 'officials', 'authorities', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'authorities', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: a) substitute list without duplicates: ['authorities', 'officials', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# Complex_word_lemma: authority
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: c): substitute list without antonyms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: d) substitute list ranked based on semantic similarity: ['officials', 'police', 'investigators', 'prosecutors', 'officers', 'agencies', 'suspects', 'sources', 'victims', 'regulators', 'forces', 'concerns', 'intelligence', 'assistance', 'demonstrators', 'individuals', 'institutions', 'administrators', 'counterparts', 'figures', 'detainees', 'ministers', 'affairs', 'superiors', 'jurisdictions', 'entities']
#
# ----------------------------------------------------------------------------------------------------------------------

# %%
# try removing non-matching pos tags with wordnet: does not work, for example as wordnet cannot lemmatize verbs
#used spacy's lemmatizer here


# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>")

    ## concatenate the sentence with the complex word and the sentence with the masked word, by using RoBERTa's separator token to create one string of both sentencesion 
    sentences_concat = f"{sentence} {tokenizer.sep_token} {sentence_masked_word}"

    ## tokenize the concatenated sentence
    sentences_concat_tokenized = tokenizer.encode(sentences_concat, return_tensors='pt')

    ## find the masked word in the tokenized sentence
    mask_location = torch.where(sentences_concat_tokenized == tokenizer.mask_token_id)[1].item()

    ## generate predictions for the masked word (forward pass not needed for predictions, only for training)
    with torch.no_grad():
        outputs = model(sentences_concat_tokenized)
        predictions = outputs.logits

    ## get the top-k substitutes based on the predicted logits
    top_k = 30
    top_tokens = torch.topk(predictions[0, mask_location], top_k).indices

    ## decode the top-k substitutes, lowercase and print them
    substitutes = [tokenizer.decode(token.item()).strip().lower() for token in top_tokens]
    print(f"SG step: generated substitutes: {substitutes}\n")
    
    

    # 2. Substitute Selection (SS): 
    
    # a) remove duplicates from the substitute list 
    
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"SS step: a) substitute list without duplicates: {substitutes_no_dupl}\n")

   
    # b) remove duplicates and inflected forms of the complex word from the substitute list
    complex_word_doc = nlp(complex_word)
    complex_word_lemma = complex_word_doc[0].lemma_
    print(f"Complex_word_lemma: {complex_word_lemma}\n")

    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        substitute_doc = nlp(substitute)
        substitute_lemma = substitute_doc[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)

    print(f"SS step: b) substitute list without duplicates and inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")

    # c) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute:
                    print(f"Antonym removed: {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    print(f"SS step: c): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")

    # d) in the last substitute list, remove noun versions of the complex word if the complex word is a verb, and remove verb versions of the complex word if the complex word is a noun
    substitutes_no_dupl_complex_word_no_antonym_no_matchpos = []
    complex_word_synsets = wn.synsets(complex_word_lemma)
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}")
    if complex_word_synsets:
        complex_word_pos = complex_word_synsets[0].pos()
        print (f"complex_word_pos: {complex_word_pos}")
        for substitute in substitutes_no_dupl_complex_word_no_antonym:
            substitute_doc = nlp(substitute)
            substitute_lemma = substitute_doc[0].lemma_
            print(f"substitute_lemma for substitute '{substitute}': {substitute_lemma}")
            substitute_synsets = wn.synsets(substitute_lemma)
            if substitute_synsets:
                substitute_pos = substitute_synsets[0].pos()
                print(f"substitute_pos: {substitute_pos}")
                if complex_word_pos == 'v' and substitute_pos != 'v':
                    print(f"Non-matching pos removed: {substitute}")
                elif complex_word_pos == 'n' and substitute_pos != 'n':
                    print(f"Non-matching pos removed: {substitute}")
                elif complex_word_pos == 's' and substitute_pos == 'n': #to keep e.g., verbs like required as subs for compulsory
                    print(f"Non-matching pos removed: {substitute}")    
                elif complex_word_pos == 'a' and substitute_pos == 'n': #to keep e.g., verbs like required as subs for compulsory
                    print(f"Non-matching pos removed: {substitute}")       
                else:
                    substitutes_no_dupl_complex_word_no_antonym_no_matchpos.append(substitute)
            else:
                substitutes_no_dupl_complex_word_no_antonym_no_matchpos.append(substitute)
    else:
        substitutes_no_dupl_complex_word_no_antonym_no_matchpos = substitutes_no_dupl_complex_word_no_antonym
    print(f"SS step: d) substitute list without non-matching pos tags: {substitutes_no_dupl_complex_word_no_antonym_no_matchpos}\n")
    

    
    # e) perform ranking of substitutes_no_dupl_complex_word_no_antonym_no_matchpos on semantic similarity
    # compute the semantic similarity between the complex word and each substitute
    
    similarities = []
    for substitute in substitutes_no_dupl_complex_word_no_antonym_no_matchpos:
        if substitute.lower() in glove.key_to_index:
            similarity = glove.similarity(complex_word.lower(), substitute.lower())
        else:
            print(f"Word not found in embeddings (will be put at the end of the list): {substitute}")
            similarity = -1.0  # set similarity to a negative value to indicate it should be put at the very end of the list
        similarities.append(similarity)

    # rank the substitutes based on their semantic similarity with the complex word
    substitutes_ranked = [x for _, x in sorted(zip(similarities, substitutes_no_dupl_complex_word_no_antonym_no_matchpos), reverse=True)]
    print(f"SS step: e) substitute list ranked based on semantic similarity: {substitutes_ranked}\n")
    print('----------------------------------------------------------------------------------------------------------------------')
    print()
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# SG step: generated substitutes: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion', 'mandatory']
#
# SS step: a) substitute list without duplicates: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# Complex_word_lemma: compulsory
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: c): substitute list without antonyms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# complex_word_lemma for complex word 'compulsory': compulsory
# complex_word_pos: s
# substitute_lemma for substitute 'mandatory': mandatory
# substitute_pos: n
# Non-matching pos removed: mandatory
# substitute_lemma for substitute 'obligatory': obligatory
# substitute_pos: a
# substitute_lemma for substitute 'voluntary': voluntary
# substitute_pos: n
# Non-matching pos removed: voluntary
# substitute_lemma for substitute 'required': require
# substitute_pos: v
# substitute_lemma for substitute 'optional': optional
# substitute_pos: a
# substitute_lemma for substitute 'obliged': oblige
# substitute_pos: v
# substitute_lemma for substitute 'uniform': uniform
# substitute_pos: n
# Non-matching pos removed: uniform
# substitute_lemma for substitute 'necessary': necessary
# substitute_pos: n
# Non-matching pos removed: necessary
# substitute_lemma for substitute 'available': available
# substitute_pos: a
# substitute_lemma for substitute 'mandated': mandate
# substitute_pos: n
# Non-matching pos removed: mandated
# substitute_lemma for substitute 'sufficient': sufficient
# substitute_pos: a
# substitute_lemma for substitute 'routine': routine
# substitute_pos: n
# Non-matching pos removed: routine
# substitute_lemma for substitute 'forced': force
# substitute_pos: n
# Non-matching pos removed: forced
# substitute_lemma for substitute 'customary': customary
# substitute_pos: s
# substitute_lemma for substitute 'prerequisite': prerequisite
# substitute_pos: n
# Non-matching pos removed: prerequisite
# substitute_lemma for substitute 'feasible': feasible
# substitute_pos: s
# substitute_lemma for substitute 'indispensable': indispensable
# substitute_pos: a
# substitute_lemma for substitute 'forthcoming': forthcoming
# substitute_pos: s
# substitute_lemma for substitute 'universal': universal
# substitute_pos: n
# Non-matching pos removed: universal
# substitute_lemma for substitute 'requirement': requirement
# substitute_pos: n
# Non-matching pos removed: requirement
# substitute_lemma for substitute 'involuntary': involuntary
# substitute_pos: a
# substitute_lemma for substitute 'obligated': obligate
# substitute_pos: v
# substitute_lemma for substitute 'compelled': compel
# substitute_pos: v
# substitute_lemma for substitute 'conditional': conditional
# substitute_pos: s
# substitute_lemma for substitute 'enforced': enforce
# substitute_pos: v
# substitute_lemma for substitute 'contingent': contingent
# substitute_pos: n
# Non-matching pos removed: contingent
# substitute_lemma for substitute 'possible': possible
# substitute_pos: n
# Non-matching pos removed: possible
# substitute_lemma for substitute 'compulsion': compulsion
# substitute_pos: n
# Non-matching pos removed: compulsion
# SS step: d) substitute list without non-matching pos tags: ['obligatory', 'required', 'optional', 'obliged', 'available', 'sufficient', 'customary', 'feasible', 'indispensable', 'forthcoming', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced']
#
# SS step: e) substitute list ranked based on semantic similarity: ['obligatory', 'required', 'enforced', 'customary', 'optional', 'conditional', 'involuntary', 'available', 'obliged', 'sufficient', 'feasible', 'forthcoming', 'compelled', 'obligated', 'indispensable']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# SG step: generated substitutes: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'filled', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: a) substitute list without duplicates: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Complex_word_lemma: instill
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: c): substitute list without antonyms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# complex_word_lemma for complex word 'instilled': instill
# complex_word_pos: v
# substitute_lemma for substitute 'infused': infuse
# substitute_pos: v
# substitute_lemma for substitute 'injected': inject
# substitute_pos: v
# substitute_lemma for substitute 'endowed': endow
# substitute_pos: v
# substitute_lemma for substitute 'illed': ille
# substitute_lemma for substitute 'inst': inst
# substitute_pos: s
# Non-matching pos removed: inst
# substitute_lemma for substitute 'furnished': furnish
# substitute_pos: v
# substitute_lemma for substitute 'supplied': supply
# substitute_pos: n
# Non-matching pos removed: supplied
# substitute_lemma for substitute 'bolstered': bolster
# substitute_pos: n
# Non-matching pos removed: bolstered
# substitute_lemma for substitute 'implanted': implant
# substitute_pos: n
# Non-matching pos removed: implanted
# substitute_lemma for substitute 'impressed': impress
# substitute_pos: n
# Non-matching pos removed: impressed
# substitute_lemma for substitute 'reinforced': reinforce
# substitute_pos: v
# substitute_lemma for substitute 'invested': invest
# substitute_pos: v
# substitute_lemma for substitute 'provided': provide
# substitute_pos: v
# substitute_lemma for substitute 'filled': fill
# substitute_pos: n
# Non-matching pos removed: filled
# substitute_lemma for substitute 'reassured': reassure
# substitute_pos: v
# substitute_lemma for substitute 'undermined': undermine
# substitute_pos: v
# substitute_lemma for substitute 'pumped': pump
# substitute_pos: n
# Non-matching pos removed: pumped
# substitute_lemma for substitute 'struck': strike
# substitute_pos: n
# Non-matching pos removed: struck
# substitute_lemma for substitute 'augmented': augment
# substitute_pos: v
# substitute_lemma for substitute 'enriched': enrich
# substitute_pos: v
# substitute_lemma for substitute 'stirred': stir
# substitute_pos: n
# Non-matching pos removed: stirred
# substitute_lemma for substitute 'vested': vest
# substitute_pos: n
# Non-matching pos removed: vested
# substitute_lemma for substitute 'imb': imb
# substitute_lemma for substitute 'intoxicated': intoxicate
# substitute_pos: v
# substitute_lemma for substitute 'seeded': seed
# substitute_pos: n
# Non-matching pos removed: seeded
# substitute_lemma for substitute 'misled': mislead
# substitute_pos: v
# substitute_lemma for substitute 'stunned': stun
# substitute_pos: v
# substitute_lemma for substitute 'inspired': inspire
# substitute_pos: v
# substitute_lemma for substitute 'inflated': inflate
# substitute_pos: v
# SS step: d) substitute list without non-matching pos tags: ['infused', 'injected', 'endowed', 'illed', 'furnished', 'reinforced', 'invested', 'provided', 'reassured', 'undermined', 'augmented', 'enriched', 'imb', 'intoxicated', 'misled', 'stunned', 'inspired', 'inflated']
#
# Word not found in embeddings (will be put at the end of the list): illed
# SS step: e) substitute list ranked based on semantic similarity: ['undermined', 'infused', 'endowed', 'reassured', 'inspired', 'reinforced', 'intoxicated', 'injected', 'enriched', 'misled', 'stunned', 'augmented', 'inflated', 'invested', 'furnished', 'imb', 'provided', 'illed']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #34-3 "War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# SG step: generated substitutes: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: a) substitute list without duplicates: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Complex_word_lemma: maniac
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: c): substitute list without antonyms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# complex_word_lemma for complex word 'maniacs': maniac
# complex_word_pos: n
# substitute_lemma for substitute 'criminals': criminal
# substitute_pos: n
# substitute_lemma for substitute 'riors': rior
# substitute_lemma for substitute 'hawks': hawk
# substitute_pos: n
# substitute_lemma for substitute 'heads': head
# substitute_pos: n
# substitute_lemma for substitute 'killers': killer
# substitute_pos: n
# substitute_lemma for substitute 'gangs': gang
# substitute_pos: n
# substitute_lemma for substitute 'lords': lord
# substitute_pos: n
# substitute_lemma for substitute 'thugs': thug
# substitute_pos: n
# substitute_lemma for substitute 'devils': devil
# substitute_pos: n
# substitute_lemma for substitute 'drums': drum
# substitute_pos: n
# substitute_lemma for substitute 'murderers': murderer
# substitute_pos: n
# substitute_lemma for substitute 'fighters': fighter
# substitute_pos: n
# substitute_lemma for substitute 'monsters': monster
# substitute_pos: n
# substitute_lemma for substitute 'fools': fool
# substitute_pos: n
# substitute_lemma for substitute 'villains': villain
# substitute_pos: n
# substitute_lemma for substitute 'idiots': idiot
# substitute_pos: n
# substitute_lemma for substitute 'machines': machine
# substitute_pos: n
# substitute_lemma for substitute 'demons': demon
# substitute_pos: n
# substitute_lemma for substitute 'doctors': doctor
# substitute_pos: n
# substitute_lemma for substitute 'planes': plane
# substitute_pos: n
# substitute_lemma for substitute 'igans': igan
# substitute_lemma for substitute 'bosses': boss
# substitute_pos: n
# substitute_lemma for substitute 'nazis': nazi
# substitute_pos: n
# substitute_lemma for substitute 'beasts': beast
# substitute_pos: n
# substitute_lemma for substitute 'fascists': fascist
# substitute_pos: n
# substitute_lemma for substitute 'children': child
# substitute_pos: n
# substitute_lemma for substitute 'nerds': nerd
# substitute_pos: n
# substitute_lemma for substitute 'extremists': extremist
# substitute_pos: n
# substitute_lemma for substitute 'parasites': parasite
# substitute_pos: n
# SS step: d) substitute list without non-matching pos tags: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Word not found in embeddings (will be put at the end of the list): riors
# Word not found in embeddings (will be put at the end of the list): igans
# SS step: e) substitute list ranked based on semantic similarity: ['idiots', 'nerds', 'thugs', 'fascists', 'monsters', 'fools', 'murderers', 'criminals', 'beasts', 'killers', 'gangs', 'drums', 'villains', 'nazis', 'demons', 'machines', 'fighters', 'extremists', 'parasites', 'bosses', 'children', 'hawks', 'planes', 'lords', 'devils', 'heads', 'doctors', 'riors', 'igans']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# SG step: generated substitutes: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: a) substitute list without duplicates: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# Complex_word_lemma: observer
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: c): substitute list without antonyms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# complex_word_lemma for complex word 'observers': observer
# complex_word_pos: n
# substitute_lemma for substitute 'monitors': monitor
# substitute_pos: n
# substitute_lemma for substitute 'spectators': spectator
# substitute_pos: n
# substitute_lemma for substitute 'witnesses': witness
# substitute_pos: n
# substitute_lemma for substitute 'observes': observe
# substitute_pos: v
# Non-matching pos removed: observes
# substitute_lemma for substitute 'visitors': visitor
# substitute_pos: n
# substitute_lemma for substitute 'viewers': viewer
# substitute_pos: n
# substitute_lemma for substitute 'reporters': reporter
# substitute_pos: n
# substitute_lemma for substitute 'inspectors': inspector
# substitute_pos: n
# substitute_lemma for substitute 'commentators': commentator
# substitute_pos: n
# substitute_lemma for substitute 'investigators': investigator
# substitute_pos: n
# substitute_lemma for substitute 'participants': participant
# substitute_pos: n
# substitute_lemma for substitute 'analysts': analyst
# substitute_pos: n
# substitute_lemma for substitute 'cameras': camera
# substitute_pos: n
# substitute_lemma for substitute 'outsiders': outsider
# substitute_pos: n
# substitute_lemma for substitute 'demonstrators': demonstrator
# substitute_pos: n
# substitute_lemma for substitute 'activists': activist
# substitute_pos: n
# substitute_lemma for substitute 'journalists': journalist
# substitute_pos: n
# substitute_lemma for substitute 'experts': expert
# substitute_pos: n
# substitute_lemma for substitute 'authorities': authority
# substitute_pos: n
# substitute_lemma for substitute 'observations': observation
# substitute_pos: n
# substitute_lemma for substitute 'eyes': eye
# substitute_pos: n
# substitute_lemma for substitute 'supporters': supporter
# substitute_pos: n
# substitute_lemma for substitute 'observing': observe
# substitute_pos: v
# Non-matching pos removed: observing
# substitute_lemma for substitute 'residents': resident
# substitute_pos: n
# substitute_lemma for substitute 'protesters': protester
# substitute_pos: n
# substitute_lemma for substitute 'responders': responder
# substitute_pos: n
# substitute_lemma for substitute 'parties': party
# substitute_pos: n
# substitute_lemma for substitute 'followers': follower
# substitute_pos: n
# SS step: d) substitute list without non-matching pos tags: ['monitors', 'spectators', 'witnesses', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: e) substitute list ranked based on semantic similarity: ['journalists', 'monitors', 'experts', 'analysts', 'participants', 'commentators', 'parties', 'reporters', 'supporters', 'activists', 'outsiders', 'authorities', 'witnesses', 'inspectors', 'protesters', 'investigators', 'spectators', 'demonstrators', 'residents', 'cameras', 'visitors', 'viewers', 'observations', 'followers', 'eyes', 'responders']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# SG step: generated substitutes: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: a) substitute list without duplicates: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Complex_word_lemma: shrapnel
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: c): substitute list without antonyms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# complex_word_lemma for complex word 'shrapnel': shrapnel
# complex_word_pos: n
# substitute_lemma for substitute 'rapnel': rapnel
# substitute_lemma for substitute 'bullet': bullet
# substitute_pos: n
# substitute_lemma for substitute 'gunshot': gunshot
# substitute_pos: n
# substitute_lemma for substitute 'stab': stab
# substitute_pos: n
# substitute_lemma for substitute 'radiation': radiation
# substitute_pos: n
# substitute_lemma for substitute 'projectile': projectile
# substitute_pos: n
# substitute_lemma for substitute 'crippling': crippling
# substitute_pos: v
# Non-matching pos removed: crippling
# substitute_lemma for substitute 'shotgun': shotgun
# substitute_pos: n
# substitute_lemma for substitute 'mortar': mortar
# substitute_pos: n
# substitute_lemma for substitute 'stun': stun
# substitute_pos: v
# Non-matching pos removed: stun
# substitute_lemma for substitute 'explosive': explosive
# substitute_pos: n
# substitute_lemma for substitute 'stray': stray
# substitute_pos: n
# substitute_lemma for substitute 'shell': shell
# substitute_pos: n
# substitute_lemma for substitute 'bomb': bomb
# substitute_pos: n
# substitute_lemma for substitute 'microscopic': microscopic
# substitute_pos: a
# Non-matching pos removed: microscopic
# substitute_lemma for substitute 'fragmentation': fragmentation
# substitute_pos: n
# substitute_lemma for substitute 'cartridge': cartridge
# substitute_pos: n
# substitute_lemma for substitute 'grenade': grenade
# substitute_pos: n
# substitute_lemma for substitute 'rocket': rocket
# substitute_pos: n
# substitute_lemma for substitute 'torpedo': torpedo
# substitute_pos: n
# substitute_lemma for substitute 'piercing': pierce
# substitute_pos: n
# substitute_lemma for substitute 'unidentified': unidentified
# substitute_pos: s
# Non-matching pos removed: unidentified
# substitute_lemma for substitute 'ammunition': ammunition
# substitute_pos: n
# substitute_lemma for substitute 'insurgent': insurgent
# substitute_pos: n
# substitute_lemma for substitute 'similar': similar
# substitute_pos: a
# Non-matching pos removed: similar
# substitute_lemma for substitute 'blast': blast
# substitute_pos: n
# substitute_lemma for substitute 'bullets': bullet
# substitute_pos: n
# substitute_lemma for substitute 'slug': slug
# substitute_pos: n
# substitute_lemma for substitute 'terrorist': terrorist
# substitute_pos: n
# substitute_lemma for substitute 'pillow': pillow
# substitute_pos: n
# SS step: d) substitute list without non-matching pos tags: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'shotgun', 'mortar', 'explosive', 'stray', 'shell', 'bomb', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'ammunition', 'insurgent', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Word not found in embeddings (will be put at the end of the list): rapnel
# SS step: e) substitute list ranked based on semantic similarity: ['gunshot', 'bullet', 'bullets', 'grenade', 'stab', 'mortar', 'piercing', 'blast', 'bomb', 'rocket', 'stray', 'shell', 'projectile', 'explosive', 'ammunition', 'shotgun', 'fragmentation', 'radiation', 'torpedo', 'cartridge', 'pillow', 'insurgent', 'terrorist', 'slug', 'rapnel']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# SG step: generated substitutes: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: a) substitute list without duplicates: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# Complex_word_lemma: disguised
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: c): substitute list without antonyms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# complex_word_lemma for complex word 'disguised': disguised
# complex_word_pos: v
# substitute_lemma for substitute 'dressed': dressed
# substitute_pos: v
# substitute_lemma for substitute 'veiled': veil
# substitute_pos: n
# Non-matching pos removed: veiled
# substitute_lemma for substitute 'masked': mask
# substitute_pos: n
# Non-matching pos removed: masked
# substitute_lemma for substitute 'concealed': conceal
# substitute_pos: v
# substitute_lemma for substitute 'hidden': hide
# substitute_pos: n
# Non-matching pos removed: hidden
# substitute_lemma for substitute 'disguise': disguise
# substitute_pos: n
# Non-matching pos removed: disguise
# substitute_lemma for substitute 'clothed': clothe
# substitute_pos: v
# substitute_lemma for substitute 'clad': clad
# substitute_pos: v
# substitute_lemma for substitute 'posed': pose
# substitute_pos: n
# Non-matching pos removed: posed
# substitute_lemma for substitute 'covered': cover
# substitute_pos: n
# Non-matching pos removed: covered
# substitute_lemma for substitute 'cloaked': cloak
# substitute_pos: n
# Non-matching pos removed: cloaked
# substitute_lemma for substitute 'shrouded': shroud
# substitute_pos: n
# Non-matching pos removed: shrouded
# substitute_lemma for substitute 'wrapped': wrap
# substitute_pos: n
# Non-matching pos removed: wrapped
# substitute_lemma for substitute 'posing': pose
# substitute_pos: n
# Non-matching pos removed: posing
# substitute_lemma for substitute 'hiding': hiding
# substitute_pos: n
# Non-matching pos removed: hiding
# substitute_lemma for substitute 'trained': train
# substitute_pos: n
# Non-matching pos removed: trained
# substitute_lemma for substitute 'camoufl': camoufl
# substitute_lemma for substitute 'presented': present
# substitute_pos: n
# Non-matching pos removed: presented
# substitute_lemma for substitute 'known': know
# substitute_pos: n
# Non-matching pos removed: known
# substitute_lemma for substitute 'smuggled': smuggle
# substitute_pos: v
# substitute_lemma for substitute 'staged': stage
# substitute_pos: n
# Non-matching pos removed: staged
# substitute_lemma for substitute 'draped': drape
# substitute_pos: n
# Non-matching pos removed: draped
# substitute_lemma for substitute 'described': describe
# substitute_pos: v
# substitute_lemma for substitute 'decorated': decorate
# substitute_pos: v
# substitute_lemma for substitute 'armed': arm
# substitute_pos: n
# Non-matching pos removed: armed
# substitute_lemma for substitute 'buried': bury
# substitute_pos: v
# substitute_lemma for substitute 'camouflage': camouflage
# substitute_pos: n
# Non-matching pos removed: camouflage
# substitute_lemma for substitute 'marked': mark
# substitute_pos: n
# Non-matching pos removed: marked
# substitute_lemma for substitute 'hid': hide
# substitute_pos: n
# Non-matching pos removed: hid
# SS step: d) substitute list without non-matching pos tags: ['dressed', 'concealed', 'clothed', 'clad', 'camoufl', 'smuggled', 'described', 'decorated', 'buried']
#
# Word not found in embeddings (will be put at the end of the list): camoufl
# SS step: e) substitute list ranked based on semantic similarity: ['concealed', 'dressed', 'clothed', 'clad', 'smuggled', 'described', 'decorated', 'buried', 'camoufl']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# SG step: generated substitutes: ['off', 'extension', 'opposite', 'outpost', 'off', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: a) substitute list without duplicates: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# Complex_word_lemma: offshoot
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: c): substitute list without antonyms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# complex_word_lemma for complex word 'offshoot': offshoot
# complex_word_pos: n
# substitute_lemma for substitute 'off': off
# substitute_pos: v
# Non-matching pos removed: off
# substitute_lemma for substitute 'extension': extension
# substitute_pos: n
# substitute_lemma for substitute 'opposite': opposite
# substitute_pos: n
# substitute_lemma for substitute 'outpost': outpost
# substitute_pos: n
# substitute_lemma for substitute 'out': out
# substitute_pos: n
# substitute_lemma for substitute 'affiliate': affiliate
# substitute_pos: n
# substitute_lemma for substitute 'offspring': offspring
# substitute_pos: n
# substitute_lemma for substitute 'overthrow': overthrow
# substitute_pos: n
# substitute_lemma for substitute 'element': element
# substitute_pos: n
# substitute_lemma for substitute 'outside': outside
# substitute_pos: n
# substitute_lemma for substitute 'echo': echo
# substitute_pos: n
# substitute_lemma for substitute 'expansion': expansion
# substitute_pos: n
# substitute_lemma for substitute 'imprint': imprint
# substitute_pos: n
# substitute_lemma for substitute 'arm': arm
# substitute_pos: n
# substitute_lemma for substitute 'ideology': ideology
# substitute_pos: n
# substitute_lemma for substitute 'overhaul': overhaul
# substitute_pos: n
# substitute_lemma for substitute 'branch': branch
# substitute_pos: n
# substitute_lemma for substitute 'opposition': opposition
# substitute_pos: n
# substitute_lemma for substitute 'evolution': evolution
# substitute_pos: n
# substitute_lemma for substitute 'indication': indication
# substitute_pos: n
# substitute_lemma for substitute 'upset': upset
# substitute_pos: n
# substitute_lemma for substitute 'archetype': archetype
# substitute_pos: n
# substitute_lemma for substitute 'extend': extend
# substitute_pos: v
# Non-matching pos removed: extend
# substitute_lemma for substitute 'independent': independent
# substitute_pos: n
# substitute_lemma for substitute 'alternative': alternative
# substitute_pos: n
# substitute_lemma for substitute 'example': example
# substitute_pos: n
# substitute_lemma for substitute 'instance': instance
# substitute_pos: n
# substitute_lemma for substitute 'embrace': embrace
# substitute_pos: n
# substitute_lemma for substitute 'adjunct': adjunct
# substitute_pos: n
# SS step: d) substitute list without non-matching pos tags: ['extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: e) substitute list ranked based on semantic similarity: ['ideology', 'affiliate', 'overthrow', 'archetype', 'imprint', 'independent', 'branch', 'alternative', 'element', 'outpost', 'opposition', 'evolution', 'arm', 'embrace', 'offspring', 'expansion', 'indication', 'example', 'out', 'outside', 'echo', 'adjunct', 'extension', 'instance', 'overhaul', 'opposite', 'upset']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# SG step: generated substitutes: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: a) substitute list without duplicates: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Complex_word_lemma: symphonic
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: c): substitute list without antonyms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# complex_word_lemma for complex word 'symphonic': symphonic
# complex_word_pos: a
# substitute_lemma for substitute 'classical': classical
# substitute_pos: n
# Non-matching pos removed: classical
# substitute_lemma for substitute 'harmonic': harmonic
# substitute_pos: n
# Non-matching pos removed: harmonic
# substitute_lemma for substitute 'musical': musical
# substitute_pos: n
# Non-matching pos removed: musical
# substitute_lemma for substitute 'sym': sym
# substitute_lemma for substitute 'music': music
# substitute_pos: n
# Non-matching pos removed: music
# substitute_lemma for substitute 'instrumental': instrumental
# substitute_pos: a
# substitute_lemma for substitute 'piano': piano
# substitute_pos: n
# Non-matching pos removed: piano
# substitute_lemma for substitute 'lyric': lyric
# substitute_pos: n
# Non-matching pos removed: lyric
# substitute_lemma for substitute 'jazz': jazz
# substitute_pos: n
# Non-matching pos removed: jazz
# substitute_lemma for substitute 'modern': modern
# substitute_pos: n
# Non-matching pos removed: modern
# substitute_lemma for substitute 'dramatic': dramatic
# substitute_pos: a
# substitute_lemma for substitute 'major': major
# substitute_pos: n
# Non-matching pos removed: major
# substitute_lemma for substitute 'vocal': vocal
# substitute_pos: n
# Non-matching pos removed: vocal
# substitute_lemma for substitute 'composing': compose
# substitute_pos: v
# substitute_lemma for substitute 'concert': concert
# substitute_pos: n
# Non-matching pos removed: concert
# substitute_lemma for substitute 'opera': opera
# substitute_pos: n
# Non-matching pos removed: opera
# substitute_lemma for substitute 'sonic': sonic
# substitute_pos: a
# substitute_lemma for substitute 'formal': formal
# substitute_pos: n
# Non-matching pos removed: formal
# substitute_lemma for substitute 'popular': popular
# substitute_pos: a
# substitute_lemma for substitute 'early': early
# substitute_pos: a
# substitute_lemma for substitute 'composition': composition
# substitute_pos: n
# Non-matching pos removed: composition
# substitute_lemma for substitute 'english': english
# substitute_pos: n
# Non-matching pos removed: english
# substitute_lemma for substitute 'singing': singe
# substitute_pos: n
# Non-matching pos removed: singing
# substitute_lemma for substitute 'standard': standard
# substitute_pos: n
# Non-matching pos removed: standard
# substitute_lemma for substitute 'trumpet': trumpet
# substitute_pos: n
# Non-matching pos removed: trumpet
# substitute_lemma for substitute 'keyboard': keyboard
# substitute_pos: n
# Non-matching pos removed: keyboard
# substitute_lemma for substitute 'contemporary': contemporary
# substitute_pos: n
# Non-matching pos removed: contemporary
# substitute_lemma for substitute 'orchestra': orchestra
# substitute_pos: n
# Non-matching pos removed: orchestra
# substitute_lemma for substitute 'technical': technical
# substitute_pos: n
# Non-matching pos removed: technical
# substitute_lemma for substitute 'onic': onic
# SS step: d) substitute list without non-matching pos tags: ['sym', 'instrumental', 'dramatic', 'composing', 'sonic', 'popular', 'early', 'onic']
#
# Word not found in embeddings (will be put at the end of the list): onic
# SS step: e) substitute list ranked based on semantic similarity: ['instrumental', 'composing', 'dramatic', 'sonic', 'popular', 'early', 'sym', 'onic']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# SG step: generated substitutes: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'deploy', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: a) substitute list without duplicates: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# Complex_word_lemma: deploy
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: c): substitute list without antonyms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# complex_word_lemma for complex word 'deploy': deploy
# complex_word_pos: v
# substitute_lemma for substitute 'deployment': deployment
# substitute_pos: n
# Non-matching pos removed: deployment
# substitute_lemma for substitute 'utilize': utilize
# substitute_pos: v
# substitute_lemma for substitute 'mobilize': mobilize
# substitute_pos: v
# substitute_lemma for substitute 'employ': employ
# substitute_pos: n
# Non-matching pos removed: employ
# substitute_lemma for substitute 'dispatch': dispatch
# substitute_pos: n
# Non-matching pos removed: dispatch
# substitute_lemma for substitute 'equip': equip
# substitute_pos: v
# substitute_lemma for substitute 'ploy': ploy
# substitute_pos: n
# Non-matching pos removed: ploy
# substitute_lemma for substitute 'use': use
# substitute_pos: n
# Non-matching pos removed: use
# substitute_lemma for substitute 'activate': activate
# substitute_pos: v
# substitute_lemma for substitute 'recruit': recruit
# substitute_pos: n
# Non-matching pos removed: recruit
# substitute_lemma for substitute 'transport': transport
# substitute_pos: n
# Non-matching pos removed: transport
# substitute_lemma for substitute 'operate': operate
# substitute_pos: v
# substitute_lemma for substitute 'withdraw': withdraw
# substitute_pos: v
# substitute_lemma for substitute 'install': install
# substitute_pos: v
# substitute_lemma for substitute 'locate': locate
# substitute_pos: v
# substitute_lemma for substitute 'commit': commit
# substitute_pos: v
# substitute_lemma for substitute 'construct': construct
# substitute_pos: n
# Non-matching pos removed: construct
# substitute_lemma for substitute 'summon': summon
# substitute_pos: v
# substitute_lemma for substitute 'expend': expend
# substitute_pos: v
# substitute_lemma for substitute 'send': send
# substitute_pos: v
# substitute_lemma for substitute 'reserve': reserve
# substitute_pos: n
# Non-matching pos removed: reserve
# substitute_lemma for substitute 'possess': possess
# substitute_pos: n
# Non-matching pos removed: possess
# substitute_lemma for substitute 'cultivate': cultivate
# substitute_pos: v
# substitute_lemma for substitute 'adopt': adopt
# substitute_pos: v
# substitute_lemma for substitute 'engage': engage
# substitute_pos: v
# substitute_lemma for substitute 'unleash': unleash
# substitute_pos: v
# SS step: d) substitute list without non-matching pos tags: ['utilize', 'mobilize', 'equip', 'activate', 'operate', 'withdraw', 'install', 'locate', 'commit', 'summon', 'expend', 'send', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: e) substitute list ranked based on semantic similarity: ['equip', 'send', 'withdraw', 'install', 'mobilize', 'operate', 'activate', 'utilize', 'unleash', 'engage', 'locate', 'adopt', 'summon', 'commit', 'cultivate', 'expend']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #35-14 UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# SG step: generated substitutes: ['authorities', 'officials', 'authorities', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'authorities', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: a) substitute list without duplicates: ['authorities', 'officials', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# Complex_word_lemma: authority
#
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: c): substitute list without antonyms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# complex_word_lemma for complex word 'authorities': authority
# complex_word_pos: n
# substitute_lemma for substitute 'officials': official
# substitute_pos: n
# substitute_lemma for substitute 'investigators': investigator
# substitute_pos: n
# substitute_lemma for substitute 'counterparts': counterpart
# substitute_pos: n
# substitute_lemma for substitute 'police': police
# substitute_pos: n
# substitute_lemma for substitute 'agencies': agency
# substitute_pos: n
# substitute_lemma for substitute 'administrators': administrator
# substitute_pos: n
# substitute_lemma for substitute 'forces': force
# substitute_pos: n
# substitute_lemma for substitute 'prosecutors': prosecutor
# substitute_pos: n
# substitute_lemma for substitute 'officers': officer
# substitute_pos: n
# substitute_lemma for substitute 'entities': entity
# substitute_pos: n
# substitute_lemma for substitute 'intelligence': intelligence
# substitute_pos: n
# substitute_lemma for substitute 'jurisdictions': jurisdiction
# substitute_pos: n
# substitute_lemma for substitute 'individuals': individual
# substitute_pos: n
# substitute_lemma for substitute 'detainees': detainee
# substitute_pos: n
# substitute_lemma for substitute 'institutions': institution
# substitute_pos: n
# substitute_lemma for substitute 'affairs': affair
# substitute_pos: n
# substitute_lemma for substitute 'demonstrators': demonstrator
# substitute_pos: n
# substitute_lemma for substitute 'superiors': superior
# substitute_pos: n
# substitute_lemma for substitute 'victims': victim
# substitute_pos: n
# substitute_lemma for substitute 'regulators': regulator
# substitute_pos: n
# substitute_lemma for substitute 'concerns': concern
# substitute_pos: n
# substitute_lemma for substitute 'ministers': minister
# substitute_pos: n
# substitute_lemma for substitute 'figures': figure
# substitute_pos: n
# substitute_lemma for substitute 'suspects': suspect
# substitute_pos: n
# substitute_lemma for substitute 'sources': source
# substitute_pos: n
# substitute_lemma for substitute 'assistance': assistance
# substitute_pos: n
# SS step: d) substitute list without non-matching pos tags: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: e) substitute list ranked based on semantic similarity: ['officials', 'police', 'investigators', 'prosecutors', 'officers', 'agencies', 'suspects', 'sources', 'victims', 'regulators', 'forces', 'concerns', 'intelligence', 'assistance', 'demonstrators', 'individuals', 'institutions', 'administrators', 'counterparts', 'figures', 'detainees', 'ministers', 'affairs', 'superiors', 'jurisdictions', 'entities']
#
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Results:
# SS step d) both lemmatizing and pos tagging with wordnet is not satisfactory: lemmatizing does not lemmatize verbs, and pos tagging goes wrong a lot. Moved over to spacy pos tagging which does not use wordnet pos tagging.

# %%
# use spacy for pos tagging


# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>")

    ## concatenate the sentence with the complex word and the sentence with the masked word, by using RoBERTa's separator token to create one string of both sentencesion 
    sentences_concat = f"{sentence} {tokenizer.sep_token} {sentence_masked_word}"

    ## tokenize the concatenated sentence
    sentences_concat_tokenized = tokenizer.encode(sentences_concat, return_tensors='pt')

    ## find the masked word in the tokenized sentence
    mask_location = torch.where(sentences_concat_tokenized == tokenizer.mask_token_id)[1].item()

    ## generate predictions for the masked word (forward pass not needed for predictions, only for training)
    with torch.no_grad():
        outputs = model(sentences_concat_tokenized)
        predictions = outputs.logits

    ## get the top-k substitutes based on the predicted logits
    top_k = 30
    top_tokens = torch.topk(predictions[0, mask_location], top_k).indices

    ## decode the top-k substitutes, lowercase and print them
    substitutes = [tokenizer.decode(token.item()).strip().lower() for token in top_tokens]
    print(f"SG step: generated substitutes: {substitutes}\n")
    
    

    # 2. Substitute Selection (SS): 
    
    # a) remove duplicates from the substitute list 
    
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"SS step: a) substitute list without duplicates: {substitutes_no_dupl}\n")

   
    # b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same (will be deleted)
    doc = nlp(complex_word)
    complex_word_lemma = doc[0].lemma_
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}")

    ## remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc = nlp(substitute)
        if doc[0].lemma_ != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"SS step: b) substitute list without duplicates and inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")

    # c) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute:
                    print(f"Antonym removed: {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    print(f"SS step: c): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")

    # d) in the last substitute list, remove selected non-matching pos tags # does not work well! spacy's pos tagger does not work well, just like Wordnet's
    substitutes_no_dupl_complex_word_no_antonym_no_matchpos = []
    complex_word_pos = doc[0].pos_
    print(f"complex_word_pos: {complex_word_pos}")
    for substitute in substitutes_no_dupl_complex_word_no_antonym:
        substitute_doc = nlp(substitute)
        substitute_lemma = substitute_doc[0].lemma_
        print(f"substitute_lemma for substitute '{substitute}': {substitute_lemma}")
        substitute_pos = substitute_doc[0].pos_
        print(f"substitute_pos: {substitute_pos}")
        if complex_word_pos == 'VERB' and substitute_pos == 'NOUN' or substitute_pos == 'ADP' or substitute_pos == 'PROPN':
            print(f"Non-matching pos removed: {substitute}")
        elif complex_word_pos == 'NOUN' and substitute_pos == 'VERB':
            print(f"Non-matching pos removed: {substitute}")
        elif complex_word_pos == 'ADJ' and substitute_pos == 'VERB':
            print(f"Non-matching pos removed: {substitute}")
        elif complex_word_pos == 'ADV' and substitute_pos == 'VERB':
            print(f"Non-matching pos removed: {substitute}")
        else:
            substitutes_no_dupl_complex_word_no_antonym_no_matchpos.append(substitute)
    print(f"SS step: d) substitute list without non-matching pos tags: {substitutes_no_dupl_complex_word_no_antonym_no_matchpos}\n")
    

    
    # e) perform ranking of substitutes_no_dupl_complex_word_no_antonym_no_matchpos on semantic similarity
    # compute the semantic similarity between the complex word and each substitute
    
    similarities = []
    for substitute in substitutes_no_dupl_complex_word_no_antonym_no_matchpos:
        if substitute.lower() in glove.key_to_index:
            similarity = glove.similarity(complex_word.lower(), substitute.lower())
        else:
            print(f"Word not found in embeddings (will be put at the end of the list): {substitute}")
            similarity = -1.0  # set similarity to a negative value to indicate it should be put at the very end of the list
        similarities.append(similarity)

    # rank the substitutes based on their semantic similarity with the complex word
    substitutes_ranked = [x for _, x in sorted(zip(similarities, substitutes_no_dupl_complex_word_no_antonym_no_matchpos), reverse=True)]
    print(f"SS step: e) substitute list ranked based on semantic similarity: {substitutes_ranked}\n")
    print('----------------------------------------------------------------------------------------------------------------------')
    print()
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# SG step: generated substitutes: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion', 'mandatory']
#
# SS step: a) substitute list without duplicates: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# complex_word_lemma for complex word 'compulsory': compulsory
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: c): substitute list without antonyms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# complex_word_pos: NOUN
# substitute_lemma for substitute 'mandatory': mandatory
# substitute_pos: ADJ
# substitute_lemma for substitute 'obligatory': obligatory
# substitute_pos: NOUN
# substitute_lemma for substitute 'voluntary': voluntary
# substitute_pos: ADJ
# substitute_lemma for substitute 'required': require
# substitute_pos: VERB
# Non-matching pos removed: required
# substitute_lemma for substitute 'optional': optional
# substitute_pos: PROPN
# Non-matching pos removed: optional
# substitute_lemma for substitute 'obliged': oblige
# substitute_pos: VERB
# Non-matching pos removed: obliged
# substitute_lemma for substitute 'uniform': uniform
# substitute_pos: NOUN
# substitute_lemma for substitute 'necessary': necessary
# substitute_pos: ADJ
# substitute_lemma for substitute 'available': available
# substitute_pos: ADJ
# substitute_lemma for substitute 'mandated': mandate
# substitute_pos: VERB
# Non-matching pos removed: mandated
# substitute_lemma for substitute 'sufficient': sufficient
# substitute_pos: ADJ
# substitute_lemma for substitute 'routine': routine
# substitute_pos: ADJ
# substitute_lemma for substitute 'forced': force
# substitute_pos: VERB
# Non-matching pos removed: forced
# substitute_lemma for substitute 'customary': customary
# substitute_pos: ADJ
# substitute_lemma for substitute 'prerequisite': prerequisite
# substitute_pos: NOUN
# substitute_lemma for substitute 'feasible': feasible
# substitute_pos: ADJ
# substitute_lemma for substitute 'indispensable': indispensable
# substitute_pos: ADJ
# substitute_lemma for substitute 'forthcoming': forthcoming
# substitute_pos: ADJ
# substitute_lemma for substitute 'universal': universal
# substitute_pos: ADJ
# substitute_lemma for substitute 'requirement': requirement
# substitute_pos: NOUN
# substitute_lemma for substitute 'involuntary': involuntary
# substitute_pos: PROPN
# Non-matching pos removed: involuntary
# substitute_lemma for substitute 'obligated': obligate
# substitute_pos: VERB
# Non-matching pos removed: obligated
# substitute_lemma for substitute 'compelled': compel
# substitute_pos: VERB
# Non-matching pos removed: compelled
# substitute_lemma for substitute 'conditional': conditional
# substitute_pos: ADJ
# substitute_lemma for substitute 'enforced': enforce
# substitute_pos: VERB
# Non-matching pos removed: enforced
# substitute_lemma for substitute 'contingent': contingent
# substitute_pos: NOUN
# substitute_lemma for substitute 'possible': possible
# substitute_pos: ADJ
# substitute_lemma for substitute 'compulsion': compulsion
# substitute_pos: NOUN
# SS step: d) substitute list without non-matching pos tags: ['mandatory', 'obligatory', 'voluntary', 'uniform', 'necessary', 'available', 'sufficient', 'routine', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'conditional', 'contingent', 'possible', 'compulsion']
#
# SS step: e) substitute list ranked based on semantic similarity: ['obligatory', 'mandatory', 'voluntary', 'requirement', 'routine', 'uniform', 'customary', 'prerequisite', 'universal', 'necessary', 'conditional', 'available', 'sufficient', 'feasible', 'contingent', 'possible', 'forthcoming', 'compulsion', 'indispensable']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# SG step: generated substitutes: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'filled', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: a) substitute list without duplicates: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# complex_word_lemma for complex word 'instilled': instill
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: c): substitute list without antonyms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# complex_word_pos: VERB
# substitute_lemma for substitute 'infused': infuse
# substitute_pos: VERB
# substitute_lemma for substitute 'injected': inject
# substitute_pos: VERB
# substitute_lemma for substitute 'endowed': endow
# substitute_pos: VERB
# substitute_lemma for substitute 'illed': ille
# substitute_pos: VERB
# substitute_lemma for substitute 'inst': inst
# substitute_pos: ADP
# Non-matching pos removed: inst
# substitute_lemma for substitute 'furnished': furnish
# substitute_pos: VERB
# substitute_lemma for substitute 'supplied': supply
# substitute_pos: VERB
# substitute_lemma for substitute 'bolstered': bolster
# substitute_pos: VERB
# substitute_lemma for substitute 'implanted': implant
# substitute_pos: VERB
# substitute_lemma for substitute 'impressed': impress
# substitute_pos: VERB
# substitute_lemma for substitute 'reinforced': reinforce
# substitute_pos: VERB
# substitute_lemma for substitute 'invested': invest
# substitute_pos: VERB
# substitute_lemma for substitute 'provided': provide
# substitute_pos: VERB
# substitute_lemma for substitute 'filled': fill
# substitute_pos: VERB
# substitute_lemma for substitute 'reassured': reassure
# substitute_pos: VERB
# substitute_lemma for substitute 'undermined': undermine
# substitute_pos: VERB
# substitute_lemma for substitute 'pumped': pump
# substitute_pos: VERB
# substitute_lemma for substitute 'struck': strike
# substitute_pos: VERB
# substitute_lemma for substitute 'augmented': augment
# substitute_pos: VERB
# substitute_lemma for substitute 'enriched': enrich
# substitute_pos: VERB
# substitute_lemma for substitute 'stirred': stir
# substitute_pos: VERB
# substitute_lemma for substitute 'vested': vest
# substitute_pos: VERB
# substitute_lemma for substitute 'imb': imb
# substitute_pos: PROPN
# Non-matching pos removed: imb
# substitute_lemma for substitute 'intoxicated': intoxicate
# substitute_pos: VERB
# substitute_lemma for substitute 'seeded': seed
# substitute_pos: VERB
# substitute_lemma for substitute 'misled': mislead
# substitute_pos: VERB
# substitute_lemma for substitute 'stunned': stun
# substitute_pos: VERB
# substitute_lemma for substitute 'inspired': inspire
# substitute_pos: VERB
# substitute_lemma for substitute 'inflated': inflate
# substitute_pos: VERB
# SS step: d) substitute list without non-matching pos tags: ['infused', 'injected', 'endowed', 'illed', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Word not found in embeddings (will be put at the end of the list): illed
# SS step: e) substitute list ranked based on semantic similarity: ['stirred', 'undermined', 'infused', 'impressed', 'endowed', 'reassured', 'vested', 'bolstered', 'inspired', 'reinforced', 'intoxicated', 'injected', 'enriched', 'implanted', 'misled', 'stunned', 'augmented', 'inflated', 'pumped', 'invested', 'furnished', 'struck', 'filled', 'supplied', 'seeded', 'provided', 'illed']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #34-3 "War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# SG step: generated substitutes: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: a) substitute list without duplicates: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# complex_word_lemma for complex word 'maniacs': maniac
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: c): substitute list without antonyms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# complex_word_pos: NOUN
# substitute_lemma for substitute 'criminals': criminal
# substitute_pos: NOUN
# substitute_lemma for substitute 'riors': rior
# substitute_pos: NOUN
# substitute_lemma for substitute 'hawks': hawk
# substitute_pos: NOUN
# substitute_lemma for substitute 'heads': head
# substitute_pos: NOUN
# substitute_lemma for substitute 'killers': killer
# substitute_pos: NOUN
# substitute_lemma for substitute 'gangs': gang
# substitute_pos: NOUN
# substitute_lemma for substitute 'lords': lord
# substitute_pos: NOUN
# substitute_lemma for substitute 'thugs': thug
# substitute_pos: NOUN
# substitute_lemma for substitute 'devils': devil
# substitute_pos: NOUN
# substitute_lemma for substitute 'drums': drum
# substitute_pos: NOUN
# substitute_lemma for substitute 'murderers': murderer
# substitute_pos: NOUN
# substitute_lemma for substitute 'fighters': fighter
# substitute_pos: NOUN
# substitute_lemma for substitute 'monsters': monster
# substitute_pos: NOUN
# substitute_lemma for substitute 'fools': fool
# substitute_pos: NOUN
# substitute_lemma for substitute 'villains': villain
# substitute_pos: NOUN
# substitute_lemma for substitute 'idiots': idiot
# substitute_pos: NOUN
# substitute_lemma for substitute 'machines': machine
# substitute_pos: NOUN
# substitute_lemma for substitute 'demons': demon
# substitute_pos: NOUN
# substitute_lemma for substitute 'doctors': doctor
# substitute_pos: NOUN
# substitute_lemma for substitute 'planes': plane
# substitute_pos: NOUN
# substitute_lemma for substitute 'igans': igan
# substitute_pos: NOUN
# substitute_lemma for substitute 'bosses': boss
# substitute_pos: NOUN
# substitute_lemma for substitute 'nazis': nazi
# substitute_pos: NOUN
# substitute_lemma for substitute 'beasts': beast
# substitute_pos: NOUN
# substitute_lemma for substitute 'fascists': fascist
# substitute_pos: NOUN
# substitute_lemma for substitute 'children': child
# substitute_pos: NOUN
# substitute_lemma for substitute 'nerds': nerd
# substitute_pos: NOUN
# substitute_lemma for substitute 'extremists': extremist
# substitute_pos: NOUN
# substitute_lemma for substitute 'parasites': parasite
# substitute_pos: NOUN
# SS step: d) substitute list without non-matching pos tags: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Word not found in embeddings (will be put at the end of the list): riors
# Word not found in embeddings (will be put at the end of the list): igans
# SS step: e) substitute list ranked based on semantic similarity: ['idiots', 'nerds', 'thugs', 'fascists', 'monsters', 'fools', 'murderers', 'criminals', 'beasts', 'killers', 'gangs', 'drums', 'villains', 'nazis', 'demons', 'machines', 'fighters', 'extremists', 'parasites', 'bosses', 'children', 'hawks', 'planes', 'lords', 'devils', 'heads', 'doctors', 'riors', 'igans']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# SG step: generated substitutes: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: a) substitute list without duplicates: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# complex_word_lemma for complex word 'observers': observer
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: c): substitute list without antonyms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# complex_word_pos: NOUN
# substitute_lemma for substitute 'monitors': monitor
# substitute_pos: NOUN
# substitute_lemma for substitute 'spectators': spectator
# substitute_pos: NOUN
# substitute_lemma for substitute 'witnesses': witness
# substitute_pos: NOUN
# substitute_lemma for substitute 'observes': observe
# substitute_pos: VERB
# Non-matching pos removed: observes
# substitute_lemma for substitute 'visitors': visitor
# substitute_pos: NOUN
# substitute_lemma for substitute 'viewers': viewer
# substitute_pos: NOUN
# substitute_lemma for substitute 'reporters': reporter
# substitute_pos: NOUN
# substitute_lemma for substitute 'inspectors': inspector
# substitute_pos: NOUN
# substitute_lemma for substitute 'commentators': commentator
# substitute_pos: NOUN
# substitute_lemma for substitute 'investigators': investigator
# substitute_pos: NOUN
# substitute_lemma for substitute 'participants': participant
# substitute_pos: NOUN
# substitute_lemma for substitute 'analysts': analyst
# substitute_pos: NOUN
# substitute_lemma for substitute 'cameras': camera
# substitute_pos: NOUN
# substitute_lemma for substitute 'outsiders': outsider
# substitute_pos: NOUN
# substitute_lemma for substitute 'demonstrators': demonstrator
# substitute_pos: NOUN
# substitute_lemma for substitute 'activists': activist
# substitute_pos: NOUN
# substitute_lemma for substitute 'journalists': journalist
# substitute_pos: NOUN
# substitute_lemma for substitute 'experts': expert
# substitute_pos: NOUN
# substitute_lemma for substitute 'authorities': authority
# substitute_pos: NOUN
# substitute_lemma for substitute 'observations': observation
# substitute_pos: NOUN
# substitute_lemma for substitute 'eyes': eye
# substitute_pos: NOUN
# substitute_lemma for substitute 'supporters': supporter
# substitute_pos: NOUN
# substitute_lemma for substitute 'observing': observe
# substitute_pos: VERB
# Non-matching pos removed: observing
# substitute_lemma for substitute 'residents': resident
# substitute_pos: NOUN
# substitute_lemma for substitute 'protesters': protester
# substitute_pos: NOUN
# substitute_lemma for substitute 'responders': responder
# substitute_pos: NOUN
# substitute_lemma for substitute 'parties': party
# substitute_pos: NOUN
# substitute_lemma for substitute 'followers': follower
# substitute_pos: NOUN
# SS step: d) substitute list without non-matching pos tags: ['monitors', 'spectators', 'witnesses', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: e) substitute list ranked based on semantic similarity: ['journalists', 'monitors', 'experts', 'analysts', 'participants', 'commentators', 'parties', 'reporters', 'supporters', 'activists', 'outsiders', 'authorities', 'witnesses', 'inspectors', 'protesters', 'investigators', 'spectators', 'demonstrators', 'residents', 'cameras', 'visitors', 'viewers', 'observations', 'followers', 'eyes', 'responders']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# SG step: generated substitutes: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: a) substitute list without duplicates: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# complex_word_lemma for complex word 'shrapnel': shrapnel
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: c): substitute list without antonyms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# complex_word_pos: NOUN
# substitute_lemma for substitute 'rapnel': rapnel
# substitute_pos: NOUN
# substitute_lemma for substitute 'bullet': bullet
# substitute_pos: NOUN
# substitute_lemma for substitute 'gunshot': gunshot
# substitute_pos: NOUN
# substitute_lemma for substitute 'stab': stab
# substitute_pos: PROPN
# Non-matching pos removed: stab
# substitute_lemma for substitute 'radiation': radiation
# substitute_pos: NOUN
# substitute_lemma for substitute 'projectile': projectile
# substitute_pos: VERB
# Non-matching pos removed: projectile
# substitute_lemma for substitute 'crippling': crippling
# substitute_pos: ADJ
# substitute_lemma for substitute 'shotgun': shotgun
# substitute_pos: PROPN
# Non-matching pos removed: shotgun
# substitute_lemma for substitute 'mortar': mortar
# substitute_pos: PROPN
# Non-matching pos removed: mortar
# substitute_lemma for substitute 'stun': stun
# substitute_pos: PROPN
# Non-matching pos removed: stun
# substitute_lemma for substitute 'explosive': explosive
# substitute_pos: ADJ
# substitute_lemma for substitute 'stray': stray
# substitute_pos: VERB
# Non-matching pos removed: stray
# substitute_lemma for substitute 'shell': shell
# substitute_pos: PROPN
# Non-matching pos removed: shell
# substitute_lemma for substitute 'bomb': bomb
# substitute_pos: NOUN
# substitute_lemma for substitute 'microscopic': microscopic
# substitute_pos: PROPN
# Non-matching pos removed: microscopic
# substitute_lemma for substitute 'fragmentation': fragmentation
# substitute_pos: NOUN
# substitute_lemma for substitute 'cartridge': cartridge
# substitute_pos: PROPN
# Non-matching pos removed: cartridge
# substitute_lemma for substitute 'grenade': grenade
# substitute_pos: NOUN
# substitute_lemma for substitute 'rocket': rocket
# substitute_pos: NOUN
# substitute_lemma for substitute 'torpedo': torpedo
# substitute_pos: PROPN
# Non-matching pos removed: torpedo
# substitute_lemma for substitute 'piercing': pierce
# substitute_pos: VERB
# Non-matching pos removed: piercing
# substitute_lemma for substitute 'unidentified': unidentified
# substitute_pos: ADJ
# substitute_lemma for substitute 'ammunition': ammunition
# substitute_pos: NOUN
# substitute_lemma for substitute 'insurgent': insurgent
# substitute_pos: NOUN
# substitute_lemma for substitute 'similar': similar
# substitute_pos: ADJ
# substitute_lemma for substitute 'blast': blast
# substitute_pos: NOUN
# substitute_lemma for substitute 'bullets': bullet
# substitute_pos: NOUN
# substitute_lemma for substitute 'slug': slug
# substitute_pos: ADJ
# substitute_lemma for substitute 'terrorist': terrorist
# substitute_pos: NOUN
# substitute_lemma for substitute 'pillow': pillow
# substitute_pos: NOUN
# SS step: d) substitute list without non-matching pos tags: ['rapnel', 'bullet', 'gunshot', 'radiation', 'crippling', 'explosive', 'bomb', 'fragmentation', 'grenade', 'rocket', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Word not found in embeddings (will be put at the end of the list): rapnel
# SS step: e) substitute list ranked based on semantic similarity: ['gunshot', 'bullet', 'bullets', 'grenade', 'blast', 'bomb', 'rocket', 'unidentified', 'explosive', 'ammunition', 'fragmentation', 'radiation', 'pillow', 'insurgent', 'crippling', 'similar', 'terrorist', 'slug', 'rapnel']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# SG step: generated substitutes: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: a) substitute list without duplicates: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# complex_word_lemma for complex word 'disguised': disguised
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: c): substitute list without antonyms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# complex_word_pos: VERB
# substitute_lemma for substitute 'dressed': dressed
# substitute_pos: ADJ
# substitute_lemma for substitute 'veiled': veil
# substitute_pos: VERB
# substitute_lemma for substitute 'masked': mask
# substitute_pos: VERB
# substitute_lemma for substitute 'concealed': conceal
# substitute_pos: VERB
# substitute_lemma for substitute 'hidden': hide
# substitute_pos: VERB
# substitute_lemma for substitute 'disguise': disguise
# substitute_pos: PROPN
# Non-matching pos removed: disguise
# substitute_lemma for substitute 'clothed': clothe
# substitute_pos: VERB
# substitute_lemma for substitute 'clad': clad
# substitute_pos: ADJ
# substitute_lemma for substitute 'posed': pose
# substitute_pos: VERB
# substitute_lemma for substitute 'covered': cover
# substitute_pos: VERB
# substitute_lemma for substitute 'cloaked': cloak
# substitute_pos: VERB
# substitute_lemma for substitute 'shrouded': shroud
# substitute_pos: VERB
# substitute_lemma for substitute 'wrapped': wrap
# substitute_pos: VERB
# substitute_lemma for substitute 'posing': pose
# substitute_pos: VERB
# substitute_lemma for substitute 'hiding': hiding
# substitute_pos: NOUN
# Non-matching pos removed: hiding
# substitute_lemma for substitute 'trained': train
# substitute_pos: VERB
# substitute_lemma for substitute 'camoufl': camoufl
# substitute_pos: NOUN
# Non-matching pos removed: camoufl
# substitute_lemma for substitute 'presented': present
# substitute_pos: VERB
# substitute_lemma for substitute 'known': know
# substitute_pos: VERB
# substitute_lemma for substitute 'smuggled': smuggle
# substitute_pos: VERB
# substitute_lemma for substitute 'staged': stage
# substitute_pos: VERB
# substitute_lemma for substitute 'draped': drape
# substitute_pos: VERB
# substitute_lemma for substitute 'described': describe
# substitute_pos: VERB
# substitute_lemma for substitute 'decorated': decorate
# substitute_pos: VERB
# substitute_lemma for substitute 'armed': arm
# substitute_pos: VERB
# substitute_lemma for substitute 'buried': bury
# substitute_pos: VERB
# substitute_lemma for substitute 'camouflage': camouflage
# substitute_pos: NOUN
# Non-matching pos removed: camouflage
# substitute_lemma for substitute 'marked': mark
# substitute_pos: VERB
# substitute_lemma for substitute 'hid': hide
# substitute_pos: VERB
# SS step: d) substitute list without non-matching pos tags: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'trained', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'marked', 'hid']
#
# SS step: e) substitute list ranked based on semantic similarity: ['veiled', 'masked', 'concealed', 'posing', 'dressed', 'hidden', 'hid', 'clothed', 'cloaked', 'armed', 'clad', 'smuggled', 'posed', 'draped', 'wrapped', 'described', 'known', 'staged', 'trained', 'decorated', 'shrouded', 'covered', 'presented', 'buried', 'marked']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# SG step: generated substitutes: ['off', 'extension', 'opposite', 'outpost', 'off', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: a) substitute list without duplicates: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# complex_word_lemma for complex word 'offshoot': offshoot
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: c): substitute list without antonyms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# complex_word_pos: ADJ
# substitute_lemma for substitute 'off': off
# substitute_pos: ADP
# Non-matching pos removed: off
# substitute_lemma for substitute 'extension': extension
# substitute_pos: NOUN
# substitute_lemma for substitute 'opposite': opposite
# substitute_pos: ADJ
# substitute_lemma for substitute 'outpost': outpost
# substitute_pos: NOUN
# substitute_lemma for substitute 'out': out
# substitute_pos: ADP
# Non-matching pos removed: out
# substitute_lemma for substitute 'affiliate': affiliate
# substitute_pos: NOUN
# substitute_lemma for substitute 'offspring': offspring
# substitute_pos: NOUN
# substitute_lemma for substitute 'overthrow': overthrow
# substitute_pos: VERB
# Non-matching pos removed: overthrow
# substitute_lemma for substitute 'element': element
# substitute_pos: NOUN
# substitute_lemma for substitute 'outside': outside
# substitute_pos: ADV
# substitute_lemma for substitute 'echo': echo
# substitute_pos: VERB
# Non-matching pos removed: echo
# substitute_lemma for substitute 'expansion': expansion
# substitute_pos: NOUN
# substitute_lemma for substitute 'imprint': imprint
# substitute_pos: NOUN
# substitute_lemma for substitute 'arm': arm
# substitute_pos: VERB
# Non-matching pos removed: arm
# substitute_lemma for substitute 'ideology': ideology
# substitute_pos: NOUN
# substitute_lemma for substitute 'overhaul': overhaul
# substitute_pos: PROPN
# Non-matching pos removed: overhaul
# substitute_lemma for substitute 'branch': branch
# substitute_pos: NOUN
# substitute_lemma for substitute 'opposition': opposition
# substitute_pos: NOUN
# substitute_lemma for substitute 'evolution': evolution
# substitute_pos: NOUN
# substitute_lemma for substitute 'indication': indication
# substitute_pos: NOUN
# substitute_lemma for substitute 'upset': upset
# substitute_pos: ADJ
# substitute_lemma for substitute 'archetype': archetype
# substitute_pos: NOUN
# substitute_lemma for substitute 'extend': extend
# substitute_pos: VERB
# Non-matching pos removed: extend
# substitute_lemma for substitute 'independent': independent
# substitute_pos: ADJ
# substitute_lemma for substitute 'alternative': alternative
# substitute_pos: NOUN
# substitute_lemma for substitute 'example': example
# substitute_pos: NOUN
# substitute_lemma for substitute 'instance': instance
# substitute_pos: NOUN
# substitute_lemma for substitute 'embrace': embrace
# substitute_pos: NOUN
# substitute_lemma for substitute 'adjunct': adjunct
# substitute_pos: ADJ
# SS step: d) substitute list without non-matching pos tags: ['extension', 'opposite', 'outpost', 'affiliate', 'offspring', 'element', 'outside', 'expansion', 'imprint', 'ideology', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: e) substitute list ranked based on semantic similarity: ['ideology', 'affiliate', 'archetype', 'imprint', 'independent', 'branch', 'alternative', 'element', 'outpost', 'opposition', 'evolution', 'embrace', 'offspring', 'expansion', 'indication', 'example', 'outside', 'adjunct', 'extension', 'instance', 'opposite', 'upset']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# SG step: generated substitutes: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: a) substitute list without duplicates: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# complex_word_lemma for complex word 'symphonic': symphonic
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: c): substitute list without antonyms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# complex_word_pos: ADJ
# substitute_lemma for substitute 'classical': classical
# substitute_pos: ADJ
# substitute_lemma for substitute 'harmonic': harmonic
# substitute_pos: ADJ
# substitute_lemma for substitute 'musical': musical
# substitute_pos: ADJ
# substitute_lemma for substitute 'sym': sym
# substitute_pos: PROPN
# Non-matching pos removed: sym
# substitute_lemma for substitute 'music': music
# substitute_pos: NOUN
# substitute_lemma for substitute 'instrumental': instrumental
# substitute_pos: ADJ
# substitute_lemma for substitute 'piano': piano
# substitute_pos: NOUN
# substitute_lemma for substitute 'lyric': lyric
# substitute_pos: NOUN
# substitute_lemma for substitute 'jazz': jazz
# substitute_pos: NOUN
# substitute_lemma for substitute 'modern': modern
# substitute_pos: ADJ
# substitute_lemma for substitute 'dramatic': dramatic
# substitute_pos: ADJ
# substitute_lemma for substitute 'major': major
# substitute_pos: ADJ
# substitute_lemma for substitute 'vocal': vocal
# substitute_pos: NOUN
# substitute_lemma for substitute 'composing': compose
# substitute_pos: VERB
# Non-matching pos removed: composing
# substitute_lemma for substitute 'concert': concert
# substitute_pos: VERB
# Non-matching pos removed: concert
# substitute_lemma for substitute 'opera': opera
# substitute_pos: NOUN
# substitute_lemma for substitute 'sonic': sonic
# substitute_pos: PROPN
# Non-matching pos removed: sonic
# substitute_lemma for substitute 'formal': formal
# substitute_pos: ADJ
# substitute_lemma for substitute 'popular': popular
# substitute_pos: ADJ
# substitute_lemma for substitute 'early': early
# substitute_pos: ADV
# substitute_lemma for substitute 'composition': composition
# substitute_pos: NOUN
# substitute_lemma for substitute 'english': english
# substitute_pos: PROPN
# Non-matching pos removed: english
# substitute_lemma for substitute 'singing': singe
# substitute_pos: VERB
# Non-matching pos removed: singing
# substitute_lemma for substitute 'standard': standard
# substitute_pos: NOUN
# substitute_lemma for substitute 'trumpet': trumpet
# substitute_pos: PROPN
# Non-matching pos removed: trumpet
# substitute_lemma for substitute 'keyboard': keyboard
# substitute_pos: PROPN
# Non-matching pos removed: keyboard
# substitute_lemma for substitute 'contemporary': contemporary
# substitute_pos: ADJ
# substitute_lemma for substitute 'orchestra': orchestra
# substitute_pos: PROPN
# Non-matching pos removed: orchestra
# substitute_lemma for substitute 'technical': technical
# substitute_pos: ADJ
# substitute_lemma for substitute 'onic': onic
# substitute_pos: ADJ
# SS step: d) substitute list without non-matching pos tags: ['classical', 'harmonic', 'musical', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'opera', 'formal', 'popular', 'early', 'composition', 'standard', 'contemporary', 'technical', 'onic']
#
# Word not found in embeddings (will be put at the end of the list): onic
# SS step: e) substitute list ranked based on semantic similarity: ['piano', 'classical', 'opera', 'composition', 'musical', 'jazz', 'music', 'instrumental', 'lyric', 'vocal', 'harmonic', 'contemporary', 'dramatic', 'modern', 'popular', 'formal', 'early', 'technical', 'standard', 'major', 'onic']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# SG step: generated substitutes: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'deploy', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: a) substitute list without duplicates: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# complex_word_lemma for complex word 'deploy': deploy
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: c): substitute list without antonyms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# complex_word_pos: PROPN
# substitute_lemma for substitute 'deployment': deployment
# substitute_pos: NOUN
# substitute_lemma for substitute 'utilize': utilize
# substitute_pos: VERB
# substitute_lemma for substitute 'mobilize': mobilize
# substitute_pos: VERB
# substitute_lemma for substitute 'employ': employ
# substitute_pos: VERB
# substitute_lemma for substitute 'dispatch': dispatch
# substitute_pos: ADV
# substitute_lemma for substitute 'equip': equip
# substitute_pos: PROPN
# Non-matching pos removed: equip
# substitute_lemma for substitute 'ploy': ploy
# substitute_pos: VERB
# substitute_lemma for substitute 'use': use
# substitute_pos: VERB
# substitute_lemma for substitute 'activate': activate
# substitute_pos: VERB
# substitute_lemma for substitute 'recruit': recruit
# substitute_pos: NOUN
# substitute_lemma for substitute 'transport': transport
# substitute_pos: NOUN
# substitute_lemma for substitute 'operate': operate
# substitute_pos: VERB
# substitute_lemma for substitute 'withdraw': withdraw
# substitute_pos: VERB
# substitute_lemma for substitute 'install': install
# substitute_pos: VERB
# substitute_lemma for substitute 'locate': locate
# substitute_pos: VERB
# substitute_lemma for substitute 'commit': commit
# substitute_pos: VERB
# substitute_lemma for substitute 'construct': construct
# substitute_pos: VERB
# substitute_lemma for substitute 'summon': summon
# substitute_pos: ADJ
# substitute_lemma for substitute 'expend': expend
# substitute_pos: VERB
# substitute_lemma for substitute 'send': send
# substitute_pos: VERB
# substitute_lemma for substitute 'reserve': reserve
# substitute_pos: PROPN
# Non-matching pos removed: reserve
# substitute_lemma for substitute 'possess': possess
# substitute_pos: VERB
# substitute_lemma for substitute 'cultivate': cultivate
# substitute_pos: VERB
# substitute_lemma for substitute 'adopt': adopt
# substitute_pos: VERB
# substitute_lemma for substitute 'engage': engage
# substitute_pos: VERB
# substitute_lemma for substitute 'unleash': unleash
# substitute_pos: PROPN
# Non-matching pos removed: unleash
# SS step: d) substitute list without non-matching pos tags: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'possess', 'cultivate', 'adopt', 'engage']
#
# SS step: e) substitute list ranked based on semantic similarity: ['deployment', 'send', 'withdraw', 'install', 'mobilize', 'dispatch', 'recruit', 'operate', 'employ', 'activate', 'utilize', 'engage', 'locate', 'adopt', 'use', 'summon', 'construct', 'commit', 'possess', 'transport', 'cultivate', 'expend', 'ploy']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #35-14 UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# SG step: generated substitutes: ['authorities', 'officials', 'authorities', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'authorities', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: a) substitute list without duplicates: ['authorities', 'officials', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# complex_word_lemma for complex word 'authorities': authority
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: c): substitute list without antonyms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# complex_word_pos: NOUN
# substitute_lemma for substitute 'officials': official
# substitute_pos: NOUN
# substitute_lemma for substitute 'investigators': investigator
# substitute_pos: NOUN
# substitute_lemma for substitute 'counterparts': counterpart
# substitute_pos: NOUN
# substitute_lemma for substitute 'police': police
# substitute_pos: NOUN
# substitute_lemma for substitute 'agencies': agency
# substitute_pos: NOUN
# substitute_lemma for substitute 'administrators': administrator
# substitute_pos: NOUN
# substitute_lemma for substitute 'forces': force
# substitute_pos: NOUN
# substitute_lemma for substitute 'prosecutors': prosecutor
# substitute_pos: NOUN
# substitute_lemma for substitute 'officers': officer
# substitute_pos: NOUN
# substitute_lemma for substitute 'entities': entity
# substitute_pos: NOUN
# substitute_lemma for substitute 'intelligence': intelligence
# substitute_pos: NOUN
# substitute_lemma for substitute 'jurisdictions': jurisdiction
# substitute_pos: NOUN
# substitute_lemma for substitute 'individuals': individual
# substitute_pos: NOUN
# substitute_lemma for substitute 'detainees': detainee
# substitute_pos: NOUN
# substitute_lemma for substitute 'institutions': institution
# substitute_pos: NOUN
# substitute_lemma for substitute 'affairs': affair
# substitute_pos: NOUN
# substitute_lemma for substitute 'demonstrators': demonstrator
# substitute_pos: NOUN
# substitute_lemma for substitute 'superiors': superior
# substitute_pos: NOUN
# substitute_lemma for substitute 'victims': victim
# substitute_pos: NOUN
# substitute_lemma for substitute 'regulators': regulator
# substitute_pos: NOUN
# substitute_lemma for substitute 'concerns': concern
# substitute_pos: NOUN
# substitute_lemma for substitute 'ministers': minister
# substitute_pos: NOUN
# substitute_lemma for substitute 'figures': figure
# substitute_pos: NOUN
# substitute_lemma for substitute 'suspects': suspect
# substitute_pos: NOUN
# substitute_lemma for substitute 'sources': source
# substitute_pos: NOUN
# substitute_lemma for substitute 'assistance': assistance
# substitute_pos: NOUN
# SS step: d) substitute list without non-matching pos tags: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: e) substitute list ranked based on semantic similarity: ['officials', 'police', 'investigators', 'prosecutors', 'officers', 'agencies', 'suspects', 'sources', 'victims', 'regulators', 'forces', 'concerns', 'intelligence', 'assistance', 'demonstrators', 'individuals', 'institutions', 'administrators', 'counterparts', 'figures', 'detainees', 'ministers', 'affairs', 'superiors', 'jurisdictions', 'entities']
#
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### result: spacy's pos tagger also does not work well at all either. Will continue without pos tagging so removed d) and replaced it with the previous e)

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>")

    ## concatenate the sentence with the complex word and the sentence with the masked word, by using RoBERTa's separator token to create one string of both sentencesion 
    sentences_concat = f"{sentence} {tokenizer.sep_token} {sentence_masked_word}"

    ## tokenize the concatenated sentence
    sentences_concat_tokenized = tokenizer.encode(sentences_concat, return_tensors='pt')

    ## find the masked word in the tokenized sentence
    mask_location = torch.where(sentences_concat_tokenized == tokenizer.mask_token_id)[1].item()

    ## generate predictions for the masked word (forward pass not needed for predictions, only for training)
    with torch.no_grad():
        outputs = model(sentences_concat_tokenized)
        predictions = outputs.logits

    ## get the top-k substitutes based on the predicted logits
    top_k = 30
    top_tokens = torch.topk(predictions[0, mask_location], top_k).indices

    ## decode the top-k substitutes, lowercase and print them
    substitutes = [tokenizer.decode(token.item()).strip().lower() for token in top_tokens]
    print(f"SG step: generated substitutes: {substitutes}\n")
    
    

    # 2. Substitute Selection (SS): 
    
    # a) remove duplicates from the substitute list 
    
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    print(f"SS step: a) substitute list without duplicates: {substitutes_no_dupl}\n")

   
    # b) remove duplicates and inflected forms of the complex word from the substitute list
    ## Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same (will be deleted)
    doc = nlp(complex_word)
    complex_word_lemma = doc[0].lemma_
    print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}")

    ## remove duplicates and inflected forms of the complex word from the substitute list
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc = nlp(substitute)
        if doc[0].lemma_ != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    print(f"SS step: b) substitute list without duplicates and inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")

    # c) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute:
                    print(f"Antonym removed: {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    print(f"SS step: c): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
    
    # d) perform ranking of substitutes_no_dupl_complex_word_no_antonym_no_matchpos on semantic similarity
    # compute the semantic similarity between the complex word and each substitute
    
    similarities = []
    for substitute in substitutes_no_dupl_complex_word_no_antonym:
        if substitute.lower() in glove.key_to_index:
            similarity = glove.similarity(complex_word.lower(), substitute.lower())
        else:
            print(f"Word not found in embeddings (will be put at the end of the list): {substitute}")
            similarity = -1.0  # set similarity to a negative value to indicate it should be put at the very end of the list
        similarities.append(similarity)

    # rank the substitutes based on their semantic similarity with the complex word
    substitutes_ranked = [x for _, x in sorted(zip(similarities, substitutes_no_dupl_complex_word_no_antonym), reverse=True)]
    print(f"SS step: e) substitute list ranked with glove on semantic similarity: {substitutes_ranked}\n")
    print('----------------------------------------------------------------------------------------------------------------------')
    print()
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# SG step: generated substitutes: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion', 'mandatory']
#
# SS step: a) substitute list without duplicates: ['compulsory', 'mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# complex_word_lemma for complex word 'compulsory': compulsory
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: c): substitute list without antonyms of the complex word: ['mandatory', 'obligatory', 'voluntary', 'required', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# SS step: e) substitute list ranked with glove on semantic similarity: ['obligatory', 'mandatory', 'voluntary', 'requirement', 'required', 'mandated', 'routine', 'enforced', 'uniform', 'customary', 'prerequisite', 'optional', 'universal', 'necessary', 'conditional', 'forced', 'involuntary', 'available', 'obliged', 'sufficient', 'feasible', 'contingent', 'possible', 'forthcoming', 'compelled', 'obligated', 'compulsion', 'indispensable']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# SG step: generated substitutes: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'filled', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: a) substitute list without duplicates: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# complex_word_lemma for complex word 'instilled': instill
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# SS step: c): substitute list without antonyms of the complex word: ['infused', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'impressed', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'struck', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Word not found in embeddings (will be put at the end of the list): illed
# SS step: e) substitute list ranked with glove on semantic similarity: ['stirred', 'undermined', 'infused', 'impressed', 'endowed', 'reassured', 'vested', 'bolstered', 'inspired', 'reinforced', 'intoxicated', 'injected', 'enriched', 'implanted', 'misled', 'stunned', 'augmented', 'inflated', 'pumped', 'invested', 'furnished', 'struck', 'filled', 'imb', 'supplied', 'seeded', 'provided', 'inst', 'illed']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #34-3 "War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# SG step: generated substitutes: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: a) substitute list without duplicates: ['maniac', 'criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# complex_word_lemma for complex word 'maniacs': maniac
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# SS step: c): substitute list without antonyms of the complex word: ['criminals', 'riors', 'hawks', 'heads', 'killers', 'gangs', 'lords', 'thugs', 'devils', 'drums', 'murderers', 'fighters', 'monsters', 'fools', 'villains', 'idiots', 'machines', 'demons', 'doctors', 'planes', 'igans', 'bosses', 'nazis', 'beasts', 'fascists', 'children', 'nerds', 'extremists', 'parasites']
#
# Word not found in embeddings (will be put at the end of the list): riors
# Word not found in embeddings (will be put at the end of the list): igans
# SS step: e) substitute list ranked with glove on semantic similarity: ['idiots', 'nerds', 'thugs', 'fascists', 'monsters', 'fools', 'murderers', 'criminals', 'beasts', 'killers', 'gangs', 'drums', 'villains', 'nazis', 'demons', 'machines', 'fighters', 'extremists', 'parasites', 'bosses', 'children', 'hawks', 'planes', 'lords', 'devils', 'heads', 'doctors', 'riors', 'igans']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# SG step: generated substitutes: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: a) substitute list without duplicates: ['observers', 'monitors', 'spectators', 'witnesses', 'observer', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# complex_word_lemma for complex word 'observers': observer
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: c): substitute list without antonyms of the complex word: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'commentators', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# SS step: e) substitute list ranked with glove on semantic similarity: ['journalists', 'monitors', 'experts', 'analysts', 'participants', 'commentators', 'parties', 'reporters', 'supporters', 'activists', 'outsiders', 'authorities', 'witnesses', 'inspectors', 'protesters', 'investigators', 'spectators', 'demonstrators', 'residents', 'observing', 'cameras', 'visitors', 'viewers', 'observations', 'followers', 'eyes', 'responders', 'observes']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# SG step: generated substitutes: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: a) substitute list without duplicates: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# complex_word_lemma for complex word 'shrapnel': shrapnel
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# SS step: c): substitute list without antonyms of the complex word: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Word not found in embeddings (will be put at the end of the list): rapnel
# SS step: e) substitute list ranked with glove on semantic similarity: ['gunshot', 'bullet', 'bullets', 'grenade', 'stab', 'mortar', 'piercing', 'blast', 'bomb', 'rocket', 'stray', 'shell', 'projectile', 'unidentified', 'explosive', 'ammunition', 'shotgun', 'fragmentation', 'radiation', 'torpedo', 'stun', 'cartridge', 'pillow', 'insurgent', 'microscopic', 'crippling', 'similar', 'terrorist', 'slug', 'rapnel']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# SG step: generated substitutes: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: a) substitute list without duplicates: ['disguised', 'dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# complex_word_lemma for complex word 'disguised': disguised
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# SS step: c): substitute list without antonyms of the complex word: ['dressed', 'veiled', 'masked', 'concealed', 'hidden', 'disguise', 'clothed', 'clad', 'posed', 'covered', 'cloaked', 'shrouded', 'wrapped', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'draped', 'described', 'decorated', 'armed', 'buried', 'camouflage', 'marked', 'hid']
#
# Word not found in embeddings (will be put at the end of the list): camoufl
# SS step: e) substitute list ranked with glove on semantic similarity: ['disguise', 'veiled', 'masked', 'concealed', 'posing', 'dressed', 'hidden', 'camouflage', 'hid', 'clothed', 'cloaked', 'hiding', 'armed', 'clad', 'smuggled', 'posed', 'draped', 'wrapped', 'described', 'known', 'staged', 'trained', 'decorated', 'shrouded', 'covered', 'presented', 'buried', 'marked', 'camoufl']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# SG step: generated substitutes: ['off', 'extension', 'opposite', 'outpost', 'off', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: a) substitute list without duplicates: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# complex_word_lemma for complex word 'offshoot': offshoot
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: c): substitute list without antonyms of the complex word: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'arm', 'ideology', 'overhaul', 'branch', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# SS step: e) substitute list ranked with glove on semantic similarity: ['ideology', 'affiliate', 'overthrow', 'archetype', 'imprint', 'independent', 'branch', 'alternative', 'element', 'outpost', 'opposition', 'evolution', 'arm', 'embrace', 'offspring', 'expansion', 'indication', 'example', 'out', 'outside', 'echo', 'adjunct', 'extension', 'off', 'instance', 'overhaul', 'opposite', 'extend', 'upset']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# SG step: generated substitutes: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: a) substitute list without duplicates: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# complex_word_lemma for complex word 'symphonic': symphonic
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# SS step: c): substitute list without antonyms of the complex word: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Word not found in embeddings (will be put at the end of the list): onic
# SS step: e) substitute list ranked with glove on semantic similarity: ['orchestra', 'piano', 'classical', 'opera', 'composition', 'musical', 'concert', 'jazz', 'music', 'instrumental', 'lyric', 'composing', 'vocal', 'harmonic', 'singing', 'contemporary', 'trumpet', 'keyboard', 'dramatic', 'modern', 'sonic', 'popular', 'english', 'formal', 'early', 'technical', 'standard', 'major', 'sym', 'onic']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# SG step: generated substitutes: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'deploy', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: a) substitute list without duplicates: ['deploy', 'deployed', 'deployment', 'utilize', 'mobilize', 'employ', 'deploying', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# complex_word_lemma for complex word 'deploy': deploy
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: c): substitute list without antonyms of the complex word: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# SS step: e) substitute list ranked with glove on semantic similarity: ['deployment', 'equip', 'send', 'withdraw', 'install', 'mobilize', 'dispatch', 'recruit', 'operate', 'employ', 'activate', 'utilize', 'unleash', 'engage', 'locate', 'adopt', 'use', 'summon', 'construct', 'commit', 'reserve', 'possess', 'transport', 'cultivate', 'expend', 'ploy']
#
# ----------------------------------------------------------------------------------------------------------------------
#
# Sentence: #35-14 UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# SG step: generated substitutes: ['authorities', 'officials', 'authorities', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'authorities', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: a) substitute list without duplicates: ['authorities', 'officials', 'authority', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# complex_word_lemma for complex word 'authorities': authority
# SS step: b) substitute list without duplicates and inflected forms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: c): substitute list without antonyms of the complex word: ['officials', 'investigators', 'counterparts', 'police', 'agencies', 'administrators', 'forces', 'prosecutors', 'officers', 'entities', 'intelligence', 'jurisdictions', 'individuals', 'detainees', 'institutions', 'affairs', 'demonstrators', 'superiors', 'victims', 'regulators', 'concerns', 'ministers', 'figures', 'suspects', 'sources', 'assistance']
#
# SS step: e) substitute list ranked with glove on semantic similarity: ['officials', 'police', 'investigators', 'prosecutors', 'officers', 'agencies', 'suspects', 'sources', 'victims', 'regulators', 'forces', 'concerns', 'intelligence', 'assistance', 'demonstrators', 'individuals', 'institutions', 'administrators', 'counterparts', 'figures', 'detainees', 'ministers', 'affairs', 'superiors', 'jurisdictions', 'entities']
#
# ----------------------------------------------------------------------------------------------------------------------
