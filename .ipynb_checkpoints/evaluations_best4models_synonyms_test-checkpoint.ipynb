# %% [markdown]
# #### Evaluations BERT for the TEST set

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/test/tsar2022_en_test_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
# the code below is used for morphological adjustments in step MA
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %% [markdown]
# #### Bert-large-uncased

# %%
# Instantiate the tokenizer and the model

lm_tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")
lm_model= AutoModelForMaskedLM.from_pretrained("bert-large-uncased")


# Instantiate the fill-mask pipeline with the model
fill_mask= pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #### Substitute Generation and Morphological Adaptation: substitutes with shared synonyms with the complex word first:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes model: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
    
    
    
    # create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    # iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
    
    #print(f"List of substitutes that are synonyms with the complex word in Wordnet: {synonyms}\n")
    #print(f"List of substitutes that are not synonyms with the complex word in Wordnet: {non_synonyms}\n")

    # combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    #print(f"Final list with synonyms appearing first: {final_list}\n")

        
    
    #     # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    #print(f"Final top-10 with synonyms with the complex word in Wordnet appearing first: {top_10_substitutes}\n")
    
    #print('--------------------------------------------------------------------------------------------------------------------------------------------')
    

    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/test/SG_MA_bertlarge_synsfirst.tsv", sep="\t", index=False, header=False)
print("SG_MA_bertlarge_synsfirst exported to csv in path './predictions/test/SG_MA_bertlarge_synsfirst.tsv'}\n")
# Out:
# List of substitutes that are synonyms with the complex word in Wordnet: ['mandatory', 'required']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Final list with synonyms appearing first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed', 'illegal', 'available', 'beneficial', 'prohibited', 'scheduled', 'obliged', 'tertiary', 'secondary', 'statutory', 'legal', 'free', 'used', 'customary', 'primary', 'authorised', 'canonical', 'standard', 'lawful']
#
# Final top-10 with synonyms appearing first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'mandated', 'necessary', 'forbidden', 'permitted', 'prescribed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['infused', 'impressed', 'struck']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'fed', 'gifted', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Final list with synonyms appearing first: ['infused', 'impressed', 'struck', 'provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed', 'fed', 'gifted', 'furnished', 'inspired', 'fitted', 'equipped', 'raised', 'given', 'seeded', 'created', 'rewarded', 'hit', 'treated', 'introduced', 'encouraged', 'infected', 'tested', 'shaken', 'offered', 'filled']
#
# Final top-10 with synonyms appearing first: ['infused', 'impressed', 'struck', 'provided', 'injected', 'presented', 'left', 'supplied', 'delivered', 'endowed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Final list with synonyms appearing first: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans', 'heroes', 'leaders', 'victims', 'crimes', 'elephants', 'enthusiasts', 'monsters', 'gods', 'zombies', 'puppets', 'dolls', 'theorists', 'insects', 'pigs', 'demons', 'lovers', 'fighters', 'makers']
#
# Final top-10 with synonyms appearing first: ['mania', 'machines', 'criminals', 'killers', 'freaks', 'hysteria', 'sims', 'dogs', 'followers', 'fans']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Final list with synonyms appearing first: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts', 'activists', 'casualties', 'volunteers', 'civilians', 'observing', 'people', 'citizens', 'combatants', 'observe', 'individuals', 'indicators', 'monitoring', 'troops', 'soldiers', 'victims', 'refugees', 'instruments']
#
# Final top-10 with synonyms appearing first: ['monitors', 'witnesses', 'participants', 'analysts', 'spectators', 'observations', 'journalists', 'fighters', 'observation', 'experts']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Final list with synonyms appearing first: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle', 'three', 'splinter', 'shot', 'serious', 'exit', 'entry', 'shotgun', 'several', 'two', 'severe', 'shell', 'open', 'burn', 'bomb', 'penetrating', 'the', 'inflicted', 'stabbing', 'internal', 'fatal']
#
# Final top-10 with synonyms appearing first: ['gunshot', 'bullet', 'stab', 'knife', 'flesh', 'arrow', 'multiple', 'minor', 'blast', 'battle']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['masked', 'disguise', 'clothed', 'draped', 'cloak']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['dressed', 'dressing', 'armoured', 'concealed', 'clad', 'guise', 'hiding', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Final list with synonyms appearing first: ['masked', 'disguise', 'clothed', 'draped', 'cloak', 'dressed', 'dressing', 'armoured', 'concealed', 'clad', 'guise', 'hiding', 'posing', 'appearing', 'hidden', 'acting', 'dress', 'painted', 'seated', 'fitted', 'identified', 'covered', 'armed', 'appeared', 'armored', 'undercover', 'portrayed', 'depicted']
#
# Final top-10 with synonyms appearing first: ['masked', 'disguise', 'clothed', 'draped', 'cloak', 'dressed', 'dressing', 'armoured', 'concealed', 'clad']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['arm']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Final list with synonyms appearing first: ['arm', 'extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave', 'heir', 'isolate', 'offspring', 'expression', 'orthodox', 'evolution', 'exception', 'example', 'sect', 'embrace', 'echo', 'approximation', 'adherence', 'adhere', 'adaptation', 'associate', 'issue', 'inhibitor', 'imitation', 'extreme']
#
# Final top-10 with synonyms appearing first: ['arm', 'extension', 'affiliate', 'ally', 'outpost', 'element', 'opponent', 'enemy', 'aspect', 'enclave']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Final list with synonyms appearing first: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano', 'concert', 'chamber', 'music', 'orchestra', 'modern', 'lyrical', 'thematic', 'instrumental', 'continental', 'orchestrated', 'scholarly', 'dramatic', 'goldberg', 'romantic', 'standard', 'choral', 'poetic', 'comparative', 'written']
#
# Final top-10 with synonyms appearing first: ['orchestral', 'classical', 'symphony', 'philharmonic', 'symphonies', 'musical', 'concerto', 'sonata', 'operatic', 'piano']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Final list with synonyms appearing first: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate', 'employ', 'acquire', 'maintain', 'reinforce', 'exercise', 'install', 'build', 'move', 'drill', 'fire', 'construct', 'alert', 'dock', 'establish', 'release', 'outfit', 'station', 'ready']
#
# Final top-10 with synonyms appearing first: ['activate', 'deployment', 'dispatch', 'assemble', 'launch', 'send', 'use', 'withdraw', 'utilize', 'operate']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Final list with synonyms appearing first: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government', 'prosecutors', 'journalists', 'governments', 'nationals', 'prisoners', 'citizens', 'judges', 'ministers', 'applicants', 'bodies', 'residents', 'operators', 'policemen', 'rulers', 'suspects', 'defendants']
#
# Final top-10 with synonyms appearing first: ['police', 'officials', 'courts', 'people', 'magistrates', 'officers', 'victims', 'investigators', 'forces', 'government']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SG_MA_bertlarge_synsfirst exported to csv in path './predictions/trial/SG_MA_bertlarge_synsfirst.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/test/tsar2022_en_test_gold_no_noise.tsv --predictions_file ./predictions/test/SG_MA_bertlarge_synsfirst.tsv --output_file ./output/test/SG_MA_bertlarge_synsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/test/tsar2022_en_test_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/test/SG_MA_bertlarge_synsfirst.tsv
# OUTPUT file = ./output/test/SG_MA_bertlarge_synsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6102
#
# MAP@3 = 0.3921
# MAP@5 = 0.299
# MAP@10 = 0.1861
#
# Potential@3 = 0.8172
# Potential@5 = 0.8844
# Potential@10 = 0.9408
#
# Accuracy@1@top_gold_1 = 0.2741
# Accuracy@2@top_gold_1 = 0.3709
# Accuracy@3@top_gold_1 = 0.4838

# %% [markdown]
# #### Electra-large:

# %%
# Instantiate the tokenizer and the model
lm_tokenizer = AutoTokenizer.from_pretrained("google/electra-large-generator")
lm_model = AutoModelForMaskedLM.from_pretrained("google/electra-large-generator")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes model: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
    
    
    
    # create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    # iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
  
    #print(f"List of substitutes that are synonyms with the complex word in Wordnet: {synonyms}\n")
    #print(f"List of substitutes that are not synonyms with the complex word in Wordnet: {non_synonyms}\n")

    # combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    #print(f"Final list with synonyms appearing first: {final_list}\n")

        
    
    #     # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    #print(f"Final top-10 with synonyms with the complex word in Wordnet appearing first: {top_10_substitutes}\n")
    
    #print('--------------------------------------------------------------------------------------------------------------------------------------------')
    

    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/test/SG_MA_electralarge_synsfirst.tsv", sep="\t", index=False, header=False)
print("SG_MA_electralarge_synsfirst exported to csv in path './predictions/test/SG_MA_electralarge_synsfirst.tsv'}\n")
# Out:
# List of substitutes that are synonyms with the complex word in Wordnet: ['mandatory', 'required']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['obligatory', 'optional', 'necessary', 'voluntary', 'standard', 'mandated', 'redundant', 'unnecessary', 'possible', 'essential', 'prescribed', 'free', 'universal', 'consent', 'obsolete', 'sanctioned', 'fashionable', 'valid', 'taboo', 'supplementary', 'forbidden', 'continuous', 'illegal', 'requirement', 'prohibited', 'banned', 'sufficient']
#
# Final list with synonyms appearing first: ['mandatory', 'required', 'obligatory', 'optional', 'necessary', 'voluntary', 'standard', 'mandated', 'redundant', 'unnecessary', 'possible', 'essential', 'prescribed', 'free', 'universal', 'consent', 'obsolete', 'sanctioned', 'fashionable', 'valid', 'taboo', 'supplementary', 'forbidden', 'continuous', 'illegal', 'requirement', 'prohibited', 'banned', 'sufficient']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['mandatory', 'required', 'obligatory', 'optional', 'necessary', 'voluntary', 'standard', 'mandated', 'redundant', 'unnecessary']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['infused', 'impressed']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['cultivated', 'stamped', 'conditioned', 'demonstrated', 'programmed', 'blessed', 'placed', 'created', 'shocked', 'captured', 'targeted', 'fed', 'stunned', 'reinforced', 'educated', 'promoted', 'packed', 'coated', 'communicated', 'marketed', 'brought', 'developed', 'surprised']
#
# Final list with synonyms appearing first: ['infused', 'impressed', 'cultivated', 'stamped', 'conditioned', 'demonstrated', 'programmed', 'blessed', 'placed', 'created', 'shocked', 'captured', 'targeted', 'fed', 'stunned', 'reinforced', 'educated', 'promoted', 'packed', 'coated', 'communicated', 'marketed', 'brought', 'developed', 'surprised']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['infused', 'impressed', 'cultivated', 'stamped', 'conditioned', 'demonstrated', 'programmed', 'blessed', 'placed', 'created']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['mania', 'criminals', 'masters', 'crimes', 'bosses', 'freaks', 'monsters', 'monkeys', 'figures', 'mad', 'thugs', 'leaders', 'controllers', 'machines', 'devotees', 'participants', 'police', 'killers', 'followers', 'types', 'minions', 'balls', 'personalities', 'powers', 'zombies', 'nazis', 'forces', 'operators']
#
# Final list with synonyms appearing first: ['mania', 'criminals', 'masters', 'crimes', 'bosses', 'freaks', 'monsters', 'monkeys', 'figures', 'mad', 'thugs', 'leaders', 'controllers', 'machines', 'devotees', 'participants', 'police', 'killers', 'followers', 'types', 'minions', 'balls', 'personalities', 'powers', 'zombies', 'nazis', 'forces', 'operators']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['mania', 'criminals', 'masters', 'crimes', 'bosses', 'freaks', 'monsters', 'monkeys', 'figures', 'mad']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['monitors', 'journalists', 'reporters', 'diplomats', 'witnesses', 'refugees', 'experts', 'monitoring', 'observation', 'activists', 'scientists', 'analysts', 'observations', 'people', 'spectators', 'participants', 'media', 'visitors', 'ngos', 'outsiders', 'critics', 'specialists', 'civilians', 'officers', 'police', 'observing', 'officials', 'soldiers']
#
# Final list with synonyms appearing first: ['monitors', 'journalists', 'reporters', 'diplomats', 'witnesses', 'refugees', 'experts', 'monitoring', 'observation', 'activists', 'scientists', 'analysts', 'observations', 'people', 'spectators', 'participants', 'media', 'visitors', 'ngos', 'outsiders', 'critics', 'specialists', 'civilians', 'officers', 'police', 'observing', 'officials', 'soldiers']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['monitors', 'journalists', 'reporters', 'diplomats', 'witnesses', 'refugees', 'experts', 'monitoring', 'observation', 'activists']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['gunshot', 'stab', 'bullet', 'multiple', 'blood', 'bleeding', 'bloody', 'small', 'knife', 'severe', 'burn', 'skin', 'surgical', 'kidney', 'stabbing', 'cut', 'internal', 'infected', 'superficial', 'wound', 'bone', 'broken', 'sharp', 'other', 'some', 'head', 'minor', 'open', 'liver', 'raw']
#
# Final list with synonyms appearing first: ['gunshot', 'stab', 'bullet', 'multiple', 'blood', 'bleeding', 'bloody', 'small', 'knife', 'severe', 'burn', 'skin', 'surgical', 'kidney', 'stabbing', 'cut', 'internal', 'infected', 'superficial', 'wound', 'bone', 'broken', 'sharp', 'other', 'some', 'head', 'minor', 'open', 'liver', 'raw']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['gunshot', 'stab', 'bullet', 'multiple', 'blood', 'bleeding', 'bloody', 'small', 'knife', 'severe']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['clothed', 'masked', 'disguise', 'camouflage', 'wrapped']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['dressed', 'concealed', 'clad', 'hidden', 'hiding', 'armed', 'posing', 'classified', 'appearing', 'identified', 'manifested', 'contained', 'positioned', 'posed', 'dressing', 'caught', 'naked', 'trapped', 'hid', 'appeared', 'branded', 'trained', 'revealed']
#
# Final list with synonyms appearing first: ['clothed', 'masked', 'disguise', 'camouflage', 'wrapped', 'dressed', 'concealed', 'clad', 'hidden', 'hiding', 'armed', 'posing', 'classified', 'appearing', 'identified', 'manifested', 'contained', 'positioned', 'posed', 'dressing', 'caught', 'naked', 'trapped', 'hid', 'appeared', 'branded', 'trained', 'revealed']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['clothed', 'masked', 'disguise', 'camouflage', 'wrapped', 'dressed', 'concealed', 'clad', 'hidden', 'hiding']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['extension', 'antagonist', 'imitation', 'affiliate', 'adjunct', 'associate', 'affiliation', 'expansion', 'opposite', 'ally', 'embrace', 'isolate', 'subset', 'assimilation', 'outsider', 'outpost', 'attack', 'opponent', 'element', 'extract', 'amalgamation', 'origin', 'independent', 'organization', 'analogue', 'aspect', 'aggregation', 'echo']
#
# Final list with synonyms appearing first: ['extension', 'antagonist', 'imitation', 'affiliate', 'adjunct', 'associate', 'affiliation', 'expansion', 'opposite', 'ally', 'embrace', 'isolate', 'subset', 'assimilation', 'outsider', 'outpost', 'attack', 'opponent', 'element', 'extract', 'amalgamation', 'origin', 'independent', 'organization', 'analogue', 'aspect', 'aggregation', 'echo']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['extension', 'antagonist', 'imitation', 'affiliate', 'adjunct', 'associate', 'affiliation', 'expansion', 'opposite', 'ally']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['orchestral', 'symphony', 'music', 'choral', 'musical', 'melodic', 'classical', 'concert', 'romantic', 'modern', 'technical', 'gothic', 'composition', 'vocal', 'lyric', 'composer', 'instrumental', 'english', 'operatic', 'sacred', 'composing', 'piano', 'beethoven', 'concerto', 'popular', 'contemporary', 'original', 'creative', 'universal']
#
# Final list with synonyms appearing first: ['orchestral', 'symphony', 'music', 'choral', 'musical', 'melodic', 'classical', 'concert', 'romantic', 'modern', 'technical', 'gothic', 'composition', 'vocal', 'lyric', 'composer', 'instrumental', 'english', 'operatic', 'sacred', 'composing', 'piano', 'beethoven', 'concerto', 'popular', 'contemporary', 'original', 'creative', 'universal']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['orchestral', 'symphony', 'music', 'choral', 'musical', 'melodic', 'classical', 'concert', 'romantic', 'modern']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['send', 'use', 'build', 'dispatch', 'add', 'expand', 'move', 'employ', 'relocate', 'develop', 'withdraw', 'launch', 'acquire', 'station', 'deployment', 'construct', 'provide', 'maintain', 'deliver', 'adopt', 'create', 'install', 'activate', 'commit', 'utilize', 'reserve', 'design', 'establish']
#
# Final list with synonyms appearing first: ['send', 'use', 'build', 'dispatch', 'add', 'expand', 'move', 'employ', 'relocate', 'develop', 'withdraw', 'launch', 'acquire', 'station', 'deployment', 'construct', 'provide', 'maintain', 'deliver', 'adopt', 'create', 'install', 'activate', 'commit', 'utilize', 'reserve', 'design', 'establish']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['send', 'use', 'build', 'dispatch', 'add', 'expand', 'move', 'employ', 'relocate', 'develop']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['agencies']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['officials', 'police', 'people', 'government', 'prosecutors', 'governments', 'investigators', 'officers', 'courts', 'nationals', 'citizens', 'administrations', 'magistrates', 'policemen', 'personnel', 'communities', 'law', 'bodies', 'supervision', 'administration', 'prisons', 'standards', 'departments', 'institutions', 'enforcement']
#
# Final list with synonyms appearing first: ['agencies', 'officials', 'police', 'people', 'government', 'prosecutors', 'governments', 'investigators', 'officers', 'courts', 'nationals', 'citizens', 'administrations', 'magistrates', 'policemen', 'personnel', 'communities', 'law', 'bodies', 'supervision', 'administration', 'prisons', 'standards', 'departments', 'institutions', 'enforcement']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['agencies', 'officials', 'police', 'people', 'government', 'prosecutors', 'governments', 'investigators', 'officers', 'courts']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SG_MA_electralarge_synsfirst exported to csv in path './predictions/trial/SG_MA_electralarge_synsfirst.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/test/tsar2022_en_test_gold_no_noise.tsv --predictions_file ./predictions/test/SG_MA_electralarge_synsfirst.tsv --output_file ./output/test/SG_MA_electralarge_synsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/test/tsar2022_en_test_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/test/SG_MA_electralarge_synsfirst.tsv
# OUTPUT file = ./output/test/SG_MA_electralarge_synsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6048
#
# MAP@3 = 0.4011
# MAP@5 = 0.3067
# MAP@10 = 0.1874
#
# Potential@3 = 0.801
# Potential@5 = 0.8655
# Potential@10 = 0.9354
#
# Accuracy@1@top_gold_1 = 0.2634
# Accuracy@2@top_gold_1 = 0.4112
# Accuracy@3@top_gold_1 = 0.4865

# %% [markdown]
# #### Roberta-base:

# %%
# Instantiate the tokenizer and the model
lm_tokenizer = AutoTokenizer.from_pretrained("roberta-base")
lm_model = AutoModelForMaskedLM.from_pretrained("roberta-base")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes model: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
    
    
    
    # create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    # iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
    #print(f"List of substitutes that are synonyms with the complex word in Wordnet: {synonyms}\n")
    #print(f"List of substitutes that are not synonyms with the complex word in Wordnet: {non_synonyms}\n")

    # combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    #print(f"Final list with synonyms appearing first: {final_list}\n")

        
    
    #     # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    #print(f"Final top-10 with synonyms with the complex word in Wordnet appearing first: {top_10_substitutes}\n")
    
    #print('--------------------------------------------------------------------------------------------------------------------------------------------')
    
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/test/SG_MA_robertabase_synsfirst.tsv", sep="\t", index=False, header=False)
print("SG_MA_robertabase_synsfirst exported to csv in path './predictions/test/SG_MA_robertabase_synsfirst.tsv'}\n")
# Out:
# List of substitutes that are synonyms with the complex word in Wordnet: ['mandatory', 'required']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['obligatory', 'voluntary', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# Final list with synonyms appearing first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated', 'sufficient', 'routine', 'forced', 'customary', 'prerequisite', 'feasible', 'indispensable', 'forthcoming', 'universal', 'requirement', 'involuntary', 'obligated', 'compelled', 'conditional', 'enforced', 'contingent', 'possible', 'compulsion']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['mandatory', 'required', 'obligatory', 'voluntary', 'optional', 'obliged', 'uniform', 'necessary', 'available', 'mandated']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['infused', 'impressed', 'struck']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Final list with synonyms appearing first: ['infused', 'impressed', 'struck', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered', 'implanted', 'reinforced', 'invested', 'provided', 'filled', 'reassured', 'undermined', 'pumped', 'augmented', 'enriched', 'stirred', 'vested', 'imb', 'intoxicated', 'seeded', 'misled', 'stunned', 'inspired', 'inflated']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['infused', 'impressed', 'struck', 'injected', 'endowed', 'illed', 'inst', 'furnished', 'supplied', 'bolstered']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['killers', 'criminals', 's', 'murderers', 'hawks', 'thugs', 'atics', 'terrorists', 'riors', 'extremists', 'heads', 'villains', 'igans', 'gangs', 'monsters', 'militias', 'fascists', 'nazis', 'devils', 'fighters', 'jihadists', 'idiots', 'beasts', 'bombers', 'planners', 'ners', 'revolutionaries', 'creatures', 'perpetrators']
#
# Final list with synonyms appearing first: ['killers', 'criminals', 's', 'murderers', 'hawks', 'thugs', 'atics', 'terrorists', 'riors', 'extremists', 'heads', 'villains', 'igans', 'gangs', 'monsters', 'militias', 'fascists', 'nazis', 'devils', 'fighters', 'jihadists', 'idiots', 'beasts', 'bombers', 'planners', 'ners', 'revolutionaries', 'creatures', 'perpetrators']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['killers', 'criminals', 's', 'murderers', 'hawks', 'thugs', 'atics', 'terrorists', 'riors', 'extremists']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['commentators']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# Final list with synonyms appearing first: ['commentators', 'monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'investigators', 'participants', 'analysts', 'cameras', 'outsiders', 'demonstrators', 'activists', 'journalists', 'experts', 'authorities', 'observations', 'eyes', 'supporters', 'observing', 'residents', 'protesters', 'responders', 'parties', 'followers']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['commentators', 'monitors', 'spectators', 'witnesses', 'observes', 'visitors', 'viewers', 'reporters', 'inspectors', 'investigators']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Final list with synonyms appearing first: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun', 'explosive', 'stray', 'shell', 'bomb', 'microscopic', 'fragmentation', 'cartridge', 'grenade', 'rocket', 'torpedo', 'piercing', 'unidentified', 'ammunition', 'insurgent', 'similar', 'blast', 'bullets', 'slug', 'terrorist', 'pillow']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['rapnel', 'bullet', 'gunshot', 'stab', 'radiation', 'projectile', 'crippling', 'shotgun', 'mortar', 'stun']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['masked', 'disguise', 'clothed', 'cloaked', 'wrapped', 'draped', 'camouflage']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['dressed', 'veiled', 'concealed', 'hidden', 'clad', 'posed', 'covered', 'shrouded', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'described', 'decorated', 'armed', 'buried', 'marked', 'hid']
#
# Final list with synonyms appearing first: ['masked', 'disguise', 'clothed', 'cloaked', 'wrapped', 'draped', 'camouflage', 'dressed', 'veiled', 'concealed', 'hidden', 'clad', 'posed', 'covered', 'shrouded', 'posing', 'hiding', 'trained', 'camoufl', 'presented', 'known', 'smuggled', 'staged', 'described', 'decorated', 'armed', 'buried', 'marked', 'hid']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['masked', 'disguise', 'clothed', 'cloaked', 'wrapped', 'draped', 'camouflage', 'dressed', 'veiled', 'concealed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['arm', 'branch']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'ideology', 'overhaul', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# Final list with synonyms appearing first: ['arm', 'branch', 'off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow', 'element', 'outside', 'echo', 'expansion', 'imprint', 'ideology', 'overhaul', 'opposition', 'evolution', 'indication', 'upset', 'archetype', 'extend', 'independent', 'alternative', 'example', 'instance', 'embrace', 'adjunct']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['arm', 'branch', 'off', 'extension', 'opposite', 'outpost', 'out', 'affiliate', 'offspring', 'overthrow']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Final list with synonyms appearing first: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern', 'dramatic', 'major', 'vocal', 'composing', 'concert', 'opera', 'sonic', 'formal', 'popular', 'early', 'composition', 'english', 'singing', 'standard', 'trumpet', 'keyboard', 'contemporary', 'orchestra', 'technical', 'onic']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['classical', 'harmonic', 'musical', 'sym', 'music', 'instrumental', 'piano', 'lyric', 'jazz', 'modern']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# Final list with synonyms appearing first: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit', 'transport', 'operate', 'withdraw', 'install', 'locate', 'commit', 'construct', 'summon', 'expend', 'send', 'reserve', 'possess', 'cultivate', 'adopt', 'engage', 'unleash']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['deployment', 'utilize', 'mobilize', 'employ', 'dispatch', 'equip', 'ploy', 'use', 'activate', 'recruit']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['agencies']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['officials', 'police', 'counterparts', 'investigators', 'administrators', 'forces', 'officers', 'prosecutors', 'intelligence', 'entities', 'institutions', 'regulators', 'figures', 'affairs', 'individuals', 'detainees', 'superiors', 'victims', 'jurisdictions', 'ministers', 'concerns', 'demonstrators', 'courts', 'suspects', 'sources']
#
# Final list with synonyms appearing first: ['agencies', 'officials', 'police', 'counterparts', 'investigators', 'administrators', 'forces', 'officers', 'prosecutors', 'intelligence', 'entities', 'institutions', 'regulators', 'figures', 'affairs', 'individuals', 'detainees', 'superiors', 'victims', 'jurisdictions', 'ministers', 'concerns', 'demonstrators', 'courts', 'suspects', 'sources']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['agencies', 'officials', 'police', 'counterparts', 'investigators', 'administrators', 'forces', 'officers', 'prosecutors', 'intelligence']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SG_MA_robertabase_synsfirst exported to csv in path './predictions/trial/SG_MA_robertabase_synsfirst.tsv'}

# %%
python tsar_eval.py --gold_file ./data/test/tsar2022_en_test_gold_no_noise.tsv --predictions_file ./predictions/test/SG_MA_robertabase_synsfirst.tsv --output_file ./output/test/SG_MA_robertabase_synsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/test/tsar2022_en_test_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/test/SG_MA_robertabase_synsfirst.tsv
# OUTPUT file = ./output/test/SG_MA_robertabase_synsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5672
#
# MAP@3 = 0.3942
# MAP@5 = 0.2981
# MAP@10 = 0.1867
#
# Potential@3 = 0.8145
# Potential@5 = 0.9139
# Potential@10 = 0.9596
#
# Accuracy@1@top_gold_1 = 0.2795
# Accuracy@2@top_gold_1 = 0.4005
# Accuracy@3@top_gold_1 = 0.4758

# %% [markdown]
# #### Roberta-large:

# %%
# Instantiate the tokenizer and the model
lm_tokenizer = AutoTokenizer.from_pretrained("roberta-large")
lm_model = AutoModelForMaskedLM.from_pretrained("roberta-large")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
    
    # print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    #print(f"Sentence: {sentence}")
    #print(f"Complex word: {complex_word}")
    
    
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, lm_tokenizer.mask_token)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result= fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes. Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower().strip() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) # added .strip as roberta uses a leading space before each substitute
                      and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes model: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


     ## d) remove antonyms of the complex word from the substitute list
    ## step 1: get the antonyms of the complex word
    antonyms_complex_word = []
    for syn in wn.synsets(complex_word_lemma):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                    antonyms_complex_word.append(antonym.name())

    #print(f"Antonyms for complex word '{complex_word}': {antonyms_complex_word}\n")

    ## step 2: remove antonyms of the complex word from the list with substitutes
    substitutes_no_antonyms = []
    for substitute in substitutes_no_dupl_complex_word:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma not in antonyms_complex_word:
            substitutes_no_antonyms.append(substitute)
        # else:
        #     print(f"Removed antonym: {substitute}")
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_antonyms}\n") 
    
    
    
    # create two lists to hold synonyms and non-synonyms
    synonyms = []
    non_synonyms = []

    # iterate through each substitute
    for substitute in substitutes_no_antonyms:
        substitute_synsets = wn.synsets(substitute)
        #print(f"substitute_synsets for {substitute}: {substitute_synsets}\n")

        # get all the lemmas for the substitute
        substitute_syn_lemmas = [lemma.name() for syn in substitute_synsets for lemma in syn.lemmas()]
        #print(f"substitute_syn_lemmas for {substitute}: {substitute_syn_lemmas}\n")

        # get all the lemmas for the complex word
        complex_word_synsets = wn.synsets(complex_word_lemma)
        #print(f"complex_word_synsets for {complex_word}: {complex_word_synsets}\n")

        complex_word_syn_lemmas = [lemma.name() for syn in complex_word_synsets for lemma in syn.lemmas()]
        #print(f"complex_word_syn_lemmas for {complex_word}: {complex_word_syn_lemmas}\n")

        # find the intersection between the lemmas of the substitute and the complex word
        intersection = set(complex_word_syn_lemmas).intersection(set(substitute_syn_lemmas))
        #print(f"intersection between lemmas of synsets of complex word {complex_word} and lemmas of synsets of substitute {substitute}: {intersection}\n")

        if intersection:
            #print(f"Substitute {substitute} is a synonym of the complex word. Matching lemmas of their synsets: {intersection}\n")
            # Add substitute to synonyms list
            synonyms.append(substitute)
        else:
            # Add substitute to non_synonyms list
            non_synonyms.append(substitute)

        
    #print(f"List of substitutes that are synonyms with the complex word in Wordnet: {synonyms}\n")
    #print(f"List of substitutes that are not synonyms with the complex word in Wordnet: {non_synonyms}\n")

    # combine the lists with synonyms appearing first
    final_list = synonyms + non_synonyms
    #print(f"Final list with synonyms appearing first: {final_list}\n")

        
    
    #     # limit the substitutes to the 10 highest ranked ones for evaluation
    top_10_substitutes = final_list[:10]
    #print(f"Final top-10 with synonyms with the complex word in Wordnet appearing first: {top_10_substitutes}\n")
    
    #print('--------------------------------------------------------------------------------------------------------------------------------------------')
    
    
    # # add the sentence, complex_word, and the substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes
    
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/test/SG_MA_robertalarge_synsfirst.tsv", sep="\t", index=False, header=False)
print("SG_MA_robertalarge_synsfirst exported to csv in path './predictions/test/SG_MA_robertalarge_synsfirst.tsv'}\n")
# Out:
# List of substitutes that are synonyms with the complex word in Wordnet: ['mandatory', 'required', 'mandate']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['mandated', 'voluntary', 'obligatory', 'statutory', 'redundant', 'enforced', 'routine', 'relevant', 'vital', 'clandestine', 'obliged', 'bureaucratic', 'ministerial', 'necessary', 'lifelong', 'strict', 'gradual', 'demanded', 'lax', 'continuous', 'practicable', 'indispensable', 'forced', 'habitual', 'plain', 'preferable']
#
# Final list with synonyms appearing first: ['mandatory', 'required', 'mandate', 'mandated', 'voluntary', 'obligatory', 'statutory', 'redundant', 'enforced', 'routine', 'relevant', 'vital', 'clandestine', 'obliged', 'bureaucratic', 'ministerial', 'necessary', 'lifelong', 'strict', 'gradual', 'demanded', 'lax', 'continuous', 'practicable', 'indispensable', 'forced', 'habitual', 'plain', 'preferable']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['mandatory', 'required', 'mandate', 'mandated', 'voluntary', 'obligatory', 'statutory', 'redundant', 'enforced', 'routine']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['infused', 'impressed']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['injected', 'filled', 'inst', 'invested', 'illed', 'infected', 'revived', 'endowed', 'gifted', 'reassured', 'implanted', 'infiltrated', 'pumped', 'inject', 'flooded', 'sprinkled', 'installed', 'vested', 'thrilled', 'assured', 'penetrated', 'hit', 'provided', 'insulated', 'vaccinated', 'stocked', 'stoked', 'elevated']
#
# Final list with synonyms appearing first: ['infused', 'impressed', 'injected', 'filled', 'inst', 'invested', 'illed', 'infected', 'revived', 'endowed', 'gifted', 'reassured', 'implanted', 'infiltrated', 'pumped', 'inject', 'flooded', 'sprinkled', 'installed', 'vested', 'thrilled', 'assured', 'penetrated', 'hit', 'provided', 'insulated', 'vaccinated', 'stocked', 'stoked', 'elevated']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['infused', 'impressed', 'injected', 'filled', 'inst', 'invested', 'illed', 'infected', 'revived', 'endowed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['s', 'mercenaries', 'killers', 'militias', 'thugs', 'fighters', 'criminals', 'troops', 'murderers', 'the', 'members', 'rists', 'terrorists', 'factions', 'combatants', 'warriors', 'monsters', 'ists', 'fascists', 'militants', 'jihadists', 'groups', 'assassins', 'atics', 'gangs', 'forces']
#
# Final list with synonyms appearing first: ['s', 'mercenaries', 'killers', 'militias', 'thugs', 'fighters', 'criminals', 'troops', 'murderers', 'the', 'members', 'rists', 'terrorists', 'factions', 'combatants', 'warriors', 'monsters', 'ists', 'fascists', 'militants', 'jihadists', 'groups', 'assassins', 'atics', 'gangs', 'forces']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['s', 'mercenaries', 'killers', 'militias', 'thugs', 'fighters', 'criminals', 'troops', 'murderers', 'the']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['monitors', 'demonstrators', 'participants', 'opponents', 'advisors', 'experts', 'supervisors', 'analysts', 'operators', 'responders', 'reporters', 'witnesses', 'observations', 'inspectors', 'observes', 'investigators', 'dissidents', 'bystanders', 'visitors', 'officials', 'educators', 'airstrikes', 'organizers', 'followers', 'observed', 'outsiders', 'reinforcements']
#
# Final list with synonyms appearing first: ['monitors', 'demonstrators', 'participants', 'opponents', 'advisors', 'experts', 'supervisors', 'analysts', 'operators', 'responders', 'reporters', 'witnesses', 'observations', 'inspectors', 'observes', 'investigators', 'dissidents', 'bystanders', 'visitors', 'officials', 'educators', 'airstrikes', 'organizers', 'followers', 'observed', 'outsiders', 'reinforcements']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['monitors', 'demonstrators', 'participants', 'opponents', 'advisors', 'experts', 'supervisors', 'analysts', 'operators', 'responders']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['gunshot', 'rapnel', 'bullet', 'gunfire', 'grenade', 'gun', 'rifle', 'mortar', 'sh', 'shell', 'sniper', 'projectile', 'stab', 'multiple', 'shot', 'gunshots', 'several', 'blast', 'arrow', 'a', 'shotgun', 'spear', 'shock', 'dagger', 'blaster', 'the', 'stray', 'explosive', 'unspecified', 'knife']
#
# Final list with synonyms appearing first: ['gunshot', 'rapnel', 'bullet', 'gunfire', 'grenade', 'gun', 'rifle', 'mortar', 'sh', 'shell', 'sniper', 'projectile', 'stab', 'multiple', 'shot', 'gunshots', 'several', 'blast', 'arrow', 'a', 'shotgun', 'spear', 'shock', 'dagger', 'blaster', 'the', 'stray', 'explosive', 'unspecified', 'knife']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['gunshot', 'rapnel', 'bullet', 'gunfire', 'grenade', 'gun', 'rifle', 'mortar', 'sh', 'shell']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['cloaked', 'masked', 'clothed', 'disguise', 'wrapped']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['dressed', 'concealed', 'clad', 'recognised', 'portrayed', 'shrouded', 'styled', 'packaged', 'posed', 'adorned', 'imprisoned', 'dispersed', 'united', 'disgu', 'displayed', 'veiled', 'fitted', 'framed', 'armoured', 'frightened', 'formed', 'revealed', 'organised', 'branded']
#
# Final list with synonyms appearing first: ['cloaked', 'masked', 'clothed', 'disguise', 'wrapped', 'dressed', 'concealed', 'clad', 'recognised', 'portrayed', 'shrouded', 'styled', 'packaged', 'posed', 'adorned', 'imprisoned', 'dispersed', 'united', 'disgu', 'displayed', 'veiled', 'fitted', 'framed', 'armoured', 'frightened', 'formed', 'revealed', 'organised', 'branded']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['cloaked', 'masked', 'clothed', 'disguise', 'wrapped', 'dressed', 'concealed', 'clad', 'recognised', 'portrayed']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: ['arm', 'branch']
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['shoot', 'affiliate', 'extension', 'outpost', 'adherent', 'offspring', 'ally', 'adaptation', 'off', 'adjunct', 'iteration', 'incarnation', 'enclave', 'embryo', 'affiliation', 'example', 'acronym', 'outreach', 'extremist', 'outline', 'insurgency', 'affiliated', 'embrace', 'orthodoxy', 'undercut', 'outlet', 'subset']
#
# Final list with synonyms appearing first: ['arm', 'branch', 'shoot', 'affiliate', 'extension', 'outpost', 'adherent', 'offspring', 'ally', 'adaptation', 'off', 'adjunct', 'iteration', 'incarnation', 'enclave', 'embryo', 'affiliation', 'example', 'acronym', 'outreach', 'extremist', 'outline', 'insurgency', 'affiliated', 'embrace', 'orthodoxy', 'undercut', 'outlet', 'subset']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['arm', 'branch', 'shoot', 'affiliate', 'extension', 'outpost', 'adherent', 'offspring', 'ally', 'adaptation']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['musical', 'classical', 'harmonic', 'music', 'popular', 'onic', 'sym', 'canonical', 'instrumental', 'piano', 'the', 'of', 'historical', 'dramatic', 'general', 'modern', 'theoretical', 'or', 'and', 'traditional', 'concert', 'romantic', 'vocal', 'in', 'contemporary', 'formal', 'analytic']
#
# Final list with synonyms appearing first: ['musical', 'classical', 'harmonic', 'music', 'popular', 'onic', 'sym', 'canonical', 'instrumental', 'piano', 'the', 'of', 'historical', 'dramatic', 'general', 'modern', 'theoretical', 'or', 'and', 'traditional', 'concert', 'romantic', 'vocal', 'in', 'contemporary', 'formal', 'analytic']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['musical', 'classical', 'harmonic', 'music', 'popular', 'onic', 'sym', 'canonical', 'instrumental', 'piano']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['deployment', 'mobilize', 'dispatch', 'ploy', 'employ', 'maneuver', 'disperse', 'send', 'launch', 'recruit', 'contract', 'use', 'move', 'tether', 'expend', 'monitor', 'deliver', 'secure', 'operate', 'construct', 'wield', 'patrol', 'combat', 'command', 'withdraw', 'transport']
#
# Final list with synonyms appearing first: ['deployment', 'mobilize', 'dispatch', 'ploy', 'employ', 'maneuver', 'disperse', 'send', 'launch', 'recruit', 'contract', 'use', 'move', 'tether', 'expend', 'monitor', 'deliver', 'secure', 'operate', 'construct', 'wield', 'patrol', 'combat', 'command', 'withdraw', 'transport']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['deployment', 'mobilize', 'dispatch', 'ploy', 'employ', 'maneuver', 'disperse', 'send', 'launch', 'recruit']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# List of substitutes that are synonyms with the complex word in Wordnet: []
#
# List of substitutes that are not synonyms with the complex word in Wordnet: ['officials', 'police', 'regulators', 'arrests', 'governments', 'colleagues', 'superiors', 'investigators', 'employees', 'courts', 'residents', 'detainees', 'officers', 'authors', 'applications', 'prosecutors', 'requirements', 'regimes', 'representatives', 'institutions', 'paramedics', 'forces', 'examinations', 'bodies', 'inquiries', 'policemen']
#
# Final list with synonyms appearing first: ['officials', 'police', 'regulators', 'arrests', 'governments', 'colleagues', 'superiors', 'investigators', 'employees', 'courts', 'residents', 'detainees', 'officers', 'authors', 'applications', 'prosecutors', 'requirements', 'regimes', 'representatives', 'institutions', 'paramedics', 'forces', 'examinations', 'bodies', 'inquiries', 'policemen']
#
# Final top-10 with synonyms with the complex word in Wordnet appearing first: ['officials', 'police', 'regulators', 'arrests', 'governments', 'colleagues', 'superiors', 'investigators', 'employees', 'courts']
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# SG_MA_robertalarge_synsfirst exported to csv in path './predictions/trial/SG_MA_robertalarge_synsfirst.tsv'}

# %%
python tsar_eval.py --gold_file ./data/test/tsar2022_en_test_gold_no_noise.tsv --predictions_file ./predictions/test/SG_MA_robertalarge_synsfirst.tsv --output_file ./output/test/SG_MA_robertalarge_synsfirst.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/test/tsar2022_en_test_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/test/SG_MA_robertalarge_synsfirst.tsv
# OUTPUT file = ./output/test/SG_MA_robertalarge_synsfirst.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5779
#
# MAP@3 = 0.375
# MAP@5 = 0.2761
# MAP@10 = 0.1646
#
# Potential@3 = 0.8172
# Potential@5 = 0.887
# Potential@10 = 0.9354
#
# Accuracy@1@top_gold_1 = 0.2419
# Accuracy@2@top_gold_1 = 0.3682
# Accuracy@3@top_gold_1 = 0.4677
