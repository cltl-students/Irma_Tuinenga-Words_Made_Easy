# %% [markdown]
# #### Evaluations RoBERTa for the trial set (10 sentences)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import pandas as pd
from transformers import pipeline

# read the tsv file
filename = "./data/trial/tsar2022_en_trial_none_no_noise.tsv"
data = pd.read_csv(filename, sep='\t', header=None, names=["sentence", "complex_word"])

# create an empty dataframe to store the substitutes for evaluation
substitutes_df = pd.DataFrame(columns=["sentence", "complex_word"] + [f"substitute_{i+1}" for i in range(10)])

# %%
import logging

# %%
# the code below is used for morphological adjustments in step MA
from nltk.corpus import wordnet as wn
import spacy
nlp = spacy.load("en_core_web_sm")

import string

# %%
# the code below is used when word embeddings are used in step SS
from transformers import TFAutoModel
import tensorflow as tf
import numpy as np

# %%
# the code below is used when Bertscore is used in step SS
import bert_score
from bert_score import score

# %%
# set the display.max_rows option to None to display all rows instead of limiting it to 50
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Roberta-base

# %%
# Instantiate the tokenizer and the model
lm_tokenizer = AutoTokenizer.from_pretrained("roberta-base")
lm_model = AutoModelForMaskedLM.from_pretrained("roberta-base")


# Instantiate the fill-mask pipeline with the model
fill_mask = pipeline("fill-mask", lm_model, tokenizer = lm_tokenizer)

# %% [markdown]
# #### Substitute Generation and Morphological Adaptation:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:

    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)


    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)

    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen

    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

    try:
        substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue



    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



    ## c) remove duplicates and inflected forms of the complex word from the substitute list

    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


    ## d) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word_lemma)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute_lemma:
                    print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")


    # limit the substitutes to the 10 first ones for evaluation
    top_10_substitutes = substitutes_no_dupl_complex_word_no_antonym[:10]
    print(f"top-10 substitutes SG and MA: {top_10_substitutes}\n")

    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + top_10_substitutes

    print('---------------------------------------------------------------------------------------------------------------------------------------------')

# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA.tsv", sep="\t", index=False, header=False)
print("RobertaBase_SG_MA exported to csv in path './predictions/trial/RobertaBase_SG_MA.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# top-10 substitutes SG and MA: [' compulsory', ' mandatory', ' obligatory', ' voluntary', ' required', ' optional', ' obliged', ' uniform', ' necessary', ' available']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# top-10 substitutes SG and MA: [' infused', ' injected', ' endowed', 'illed', ' inst', ' furnished', ' supplied', ' bolstered', ' implanted', ' impressed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# top-10 substitutes SG and MA: [' maniac', ' killers', ' criminals', 's', ' murderers', 'hawks', ' thugs', 'atics', ' terrorists', 'riors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# top-10 substitutes SG and MA: [' observers', ' monitors', ' spectators', ' witnesses', ' observer', ' observes', ' visitors', ' viewers', ' reporters', ' inspectors']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# top-10 substitutes SG and MA: ['rapnel', ' bullet', ' gunshot', ' stab', ' radiation', ' projectile', ' crippling', ' shotgun', ' mortar', ' stun']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# top-10 substitutes SG and MA: [' disguised', ' dressed', ' veiled', ' masked', ' concealed', ' hidden', ' disguise', ' clothed', ' clad', ' posed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# top-10 substitutes SG and MA: [' off', ' extension', ' opposite', ' outpost', 'off', ' out', ' affiliate', ' offspring', ' overthrow', ' element']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# top-10 substitutes SG and MA: [' classical', ' harmonic', ' musical', ' sym', ' music', ' instrumental', ' piano', ' lyric', ' jazz', ' modern']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# top-10 substitutes SG and MA: [' deploy', ' deployed', ' deployment', ' utilize', ' mobilize', ' employ', ' deploying', ' dispatch', ' equip', 'ploy']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# top-10 substitutes SG and MA: [' authorities', ' officials', ' police', ' authority', ' counterparts', ' investigators', ' agencies', ' administrators', ' forces', ' officers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# RobertaBase_SG_MA exported to csv in path './predictions/trial/RobertaBase_SG_MA.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/RobertaBase_SG_MA.tsv --output_file ./output/trial/RobertaBase_SG_MA.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/RobertaBase_SG_MA.tsv
# OUTPUT file = ./output/trial/RobertaBase_SG_MA.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.3166
# MAP@5 = 0.24
# MAP@10 = 0.1445
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.6

# %% [markdown]
# #### Substitute Generation, Morphological Adaptation, and Contextualized embeddings:

# %%
# Calculates similarity between the original sentence and the sentences with candidate substitutes that were retrieved in the SG step 
# creates a list with sentences with substitute words filled in (commented out for oversight purposes)


def calculate_similarity_scores(sentence, sentence_with_substitutes):
    tokenizer = AutoTokenizer.from_pretrained("roberta-base")
    tf_model = TFAutoModel.from_pretrained("roberta-base")

    def embed_text(text):
        tokens = tokenizer(text, padding=True, truncation=True, return_tensors="tf")
        outputs = tf_model(**tokens)
        embeddings = outputs.last_hidden_state[:, 0, :]
        embeddings = tf.nn.l2_normalize(embeddings, axis=1)
        return embeddings

    original_sentence_embedding = embed_text(sentence)
    substitute_sentence_embeddings = embed_text(sentence_with_substitutes)

    cosine_similarity = np.inner(original_sentence_embedding, substitute_sentence_embeddings)
    similarity_scores = cosine_similarity[0]

    return similarity_scores

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)


    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen
    
    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set
    
    try:
        substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    
    
    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")
    
    
    
    ## c) remove duplicates and inflected forms of the complex word from the substitute list
    
    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")
    
    
    ## d) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word_lemma)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute_lemma:
                    print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
    
    
    # create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_dupl_complex_word_no_antonym]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")
    
    
    # d) calculate cosine similarity scores, and rank the substitutes based on their similarity score
    logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times  
    similarity_scores = calculate_similarity_scores(sentence, sentence_with_substitutes)
    #print(f"Similarity scores: {similarity_scores}\n")
    logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
    
    embeddings_ranked_substitutes_with_scores = sorted(zip(substitutes_no_dupl_complex_word_no_antonym, similarity_scores), key=lambda x: x[1], reverse=True)
    #print(f"SS step d) Ranked substitutes, including similarity scores in context: {embeddings_ranked_substitutes_with_scores}\n")
    embeddings_ranked_substitutes_only = [substitute for substitute, score in embeddings_ranked_substitutes_with_scores]
    #print(f"SS step d) Ranked substitutes, based on embedding scores in context: {embeddings_ranked_substitutes_only}\n")
        
     
    
    
    # limit the substitutes to the 10 first ones for evaluation
    embeddings_top_10_substitutes = embeddings_ranked_substitutes_only[:10]
    print(f"top-10 substitutes based on embedding scores in context: {embeddings_top_10_substitutes}\n")
    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + embeddings_top_10_substitutes
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_SS_ce.tsv", sep="\t", index=False, header=False) 
print("RobertaBase_SG_MA_SS_ce exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_ce.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# top-10 substitutes based on embedding scores in context: [' compulsory', ' mandatory', ' required', ' requirement', ' necessary', ' possible', ' optional', ' voluntary', ' routine', ' prerequisite']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# top-10 substitutes based on embedding scores in context: ['filled', ' provided', ' bolstered', ' struck', 'illed', ' filled', ' undermined', ' stirred', ' stunned', ' inspired']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# top-10 substitutes based on embedding scores in context: ['hawks', 'fighters', 's', 'heads', ' gangs', ' thugs', ' militias', 'riors', ' extremists', ' terrorists']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# top-10 substitutes based on embedding scores in context: [' observers', ' monitors', ' participants', ' visitors', ' inspectors', ' observer', ' experts', ' spectators', ' investigators', ' authorities']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# top-10 substitutes based on embedding scores in context: [' bullet', ' gunshot', ' grenade', ' blast', ' stab', ' explosive', ' bomb', ' shotgun', ' radiation', ' crippling']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# top-10 substitutes based on embedding scores in context: [' disguised', ' masked', ' cloaked', ' clad', ' armed', ' dressed', ' clothed', ' draped', ' shrouded', ' wrapped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# top-10 substitutes based on embedding scores in context: ['off', ' branch', ' extension', ' affiliate', ' element', ' arm', ' outpost', ' echo', ' independent', ' example']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# top-10 substitutes based on embedding scores in context: [' musical', ' music', ' formal', ' dramatic', ' composition', ' concert', ' instrumental', ' popular', ' classical', ' lyric']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# top-10 substitutes based on embedding scores in context: [' deploy', ' deploying', 'ploy', ' deployed', ' install', ' equip', ' adopt', ' deployment', ' withdraw', ' activate']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# top-10 substitutes based on embedding scores in context: [' authorities', ' counterparts', ' police', ' forces', ' officials', ' agencies', ' officers', ' figures', ' ministers', ' courts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# RobertaBase_SG_MA_SS_ce exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_ce.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/RobertaBase_SG_MA_SS_ce.tsv --output_file ./output/trial/RobertaBase_SG_MA_SS_ce

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/RobertaBase_SG_MA_SS_ce.tsv
# OUTPUT file = ./output/trial/RobertaBase_SG_MA_SS_ce
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.2666
# MAP@5 = 0.193
# MAP@10 = 0.1127
#
# Potential@3 = 0.8
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# Result: BertBase_SG_MA_SS_ce is better than BertBase_SG_MA

# %% [markdown]
# #### Substitute Generation, Morphological Adaptation, and BertScore:

# %% [raw]
# ##### BErtscore based on BERT:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen
    
    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set
    
    try:
        substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    
    
    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")
    
    
    
    ## c) remove duplicates and inflected forms of the complex word from the substitute list
    
    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")
    
    
    ## d) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word_lemma)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute_lemma:
                    print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
    
    
    # create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_dupl_complex_word_no_antonym]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")
    
    
    # d) use BERTScore for sorting
    logging.getLogger('transformers').setLevel(logging.ERROR)   # to prevent the same warnings from being printed x times 
    scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='bert-base-uncased', verbose=False)  #use bert for BERTscore
    logging.getLogger('transformers').setLevel(logging.WARNING)  # to reset the logging level back to printing warnings
    

    # create a list of tuples, each tuple containing a substitute and its score
    substitute_score_pairs = list(zip(substitutes_no_dupl_complex_word_no_antonym, scores[0].tolist()))

    # sort the list of tuples by the scores (the second element of each tuple), in descending order
    sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

    # print each substitute with its score
    # for substitute, score in sorted_substitute_score_pairs:
    #     print(f"Substitute: {substitute}, BertScore: {score}")

    # extract the list of substitutes from the sorted pairs
    bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
    #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}

    
    # limit the substitutes to the 10 first ones for evaluation
    bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
    print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")
    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes
       
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_SS_bsBert.tsv", sep="\t", index=False, header=False)
print("RobertaBase_SG_MA_SS_bsBert exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsBert.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# top-10 substitutes based on bertscores in context: [' compulsory', ' mandatory', ' obligatory', ' optional', ' voluntary', ' mandated', ' required', ' universal', ' conditional', ' enforced']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# top-10 substitutes based on bertscores in context: [' implanted', ' bolstered', ' injected', ' infused', ' undermined', ' enriched', ' reinforced', ' endowed', ' seeded', ' struck']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# top-10 substitutes based on bertscores in context: [' maniac', ' devils', ' monsters', ' thugs', ' creatures', ' idiots', 'ners', 'hawks', ' villains', ' beasts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# top-10 substitutes based on bertscores in context: [' observers', ' monitors', ' observer', ' analysts', ' witnesses', ' observes', ' commentators', ' reporters', ' journalists', ' experts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# top-10 substitutes based on bertscores in context: ['rapnel', ' crippling', ' stun', ' bullet', ' stab', ' mortar', ' shell', ' blast', ' slug', ' gunshot']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# top-10 substitutes based on bertscores in context: [' disguised', ' masked', ' clad', ' dressed', ' posing', ' clothed', ' armed', ' cloaked', ' concealed', ' wrapped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# top-10 substitutes based on bertscores in context: [' branch', ' extension', ' affiliate', ' arm', ' offspring', ' extend', ' imprint', ' outpost', ' adjunct', ' element']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# top-10 substitutes based on bertscores in context: [' orchestra', ' concert', ' instrumental', ' musical', ' composing', ' lyric', ' opera', ' harmonic', ' vocal', ' sonic']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# top-10 substitutes based on bertscores in context: [' deploy', ' deployment', ' deployed', ' dispatch', ' activate', ' commit', ' employ', ' send', ' recruit', ' install']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# top-10 substitutes based on bertscores in context: [' authorities', ' officials', ' authority', ' agencies', ' administrators', ' police', ' forces', ' officers', ' institutions', ' investigators']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# RobertaBase_SG_MA_SS_bsBert exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsBert.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/RobertaBase_SG_MA_SS_bsBert.tsv --output_file ./output/trial/RobertaBase_SG_MA_SS_bsBert.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/RobertaBase_SG_MA_SS_bsBert.tsv
# OUTPUT file = ./output/trial/RobertaBase_SG_MA_SS_bsBert.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.5
#
# MAP@3 = 0.2222
# MAP@5 = 0.1663
# MAP@10 = 0.1073
#
# Potential@3 = 0.5
# Potential@5 = 0.8
# Potential@10 = 1.0
#
# Accuracy@1@top_gold_1 = 0.3
# Accuracy@2@top_gold_1 = 0.3
# Accuracy@3@top_gold_1 = 0.4

# %% [markdown]
# #### bertscore based on Roberta:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen
    
    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set
    
    try:
        substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    
    
    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")
    
    
    
    ## c) remove duplicates and inflected forms of the complex word from the substitute list
    
    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")
    
    
    ## d) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word_lemma)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute_lemma:
                    print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
    
    
    # create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_dupl_complex_word_no_antonym]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")
    
    
    # d) use BERTScore for sorting
    logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
    scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='roberta-base', verbose=False)  #use roberta for BERTscore
    logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings
     
    

    # create a list of tuples, each tuple containing a substitute and its score
    substitute_score_pairs = list(zip(substitutes_no_dupl_complex_word_no_antonym, scores[0].tolist()))

    # sort the list of tuples by the scores (the second element of each tuple), in descending order
    sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

    # print each substitute with its score
    # for substitute, score in sorted_substitute_score_pairs:
    #     print(f"Substitute: {substitute}, BertScore: {score}")

    # extract the list of substitutes from the sorted pairs
    bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
    #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}

    
    # limit the substitutes to the 10 first ones for evaluation
    bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
    print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")
    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes
       
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv", sep="\t", index=False, header=False)
print("RobertaBase_SG_MA_SS_bsRoberta exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# top-10 substitutes based on bertscores in context: [' compulsory', ' mandatory', ' optional', ' routine', ' voluntary', ' required', ' obligatory', ' requirement', ' mandated', ' necessary']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# top-10 substitutes based on bertscores in context: ['filled', ' filled', ' bolstered', ' provided', ' struck', ' stirred', ' supplied', ' injected', ' infused', 'illed']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# top-10 substitutes based on bertscores in context: ['hawks', ' thugs', ' criminals', ' extremists', 'fighters', ' nazis', ' terrorists', ' monsters', ' creatures', ' murderers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# top-10 substitutes based on bertscores in context: [' observers', ' monitors', ' inspectors', ' investigators', ' participants', ' reporters', ' spectators', ' visitors', ' experts', ' responders']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# top-10 substitutes based on bertscores in context: [' bullet', ' gunshot', ' stab', ' microscopic', ' crippling', ' explosive', ' radiation', ' piercing', ' torpedo', ' bomb']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# top-10 substitutes based on bertscores in context: [' disguised', ' clothed', ' dressed', ' masked', ' clad', ' cloaked', ' armed', ' draped', ' concealed', ' covered']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# top-10 substitutes based on bertscores in context: [' branch', ' extension', 'off', ' affiliate', ' echo', ' arm', ' outpost', ' offspring', ' imprint', ' off']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# top-10 substitutes based on bertscores in context: ['onic', ' concert', ' classical', ' formal', ' opera', ' harmonic', ' instrumental', ' composition', ' trumpet', ' dramatic']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# top-10 substitutes based on bertscores in context: [' deploy', ' deploying', ' deployed', ' construct', ' dispatch', ' adopt', ' equip', ' install', ' activate', ' operate']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# top-10 substitutes based on bertscores in context: [' authorities', ' officials', ' police', ' agencies', ' forces', ' authority', ' regulators', ' investigators', ' prosecutors', ' courts']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# RobertaBase_SG_MA_SS_bsRoberta exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv --output_file ./output/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv
# OUTPUT file = ./output/trial/RobertaBase_SG_MA_SS_bsRoberta.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.6
#
# MAP@3 = 0.2722
# MAP@5 = 0.1753
# MAP@10 = 0.1191
#
# Potential@3 = 0.7
# Potential@5 = 0.8
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.4
# Accuracy@2@top_gold_1 = 0.5
# Accuracy@3@top_gold_1 = 0.5

# %% [markdown]
# Result: better than with using Bert for Bertscore

# %% [markdown]
# #### bertscore based on Electra:

# %%
# in each row, for each complex word: 
for index, row in data.iterrows():
       
    # 1. Substitute Generation (SG): perform masking and generate substitutes:
    
    ## print the sentence and the complex word
    sentence, complex_word = row["sentence"], row["complex_word"]
    print(f"Sentence: {sentence}")
    print(f"Complex word: {complex_word}")

    ## in the sentence, replace the complex word with a masked word
    sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)

    ## concatenate the original sentence and the masked sentence
    sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

    ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
    top_k = 30
    result = fill_mask(sentences_concat, top_k=top_k)
    substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
    #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


    #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
    ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
    ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen
    
    punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
    punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set
    
    try:
        substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
                       and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
        # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
    except TypeError as error:
        continue
    
    
    
    ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
    ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
    substitutes_no_dupl = []
    for sub in substitutes:
        if sub not in substitutes_no_dupl:
            substitutes_no_dupl.append(sub)
    #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")
    
    
    
    ## c) remove duplicates and inflected forms of the complex word from the substitute list
    
    ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
    doc_complex_word = nlp(complex_word)
    complex_word_lemma = doc_complex_word[0].lemma_
    #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


    ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
    substitutes_no_dupl_complex_word = []
    for substitute in substitutes_no_dupl:
        doc_substitute = nlp(substitute)
        substitute_lemma = doc_substitute[0].lemma_
        if substitute_lemma != complex_word_lemma:
            substitutes_no_dupl_complex_word.append(substitute)
    #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")
    
    
    ## d) remove antonyms of the complex word from the substitute list
    substitutes_no_dupl_complex_word_no_antonym = []
    for substitute in substitutes_no_dupl_complex_word:
        syn = wn.synsets(complex_word_lemma)
        if syn:
            syn = syn[0]
            for lemma in syn.lemmas():
                if lemma.antonyms() and lemma.name() == substitute_lemma:
                    print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
                    break
            else:
                substitutes_no_dupl_complex_word_no_antonym.append(substitute)
        else:
            substitutes_no_dupl_complex_word_no_antonym.append(substitute)
    #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")
    
    
    # create sentence with the complex word replaced by the substitutes
    sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_dupl_complex_word_no_antonym]
    #print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")
    
    
    # d) use BERTScore for sorting
    
    logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 
    scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='google/electra-base-generator', verbose=False)  #use Electra for BERTscore
    logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings


    # create a list of tuples, each tuple containing a substitute and its score
    substitute_score_pairs = list(zip(substitutes_no_dupl_complex_word_no_antonym, scores[0].tolist()))

    # sort the list of tuples by the scores (the second element of each tuple), in descending order
    sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

    # print each substitute with its score
    # for substitute, score in sorted_substitute_score_pairs:
    #     print(f"Substitute: {substitute}, BertScore: {score}")

    # extract the list of substitutes from the sorted pairs
    bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
    #print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}

    
    # limit the substitutes to the 10 first ones for evaluation
    bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
    print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")
    # add the sentence, complex_word, and substitutes to the dataframe 
    substitutes_df.loc[index] = [sentence, complex_word] + bertscore_top_10_substitutes
       
    
    print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
# export the dataframe to a tsv file for evaluation
substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_SS_bsElectra.tsv", sep="\t", index=False, header=False)
print("RobertaBase_SG_MA_SS_bsElectra exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsElectra.tsv'}\n")
# Out:
# Sentence: A Spanish government source, however, later said that banks able to cover by themselves losses on their toxic property assets will not be forced to remove them from their books while it will be compulsory for those receiving public help.
# Complex word: compulsory
# top-10 substitutes based on bertscores in context: [' compulsory', ' mandatory', ' obligatory', ' voluntary', ' optional', ' mandated', ' universal', ' required', ' conditional', ' requirement']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Rajoy's conservative government had instilled markets with a brief dose of confidence by stepping into Bankia, performing a U-turn on its refusal to spend public money to rescue banks.
# Complex word: instilled
# top-10 substitutes based on bertscores in context: [' implanted', ' bolstered', 'illed', ' undermined', ' impressed', ' infused', ' intoxicated', ' seeded', ' misled', ' reinforced']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: War maniacs of the South Korean puppet military made another grave provocation to the DPRK in the central western sector of the front on Thursday afternoon.
# Complex word: maniacs
# top-10 substitutes based on bertscores in context: [' maniac', ' monsters', ' jihadists', ' idiots', 'ners', ' villains', ' fascists', ' extremists', ' devils', ' killers']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: The daily death toll in Syria has declined as the number of observers has risen, but few experts expect the U.N. plan to succeed in its entirety.
# Complex word: observers
# top-10 substitutes based on bertscores in context: [' observers', ' monitors', ' investigators', ' experts', ' witnesses', ' observer', ' inspectors', ' spectators', ' activists', ' journalists']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: An amateur video showed a young girl who apparently suffered shrapnel wounds in her thigh undergoing treatment in a makeshift Rastan hospital while screaming in pain.
# Complex word: shrapnel
# top-10 substitutes based on bertscores in context: ['rapnel', ' stun', ' crippling', ' insurgent', ' bullet', ' shell', ' stab', ' piercing', ' cartridge', ' mortar']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: A local witness said a separate group of attackers disguised in burqas — the head-to-toe robes worn by conservative Afghan women — then tried to storm the compound.
# Complex word: disguised
# top-10 substitutes based on bertscores in context: [' disguised', ' masked', ' dressed', ' clothed', ' clad', ' cloaked', ' concealed', ' wrapped', ' veiled', ' draped']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Syria's Sunni majority is at the forefront of the uprising against Assad, whose minority Alawite sect is an offshoot of Shi'ite Islam.
# Complex word: offshoot
# top-10 substitutes based on bertscores in context: [' affiliate', ' branch', ' offspring', ' extension', ' adjunct', ' outside', ' off', 'off', ' arm', ' outpost']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Although not as rare in the symphonic literature as sharper keys , examples of symphonies in A major are not as numerous as for D major or G major .
# Complex word: symphonic
# top-10 substitutes based on bertscores in context: [' classical', ' dramatic', ' opera', ' sonic', ' musical', ' lyric', ' instrumental', ' concert', ' harmonic', ' vocal']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: That prompted the military to deploy its largest warship, the BRP Gregorio del Pilar, which was recently acquired from the United States.
# Complex word: deploy
# top-10 substitutes based on bertscores in context: [' deploy', ' deployed', ' deployment', ' employ', ' install', ' transport', ' utilize', ' dispatch', ' use', ' adopt']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# Sentence:  UK police were expressly forbidden, at a ministerial level, to provide any assistance to Thai authorities as the case involves the death penalty.
# Complex word: authorities
# top-10 substitutes based on bertscores in context: [' authorities', ' officials', ' authority', ' police', ' regulators', ' prosecutors', ' officers', ' agencies', ' investigators', ' forces']
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# RobertaBase_SG_MA_SS_bsElectra exported to csv in path './predictions/trial/RobertaBase_SG_MA_SS_bsElectra.tsv'}

# %% [markdown]
# python tsar_eval.py --gold_file ./data/trial/tsar2022_en_trial_gold_no_noise.tsv --predictions_file ./predictions/trial/RobertaBase_SG_MA_SS_bsElectra.tsv --output_file ./output/trial/RobertaBase_SG_MA_SS_bsElectra.tsv

# %% [raw]
# =========   EVALUATION config.=========
# GOLD file = ./data/trial/tsar2022_en_trial_gold_no_noise.tsv
# PREDICTION LABELS file = ./predictions/trial/RobertaBase_SG_MA_SS_bsElectra.tsv
# OUTPUT file = ./output/trial/RobertaBase_SG_MA_SS_bsElectra.tsv
# ===============   RESULTS  =============
#
# MAP@1/Potential@1/Precision@1 = 0.4
#
# MAP@3 = 0.25
# MAP@5 = 0.1709
# MAP@10 = 0.1123
#
# Potential@3 = 0.6
# Potential@5 = 0.9
# Potential@10 = 0.9
#
# Accuracy@1@top_gold_1 = 0.2
# Accuracy@2@top_gold_1 = 0.4
# Accuracy@3@top_gold_1 = 0.4

# %%
#worst results

# %% [markdown]
# Conclusion bertscores: perform bertscores with Roberta if the model for the SG step is also Roberta

# %% [markdown]
# #### Conclusion (based on on MAP@1):
# 1. RobertaBase_SG_MA_SS_bsRoberta (0.6) with better scores on the other metrics than no.2
# 2. RobertaBase_SG_MA_SS_ce (0.6)
# 3. RobertaBase_SG_MA_SS_bsBert (0.5)
# 4. RobertaBase_SG_MA (0.4)
# 5. RobertaBase_SG_MA_SS_bsElectra

# %% [markdown]
# ### data.loc for 1 subs list (examples below)

# %%
# #for SG_MA step: 

# row = data.loc[1]
       
# # 1. Substitute Generation (SG): perform masking and generate substitutes:

# ## print the sentence and the complex word
# sentence, complex_word = row["sentence"], row["complex_word"]
# print(f"Sentence: {sentence}")
# print(f"Complex word: {complex_word}")

# ## in the sentence, replace the complex word with a masked word
# sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)


# ## concatenate the original sentence and the masked sentence
# sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

# ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
# top_k = 30
# result = fill_mask(sentences_concat, top_k=top_k)

# substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
# #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


# #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
# ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
# ## and lowercase all substitutes (not needed for BERT-base-uncased but by default applied). Use try/except statement to prevent other character-related problems to happen

# punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
# punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

# try:
#     substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
#                    and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
#     # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
# except TypeError as error:
#     print(f"Error occurred: {error}")



# ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
# ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
# substitutes_no_dupl = []
# for sub in substitutes:
#     if sub not in substitutes_no_dupl:
#         substitutes_no_dupl.append(sub)
# #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



# ## c) remove duplicates and inflected forms of the complex word from the substitute list

# ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
# doc_complex_word = nlp(complex_word)
# complex_word_lemma = doc_complex_word[0].lemma_
# #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


# ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
# substitutes_no_dupl_complex_word = []
# for substitute in substitutes_no_dupl:
#     doc_substitute = nlp(substitute)
#     substitute_lemma = doc_substitute[0].lemma_
#     if substitute_lemma != complex_word_lemma:
#         substitutes_no_dupl_complex_word.append(substitute)
# #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


# ## d) remove antonyms of the complex word from the substitute list
# substitutes_no_dupl_complex_word_no_antonym = []
# for substitute in substitutes_no_dupl_complex_word:
#     syn = wn.synsets(complex_word_lemma)
#     if syn:
#         syn = syn[0]
#         for lemma in syn.lemmas():
#             if lemma.antonyms() and lemma.name() == substitute_lemma:
#                 print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
#                 break
#         else:
#             substitutes_no_dupl_complex_word_no_antonym.append(substitute)
#     else:
#         substitutes_no_dupl_complex_word_no_antonym.append(substitute)
# #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")


# # limit the substitutes to the 10 first ones for evaluation
# top_10_substitutes = substitutes_no_dupl_complex_word_no_antonym[:10]
# print(f"top-10 substitutes SG and MA: {top_10_substitutes}\n")

# # add the sentence, complex_word, and substitutes to the dataframe 
# substitutes_df.loc[1] = [sentence, complex_word] + top_10_substitutes

# print('---------------------------------------------------------------------------------------------------------------------------------------------')

# # export the dataframe to a tsv file for evaluation
# substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_dataloc1.tsv", sep="\t", index=False, header=False)

# %%
# # including all print statements to check where errors occur

# #for SG_MA_SS (Bertscore) step:

# row = data.loc[1]

# # 1. Substitute Generation (SG): perform masking and generate substitutes:

# ## print the sentence and the complex word
# sentence, complex_word = row["sentence"], row["complex_word"]
# print(f"Sentence: {sentence}")
# print(f"Complex word: {complex_word}")

# ## in the sentence, replace the complex word with a masked word
# sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)

# ## concatenate the original sentence and the masked sentence
# sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

# ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
# top_k = 30
# result = fill_mask(sentences_concat, top_k=top_k)
# substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
# print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


# #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
# ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
# ## and lowercase all substitutes (not needed for BERT-base-uncase but by default applied). Use try/except statement to prevent other character-related problems to happen

# punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
# punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

# try:
#     substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
#                    and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
#     print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
# except TypeError as error:
#     print(f"Error occurred: {error}")



# ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
# ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
# substitutes_no_dupl = []
# for sub in substitutes:
#     if sub not in substitutes_no_dupl:
#         substitutes_no_dupl.append(sub)
# print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



# ## c) remove duplicates and inflected forms of the complex word from the substitute list

# ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
# doc_complex_word = nlp(complex_word)
# complex_word_lemma = doc_complex_word[0].lemma_
# print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


# ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
# substitutes_no_dupl_complex_word = []
# for substitute in substitutes_no_dupl:
#     doc_substitute = nlp(substitute)
#     substitute_lemma = doc_substitute[0].lemma_
#     if substitute_lemma != complex_word_lemma:
#         substitutes_no_dupl_complex_word.append(substitute)
# print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


# ## d) remove antonyms of the complex word from the substitute list
# substitutes_no_dupl_complex_word_no_antonym = []
# for substitute in substitutes_no_dupl_complex_word:
#     syn = wn.synsets(complex_word_lemma)
#     if syn:
#         syn = syn[0]
#         for lemma in syn.lemmas():
#             if lemma.antonyms() and lemma.name() == substitute_lemma:
#                 print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
#                 break
#         else:
#             substitutes_no_dupl_complex_word_no_antonym.append(substitute)
#     else:
#         substitutes_no_dupl_complex_word_no_antonym.append(substitute)
# print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")


# # create sentence with the complex word replaced by the substitutes
# sentence_with_substitutes = [sentence.replace(complex_word, sub) for sub in substitutes_no_dupl_complex_word_no_antonym]
# print(f"List with sentences where complex word is substituted: {sentence_with_substitutes}\n")


# # d) use BERTScore for sorting
# logging.getLogger('transformers').setLevel(logging.ERROR)  # to prevent the same warnings from being printed x times 

# scores = bert_score.score([sentence]*len(sentence_with_substitutes), sentence_with_substitutes, lang="en", model_type='roberta-base', verbose=False)  #use bert for BERTscore

# logging.getLogger('transformers').setLevel(logging.WARNING) # to reset the logging level back to printing warnings


# # create a list of tuples, each tuple containing a substitute and its score
# substitute_score_pairs = list(zip(substitutes_no_dupl_complex_word_no_antonym, scores[0].tolist()))

# # sort the list of tuples by the scores (the second element of each tuple), in descending order
# sorted_substitute_score_pairs = sorted(substitute_score_pairs, key=lambda x: x[1], reverse=True)

# warnings.resetwarnings() # reset the warnings so that any other warning will stil be printed

# # print each substitute with its score
# for substitute, score in sorted_substitute_score_pairs:
#     print(f"Substitute: {substitute}, BertScore: {score}")

# # extract the list of substitutes from the sorted pairs
# bertscore_ranked_substitutes_only = [substitute for substitute, _ in sorted_substitute_score_pairs]
# print(f"substitutes based on bertscores in context: {bertscore_ranked_substitutes_only}")


# # limit the substitutes to the 10 first ones for evaluation
# bertscore_top_10_substitutes = bertscore_ranked_substitutes_only[:10]
# print(f"top-10 substitutes based on bertscores in context: {bertscore_top_10_substitutes}\n")
# # add the sentence, complex_word, and substitutes to the dataframe 
# substitutes_df.loc[1] = [sentence, complex_word] + bertscore_top_10_substitutes


# print('---------------------------------------------------------------------------------------------------------------------------------------------')
    
# # export the dataframe to a tsv file for evaluation
# substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_SS_bsRoberta_dataloc1.tsv", sep="\t", index=False, header=False)

# %%
# row = data.loc[1]
       
# # 1. Substitute Generation (SG): perform masking and generate substitutes:

# ## print the sentence and the complex word
# sentence, complex_word = row["sentence"], row["complex_word"]
# print(f"Sentence: {sentence}")
# print(f"Complex word: {complex_word}")

# ## in the sentence, replace the complex word with a masked word
# sentence_masked_word = sentence.replace(complex_word, "<mask>") # this is different per model (this code line applies to Roberta)


# ## concatenate the original sentence and the masked sentence
# sentences_concat = f"{sentence} {lm_tokenizer.sep_token} {sentence_masked_word}"

# ## generate and rank candidate substitutes for the masked word using the fill_mask pipeline (removing elements without token_str key; as this gave errors in the ELECTRA models) .
# top_k = 30
# result = fill_mask(sentences_concat, top_k=top_k)

# substitutes = [substitute["token_str"] for substitute in result if "token_str" in substitute]
# #print(f"Substitute Generation step: initial substitute list: {substitutes}\n")


# #2: Morphological Generation and Context Adaptation (Morphological Adaptation):  
# ## a) remove noise in the substitutes, by ignoring generated substitutes that are empty or that have unwanted punctuation characters or that start with '##' (this returned errors with the ELECTRA model), and lowercase the substitutes (as some models don't lowercase by default)
# ## and lowercase all substitutes (not needed for BERT-base-uncased but by default applied). Use try/except statement to prevent other character-related problems to happen

# punctuation_set = set(string.punctuation) - set('-') # retained hyphens in case tokenizers don't split on hyphenated compounds
# punctuation_set.update({'“','”'})   # as these curly quotes appeared in the Electra (SG step) results but were not part of the string set

# try:
#     substitutes = [substitute["token_str"].lower() for substitute in result if not any(char in punctuation_set for char in substitute["token_str"]) 
#                    and not substitute["token_str"].startswith('##') and substitute["token_str"].strip() != ""]
#     # print(f"Morphological Adaptation step a): substitute list without unwanted punctuation characters: {substitutes}\n")
# except TypeError as error:
#     print(f"Error occurred: {error}")



# ## b) remove duplicates within the substitute list from the substitute list (duplicates are likely for models that did not lowercase by default)
# ## the last mentioned duplicate is removed on purpose, as this may probably be the (previously) uppercased variant of the lowercased substitute (lowercased subs are most likely higher ranked by the model)
# substitutes_no_dupl = []
# for sub in substitutes:
#     if sub not in substitutes_no_dupl:
#         substitutes_no_dupl.append(sub)
# #print(f"Morphological Adaptation step b): substitute list without duplicates of substitutes: {substitutes_no_dupl}\n")



# ## c) remove duplicates and inflected forms of the complex word from the substitute list

# ## first Lemmatize the complex word with spaCy, in order to compare it with the lemmatized substitute later to see if their mutual lemmas are the same
# doc_complex_word = nlp(complex_word)
# complex_word_lemma = doc_complex_word[0].lemma_
# #print(f"complex_word_lemma for complex word '{complex_word}': {complex_word_lemma}\n")


# ## then, remove duplicates and inflected forms of the complex word from the list with substitutes
# substitutes_no_dupl_complex_word = []
# for substitute in substitutes_no_dupl:
#     doc_substitute = nlp(substitute)
#     substitute_lemma = doc_substitute[0].lemma_
#     if substitute_lemma != complex_word_lemma:
#         substitutes_no_dupl_complex_word.append(substitute)
# #print(f"Morphological Adaptation step c): substitute list without duplicates of the complex word nor inflected forms of the complex word: {substitutes_no_dupl_complex_word}\n")


# ## d) remove antonyms of the complex word from the substitute list
# substitutes_no_dupl_complex_word_no_antonym = []
# for substitute in substitutes_no_dupl_complex_word:
#     syn = wn.synsets(complex_word_lemma)
#     if syn:
#         syn = syn[0]
#         for lemma in syn.lemmas():
#             if lemma.antonyms() and lemma.name() == substitute_lemma:
#                 print(f"Antonym removed (lemma): {lemma.antonyms()[0].name()}")
#                 break
#         else:
#             substitutes_no_dupl_complex_word_no_antonym.append(substitute)
#     else:
#         substitutes_no_dupl_complex_word_no_antonym.append(substitute)
# #print(f"Morphological Adaptation step d): substitute list without antonyms of the complex word: {substitutes_no_dupl_complex_word_no_antonym}\n")


# # limit the substitutes to the 10 first ones for evaluation
# top_10_substitutes = substitutes_no_dupl_complex_word_no_antonym[:10]
# print(f"top-10 substitutes SG and MA: {top_10_substitutes}\n")

# # add the sentence, complex_word, and substitutes to the dataframe 
# substitutes_df.loc[1] = [sentence, complex_word] + top_10_substitutes

# print('---------------------------------------------------------------------------------------------------------------------------------------------')

# # export the dataframe to a tsv file for evaluation
# substitutes_df.to_csv("./predictions/trial/RobertaBase_SG_MA_dataloc1.tsv", sep="\t", index=False, header=False)
